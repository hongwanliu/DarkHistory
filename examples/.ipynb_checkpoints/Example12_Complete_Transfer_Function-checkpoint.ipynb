# %% [markdown]
# # Full Transfer Functions

# %%
# %load_ext autoreload
import sys
sys.path.append("..")

# %%
# %autoreload

import matplotlib
matplotlib.rc_file('matplotlibrc')
import matplotlib.pyplot as plt

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [10,10]


from astropy.io import fits

import numpy as np
import copy
import pickle

import darkhistory.physics as phys
import darkhistory.utilities as utils
import darkhistory.spec.spectools as spectools
import darkhistory.spec.transferfunction as tf
import darkhistory.spec.transferfunclist as tflist
from darkhistory.spec.spectrum import Spectrum
from darkhistory.spec.spectra import Spectra
import darkhistory.history.tla as tla

from scipy.interpolate import interp1d

from tqdm import tqdm_notebook as tqdm

from darkhistory.electrons.ics.ics_spectrum import ics_spec
from darkhistory.electrons.ics.ics_engloss_spectrum import engloss_spec
from darkhistory.electrons.ics.ics_cooling import get_ics_cooling_tf

from darkhistory.low_energy.lowE_deposition import compute_fs

# np.set_printoptions(threshold=np.nan)

# %%
# mDM = 1e11
# sigmav = 1e-24

# def rate_func_swave(rs):
#     return 0*phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)/(2*mDM)

# def test(rs, x1, x2, x3):
#     return 0.3

# test = tla.get_history(
#                 np.array([phys.TCMB(3000), 1, 0, 0]), 0.3, 0.3, 0.3, 
#                 rate_func_swave, np.flipud(np.arange(1, 3001)), reion_switch=False
#             )

# out = np.stack((np.flipud(np.arange(1, 3001)), test[:,0], test[:,1]))
# # pickle.dump(
# #     out, open("/Users/hongwan/GitHub/DarkHistory/darkhistory/history/std_soln.p", "wb")       
# #            )

# %%
soln = pickle.load(open("../darkhistory/history/std_soln.p", "rb"))
xe_std  = interp1d(soln[0,:], soln[2,:])
T_m_std = interp1d(soln[0,:], soln[1,:])

# %%
rs = 600
print(xe_std(rs))
print(T_m_std(rs)/phys.kB)
print(phys.TCMB(rs)/phys.kB)
# Out:
# 0.0009648017275850074
# 1625.561215315584
# 1635.2995445551107

# %%
# plt.figure()

# plt.plot(np.flipud(np.arange(1, 3001)), test[:,0]/phys.kB)
# plt.plot(np.flipud(np.arange(1, 3001)), phys.TCMB(np.flipud(np.arange(1, 3001)))/phys.kB, 'k:')
# ax = plt.gca()

# ax.set_xscale('log')
# ax.set_yscale('log')

# plt.figure()

# plt.plot(np.flipud(np.arange(1, 3001)), test[:,1])
# ax = plt.gca()

# ax.set_xscale('log')
# ax.set_yscale('log')

# %% [markdown]
# ## Photon Transfer Functions

# %%
user = 'hongwan'

highengphot_tflist_arr = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_photspec_60eV_complete_coarse.raw", "rb"))
lowengphot_tflist_arr  = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_lowengphotspec_60eV_complete_coarse.raw", "rb"))
lowengelec_tflist_arr  = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_lowengelecspec_60eV_complete_coarse.raw", "rb"))
CMB_engloss_arr = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/CMB_engloss_60eV_complete_coarse.raw", "rb"))

# %%
highengphot_tflist_arr[0]._grid_vals.shape
# Out:
# (51, 325, 500)

# %%
photeng = highengphot_tflist_arr[0].eng
eleceng = lowengelec_tflist_arr[0].eng

#Split photeng into high and low energy. 
photeng_high = photeng[photeng > 60]
photeng_low  = photeng[photeng <= 60]

# Split eleceng into high and low energy. 
eleceng_high = eleceng[eleceng > 3000]
eleceng_low  = eleceng[eleceng <= 3000]


for highengphot_tflist in highengphot_tflist_arr:
    
#     highengphot_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)

    for tf in highengphot_tflist:
        # tf.rebin(photeng_high)
#         tf.rebin(photeng)
        
        # Pad with zeros so that it becomes photeng x photeng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size, 0), (0, 0)), 'constant')
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = photeng
        tf._rs = tf.rs[0]*np.ones_like(photeng)
    
    highengphot_tflist._eng = photeng
    highengphot_tflist._in_eng = photeng
    highengphot_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in highengphot_tflist._tflist])
    )
    
# lowengphot_tflist.in_eng set to photeng_high
for lowengphot_tflist in lowengphot_tflist_arr:
    
#     lowengphot_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)
    
    for tf in lowengphot_tflist:
#         tf.rebin(photeng)
        # Pad with zeros so that it becomes photeng x photeng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size,0), (0,0)), 'constant')
        # Photons in the low energy bins should be immediately deposited.
        tf._grid_vals[0:photeng_low.size, 0:photeng_low.size] = np.identity(photeng_low.size)
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = photeng
        tf._rs = tf.rs[0]*np.ones_like(photeng)
    
    lowengphot_tflist._eng = photeng
    lowengphot_tflist._in_eng = photeng
    lowengphot_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in lowengphot_tflist._tflist])
    )
    
# lowengelec_tflist.in_eng set to photeng_high 
for lowengelec_tflist in lowengelec_tflist_arr:
    
#     lowengelec_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)
    
    for tf in lowengelec_tflist:
#         tf.rebin(eleceng)
        # Pad with zeros so that it becomes photeng x eleceng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size,0), (0,0)), 'constant')
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = eleceng
        tf._rs = tf.rs[0]*np.ones_like(photeng)

    lowengelec_tflist._eng = eleceng
    lowengelec_tflist._in_eng = photeng
    lowengelec_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in lowengelec_tflist._tflist])
    )
    
    for engloss in CMB_engloss_arr:
        engloss = np.pad(engloss, ((0,0),(photeng_low.size, 0)), 'constant')

# %%
xes = 0.5 + 0.5*np.tanh([-5., -4.1, -3.2, -2.3, -1.4, -0.5, 0.4, 1.3, 2.2, 3.1, 4])

# %%
highengphot_tf_interp = tflist.TransferFuncInterp(xes, highengphot_tflist_arr)
lowengphot_tf_interp = tflist.TransferFuncInterp(xes, lowengphot_tflist_arr)
lowengelec_tf_interp = tflist.TransferFuncInterp(xes, lowengelec_tflist_arr)


phot_spec_init = spectools.rebin_N_arr(np.array([2]), 
                                      np.array([1e11]), 
                                      photeng)
phot_spec_init.switch_spec_type()

# %%
phot_spec_init.rs = 1800
end_rs   = 18
mDM = 1e8
sigmav = 1e-26
tau = 1e26

def rate_func_swave_N(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)/(2*mDM)

def rate_func_swave_eng(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)

def rate_func_decay_N(rs):
    # This is dN/dV dt
    return phys.inj_rate('decay', rs, tau=tau)/mDM

def rate_func_decay_eng(rs):
    # This is dN/dV dt
    return phys.inj_rate('decay', rs, tau=tau)


def rate_func_swave_N_2(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav*1e-30)/(2*mDM)

def rate_func_swave_eng_2(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav*1e-30)


def evolve(
    in_spec_elec, in_spec_phot, 
    rate_func_N, rate_func_eng, xe_init, T_m_init,
    highengphot_tf_interp, lowengphot_tf_interp, 
    lowengelec_tf_interp, 
    end_rs, coarsen_factor=1, std_soln=False
):
    """
    Main function that computes the temperature and ionization history. 
    
    Parameters
    ----------
    in_spec_elec : Spectrum
        Spectrum per annihilation/decay into electrons. 
    in_spec_phot : Spectrum
        Spectrum per annihilation/decay into photons.
    rate_func_N : function
        Function describing the rate of annihilation/decay, dN/(dV dt)
    rate_func_eng : function
        Function describing the rate of annihilation/decay, dE/(dV dt)
    xe_init : float
        xe at the initial redshift. 
    T_m_init : float
        Matter temperature at the initial redshift. 
    highengphot_tf_interp : TransferFuncInterp
        Interpolation table for high energy photons. 
    lowengphot_tf_interp : TransferFuncInterp
        Interpolation table for low energy photons. 
    lowengelec_tf_interp : TransferFuncInterp
        Interpolation table for low energy electrons. 
    end_rs : float
        Final redshift to evolve to. 
    coarsen_factor : int
        Coarsening to apply to the transfer function matrix. 
    std_soln : bool
        If true, uses the standard TLA solution for f(z). 
    """
    
    # Initialize the next spectrum as None.
    next_highengphot_spec = None
    next_lowengphot_spec  = None
    next_lowengelec_spec  = None
    
    if (
        highengphot_tf_interp.dlnz    != lowengphot_tf_interp.dlnz
        or highengphot_tf_interp.dlnz != lowengelec_tf_interp.dlnz
        or lowengphot_tf_interp.dlnz  != lowengelec_tf_interp.dlnz
    ):
        raise TypeError('TransferFuncInterp objects must all have the same dlnz.')
    
    if in_spec_elec.rs != in_spec_phot.rs:
        raise TypeError('Input spectra must have the same rs.')
    
    # redshift/timestep related quantities. 
    dlnz = highengphot_tf_interp.dlnz
    prev_rs = None
    rs = in_spec_phot.rs
    dt = dlnz/phys.hubble(rs)
    
    # The initial input dN/dE per annihilation to per baryon per dlnz, 
    # based on the specified rate. 
    # dN/(dN_B d lnz dE) = dN/dE * (dN_ann/(dV dt)) * dV/dN_B * dt/dlogz
    
    # ICS for in_spec_elec goes here.
    
    # (Should this be multiplied by dlnz?)
    init_inj_spec = (
        in_spec_phot * rate_func_N(rs) 
        / phys.hubble(rs) / (phys.nB * rs**3)
    )
    
    
    # Initialize the Spectra object that will contain all the 
    # output spectra during the evolution.
    out_highengphot_specs = Spectra([init_inj_spec], spec_type=init_inj_spec.spec_type)
    out_lowengphot_specs  = Spectra([], spec_type=init_inj_spec.spec_type)
    out_lowengelec_specs  = Spectra([], spec_type=init_inj_spec.spec_type)
    
    # Initialize the xe and T array that will store the solutions.
    xe_arr  = np.array([xe_init])
    T_m_arr = np.array([T_m_init])
    
    # Load the standard TLA solution if necessary. 
#     if std_soln:
    if True:
        soln = pickle.load(open("../darkhistory/history/std_soln.p", "rb"))
        xe_std  = interp1d(soln[0,:], soln[2,:])
        T_m_std = interp1d(soln[0,:], soln[1,:])

    # Define these methods for speed.
    append_highengphot_spec = out_highengphot_specs.append
    append_lowengphot_spec  = out_lowengphot_specs.append
    append_lowengelec_spec  = out_lowengelec_specs.append
    
    # Loop while we are still at a redshift above end_rs.
    while rs > end_rs:
        
        # If prev_rs exists, calculate xe and T_m. 
        if prev_rs is not None:
#             print('here at least?')
            
            # f_continuum, f_lyman, f_ionH, f_ionHe, f_heat
            # f_raw takes in dE/(dV dt)
            if std_soln:
                f_raw = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_std(rs), 0, 0]), rate_func_eng(rs), dt
                )
                
            else:
                f_raw = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_arr[-1], 0, 0]), rate_func_eng(rs), dt
                )
                
            std_f = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_std(rs), 0, 0]), rate_func_eng(rs), dt
                )
            
            backreaction_f = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_arr[-1], 0, 0]), rate_func_eng(rs), dt
                )
            
            init_cond = np.array([T_m_arr[-1], xe_arr[-1], 0, 0])

            new_vals = tla.get_history(
                init_cond, f_raw[2], f_raw[1], f_raw[4], 
                rate_func_eng, np.array([prev_rs, rs])
            )

            T_m_arr = np.append(T_m_arr, new_vals[-1,0])
            xe_arr  = np.append(xe_arr,  new_vals[-1,1])
            
        print('T_m at '+str(rs)+': '+ str(T_m_arr[-1]))
        print('x_e at '+str(rs)+': '+ str(xe_arr[-1]))
        print('Standard x_e at '+str(rs)+': '+str(xe_std(rs)))
        if prev_rs is not None:
            print('Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat: ', backreaction_f)
            print('Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat: ', std_f)
            
        if std_soln:
            highengphot_tf = highengphot_tf_interp.get_tf(rs, xe_std(rs))
            lowengphot_tf  = lowengphot_tf_interp.get_tf(rs, xe_std(rs))
            lowengelec_tf  = lowengelec_tf_interp.get_tf(rs, xe_std(rs))
        else:
            highengphot_tf = highengphot_tf_interp.get_tf(rs, xe_arr[-1])
            lowengphot_tf  = lowengphot_tf_interp.get_tf(rs, xe_arr[-1])
            lowengelec_tf  = lowengelec_tf_interp.get_tf(rs, xe_arr[-1])
        
#         if coarsen_factor > 1:
#             prop_tf = np.zeros_like(highengphot_tf._grid_vals)
#             for i in np.arange(coarsen_factor):
#                 prop_tf += matrix_power(highengphot_tf._grid_vals, i)
#             lowengphot_tf._grid_vals = np.matmul(prop_tf, lowengphot_tf._grid_vals)
#             lowengelec_tf._grid_vals = np.matmul(prof_tf, lowengelec_tf._grid_vals)
#             highengphot_tf._grid_vals = matrix_power(
#                 highengphot_tf._grid_vals, coarsen_factor
#             )
            
        next_highengphot_spec = highengphot_tf.sum_specs(out_highengphot_specs[-1])
        next_lowengphot_spec  = lowengphot_tf.sum_specs(out_highengphot_specs[-1])
        next_lowengelec_spec  = lowengelec_tf.sum_specs(out_highengphot_specs[-1])
        
        # Re-define existing variables.
        prev_rs = rs
        rs = np.exp(np.log(rs) - 0.002)
        
        dt = dlnz/phys.hubble(rs)
        next_highengphot_spec.rs = rs
        next_lowengphot_spec.rs  = rs
        next_lowengelec_spec.rs  = rs
        
        # Add the next injection spectrum to next_highengphot_spec
        next_inj_spec = (
            in_spec_phot * rate_func_N(rs)
            / phys.hubble(rs) / (phys.nB * rs**3)
        )
        # This keeps the redshift. 
        next_highengphot_spec.N += next_inj_spec.N
        
        append_highengphot_spec(next_highengphot_spec)
        append_lowengphot_spec(next_lowengphot_spec)
        append_lowengelec_spec(next_lowengelec_spec)
        
        
    return (
        xe_arr, T_m_arr, 
        out_highengphot_specs, out_lowengphot_specs, out_lowengelec_specs
    )

# %%
a = evolve(
        phot_spec_init*0, phot_spec_init, 
        rate_func_decay_N, rate_func_decay_eng, .9999, phys.TCMB(phot_spec_init.rs),
        highengphot_tf_interp, lowengphot_tf_interp, 
        lowengelec_tf_interp, 
        end_rs, coarsen_factor=1, std_soln=False
    )

b = evolve(
        phot_spec_init*0, phot_spec_init, 
        rate_func_decay_N, rate_func_decay_eng, .9999, phys.TCMB(phot_spec_init.rs),
        highengphot_tf_interp, lowengphot_tf_interp, 
        lowengelec_tf_interp, 
        end_rs, coarsen_factor=1, std_soln=True
    )
# Out:
# T_m at 1800: 0.42275759247
# x_e at 1800: 0.9999
# Standard x_e at 1800: 0.9996009039448279
# 1796.4035976012003
# 1796.4035976012003
# 1796.4035976012003
# T_m at 1796.4035976012003: 0.4219125780791999
# x_e at 1796.4035976012003: 0.9998223090287323
# Standard x_e at 1796.4035976012003: 0.9995790683101462
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [8.40147228e-04 1.36136895e-04 7.54058934e-04 2.97125843e-18
#  2.41062157e-03]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [8.40147228e-04 1.36136895e-04 7.54058934e-04 6.12518213e-18
#  2.41062157e-03]
# 1792.814380819186
# 1792.814380819186
# 1792.814380819186
# T_m at 1792.814380819186: 0.4210695937786138
# x_e at 1792.814380819186: 0.9997556050716214
# Standard x_e at 1792.814380819186: 0.9995561118097385
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.21295745e-03 3.57528036e-04 2.01163449e-03 1.00966729e-17
#  6.87495547e-03]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.21295745e-03 3.57528036e-04 2.01163449e-03 1.87314376e-17
#  6.87495547e-03]
# 1789.2323352970852
# 1789.2323352970852
# 1789.2323352970852
# T_m at 1789.2323352970852: 0.42022829395604866
# x_e at 1789.2323352970852: 0.9996969226323152
# Standard x_e at 1789.2323352970852: 0.999531961084445
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [3.08569105e-03 4.97391396e-04 2.84575952e-03 1.79543727e-17
#  1.04055905e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [3.08569105e-03 4.97391396e-04 2.84575952e-03 3.05839259e-17
#  1.04055905e-02]
# 1785.6574467067112
# ../darkhistory/spec/spectrum.py:748: RuntimeWarning: The new abscissa lies below the old one: only bins that lie within the new abscissa will be rebinned, bins above the abscissa will be discarded.
#   warnings.warn("The new abscissa lies below the old one: only bins that lie within the new abscissa will be rebinned, bins above the abscissa will be discarded.", RuntimeWarning)
# 1785.6574467067112
# 1785.6574467067112
# T_m at 1785.6574467067112: 0.41938867521156986
# x_e at 1785.6574467067112: 0.999644051178037
# Standard x_e at 1785.6574467067112: 0.9995065649978474
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [3.64464423e-03 5.86511192e-04 3.39902706e-03 2.61067951e-17
#  1.30732773e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [3.64464423e-03 5.86511192e-04 3.39902706e-03 4.14216126e-17
#  1.30732773e-02]
# 1782.0897007485048
# 1782.0897007485048
# 1782.0897007485048
# T_m at 1782.0897007485048: 0.4185507341411813
# x_e at 1782.0897007485048: 0.999595325448899
# Standard x_e at 1782.0897007485048: 0.9994798779236036
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.00553176e-03 6.43840206e-04 3.76859596e-03 3.43905961e-17
#  1.50625660e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.00553176e-03 6.43840206e-04 3.76859596e-03 5.14824185e-17
#  1.50625660e-02]
# 1778.5290831514778
# 1778.5290831514778
# 1778.5290831514778
# T_m at 1778.5290831514778: 0.41771446736680756
# x_e at 1778.5290831514778: 0.9995494767622122
# Standard x_e at 1778.5290831514778: 0.9994518125580235
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.24067286e-03 6.81112150e-04 4.01799681e-03 4.27870898e-17
#  1.65430075e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.24067286e-03 6.81112150e-04 4.01799681e-03 6.11042261e-17
#  1.65430075e-02]
# 1774.9755796731547
# 1774.9755796731547
# 1774.9755796731547
# T_m at 1774.9755796731547: 0.4168798715222774
# x_e at 1774.9755796731547: 0.9995055271712181
# Standard x_e at 1774.9755796731547: 0.9994223479672263
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.39486734e-03 7.05529150e-04 4.18774174e-03 5.13569012e-17
#  1.76455056e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.39486734e-03 7.05529150e-04 4.18774174e-03 7.06041236e-17
#  1.76455056e-02]
# 1771.4291760995168
# 1771.4291760995168
# 1771.4291760995168
# T_m at 1771.4291760995168: 0.41604694325378827
# x_e at 1771.4291760995168: 0.9994627133368057
# Standard x_e at 1771.4291760995168: 0.9993913698995639
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.49646104e-03 7.21611895e-04 4.30407747e-03 6.02130510e-17
#  1.84676269e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.49646104e-03 7.21611895e-04 4.30407747e-03 8.02918088e-17
#  1.84676269e-02]
# 1767.8898582449453
# 1767.8898582449453
# 1767.8898582449453
# T_m at 1767.8898582449453: 0.41521567921825664
# x_e at 1767.8898582449453: 0.9994204312002422
# Standard x_e at 1767.8898582449453: 0.9993588632231998
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.56428910e-03 7.32349156e-04 4.38484799e-03 6.95143723e-17
#  1.90835572e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.56428910e-03 7.32349156e-04 4.38484799e-03 9.04550966e-17
#  1.90835572e-02]
# 1764.3576119521638
# 1764.3576119521638
# 1764.3576119521638
# T_m at 1764.3576119521638: 0.4143860760820635
# x_e at 1764.3576119521638: 0.9993781959945769
# Standard x_e at 1764.3576119521638: 0.9993247175343262
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.61062641e-03 7.39683466e-04 4.44201110e-03 7.94557333e-17
#  1.95485793e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.61062641e-03 7.39683466e-04 4.44201110e-03 1.01403990e-16
#  1.95485793e-02]
# 1760.8324230921828
# 1760.8324230921828
# 1760.8324230921828
# T_m at 1760.8324230921828: 0.41355813052033485
# x_e at 1760.8324230921828: 0.9993356121534127
# Standard x_e at 1760.8324230921828: 0.9992888964826013
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.64409919e-03 7.44977780e-04 4.48434877e-03 9.02979264e-17
#  1.99098531e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.64409919e-03 7.44977780e-04 4.48434877e-03 1.13487689e-16
#  1.99098531e-02]
# 1757.3142775642418
# 1757.3142775642418
# 1757.3142775642418
# T_m at 1757.3142775642418: 0.41273183921640305
# x_e at 1757.3142775642418: 0.9992923522126453
# Standard x_e at 1757.3142775642418: 0.999251299632046
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.67018757e-03 7.49095565e-04 4.51734519e-03 1.02307836e-16
#  2.01958365e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.67018757e-03 7.49095565e-04 4.51734519e-03 1.27060155e-16
#  2.01958365e-02]
# 1753.8031612957543
# 1753.8031612957543
# 1753.8031612957543
# T_m at 1753.8031612957543: 0.41190719886139177
# x_e at 1753.8031612957543: 0.9992481396772583
# Standard x_e at 1753.8031612957543: 0.9992118741159807
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.69126348e-03 7.52412731e-04 4.54364645e-03 1.15776190e-16
#  2.04233667e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.69126348e-03 7.52412731e-04 4.54364645e-03 1.42483239e-16
#  2.04233667e-02]
# 1750.2990602422503
# 1750.2990602422503
# 1750.2990602422503
# T_m at 1750.2990602422503: 0.4110842061539209
# x_e at 1750.2990602422503: 0.9992027371572285
# Standard x_e at 1750.2990602422503: 0.9991705234976908
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.70880560e-03 7.55165696e-04 4.56513715e-03 1.31067542e-16
#  2.06073488e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.70880560e-03 7.55165696e-04 4.56513715e-03 1.60221367e-16
#  2.06073488e-02]
# 1746.8019603873208
# 1746.8019603873208
# 1746.8019603873208
# T_m at 1746.8019603873208: 0.41026285779987764
# x_e at 1746.8019603873208: 0.9991559369247922
# Standard x_e at 1746.8019603873208: 0.9991271850522471
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.72406180e-03 7.57553400e-04 4.58332703e-03 1.48621161e-16
#  2.07591514e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.72406180e-03 7.57553400e-04 4.58332703e-03 1.80818944e-16
#  2.07591514e-02]
# 1743.3118477425623
# 1743.3118477425623
# 1743.3118477425623
# T_m at 1743.3118477425623: 0.409443150512245
# x_e at 1743.3118477425623: 0.9991075538949206
# Standard x_e at 1743.3118477425623: 0.999081758424989
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.73782680e-03 7.59702844e-04 4.59923101e-03 1.68970860e-16
#  2.08871115e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.73782680e-03 7.59702844e-04 4.59923101e-03 2.04956487e-16
#  2.08871115e-02]
# 1739.8287083475188
# 1739.8287083475188
# 1739.8287083475188
# T_m at 1739.8287083475188: 0.4086250810109693
# x_e at 1739.8287083475188: 0.9990574202271503
# Standard x_e at 1739.8287083475188: 0.9990341799680251
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.75061154e-03 7.61695767e-04 4.61354039e-03 1.92773434e-16
#  2.09973977e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.75061154e-03 7.61695767e-04 4.61354039e-03 2.33455470e-16
#  2.09973977e-02]
# 1736.3525282696287
# 1736.3525282696287
# 1736.3525282696287
# T_m at 1736.3525282696287: 0.4078086460228581
# x_e at 1736.3525282696287: 0.9990053811677105
# Standard x_e at 1736.3525282696287: 0.9989843350707891
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.76274731e-03 7.63585132e-04 4.62673109e-03 2.20845466e-16
#  2.10945982e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.76274731e-03 7.63585132e-04 4.62673109e-03 2.67374157e-16
#  2.10945982e-02]
# 1732.883293604167
# 1732.883293604167
# 1732.883293604167
# T_m at 1732.883293604167: 0.40699384228149815
# x_e at 1732.883293604167: 0.9989512917927834
# Standard x_e at 1732.883293604167: 0.9989321707235725
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.77444972e-03 7.65405329e-04 4.63913334e-03 2.54211553e-16
#  2.11821326e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.77444972e-03 7.65405329e-04 4.63913334e-03 3.08004437e-16
#  2.11821326e-02]
# 1729.42099047419
# 1729.42099047419
# 1729.42099047419
# T_m at 1729.42099047419: 0.4061806665271915
# x_e at 1729.42099047419: 0.9988950145966651
# Standard x_e at 1729.42099047419: 0.9988775449628787
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.78585877e-03 7.67178661e-04 4.65097746e-03 2.94168106e-16
#  2.12625467e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.78585877e-03 7.67178661e-04 4.65097746e-03 3.57063460e-16
#  2.12625467e-02]
# 1725.9656050304807
# 1725.9656050304807
# 1725.9656050304807
# T_m at 1725.9656050304807: 0.4053691155069016
# x_e at 1725.9656050304807: 0.99883641740021
# Standard x_e at 1725.9656050304807: 0.9988204298878869
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.79706492e-03 7.68919622e-04 4.66242461e-03 3.42368339e-16
#  2.13377287e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.79706492e-03 7.68919622e-04 4.66242461e-03 4.16645751e-16
#  2.13377287e-02]
# 1722.5171234514928
# 1722.5171234514928
# 1722.5171234514928
# T_m at 1722.5171234514928: 0.4045591859742097
# x_e at 1722.5171234514928: 0.9987753718612724
# Standard x_e at 1722.5171234514928: 0.9987606398541891
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.80812647e-03 7.70637717e-04 4.67358769e-03 4.00936733e-16
#  2.14090717e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.80812647e-03 7.70637717e-04 4.67358769e-03 4.89634236e-16
#  2.14090717e-02]
# 1719.0755319432956
# 1719.0755319432956
# 1719.0755319432956
# T_m at 1719.0755319432956: 0.4037508746892789
# x_e at 1719.0755319432956: 0.9987117522436997
# Standard x_e at 1719.0755319432956: 0.9986981712975871
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.81908119e-03 7.72339286e-04 4.68454573e-03 4.72623962e-16
#  2.14775983e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.81908119e-03 7.72339286e-04 4.68454573e-03 5.79551820e-16
#  2.14775983e-02]
# 1715.640816739518
# 1715.640816739518
# 1715.640816739518
# T_m at 1715.640816739518: 0.40294417841882135
# x_e at 1715.640816739518: 0.9986454344387471
# Standard x_e at 1715.640816739518: 0.9986328315694547
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.82995394e-03 7.74028611e-04 4.69535382e-03 5.61018444e-16
#  2.15440547e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.82995394e-03 7.74028611e-04 4.69535382e-03 6.91306523e-16
#  2.15440547e-02]
# 1712.212964101295
# 1712.212964101295
# 1712.212964101295
# T_m at 1712.212964101295: 0.4021390939360718
# x_e at 1712.212964101295: 0.9985762951841837
# Standard x_e at 1712.212964101295: 0.9985645866356678
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.84076152e-03 7.75708588e-04 4.70605018e-03 6.70837318e-16
#  2.16089834e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.84076152e-03 7.75708588e-04 4.70605018e-03 8.31116433e-16
#  2.16089834e-02]
# 1708.7919603172115
# 1708.7919603172115
# 1708.7919603172115
# T_m at 1708.7919603172115: 0.40133561802076256
# x_e at 1708.7919603172115: 0.9985042114520677
# Standard x_e at 1708.7919603172115: 0.9984932919882463
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.85151558e-03 7.77381148e-04 4.71666117e-03 8.08329793e-16
#  2.16727773e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.85151558e-03 7.77381148e-04 4.71666117e-03 1.00749758e-15
#  2.16727773e-02]
# 1705.3777917032476
# 1705.3777917032476
# 1705.3777917032476
# T_m at 1705.3777917032476: 0.40053374745910025
# x_e at 1705.3777917032476: 0.9984290596040333
# Standard x_e at 1705.3777917032476: 0.9984188344929606
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.86222434e-03 7.79047538e-04 4.72720485e-03 9.81840689e-16
#  2.17357204e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.86222434e-03 7.79047538e-04 4.72720485e-03 1.23184598e-15
#  2.17357204e-02]
# 1701.9704446027242
# 1701.9704446027242
# 1701.9704446027242
# T_m at 1701.9704446027242: 0.3997334790437507
# x_e at 1701.9704446027242: 0.998350715912991
# Standard x_e at 1701.9704446027242: 0.9983411527586687
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.87289364e-03 7.80708530e-04 4.73769359e-03 1.20260543e-15
#  2.17980172e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.87289364e-03 7.80708530e-04 4.73769359e-03 1.51941570e-15
#  2.17980172e-02]
# 1698.5699053862486
# 1698.5699053862486
# 1698.5699053862486
# T_m at 1698.5699053862486: 0.3989348095738159
# x_e at 1698.5699053862486: 0.9982690553186883
# Standard x_e at 1698.5699053862486: 0.9982600250362335
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.88352763e-03 7.82364577e-04 4.74813583e-03 1.48587556e-15
#  2.18598145e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.88352763e-03 7.82364577e-04 4.74813583e-03 1.89176020e-15
#  2.18598145e-02]
# 1695.1761604516594
# 1695.1761604516594
# 1695.1761604516594
# T_m at 1695.1761604516594: 0.3981377358548164
# x_e at 1695.1761604516594: 0.9981839514636768
# Standard x_e at 1695.1761604516594: 0.9981754471097578
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.89412916e-03 7.84015927e-04 4.75853732e-03 1.85253743e-15
#  2.19212176e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.89412916e-03 7.84015927e-04 4.75853732e-03 2.37757337e-15
#  2.19212176e-02]
# 1691.789196223972
# 1691.789196223972
# 1691.789196223972
# T_m at 1691.789196223972: 0.3973422546986768
# x_e at 1691.789196223972: 0.9980952764552358
# Standard x_e at 1691.789196223972: 0.9980872285363591
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.90470017e-03 7.85662702e-04 4.76890199e-03 2.33144904e-15
#  2.19823013e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.90470017e-03 7.85662702e-04 4.76890199e-03 3.01789456e-15
#  2.19823013e-02]
# 1688.4089991553253
# 1688.4089991553253
# 1688.4089991553253
# T_m at 1688.4089991553253: 0.3965483629237094
# x_e at 1688.4089991553253: 0.9980029006790596
# Standard x_e at 1688.4089991553253: 0.9979952555661379
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.91524192e-03 7.87304951e-04 4.77923249e-03 2.96285141e-15
#  2.20431187e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.91524192e-03 7.87304951e-04 4.77923249e-03 3.87000410e-15
#  2.20431187e-02]
# 1685.0355557249266
# 1685.0355557249266
# 1685.0355557249266
# T_m at 1685.0355557249266: 0.39575605735460373
# x_e at 1685.0355557249266: 0.9979066925704154
# Standard x_e at 1685.0355557249266: 0.9978994625350249
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.92575516e-03 7.88942678e-04 4.78953058e-03 3.80339460e-15
#  2.21037073e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.92575516e-03 7.88942678e-04 4.78953058e-03 5.01458513e-15
#  2.21037073e-02]
# 1681.6688524389974
# 1681.6688524389974
# 1681.6688524389974
# T_m at 1681.6688524389974: 0.3949653348223978
# x_e at 1681.6688524389974: 0.9978065186409509
# Standard x_e at 1681.6688524389974: 0.9977995963845245
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.93624032e-03 7.90575869e-04 4.79979744e-03 4.93361656e-15
#  2.21640928e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.93624032e-03 7.90575869e-04 4.79979744e-03 6.57009198e-15
#  2.21640928e-02]
# 1678.3088758307201
# 1678.3088758307201
# 1678.3088758307201
# T_m at 1678.3088758307201: 0.39417619216448163
# x_e at 1678.3088758307201: 0.9977022432785669
# Standard x_e at 1678.3088758307201: 0.9976956344398946
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.94669760e-03 7.92204493e-04 4.81003380e-03 6.46918084e-15
#  2.22242933e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.94669760e-03 7.92204493e-04 4.81003380e-03 8.70462642e-15
#  2.22242933e-02]
# 1674.955612460184
# 1674.955612460184
# 1674.955612460184
# T_m at 1674.955612460184: 0.39338862622457205
# x_e at 1674.955612460184: 0.9975937286582626
# Standard x_e at 1674.955612460184: 0.9975874393424412
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.95712703e-03 7.93828516e-04 4.82024011e-03 8.57794538e-15
#  2.22843209e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.95712703e-03 7.93828516e-04 4.82024011e-03 1.16663201e-14
#  2.22843209e-02]
# 1671.609048914331
# 1671.609048914331
# 1671.609048914331
# T_m at 1671.609048914331: 0.3926026338527027
# x_e at 1671.609048914331: 0.9974808346777433
# Standard x_e at 1671.609048914331: 0.9974747646532384
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.96752856e-03 7.95447899e-04 4.83041658e-03 1.15061632e-14
#  2.23441834e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.96752856e-03 7.95447899e-04 4.83041658e-03 1.58275238e-14
#  2.23441834e-02]
# 1668.2691718069025
# 1668.2691718069025
# 1668.2691718069025
# T_m at 1668.2691718069025: 0.3918182119052122
# x_e at 1668.2691718069025: 0.9973634188473751
# Standard x_e at 1668.2691718069025: 0.9973575956897229
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.97790205e-03 7.97062602e-04 4.84056328e-03 1.56191492e-14
#  2.24038857e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.97790205e-03 7.97062602e-04 4.84056328e-03 2.17374426e-14
#  2.24038857e-02]
# 1664.9359677783855
# 1664.9359677783855
# 1664.9359677783855
# T_m at 1664.9359677783855: 0.3910353572447282
# x_e at 1664.9359677783855: 0.9972413362483876
# Standard x_e at 1664.9359677783855: 0.9972357624367351
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.98824732e-03 7.98672581e-04 4.85068018e-03 2.14651259e-14
#  2.24634308e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.98824732e-03 7.98672581e-04 4.85068018e-03 3.02358812e-14
#  2.24634308e-02]
# 1661.6094234959594
# 1661.6094234959594
# 1661.6094234959594
# T_m at 1661.6094234959594: 0.3902540667401558
# x_e at 1661.6094234959594: 0.9971144394811512
# Standard x_e at 1661.6094234959594: 0.9971090248340968
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.99856417e-03 8.00277792e-04 4.86076714e-03 2.98766409e-14
#  2.25228200e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [4.99856417e-03 8.00277792e-04 4.86076714e-03 4.26226281e-14
#  2.25228200e-02]
# 1658.289525653443
# 1658.289525653443
# 1658.289525653443
# T_m at 1658.289525653443: 0.3894743372666648
# x_e at 1658.289525653443: 0.9969825786122894
# Standard x_e at 1658.289525653443: 0.996977355872075
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.00885237e-03 8.01878191e-04 4.87082399e-03 4.21336325e-14
#  2.25820535e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.00885237e-03 8.01878191e-04 4.87082399e-03 6.08973123e-14
#  2.25820535e-02]
# 1654.9762609712402
# 1654.9762609712402
# 1654.9762609712402
# T_m at 1654.9762609712402: 0.38869616570567694
# x_e at 1654.9762609712402: 0.9968456011249855
# Standard x_e at 1654.9762609712402: 0.9968405942025061
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.01911167e-03 8.03473731e-04 4.88085052e-03 6.02289083e-14
#  2.26411310e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.01911167e-03 8.03473731e-04 4.88085052e-03 8.82247506e-14
#  2.26411310e-02]
# 1651.6696161962877
# 1651.6696161962877
# 1651.6696161962877
# T_m at 1651.6696161962877: 0.38791954894485314
# x_e at 1651.6696161962877: 0.9967033518712543
# Standard x_e at 1651.6696161962877: 0.9966984508084265
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.02934181e-03 8.05064364e-04 4.89084646e-03 8.73059528e-14
#  2.27000514e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.02934181e-03 8.05064364e-04 4.89084646e-03 1.29706331e-13
#  2.27000514e-02]
# 1648.3695781020026
# 1648.3695781020026
# 1648.3695781020026
# T_m at 1648.3695781020026: 0.3871444838780819
# x_e at 1648.3695781020026: 0.9965556730252421
# Standard x_e at 1648.3695781020026: 0.99655091305974
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.03954254e-03 8.06650042e-04 4.90081155e-03 1.28390556e-13
#  2.27588135e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.03954254e-03 8.06650042e-04 4.90081155e-03 1.93522833e-13
#  2.27588135e-02]
# 1645.0761334882275
# 1645.0761334882275
# 1645.0761334882275
# T_m at 1645.0761334882275: 0.3863709674054662
# x_e at 1645.0761334882275: 0.9964024040366166
# Standard x_e at 1645.0761334882275: 0.9963978228601799
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.04971358e-03 8.08230715e-04 4.91074549e-03 1.91630257e-13
#  2.28174156e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.04971358e-03 8.08230715e-04 4.91074549e-03 2.93154091e-13
#  2.28174156e-02]
# 1641.7892691811799
# 1641.7892691811799
# 1641.7892691811799
# T_m at 1641.7892691811799: 0.38559899643331175
# x_e at 1641.7892691811799: 0.9962433815833623
# Standard x_e at 1641.7892691811799: 0.9962388971687991
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.05985465e-03 8.09806332e-04 4.92064797e-03 2.90423792e-13
#  2.28758559e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.05985465e-03 8.09806332e-04 4.92064797e-03 4.51223610e-13
#  2.28758559e-02]
# 1638.5089720333979
# 1638.5089720333979
# 1638.5089720333979
# T_m at 1638.5089720333979: 0.38482856787411457
# x_e at 1638.5089720333979: 0.9960784395232701
# Standard x_e at 1638.5089720333979: 0.9960740449658214
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.06996547e-03 8.11376842e-04 4.93051867e-03 4.47133000e-13
#  2.29341323e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.06996547e-03 8.11376842e-04 4.93051867e-03 7.05887263e-13
#  2.29341323e-02]
# 1635.2352289236887
# 1635.2352289236887
# 1635.2352289236887
# T_m at 1635.2352289236887: 0.38405967864654955
# x_e at 1635.2352289236887: 0.9959074088434938
# Standard x_e at 1635.2352289236887: 0.9959031417703578
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.08004573e-03 8.12942190e-04 4.94035726e-03 6.99650357e-13
#  2.29922429e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.08004573e-03 8.12942190e-04 4.94035726e-03 1.12274700e-12
#  2.29922429e-02]
# 1631.9680267570757
# 1631.9680267570757
# 1631.9680267570757
# T_m at 1631.9680267570757: 0.38329232567545785
# x_e at 1631.9680267570757: 0.9957301176077061
# Standard x_e at 1631.9680267570757: 0.9957259967869285
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.09009514e-03 8.14502322e-04 4.95016338e-03 1.11319879e-12
#  2.30501855e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.09009514e-03 8.14502322e-04 4.95016338e-03 1.81662501e-12
#  2.30501855e-02]
# 1628.7073524647456
# 1628.7073524647456
# 1628.7073524647456
# T_m at 1628.7073524647456: 0.38252650589183573
# x_e at 1628.7073524647456: 0.9955463909003315
# Standard x_e at 1628.7073524647456: 0.9955423053219965
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.10011339e-03 8.16057183e-04 4.95993669e-03 1.80187011e-12
#  2.31079577e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.10011339e-03 8.16057183e-04 4.95993669e-03 2.99263563e-12
#  2.31079577e-02]
# 1625.453193003997
# 1625.453193003997
# 1625.453193003997
# T_m at 1625.453193003997: 0.38176221623282214
# x_e at 1625.453193003997: 0.9953560507674415
# Standard x_e at 1625.453193003997: 0.9953520365771019
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.11010017e-03 8.17606715e-04 4.96967683e-03 2.96858442e-12
#  2.31655572e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.11010017e-03 8.17606715e-04 4.96967683e-03 5.01990512e-12
#  2.31655572e-02]
# 1622.2055353581877
# 1622.2055353581877
# 1622.2055353581877
# T_m at 1622.2055353581877: 0.38099945364168736
# x_e at 1622.2055353581877: 0.995158916153924
# Standard x_e at 1622.2055353581877: 0.9951550104736231
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.12005515e-03 8.19150860e-04 4.97938343e-03 4.98047758e-12
#  2.32229817e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.12005515e-03 8.19150861e-04 4.97938343e-03 8.57855387e-12
#  2.32229817e-02]
# 1618.9643665366825
# 1618.9643665366825
# 1618.9643665366825
# T_m at 1618.9643665366825: 0.3802382150678212
# x_e at 1618.9643665366825: 0.9949548028364752
# Standard x_e at 1618.9643665366825: 0.9949510178106262
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.12997800e-03 8.20689558e-04 4.98905609e-03 8.51360029e-12
#  2.32802286e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.12997800e-03 8.20689560e-04 4.98905609e-03 1.49440562e-11
#  2.32802286e-02]
# 1615.7296735748025
# 1615.7296735748025
# 1615.7296735748025
# T_m at 1615.7296735748025: 0.3794784974667219
# x_e at 1615.7296735748025: 0.9947435233523356
# Standard x_e at 1615.7296735748025: 0.9947397480792273
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.13986839e-03 8.22222750e-04 4.99869445e-03 1.48356249e-11
#  2.33372955e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.13986839e-03 8.22222752e-04 4.99869445e-03 2.65605984e-11
#  2.33372955e-02]
# 1612.5014435337707
# 1612.5014435337707
# 1612.5014435337707
# T_m at 1612.5014435337707: 0.3787202977999836
# x_e at 1612.5014435337707: 0.9945248869229854
# Standard x_e at 1612.5014435337707: 0.9945211555288689
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.14972597e-03 8.23750371e-04 5.00829808e-03 2.63683611e-11
#  2.33941798e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.14972597e-03 8.23750376e-04 5.00829809e-03 4.81715854e-11
#  2.33941797e-02]
# 1609.2796635006632
# 1609.2796635006632
# 1609.2796635006632
# T_m at 1609.2796635006632: 0.3779636130352861
# x_e at 1609.2796635006632: 0.9942986993732408
# Standard x_e at 1609.2796635006632: 0.9942950463954783
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.15955039e-03 8.25272361e-04 5.01786660e-03 4.78282373e-11
#  2.34508788e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.15955040e-03 8.25272370e-04 5.01786661e-03 8.92013472e-11
#  2.34508787e-02]
# 1606.0643205883555
# 1606.0643205883555
# 1606.0643205883555
# T_m at 1606.0643205883555: 0.3772084401463826
# x_e at 1606.0643205883555: 0.9940647630446637
# Standard x_e at 1606.0643205883555: 0.9940612233375383
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.16934129e-03 8.26788655e-04 5.02739959e-03 8.85836948e-11
#  2.35073898e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.16934130e-03 8.26788671e-04 5.02739960e-03 1.68743936e-10
#  2.35073897e-02]
# 1602.8554019354715
# 1602.8554019354715
# 1602.8554019354715
# T_m at 1602.8554019354715: 0.3764547761130893
# x_e at 1602.8554019354715: 0.9938228767212636
# Standard x_e at 1602.8554019354715: 0.9938193637082167
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.17909830e-03 8.28299190e-04 5.03689661e-03 1.67625750e-10
#  2.35637101e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.17909831e-03 8.28299222e-04 5.03689663e-03 3.26406646e-10
#  2.35637098e-02]
# 1599.6528947063325
# 1599.6528947063325
# 1599.6528947063325
# T_m at 1599.6528947063325: 0.37570261792127246
# x_e at 1599.6528947063325: 0.9935728355038674
# Standard x_e at 1599.6528947063325: 0.9935693272306068
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.18882104e-03 8.29803906e-04 5.04635725e-03 3.24264797e-10
#  2.36198367e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.18882108e-03 8.29803968e-04 5.04635728e-03 6.45874021e-10
#  2.36198363e-02]
# 1596.456786090905
# 1596.456786090905
# 1596.456786090905
# T_m at 1596.456786090905: 0.3749519625628387
# x_e at 1596.456786090905: 0.9933144307143602
# Standard x_e at 1596.456786090905: 0.9933109577430788
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.19850915e-03 8.31302747e-04 5.05578106e-03 6.41639385e-10
#  2.36757668e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.19850921e-03 8.31302873e-04 5.05578112e-03 1.30797140e-09
#  2.36757659e-02]
# 1593.2670633047505
# 1593.2670633047505
# 1593.2670633047505
# T_m at 1593.2670633047505: 0.3742028070357235
# x_e at 1593.2670633047505: 0.9930474497886078
# Standard x_e at 1593.2670633047505: 0.9930440424716158
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.20816224e-03 8.32795675e-04 5.06516759e-03 1.29951098e-09
#  2.37314971e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.20816237e-03 8.32795936e-04 5.06516772e-03 2.71257506e-09
#  2.37314952e-02]
# 1590.0837135889738
# 1590.0837135889738
# 1590.0837135889738
# T_m at 1590.0837135889738: 0.3734551483438803
# x_e at 1590.0837135889738: 0.9927716761608008
# Standard x_e at 1590.0837135889738: 0.992768364491548
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.21777993e-03 8.34282688e-04 5.07451643e-03 2.69549127e-09
#  2.37870242e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.21778020e-03 8.34283240e-04 5.07451670e-03 5.76468938e-09
#  2.37870200e-02]
# 1586.9067242101712
# 1586.9067242101712
# 1586.9067242101712
# T_m at 1586.9067242101712: 0.3727089834972689
# x_e at 1586.9067242101712: 0.9924868891411094
# Standard x_e at 1586.9067242101712: 0.9924836118042697
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.22736190e-03 8.35763866e-04 5.08382717e-03 5.72983532e-09
#  2.38423437e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.22736246e-03 8.35765063e-04 5.08382775e-03 1.25652744e-08
#  2.38423345e-02]
# 1583.7360824603816
# 1583.7360824603816
# 1583.7360824603816
# T_m at 1583.7360824603816: 0.3719643095118448
# x_e at 1583.7360824603816: 0.9921928637866351
# Standard x_e at 1583.7360824603816: 0.9921895672112869
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.23690786e-03 8.37239482e-04 5.09309948e-03 1.24903847e-08
#  2.38974498e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.23690908e-03 8.37242144e-04 5.09310076e-03 2.81093204e-08
#  2.38974290e-02]
# 1580.5717756570334
# 1580.5717756570334
# 1580.5717756570334
# T_m at 1580.5717756570334: 0.3712211234095482
# x_e at 1580.5717756570334: 0.9918893707659393
# Standard x_e at 1580.5717756570334: 0.9918860800742159
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.24641775e-03 8.38710271e-04 5.10233326e-03 2.79401247e-08
#  2.39523327e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.24642043e-03 8.38716334e-04 5.10233612e-03 6.45674146e-08
#  2.39522845e-02]
# 1577.4137911428952
# 1577.4137911428952
# 1577.4137911428952
# T_m at 1577.4137911428952: 0.3704794222182935
# x_e at 1577.4137911428952: 0.9915761762163948
# Standard x_e at 1577.4137911428952: 0.991572915832409
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.25589193e-03 8.40178072e-04 5.11152886e-03 6.41793450e-08
#  2.40069736e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.25589800e-03 8.40192236e-04 5.11153549e-03 1.52392426e-07
#  2.40068585e-02]
# 1574.2621162860248
# 1574.2621162860248
# 1574.2621162860248
# T_m at 1574.2621162860248: 0.36973920297195795
# x_e at 1574.2621162860248: 0.9912530415948755
# Standard x_e at 1574.2621162860248: 0.9912498351288633
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.26533185e-03 8.41647465e-04 5.12068793e-03 1.51487967e-07
#  2.40613300e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.26534596e-03 8.41681423e-04 5.12070364e-03 3.69834675e-07
#  2.40610479e-02]
# 1571.1167384797188
# 1571.1167384797188
# 1571.1167384797188
# T_m at 1571.1167384797188: 0.36900046271037146
# x_e at 1571.1167384797188: 0.9909197235210487
# Standard x_e at 1571.1167384797188: 0.9909165935961571
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.27474167e-03 8.43129969e-04 5.12981519e-03 3.67691306e-07
#  2.41152994e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.27477529e-03 8.43213574e-04 5.12985351e-03 9.23539532e-07
#  2.41145880e-02]
# 1567.9776451424614
# 1567.9776451424614
# 1567.9776451424614
# T_m at 1567.9776451424614: 0.36826319847930505
# x_e at 1567.9776451424614: 0.9905759736138579
# Standard x_e at 1567.9776451424614: 0.990572915924639
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.28413230e-03 8.44655138e-04 5.13892347e-03 9.18373335e-07
#  2.41686181e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.28421457e-03 8.44866671e-04 5.13901952e-03 2.37487005e-06
#  2.41667717e-02]
# 1564.844823717875
# 1564.844823717875
# 1564.844823717875
# T_m at 1564.844823717875: 0.36752740733046124
# x_e at 1564.844823717875: 0.9902215383203772
# Standard x_e at 1564.844823717875: 0.9902184405081209
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.29353221e-03 8.46300627e-04 5.14804699e-03 2.36203818e-06
#  2.42205826e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.29373907e-03 8.46851126e-04 5.14829473e-03 6.29442044e-06
#  2.42156451e-02]
# 1561.71826167467
# 1561.71826167467
# 1561.71826167467
# T_m at 1561.71826167467: 0.3667930863214624
# x_e at 1561.71826167467: 0.9898561587376278
# Standard x_e at 1561.71826167467: 0.9898530388949827
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.30301628e-03 8.48275747e-04 5.15727812e-03 6.25969451e-06
#  2.42692506e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.30327873e-03 8.48992732e-04 5.15759915e-03 1.07066677e-05
#  2.42635032e-02]
# 1558.597946506594
# 1558.597946506594
# 1558.597946506594
# T_m at 1558.597946506594: 0.3660602325158423
# x_e at 1558.597946506594: 0.9894795704265376
# Standard x_e at 1558.597946506594: 0.98947644553853
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.31251949e-03 8.50420252e-04 5.16654324e-03 1.07543225e-05
#  2.43167731e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.31252462e-03 8.50433681e-04 5.16655044e-03 8.97948998e-06
#  2.43185222e-02]
# 1555.4838657323824
# 1555.4838657323824
# 1555.4838657323824
# T_m at 1555.4838657323824: 0.36532884298303586
# x_e at 1555.4838657323824: 0.9890915032184855
# Standard x_e at 1555.4838657323824: 0.98908838909712
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.32172481e-03 8.51854251e-04 5.17545088e-03 9.01878096e-06
#  2.43715606e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.32173014e-03 8.51868203e-04 5.17545842e-03 7.51930695e-06
#  2.43730333e-02]
# 1552.3760068957074
# 1552.3760068957074
# 1552.3760068957074
# T_m at 1552.3760068957074: 0.36459891479836254
# x_e at 1552.3760068957074: 0.9886916810147082
# Standard x_e at 1552.3760068957074: 0.9886885922036449
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.33088924e-03 8.53281728e-04 5.18431458e-03 7.55154818e-06
#  2.44258349e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.33089478e-03 8.53296235e-04 5.18432248e-03 6.28991434e-06
#  2.44270686e-02]
# 1549.27435756513
# 1549.27435756513
# 1549.27435756513
# T_m at 1549.27435756513: 0.36387044504302324
# x_e at 1549.27435756513: 0.9882798215774997
# Standard x_e at 1549.27435756513: 0.9882767712865667
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.34001223e-03 8.54702616e-04 5.19313374e-03 6.31625691e-06
#  2.44796283e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.34001800e-03 8.54717711e-04 5.19314201e-03 5.25889049e-06
#  2.44806565e-02]
# 1546.1789053340485
# 1546.1789053340485
# 1546.1789053340485
# T_m at 1546.1789053340485: 0.3631434308040869
# x_e at 1546.1789053340485: 0.9878556363137321
# Standard x_e at 1546.1789053340485: 0.9878526363509036
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.34909323e-03 8.56116848e-04 5.20190773e-03 5.28033193e-06
#  2.45329692e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.34909924e-03 8.56132567e-04 5.20191641e-03 4.39742438e-06
#  2.45338217e-02]
# 1543.08963782065
# 1543.08963782065
# 1543.08963782065
# T_m at 1543.08963782065: 0.3624178691744828
# x_e at 1543.08963782065: 0.9874188300506692
# Standard x_e at 1543.08963782065: 0.9874158907606192
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.35872824e-03 8.57618431e-04 5.21126556e-03 4.41606022e-06
#  2.45906580e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.35873451e-03 8.57634815e-04 5.21127467e-03 3.68111397e-06
#  2.45913612e-02]
# 1540.00654266786
# 1540.00654266786
# 1540.00654266786
# T_m at 1540.00654266786: 0.3616937572529876
# x_e at 1540.00654266786: 0.986969100803968
# Standard x_e at 1540.00654266786: 0.9869662310106971
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.36979043e-03 8.59342159e-04 5.22194539e-03 3.69773522e-06
#  2.46557365e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.36979697e-03 8.59359257e-04 5.22195495e-03 3.08758222e-06
#  2.46563134e-02]
# 1536.9296075432942
# 1536.9296075432942
# 1536.9296075432942
# T_m at 1536.9296075432942: 0.36097109214421386
# x_e at 1536.9296075432942: 0.9865061395373105
# Standard x_e at 1536.9296075432942: 0.9865032386721534
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.38169255e-03 8.61193334e-04 5.23324424e-03 3.10117327e-06
#  2.47218674e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.38169938e-03 8.61211190e-04 5.23325430e-03 2.59590770e-06
#  2.47223379e-02]
# 1533.8588201392079
# 1533.8588201392079
# 1533.8588201392079
# T_m at 1533.8588201392079: 0.36024987095860345
# x_e at 1533.8588201392079: 0.986029629914166
# Standard x_e at 1533.8588201392079: 0.9860266970537859
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.39355756e-03 8.63037047e-04 5.24450143e-03 2.60709405e-06
#  2.47879516e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.39356470e-03 8.63055704e-04 5.24451201e-03 2.18965580e-06
#  2.47883327e-02]
# 1530.7941681724471
# 1530.7941681724471
# 1530.7941681724471
# T_m at 1530.7941681724471: 0.3595300908124172
# x_e at 1530.7941681724471: 0.9855392480417362
# Standard x_e at 1530.7941681724471: 0.9855362908751554
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.40537971e-03 8.64873031e-04 5.25571927e-03 2.19886317e-06
#  2.48540128e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.40538718e-03 8.64892534e-04 5.25573040e-03 1.85462730e-06
#  2.48543190e-02]
# 1527.7356393844002
# 1527.7356393844002
# 1527.7356393844002
# T_m at 1527.7356393844002: 0.35881174882772415
# x_e at 1527.7356393844002: 0.9850346622065054
# Standard x_e at 1527.7356393844002: 0.9850316872851678
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.41715515e-03 8.66701096e-04 5.26689519e-03 1.86220303e-06
#  2.49200063e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.41716296e-03 8.66721491e-04 5.26690691e-03 1.57870572e-06
#  2.49202499e-02]
# 1524.6832215409477
# 1524.6832215409477
# 1524.6832215409477
# T_m at 1524.6832215409477: 0.3580948421323922
# x_e at 1524.6832215409477: 0.9845155326015893
# Standard x_e at 1524.6832215409477: 0.9845125453579204
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.42888124e-03 8.68521097e-04 5.27802587e-03 1.58494341e-06
#  2.49858778e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.42888941e-03 8.68542434e-04 5.27803824e-03 1.35162913e-06
#  2.49860693e-02]
# 1521.6369024324142
# 1521.6369024324142
# 1521.6369024324142
# T_m at 1521.6369024324142: 0.35737936786007823
# x_e at 1521.6369024324142: 0.9839815110458092
# Standard x_e at 1521.6369024324142: 0.9839785158259932
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.44055607e-03 8.70332915e-04 5.28910814e-03 1.35677497e-06
#  2.50515776e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.44056463e-03 8.70355247e-04 5.28912119e-03 1.16475833e-06
#  2.50517257e-02]
# 1518.5966698735194
# 1518.5966698735194
# 1518.5966698735194
# T_m at 1518.5966698735194: 0.35666532315021865
# x_e at 1518.5966698735194: 0.9834322406943865
# Standard x_e at 1518.5966698735194: 0.9834292408059653
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.45217819e-03 8.72136447e-04 5.30013921e-03 1.16901676e-06
#  2.51170640e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.45218715e-03 8.72159830e-04 5.30015300e-03 1.01086187e-06
#  2.51171760e-02]
# 1515.562511703329
# 1515.562511703329
# 1515.562511703329
# T_m at 1515.562511703329: 0.35595270514801935
# x_e at 1515.562511703329: 0.9828673557412161
# Standard x_e at 1515.562511703329: 0.9828643535207914
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.46374641e-03 8.73931601e-04 5.31111668e-03 1.01440115e-06
#  2.51823035e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.46375580e-03 8.73956093e-04 5.31113126e-03 8.83920056e-07
#  2.51823855e-02]
# 1512.534415785206
# 1512.534415785206
# 1512.534415785206
# T_m at 1512.534415785206: 0.355241511004447
# x_e at 1512.534415785206: 0.9822864811126775
# Standard x_e at 1512.534415785206: 0.9822834780155751
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.47525970e-03 8.75718287e-04 5.32203849e-03 8.86877528e-07
#  2.52472690e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.47526955e-03 8.75743952e-04 5.32205393e-03 7.78948454e-07
#  2.52473260e-02]
# 1509.512370006763
# 1509.512370006763
# 1509.512370006763
# T_m at 1509.512370006763: 0.3545317378762192
# x_e at 1509.512370006763: 0.9816892321528319
# Standard x_e at 1509.512370006763: 0.9816862288646808
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.48671712e-03 8.77496420e-04 5.33290286e-03 7.81435485e-07
#  2.53119388e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.48672745e-03 8.77523327e-04 5.33291922e-03 6.91840838e-07
#  2.53119748e-02]
# 1506.4963622798125
# 1506.4963622798125
# 1506.4963622798125
# T_m at 1506.4963622798125: 0.35382338292579524
# x_e at 1506.4963622798125: 0.9810752143001292
# Standard x_e at 1506.4963622798125: 0.9810722108763613
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.49811778e-03 8.79265919e-04 5.34370819e-03 6.93947233e-07
#  2.53762946e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.49812862e-03 8.79294142e-04 5.34372555e-03 6.19230810e-07
#  2.53763129e-02]
# 1503.48638054032
# 1503.48638054032
# 1503.48638054032
# T_m at 1503.48638054032: 0.35311644332136705
# x_e at 1503.48638054032: 0.9804440227553316
# Standard x_e at 1503.48638054032: 0.9804410187916637
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.50946080e-03 8.81026704e-04 5.35445304e-03 6.21028671e-07
#  2.54403215e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.50947218e-03 8.81056322e-04 5.35447149e-03 5.58371112e-07
#  2.54403247e-02]
# 1500.482412748354
# 1500.482412748354
# 1500.482412748354
# T_m at 1500.482412748354: 0.35241091623685
# x_e at 1500.482412748354: 0.9797952421408046
# Standard x_e at 1500.482412748354: 0.9797922369419628
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.52074530e-03 8.82778698e-04 5.36513609e-03 5.59918134e-07
#  2.55040062e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.52075725e-03 8.82809799e-04 5.36515573e-03 5.07029331e-07
#  2.55039964e-02]
# 1497.4844468880399
# 1497.4844468880399
# 1497.4844468880399
# T_m at 1497.4844468880399: 0.3517067988518742
# x_e at 1497.4844468880399: 0.9791284461509633
# Standard x_e at 1497.4844468880399: 0.9791254385757718
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.53197039e-03 8.84521828e-04 5.37575609e-03 5.08371578e-07
#  2.55673374e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.53198296e-03 8.84554505e-04 5.37577702e-03 4.63398559e-07
#  2.55673161e-02]
# 1494.49247096751
# 1494.49247096751
# 1494.49247096751
# T_m at 1494.49247096751: 0.35100408835177505
# x_e at 1494.49247096751: 0.978443197193952
# Standard x_e at 1494.49247096751: 0.9784401863410522
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.54313518e-03 8.86256024e-04 5.38631186e-03 4.64572783e-07
#  2.56303043e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.54314840e-03 8.86290381e-04 5.38633421e-03 4.26021601e-07
#  2.56302730e-02]
# 1491.5064730188565
# 1491.5064730188565
# 1491.5064730188565
# T_m at 1491.5064730188565: 0.350302781927585
# x_e at 1491.5064730188565: 0.97773904602451
# Standard x_e at 1491.5064730188565: 0.9777360314046994
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.55423875e-03 8.87981221e-04 5.39680225e-03 4.27057090e-07
#  2.56928975e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.55425267e-03 8.88017372e-04 5.39682616e-03 3.93727016e-07
#  2.56928569e-02]
# 1488.5264410980838
# 1488.5264410980838
# 1488.5264410980838
# T_m at 1488.5264410980838: 0.34960287677602464
# x_e at 1488.5264410980838: 0.9770155313677653
# Standard x_e at 1488.5264410980838: 0.9770125132171301
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.56528016e-03 8.89697358e-04 5.40722615e-03 3.94647131e-07
#  2.57551077e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.56529483e-03 8.89735431e-04 5.40725178e-03 3.65575679e-07
#  2.57550584e-02]
# 1485.55236328506
# 1485.55236328506
# 1485.55236328506
# T_m at 1485.55236328506: 0.3489043700994938
# x_e at 1485.55236328506: 0.9762721795345106
# Standard x_e at 1485.55236328506: 0.9762691591362216
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.57625846e-03 8.91404386e-04 5.41758247e-03 3.66399086e-07
#  2.58169259e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.57627394e-03 8.91444522e-04 5.41761001e-03 3.40816408e-07
#  2.58168683e-02]
# 1482.5842276834703
# 1482.5842276834703
# 1482.5842276834703
# T_m at 1482.5842276834703: 0.3482072591060639
# x_e at 1482.5842276834703: 0.9755085040269762
# Standard x_e at 1482.5842276834703: 0.9755054836565227
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.58717267e-03 8.93102263e-04 5.42787014e-03 3.41558062e-07
#  2.58783434e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.58718901e-03 8.93144619e-04 5.42789980e-03 3.18849347e-07
#  2.58782777e-02]
# 1479.6220224207682
# 1479.6220224207682
# 1479.6220224207682
# T_m at 1479.6220224207682: 0.3475115410094689
# x_e at 1479.6220224207682: 0.9747240051360424
# Standard x_e at 1479.6220224207682: 0.9747209890372976
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.59802178e-03 8.94790958e-04 5.43808810e-03 3.19521282e-07
#  2.59393514e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.59803906e-03 8.94835716e-04 5.43812013e-03 2.99195996e-07
#  2.59392777e-02]
# 1476.6657356481285
# 1476.6657356481285
# 1476.6657356481285
# T_m at 1476.6657356481285: 0.34681721302909707
# x_e at 1476.6657356481285: 0.9739181695297968
# Standard x_e at 1476.6657356481285: 0.9739151642204011
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.60880476e-03 8.96470460e-04 5.44823530e-03 2.99807924e-07
#  2.59999411e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.60882306e-03 8.96517825e-04 5.44826999e-03 2.81474737e-07
#  2.59998590e-02]
# 1473.7153555404002
# 1473.7153555404002
# 1473.7153555404002
# T_m at 1473.7153555404002: 0.34612427238998333
# x_e at 1473.7153555404002: 0.9730904698325714
# Standard x_e at 1473.7153555404002: 0.9730874846313743
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.61952057e-03 8.98140776e-04 5.45831071e-03 2.82034540e-07
#  2.60601034e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.61953999e-03 8.98190987e-04 5.45834841e-03 2.65381039e-07
#  2.60600127e-02]
# 1470.770870296059
# 1470.770870296059
# 1470.770870296059
# T_m at 1470.770870296059: 0.34543271632280104
# x_e at 1470.770870296059: 0.9722403641953878
# Standard x_e at 1470.770870296059: 0.9722374115271872
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.63016814e-03 8.99801941e-04 5.46831333e-03 2.65895147e-07
#  2.61198291e-02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.63018880e-03 8.99855276e-04 5.46835443e-03 2.50671489e-07
#  2.61197293e-02]
# 1467.83226813716
# 1467.83226813716
# 1467.83226813716
# T_m at 1467.83226813716: 0.3447425420638542
# x_e at 1467.83226813716: 0.9713672958580105
# Standard x_e at 1467.83226813716: 0.9713643922486824
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [5.64074640e-03 9.01454024e-04 5.47824218e-03 2.51145188e-07
#  2.61791087e-02]
# ...
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.06635803e+03 4.00864076e+01 1.45149141e+02 9.34434840e-13
#  9.34434840e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2189.93616045  320.83827156  450.1540138    14.44974572  210.65022854]
# 19.289134225725142
# 19.289134225725142
# 19.289134225725142
# T_m at 19.289134225725142: 1.0426646957896064
# x_e at 19.289134225725142: 1.0
# Standard x_e at 19.289134225725142: 0.0002117208309154273
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.07518875e+03 4.02134812e+01 1.45529174e+02 9.36595329e-13
#  9.36595329e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2199.05271651  321.61473022  451.23060803   14.48376079  211.14492072]
# 19.250594509836155
# 19.250594509836155
# 19.250594509836155
# T_m at 19.250594509836155: 1.0426646957904022
# x_e at 19.250594509836155: 1.0
# Standard x_e at 19.250594509836155: 0.00021167588239788619
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.08335941e+03 4.03314167e+01 1.45880675e+02 9.38548404e-13
#  9.38548404e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2207.48170527  322.31958171  452.21053741   14.51428557  211.59379116]
# 19.212131796350878
# 19.212131796350878
# 19.212131796350878
# T_m at 19.212131796350878: 1.042664695791207
# x_e at 19.212131796350878: 1.0
# Standard x_e at 19.212131796350878: 0.00021163102368754302
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.09109006e+03 4.04435251e+01 1.46214201e+02 9.40362072e-13
#  9.40362072e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2215.45219323  322.9765545   453.12645365   14.54241952  212.01224031]
# 19.1737459314184
# 19.1737459314184
# 19.1737459314184
# T_m at 19.1737459314184: 1.0426646957920196
# x_e at 19.1737459314184: 1.0
# Standard x_e at 19.1737459314184: 0.00021158625460496292
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.09852722e+03 4.05518960e+01 1.46536325e+02 9.42081676e-13
#  9.42081676e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2223.11668123  323.60137541  453.99975331   14.5689133   212.41039347]
# 19.135436761495214
# 19.135436761495214
# 19.135436761495214
# T_m at 19.135436761495214: 1.042664695792841
# x_e at 19.135436761495214: 1.0
# Standard x_e at 19.135436761495214: 0.00021154157497106947
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.10576756e+03 4.06578406e+01 1.46851118e+02 9.43737404e-13
#  9.43737404e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2230.57586048  324.20445146  454.84443873   14.59427795  212.79489707]
# 19.097204133344587
# 19.097204133344587
# 19.097204133344587
# T_m at 19.097204133344587: 1.0426646957936685
# x_e at 19.097204133344587: 1.0
# Standard x_e at 19.097204133344587: 0.00021149698460714406
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.11287448e+03 4.07621771e+01 1.47161090e+02 9.45349327e-13
#  9.45349327e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2237.89578687  324.79265933  455.66966359   14.61886033  213.1701085 ]
# 19.059047894035956
# 19.059047894035956
# 19.059047894035956
# T_m at 19.059047894035956: 1.0426646957945043
# x_e at 19.059047894035956: 1.0
# Standard x_e at 19.059047894035956: 0.0002114524833348252
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.11988933e+03 4.08654138e+01 1.47467784e+02 9.46930774e-13
#  9.46930774e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2245.11958369  325.37053707  456.48140703   14.64289524  213.53888165]
# 19.020967890944313
# 19.020967890944313
# 19.020967890944313
# T_m at 19.020967890944313: 1.042664695795348
# x_e at 19.020967890944313: 1.0
# Standard x_e at 19.020967890944313: 0.00021140807097610776
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.12683899e+03 4.09678646e+01 1.47772143e+02 9.48490584e-13
#  9.48490584e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2252.27530333  325.94107648  457.28357279   14.66654115  213.90308458]
# 18.982963971749594
# 18.982963971749594
# 18.982963971749594
# T_m at 18.982963971749594: 1.0426646957962014
# x_e at 18.982963971749594: 1.0
# Standard x_e at 18.982963971749594: 0.0002113632021842464
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.13374087e+03 4.10697233e+01 1.48074745e+02 9.50034620e-13
#  9.50034620e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2259.38115471  326.50627844  458.0787451    14.68990199  214.26387351]
# 18.945035984436075
# 18.945035984436075
# 18.945035984436075
# T_m at 18.945035984436075: 1.042664695797059
# x_e at 18.945035984436075: 1.0
# Standard x_e at 18.945035984436075: 0.0002113177533884957
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.14060625e+03 4.11711085e+01 1.48375940e+02 9.51566767e-13
#  9.51566767e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2266.44893459  327.0674495   458.86859765   14.71304898  214.6220338 ]
# 18.907183777291753
# 18.907183777291753
# 18.907183777291753
# T_m at 18.907183777291753: 1.042664695797925
# x_e at 18.907183777291753: 1.0
# Standard x_e at 18.907183777291753: 0.00021127239539949947
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.14744243e+03 4.12720932e+01 1.48675942e+02 9.53089607e-13
#  9.53089607e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2273.48627394  327.62541165  459.65417709   14.73603412  214.9781725 ]
# 18.86940719890775
# 18.86940719890775
# 18.86940719890775
# T_m at 18.86940719890775: 1.0426646957987984
# x_e at 18.86940719890775: 1.0
# Standard x_e at 18.86940719890775: 0.00021122712803582573
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.15425411e+03 4.13727219e+01 1.48974880e+02 9.54604854e-13
#  9.54604854e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2280.49811495  328.18073232  460.43619858   14.75889003  215.33263496]
# 18.8317060981777
# 18.8317060981777
# 18.8317060981777
# T_m at 18.8317060981777: 1.0426646957996797
# x_e at 18.8317060981777: 1.0
# Standard x_e at 18.8317060981777: 0.0002111819511164049
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.16104436e+03 4.14730219e+01 1.49272833e+02 9.56113654e-13
#  9.56113654e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2287.4876576   328.73378781  461.21513281   14.78163874  215.68564891]
# 18.794080324297155
# 18.794080324297155
# 18.794080324297155
# T_m at 18.794080324297155: 1.0426646958005679
# x_e at 18.794080324297155: 1.0
# Standard x_e at 18.794080324297155: 0.00021113686446052932
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.16781513e+03 4.15730097e+01 1.49569848e+02 9.57616772e-13
#  9.57616772e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2294.45697715  329.28482859  461.99129095   14.80429512  216.03736518]
# 18.756529726762963
# 18.756529726762963
# 18.756529726762963
# T_m at 18.756529726762963: 1.0426646958014627
# x_e at 18.756529726762963: 1.0
# Standard x_e at 18.756529726762963: 0.00021109186788785224
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.17456770e+03 4.16726958e+01 1.49865955e+02 9.59114722e-13
#  9.59114722e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2301.40742226  329.83402215  462.76487985   14.82686928  216.38788415]
# 18.71905415537269
# 18.71905415537269
# 18.71905415537269
# T_m at 18.71905415537269: 1.042664695802363
# x_e at 18.71905415537269: 1.0
# Standard x_e at 18.71905415537269: 0.00021104696121838735
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18130292e+03 4.17720865e+01 1.50161173e+02 9.60607850e-13
#  9.60607850e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2308.339873    330.38148106  463.53603796   14.84936806  216.73727307]
# 18.681653460223995
# 18.681653460223995
# 18.681653460223995
# T_m at 18.681653460223995: 1.042664695803271
# x_e at 18.681653460223995: 1.0
# Standard x_e at 18.681653460223995: 0.00021100214427250788
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18802133e+03 4.18711861e+01 1.50455512e+02 9.62096392e-13
#  9.62096392e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2315.25490773  330.92728154  464.30485882   14.87179614  217.08557741]
# 18.644327491714048
# 18.644327491714048
# 18.644327491714048
# T_m at 18.644327491714048: 1.042664695804185
# x_e at 18.644327491714048: 1.0
# Standard x_e at 18.644327491714048: 0.000210957416870946
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.19472329e+03 4.19699972e+01 1.50748982e+02 9.63580510e-13
#  9.63580510e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2322.15291081  331.4714757   465.07140636   14.89415671  217.43282824]
# 18.60707610053893
# 18.60707610053893
# 18.60707610053893
# T_m at 18.60707610053893: 1.0426646958051053
# x_e at 18.60707610053893: 1.0
# Standard x_e at 18.60707610053893: 0.00021091277883479207
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.20140904e+03 4.20685219e+01 1.51041587e+02 9.65060315e-13
#  9.65060315e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2329.03414218  332.01409958  465.83572502   14.91645198  217.77904713]
# 18.56989913769302
# 18.56989913769302
# 18.56989913769302
# T_m at 18.56989913769302: 1.042664695806033
# x_e at 18.56989913769302: 1.0
# Standard x_e at 18.56989913769302: 0.00021086822998549385
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.20807876e+03 4.21667617e+01 1.51333333e+02 9.66535884e-13
#  9.66535884e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2335.89878214  332.55517859  466.59784633   14.93868348  218.12424938]
# 18.532796454468425
# 18.532796454468425
# 18.532796454468425
# T_m at 18.532796454468425: 1.0426646958069672
# x_e at 18.532796454468425: 1.0
# Standard x_e at 18.532796454468425: 0.00021082377014485589
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.21473257e+03 4.22647178e+01 1.51624223e+02 9.68007275e-13
#  9.68007275e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2342.74696013  333.09473107  467.35779335   14.96085229  218.46844613]
# 18.495767902454354
# 18.495767902454354
# 18.495767902454354
# T_m at 18.495767902454354: 1.0426646958079075
# x_e at 18.495767902454354: 1.0
# Standard x_e at 18.495767902454354: 0.0002107793991350388
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.22137055e+03 4.23623914e+01 1.51914261e+02 9.69474527e-13
#  9.69474527e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2349.57877329  333.63277066  468.11558348   14.98295919  218.81164578]
# 18.458813333536558
# 18.458813333536558
# 18.458813333536558
# T_m at 18.458813333536558: 1.0426646958088537
# x_e at 18.458813333536558: 1.0
# Standard x_e at 18.458813333536558: 0.00021073511677855843
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.22799279e+03 4.24597835e+01 1.52203450e+02 9.70937673e-13
#  9.70937673e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2356.39429817  334.16930787  468.87123043   15.00500476  219.15385492]
# 18.421932599896703
# 18.421932599896703
# 18.421932599896703
# T_m at 18.421932599896703: 1.0426646958098083
# x_e at 18.421932599896703: 1.0
# Standard x_e at 18.421932599896703: 0.00021069092289828533
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.23459934e+03 4.25568951e+01 1.52491793e+02 9.72396738e-13
#  9.72396738e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2363.19359832  334.70435118  469.62474547   15.02698942  219.49507893]
# 18.385125554011815
# 18.385125554011815
# 18.385125554011815
# T_m at 18.385125554011815: 1.0426646958107693
# x_e at 18.385125554011815: 1.0
# Standard x_e at 18.385125554011815: 0.0002106468173174439
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.24119025e+03 4.26537270e+01 1.52779292e+02 9.73851742e-13
#  9.73851742e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2369.97672909  335.23790769  470.37613822   15.04891355  219.83532241]
# 18.348392048653654
# 18.348392048653654
# 18.348392048653654
# T_m at 18.348392048653654: 1.0426646958117358
# x_e at 18.348392048653654: 1.0
# Standard x_e at 18.348392048653654: 0.00021060279985961179
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.24776558e+03 4.27502803e+01 1.53065951e+02 9.75302702e-13
#  9.75302702e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2376.74374059  335.76998361  471.12541726   15.07077742  220.17458944]
# 18.311731936888155
# 18.311731936888155
# 18.311731936888155
# T_m at 18.311731936888155: 1.0426646958127066
# x_e at 18.311731936888155: 1.0
# Standard x_e at 18.311731936888155: 0.00021055887034871908
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.25432536e+03 4.28465559e+01 1.53351772e+02 9.76749635e-13
#  9.76749635e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2383.49467966  336.30058455  471.87259047   15.0925813   220.51288375]
# 18.275145072074814
# 18.275145072074814
# 18.275145072074814
# T_m at 18.275145072074814: 1.042664695813685
# x_e at 18.275145072074814: 1.0
# Standard x_e at 18.275145072074814: 0.00021051502860904768
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.26086964e+03 4.29425546e+01 1.53636759e+02 9.78192555e-13
#  9.78192555e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2390.22959104  336.82971575  472.61766525   15.1143254   220.85020885]
# 18.238631307866132
# 18.238631307866132
# 18.238631307866132
# T_m at 18.238631307866132: 1.0426646958146675
# x_e at 18.238631307866132: 1.0
# Standard x_e at 18.238631307866132: 0.00021047127446523057
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.26739846e+03 4.30382775e+01 1.53920913e+02 9.79631475e-13
#  9.79631475e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2396.94851814  337.35738215  473.36064869   15.13600993  221.18656809]
# 18.202190498207
# 18.202190498207
# 18.202190498207
# T_m at 18.202190498207: 1.0426646958156565
# x_e at 18.202190498207: 1.0
# Standard x_e at 18.202190498207: 0.0002104276077422511
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.27391187e+03 4.31337253e+01 1.54204239e+02 9.81066410e-13
#  9.81066410e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2403.65150347  337.88358856  474.10154768   15.1576351   221.52196473]
# 18.165822497334126
# 18.165822497334126
# 18.165822497334126
# T_m at 18.165822497334126: 1.0426646958166514
# x_e at 18.165822497334126: 1.0
# Standard x_e at 18.165822497334126: 0.00021038402826544235
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.28040989e+03 4.32288991e+01 1.54486738e+02 9.82497371e-13
#  9.82497371e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2410.33858899  338.40833965  474.84036895   15.1792011   221.85640194]
# 18.129527159775467
# 18.129527159775467
# 18.129527159775467
# T_m at 18.129527159775467: 1.04266469581765
# x_e at 18.129527159775467: 1.0
# Standard x_e at 18.129527159775467: 0.00021034053586048632
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.28689258e+03 4.33237997e+01 1.54768413e+02 9.83924372e-13
#  9.83924372e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2417.00981624  338.93164     475.57711915   15.2007081   222.18988287]
# 18.09330434034962
# 18.09330434034962
# 18.09330434034962
# T_m at 18.09330434034962: 1.042664695818655
# x_e at 18.09330434034962: 1.0
# Standard x_e at 18.09330434034962: 0.0002102971303534134
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.29335997e+03 4.34184280e+01 1.55049267e+02 9.85347424e-13
#  9.85347424e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2423.66522645  339.45349417  476.31180484   15.2221563   222.52241061]
# 18.057153894165253
# 18.057153894165253
# 18.057153894165253
# T_m at 18.057153894165253: 1.0426646958196655
# x_e at 18.057153894165253: 1.0
# Standard x_e at 18.057153894165253: 0.00021025381157060142
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.29981211e+03 4.35127849e+01 1.55329303e+02 9.86766540e-13
#  9.86766540e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2430.30486067  339.97390663  477.04443255   15.24354587  222.85398823]
# 18.021075676620544
# 18.021075676620544
# 18.021075676620544
# T_m at 18.021075676620544: 1.0426646958206836
# x_e at 18.021075676620544: 1.0
# Standard x_e at 18.021075676620544: 0.00021021057933877523
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.30624902e+03 4.36068713e+01 1.55608523e+02 9.88181733e-13
#  9.88181733e+02]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2436.92875974  340.49288186  477.77500874   15.26487699  223.18461879]

# %%
plt.figure()
plt.plot(a[3].rs, a[0])
plt.plot(b[3].rs, b[0])
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')


plt.figure()
plt.plot(a[3].rs, a[1]/phys.kB)
plt.plot(b[3].rs, b[1]/phys.kB)
plt.plot(a[3].rs, phys.TCMB(a[3].rs)/phys.kB, 'k:')
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')

# %%
a[0]
a[3].rs[1:]

# %%
a = 2
str(a)
