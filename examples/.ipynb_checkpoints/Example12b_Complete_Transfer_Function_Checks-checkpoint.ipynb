# %% [markdown]
# -What about electrons? (I don't see any - 2 phys.me)
#
# -1e11 and mDM?
#
# -Compute T(E,z_in, z_dep) by doing a delta function injection

# %% [markdown]
# # Full Transfer Functions

# %%
# %load_ext autoreload
import sys
sys.path.append("..")

# %%
# %autoreload

import matplotlib
matplotlib.rc_file('matplotlibrc')
import matplotlib.pyplot as plt

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [10,10]


from astropy.io import fits

import numpy as np
import copy
import pickle

import darkhistory.physics as phys
import darkhistory.utilities as utils
import darkhistory.spec.spectools as spectools
import darkhistory.spec.transferfunction as tf
import darkhistory.spec.transferfunclist as tflist
from darkhistory.spec.spectrum import Spectrum
from darkhistory.spec.spectra import Spectra
import darkhistory.history.tla as tla

from scipy.interpolate import interp1d

from tqdm import tqdm_notebook as tqdm

from darkhistory.electrons.ics.ics_spectrum import ics_spec
from darkhistory.electrons.ics.ics_engloss_spectrum import engloss_spec
from darkhistory.electrons.ics.ics_cooling import get_ics_cooling_tf

from darkhistory.low_energy.lowE_deposition import compute_fs

# np.set_printoptions(threshold=np.nan)

# %%
# mDM = 1e11
# sigmav = 1e-24

# def rate_func_swave(rs):
#     return 0*phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)/(2*mDM)

# def test(rs, x1, x2, x3):
#     return 0.3

# test = tla.get_history(
#                 np.array([phys.TCMB(3000), 1, 0, 0]), 0.3, 0.3, 0.3, 
#                 rate_func_swave, np.flipud(np.arange(1, 3001)), reion_switch=False
#             )

# out = np.stack((np.flipud(np.arange(1, 3001)), test[:,0], test[:,1]))
# # pickle.dump(
# #     out, open("/Users/hongwan/GitHub/DarkHistory/darkhistory/history/std_soln.p", "wb")       
# #            )

# %%
soln = pickle.load(open("../darkhistory/history/std_soln.p", "rb"))
xe_std  = interp1d(soln[0,:], soln[2,:])
T_m_std = interp1d(soln[0,:], soln[1,:])

# %%
rs = 600
print(xe_std(rs))
print(T_m_std(rs)/phys.kB)
print(phys.TCMB(rs)/phys.kB)
# Out:
# 0.0009648017275850074
# 1625.561215315584
# 1635.2995445551107

# %%
# plt.figure()

# plt.plot(np.flipud(np.arange(1, 3001)), test[:,0]/phys.kB)
# plt.plot(np.flipud(np.arange(1, 3001)), phys.TCMB(np.flipud(np.arange(1, 3001)))/phys.kB, 'k:')
# ax = plt.gca()

# ax.set_xscale('log')
# ax.set_yscale('log')

# plt.figure()

# plt.plot(np.flipud(np.arange(1, 3001)), test[:,1])
# ax = plt.gca()

# ax.set_xscale('log')
# ax.set_yscale('log')

# %% [markdown]
# ## Photon Transfer Functions

# %%
user = 'hongwan'

highengphot_tflist_arr = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_photspec_60eV_complete_coarse.raw", "rb"))
lowengphot_tflist_arr  = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_lowengphotspec_60eV_complete_coarse.raw", "rb"))
lowengelec_tflist_arr  = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_lowengelecspec_60eV_complete_coarse.raw", "rb"))
CMB_engloss_arr = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/CMB_engloss_60eV_complete_coarse.raw", "rb"))

# %%
highengphot_tflist_arr[0]._grid_vals.shape
# Out:
# (51, 325, 500)

# %%
photeng = highengphot_tflist_arr[0].eng
eleceng = lowengelec_tflist_arr[0].eng

#Split photeng into high and low energy. 
photeng_high = photeng[photeng > 60]
photeng_low  = photeng[photeng <= 60]

# Split eleceng into high and low energy. 
eleceng_high = eleceng[eleceng > 3000]
eleceng_low  = eleceng[eleceng <= 3000]


for highengphot_tflist in highengphot_tflist_arr:
    
#     highengphot_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)

    for tf in highengphot_tflist:
        # tf.rebin(photeng_high)
#         tf.rebin(photeng)
        
        # Pad with zeros so that it becomes photeng x photeng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size, 0), (0, 0)), 'constant')
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = photeng
        tf._rs = tf.rs[0]*np.ones_like(photeng)
    
    highengphot_tflist._eng = photeng
    highengphot_tflist._in_eng = photeng
    highengphot_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in highengphot_tflist._tflist])
    )
    
# lowengphot_tflist.in_eng set to photeng_high
for lowengphot_tflist in lowengphot_tflist_arr:
    
#     lowengphot_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)
    
    for tf in lowengphot_tflist:
#         tf.rebin(photeng)
        # Pad with zeros so that it becomes photeng x photeng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size,0), (0,0)), 'constant')
        # Photons in the low energy bins should be immediately deposited.
        tf._grid_vals[0:photeng_low.size, 0:photeng_low.size] = np.identity(photeng_low.size)
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = photeng
        tf._rs = tf.rs[0]*np.ones_like(photeng)
    
    lowengphot_tflist._eng = photeng
    lowengphot_tflist._in_eng = photeng
    lowengphot_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in lowengphot_tflist._tflist])
    )
    
# lowengelec_tflist.in_eng set to photeng_high 
for lowengelec_tflist in lowengelec_tflist_arr:
    
#     lowengelec_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)
    
    for tf in lowengelec_tflist:
#         tf.rebin(eleceng)
        # Pad with zeros so that it becomes photeng x eleceng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size,0), (0,0)), 'constant')
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = eleceng
        tf._rs = tf.rs[0]*np.ones_like(photeng)

    lowengelec_tflist._eng = eleceng
    lowengelec_tflist._in_eng = photeng
    lowengelec_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in lowengelec_tflist._tflist])
    )
    
    for engloss in CMB_engloss_arr:
        engloss = np.pad(engloss, ((0,0),(photeng_low.size, 0)), 'constant')

# %%
xes = 0.5 + 0.5*np.tanh([-5., -4.1, -3.2, -2.3, -1.4, -0.5, 0.4, 1.3, 2.2, 3.1, 4])

highengphot_tf_interp = tflist.TransferFuncInterp(xes, highengphot_tflist_arr)
lowengphot_tf_interp = tflist.TransferFuncInterp(xes, lowengphot_tflist_arr)
lowengelec_tf_interp = tflist.TransferFuncInterp(xes, lowengelec_tflist_arr)

# %%
mDM = 5267515052.961917*2

phot_spec_init = spectools.rebin_N_arr(np.array([2]), 
                                      np.array([mDM/2]), 
                                      photeng)
phot_spec_init.switch_spec_type()

# %%
print(phot_spec_init.toteng(bound_type = 'eng', bound_arr = np.array([1,1e13]))/mDM)
# Out:
# [1.]

# %%
# %autoreload
phot_spec_init.rs = 1800
end_rs   = 1700
#mDM = 1e8
sigmav = 1e-26
tau = 1e25

def rate_func_swave_N(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)/(2*mDM)

def rate_func_swave_eng(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)

def rate_func_decay_N(rs):
    # This is dN/dV dt
    return phys.inj_rate('decay', rs, tau=tau)/mDM

def rate_func_decay_eng(rs):
    # This is dN/dV dt
    return phys.inj_rate('decay', rs, tau=tau)


def rate_func_swave_N_2(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav*1e-30)/(2*mDM)

def rate_func_swave_eng_2(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav*1e-30)


def evolve(
    in_spec_elec, in_spec_phot, 
    rate_func_N, rate_func_eng, xe_init, T_m_init,
    highengphot_tf_interp, lowengphot_tf_interp, 
    lowengelec_tf_interp, 
    end_rs, coarsen_factor=1, std_soln=False
):
    """
    Main function that computes the temperature and ionization history. 
    
    Parameters
    ----------
    in_spec_elec : Spectrum
        Spectrum per annihilation/decay into electrons. 
    in_spec_phot : Spectrum
        Spectrum per annihilation/decay into photons.
    rate_func_N : function
        Function describing the rate of annihilation/decay, dN/(dV dt)
    rate_func_eng : function
        Function describing the rate of annihilation/decay, dE/(dV dt)
    xe_init : float
        xe at the initial redshift. 
    T_m_init : float
        Matter temperature at the initial redshift. 
    highengphot_tf_interp : TransferFuncInterp
        Interpolation table for high energy photons. 
    lowengphot_tf_interp : TransferFuncInterp
        Interpolation table for low energy photons. 
    lowengelec_tf_interp : TransferFuncInterp
        Interpolation table for low energy electrons. 
    end_rs : float
        Final redshift to evolve to. 
    coarsen_factor : int
        Coarsening to apply to the transfer function matrix. 
    std_soln : bool
        If true, uses the standard TLA solution for f(z). 
    """
    
    # Initialize the next spectrum as None.
    next_highengphot_spec = None
    next_lowengphot_spec  = None
    next_lowengelec_spec  = None
    
    if (
        highengphot_tf_interp.dlnz    != lowengphot_tf_interp.dlnz
        or highengphot_tf_interp.dlnz != lowengelec_tf_interp.dlnz
        or lowengphot_tf_interp.dlnz  != lowengelec_tf_interp.dlnz
    ):
        raise TypeError('TransferFuncInterp objects must all have the same dlnz.')
    
    if in_spec_elec.rs != in_spec_phot.rs:
        raise TypeError('Input spectra must have the same rs.')
    
    # redshift/timestep related quantities. 
    dlnz = highengphot_tf_interp.dlnz
    prev_rs = None
    rs = in_spec_phot.rs
    dt = dlnz/phys.hubble(rs)
    
    # The initial input dN/dE per annihilation to per baryon per dlnz, 
    # based on the specified rate. 
    # dN/(dN_B d lnz dE) = dN/dE * (dN_ann/(dV dt)) * dV/dN_B * dt/dlogz
    
    # ICS for in_spec_elec goes here.
    
    # (Should this be multiplied by dlnz?)
    init_inj_spec = (
        in_spec_phot * rate_func_N(rs) * dt / (phys.nB * rs**3)
    )
    
    
    # Initialize the Spectra object that will contain all the 
    # output spectra during the evolution.
    out_highengphot_specs = Spectra([init_inj_spec], spec_type=init_inj_spec.spec_type)
    out_lowengphot_specs  = Spectra([], spec_type=init_inj_spec.spec_type)
    out_lowengelec_specs  = Spectra([], spec_type=init_inj_spec.spec_type)
    
    # Initialize the xe and T array that will store the solutions.
    xe_arr  = np.array([xe_init])
    T_m_arr = np.array([T_m_init])
    
    # Load the standard TLA solution if necessary. 
#     if std_soln:
    if True:
        soln = pickle.load(open("../darkhistory/history/std_soln.p", "rb"))
        xe_std  = interp1d(soln[0,:], soln[2,:])
        T_m_std = interp1d(soln[0,:], soln[1,:])

    # Define these methods for speed.
    append_highengphot_spec = out_highengphot_specs.append
    append_lowengphot_spec  = out_lowengphot_specs.append
    append_lowengelec_spec  = out_lowengelec_specs.append
    
    # Loop while we are still at a redshift above end_rs.
    while rs > end_rs:
        
        # If prev_rs exists, calculate xe and T_m. 
        if prev_rs is not None:
#             print('here at least?')
            
            # f_continuum, f_lyman, f_ionH, f_ionHe, f_heat
            # f_raw takes in dE/(dV dt)
            if std_soln:
                f_raw = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_std(rs), 0, 0]), rate_func_eng(rs), dt
                )
                print("\n SHOULD BE ONE: ", (next_lowengelec_spec.toteng() + next_lowengphot_spec.toteng())/(
                np.sum(f_raw) * rate_func_eng(rs) * dt / phys.nB / rs**3), '\n')   
            else:
                f_raw = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_arr[-1], 0, 0]), rate_func_eng(rs), dt
                )
                
            std_f = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_std(rs), 0, 0]), rate_func_eng(rs), dt
                )
            
            backreaction_f = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_arr[-1], 0, 0]), rate_func_eng(rs), dt
                )
            
            init_cond = np.array([T_m_arr[-1], xe_arr[-1], 0, 0])

            new_vals = tla.get_history(
                init_cond, f_raw[2], f_raw[1], f_raw[4], 
                rate_func_eng, np.array([prev_rs, rs]),
                reion_switch = False
            )

            T_m_arr = np.append(T_m_arr, new_vals[-1,0])
            xe_arr  = np.append(xe_arr,  new_vals[-1,1])
            
        print('T_m at '+str(rs)+': '+ str(T_m_arr[-1]))
        print('x_e at '+str(rs)+': '+ str(xe_arr[-1]))
        print('Standard x_e at '+str(rs)+': '+str(xe_std(rs)))
        print('Standard T_m at '+str(rs)+': '+str(T_m_std(rs)))
        if prev_rs is not None:
            print('Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat: ', backreaction_f)
            print('Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat: ', std_f)
            
        if std_soln:
            highengphot_tf = highengphot_tf_interp.get_tf(rs, xe_std(rs))
            lowengphot_tf  = lowengphot_tf_interp.get_tf(rs, xe_std(rs))
            lowengelec_tf  = lowengelec_tf_interp.get_tf(rs, xe_std(rs))
        else:
            highengphot_tf = highengphot_tf_interp.get_tf(rs, xe_arr[-1])
            lowengphot_tf  = lowengphot_tf_interp.get_tf(rs, xe_arr[-1])
            lowengelec_tf  = lowengelec_tf_interp.get_tf(rs, xe_arr[-1])
        
#         if coarsen_factor > 1:
#             prop_tf = np.zeros_like(highengphot_tf._grid_vals)
#             for i in np.arange(coarsen_factor):
#                 prop_tf += matrix_power(highengphot_tf._grid_vals, i)
#             lowengphot_tf._grid_vals = np.matmul(prop_tf, lowengphot_tf._grid_vals)
#             lowengelec_tf._grid_vals = np.matmul(prof_tf, lowengelec_tf._grid_vals)
#             highengphot_tf._grid_vals = matrix_power(
#                 highengphot_tf._grid_vals, coarsen_factor
#             )
            
        next_highengphot_spec = highengphot_tf.sum_specs(out_highengphot_specs[-1])
        next_lowengphot_spec  = lowengphot_tf.sum_specs(out_highengphot_specs[-1])
        next_lowengelec_spec  = lowengelec_tf.sum_specs(out_highengphot_specs[-1])
        
#         print('\n SHOULD ALSO BE ONE: ', 
#               out_highengphot_specs[-1].toteng(bound_type = 'eng', bound_arr = np.array([100,1e13]))/(
#         next_highengphot_spec.toteng(bound_type = 'eng', bound_arr = np.array([100,1e13])) + 
#             next_lowengphot_spec.toteng(bound_type = 'eng', bound_arr = np.array([100,1e13])) + 
#             next_lowengelec_spec.toteng(bound_type = 'eng', bound_arr = np.array([100,1e13]))), '\n')
        
        print('ENERGIES:')
        print(out_highengphot_specs[-1].toteng())
        print(highengphot_tf[239].toteng())
    
        print('\n SHOULD ALSO BE ONE: ', 
              out_highengphot_specs[-1].toteng()/(
        next_highengphot_spec.toteng()), '\n')
        
#         utils.compare_arr([out_highengphot_specs[-1].N, next_highengphot_spec.N])
        
        # Re-define existing variables.
        prev_rs = rs
        rs = np.exp(np.log(rs) - 0.002)
        
        dt = dlnz/phys.hubble(rs)
        next_highengphot_spec.rs = rs
        next_lowengphot_spec.rs  = rs
        next_lowengelec_spec.rs  = rs
        
        # Add the next injection spectrum to next_highengphot_spec
        next_inj_spec = (
            in_spec_phot * rate_func_N(rs)* dt / (phys.nB * rs**3)
        )

        # This keeps the redshift. 
        next_highengphot_spec.N += next_inj_spec.N
        
        append_highengphot_spec(next_highengphot_spec)
        append_lowengphot_spec(next_lowengphot_spec)
        append_lowengelec_spec(next_lowengelec_spec)
        
        print('************************ END OF LOOP **************************')
        
        
    return (
        xe_arr, T_m_arr, 
        out_highengphot_specs, out_lowengphot_specs, out_lowengelec_specs
    )

# %%
#%%prun
# a = evolve(
#         phot_spec_init*0, phot_spec_init, 
#         rate_func_decay_N, rate_func_decay_eng, .9999, phys.TCMB(phot_spec_init.rs),
#         highengphot_tf_interp, lowengphot_tf_interp, 
#         lowengelec_tf_interp, 
#         end_rs, coarsen_factor=1, std_soln=False
#     )

b = evolve(
        phot_spec_init*0, phot_spec_init, 
        rate_func_decay_N, rate_func_decay_eng, xe_std(phot_spec_init.rs), phys.TCMB(phot_spec_init.rs),
        #rate_func_decay_N, rate_func_decay_eng, 2e-4, phys.TCMB(phot_spec_init.rs),
        highengphot_tf_interp, lowengphot_tf_interp, 
        lowengelec_tf_interp, 
        end_rs, coarsen_factor=1, std_soln=True
    )
# Out:
# T_m at 1800: 0.42275759247
# x_e at 1800: 0.9996009039448279
# Standard x_e at 1800: 0.9996009039448279
# Standard T_m at 1800: 0.4227572449750811
# 8.951305216819601e-06
# 5197.9650285883545
#
#  SHOULD ALSO BE ONE:  2.101765466371064
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999891 2.653170530443292e-15 2.7665059830999622e-15 2.9948612513673666e-15 2.561420855122013e-15
# Goods:  3.7267019118106425e-05
# Split by photon and electron deposition!
# f_phot:  [1.79284136e-05 4.33815658e-07 2.72157075e-06 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [9.58417354e-20 9.94023257e-20 7.67244001e-20 1.16170660e-19
#  3.72670191e-05]
#
#  SHOULD BE ONE:  1.000061381842839
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999891 2.653170530443292e-15 2.7665059830999622e-15 2.9948612513673666e-15 2.561420855122013e-15
# Goods:  3.7267019118106425e-05
# Split by photon and electron deposition!
# f_phot:  [1.79284136e-05 4.33815658e-07 2.72157075e-06 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [9.58417354e-20 9.94023257e-20 7.67244001e-20 1.16170660e-19
#  3.72670191e-05]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999896 2.5157292348593044e-15 2.6170650405023784e-15 2.8231311262978063e-15 2.433484644892235e-15
# Goods:  3.7267019118106425e-05
# Split by photon and electron deposition!
# f_phot:  [1.79284136e-05 4.33815658e-07 2.72157075e-06 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [9.10781883e-20 9.42728099e-20 7.37090346e-20 1.09441690e-19
#  3.72670191e-05]
# T_m at 1796.4035976012003: 0.4219125738963531
# x_e at 1796.4035976012003: 0.9995790792703315
# Standard x_e at 1796.4035976012003: 0.9995790683101462
# Standard T_m at 1796.4035976012003: 0.4219125738963149
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.79284136e-05 4.33815658e-07 2.72157075e-06 1.09441690e-19
#  3.72670191e-05]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.79284136e-05 4.33815658e-07 2.72157075e-06 1.16170660e-19
#  3.72670191e-05]
# 1.3239956780827261e-05
# 5198.788804710743
#
#  SHOULD ALSO BE ONE:  2.078991212258484
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999988 2.8063869247342805e-15 2.9335290300965045e-15 3.1872360630035603e-15 2.70375458566544e-15
# Goods:  0.00014417353064701314
# Split by photon and electron deposition!
# f_phot:  [3.03923954e-04 7.60481870e-06 2.33386694e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.59653144e-19 3.73059366e-19 3.03203416e-19 4.52930081e-19
#  1.44173531e-04]
#
#  SHOULD BE ONE:  1.0001162660672267
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999988 2.8063869247342805e-15 2.9335290300965045e-15 3.1872360630035603e-15 2.70375458566544e-15
# Goods:  0.00014417353064701314
# Split by photon and electron deposition!
# f_phot:  [3.03923954e-04 7.60481870e-06 2.33386694e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.59653144e-19 3.73059366e-19 3.03203416e-19 4.52930081e-19
#  1.44173531e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999891 2.6530995553308658e-15 2.766428715685329e-15 2.994772361037088e-15 2.5613548525493078e-15
# Goods:  0.00014417353064701314
# Split by photon and electron deposition!
# f_phot:  [3.03923954e-04 7.60481870e-06 2.33386694e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.41818130e-19 3.53816376e-19 2.90768017e-19 4.26119660e-19
#  1.44173531e-04]
# T_m at 1792.814380819186: 0.4210695904720602
# x_e at 1792.814380819186: 0.9995561191003935
# Standard x_e at 1792.814380819186: 0.9995561118097385
# Standard T_m at 1792.814380819186: 0.4210695904717936
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [3.03923954e-04 7.60481870e-06 2.33386694e-05 4.26119660e-19
#  1.44173531e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [3.03923954e-04 7.60481870e-06 2.33386694e-05 4.52930081e-19
#  1.44173531e-04]
# ../darkhistory/spec/spectrum.py:748: RuntimeWarning: The new abscissa lies below the old one: only bins that lie within the new abscissa will be rebinned, bins above the abscissa will be discarded.
#   warnings.warn("The new abscissa lies below the old one: only bins that lie within the new abscissa will be rebinned, bins above the abscissa will be discarded.", RuntimeWarning)
# 1.537926393996145e-05
# 5199.612728904997
#
#  SHOULD ALSO BE ONE:  2.0688074045904012
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999875 2.9778211226813454e-15 3.120923011983295e-15 3.4035892772964817e-15 2.8626755030692265e-15
# Goods:  0.00025143256749107816
# Split by photon and electron deposition!
# f_phot:  [7.18140345e-04 1.73348912e-05 4.90131612e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [6.41112999e-19 6.65954764e-19 5.51505371e-19 8.24671868e-19
#  2.51432567e-04]
#
#  SHOULD BE ONE:  1.0001212672085396
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999875 2.9778211226813454e-15 3.120923011983295e-15 3.4035892772964817e-15 2.8626755030692265e-15
# Goods:  0.00025143256749107816
# Split by photon and electron deposition!
# f_phot:  [7.18140345e-04 1.73348912e-05 4.90131612e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [6.41112999e-19 6.65954764e-19 5.51505371e-19 8.24671868e-19
#  2.51432567e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999988 2.806336790172931e-15 2.933474305987033e-15 3.1871729598191563e-15 2.703708059552714e-15
# Goods:  0.00025143256749107816
# Split by photon and electron deposition!
# f_phot:  [7.18140345e-04 1.73348912e-05 4.90131612e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [6.08211257e-19 6.30381611e-19 5.27495064e-19 7.73825080e-19
#  2.51432567e-04]
# T_m at 1789.2323352970852: 0.420228291330289
# x_e at 1789.2323352970852: 0.9995319701598366
# Standard x_e at 1789.2323352970852: 0.999531961084445
# Standard T_m at 1789.2323352970852: 0.42022829132979483
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [7.18140345e-04 1.73348912e-05 4.90131612e-05 7.73825080e-19
#  2.51432567e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [7.18140345e-04 1.73348912e-05 4.90131612e-05 8.24671868e-19
#  2.51432567e-04]
# 1.647458591478974e-05
# 5200.436810631536
#
#  SHOULD ALSO BE ONE:  2.063574553187434
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999866 3.170171274326658e-15 3.331790824866542e-15 3.647649164869893e-15 3.0405891911175423e-15
# Goods:  0.0003371533994822068
# Split by photon and electron deposition!
# f_phot:  [1.11906832e-03 2.61229895e-05 7.12757177e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [8.94912863e-19 9.31393865e-19 7.76740575e-19 1.16997171e-18
#  3.37153399e-04]
#
#  SHOULD BE ONE:  1.000121261552837
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999866 3.170171274326658e-15 3.331790824866542e-15 3.647649164869893e-15 3.0405891911175423e-15
# Goods:  0.0003371533994822068
# Split by photon and electron deposition!
# f_phot:  [1.11906832e-03 2.61229895e-05 7.12757177e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [8.94912863e-19 9.31393865e-19 7.76740575e-19 1.16997171e-18
#  3.37153399e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999875 2.977754644953693e-15 3.1208502441786828e-15 3.403505163328748e-15 2.862613943742162e-15
# Goods:  0.0003371533994822068
# Split by photon and electron deposition!
# f_phot:  [1.11906832e-03 2.61229895e-05 7.12757177e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [8.46811170e-19 8.79271279e-19 7.40749367e-19 1.09439438e-18
#  3.37153399e-04]
# T_m at 1785.6574467067112: 0.41938867310601097
# x_e at 1785.6574467067112: 0.9995065771786604
# Standard x_e at 1785.6574467067112: 0.9995065649978474
# Standard T_m at 1785.6574467067112: 0.41938867310534084
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.11906832e-03 2.61229895e-05 7.12757177e-05 1.09439438e-18
#  3.37153399e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.11906832e-03 2.61229895e-05 7.12757177e-05 1.16997171e-18
#  3.37153399e-04]
# 1.705421630215991e-05
# 5201.261055960237
#
#  SHOULD ALSO BE ONE:  2.0605853344525205
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999986 3.386558377484166e-15 3.5697404515072815e-15 3.923765984371008e-15 3.2402678912786127e-15
# Goods:  0.00039863894443184023
# Split by photon and electron deposition!
# f_phot:  [1.45204087e-03 3.28790916e-05 8.78302992e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.11311064e-18 1.16111625e-18 9.69248116e-19 1.47573615e-18
#  3.98638944e-04]
#
#  SHOULD BE ONE:  1.0001199057515087
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999986 3.386558377484166e-15 3.5697404515072815e-15 3.923765984371008e-15 3.2402678912786127e-15
# Goods:  0.00039863894443184023
# Split by photon and electron deposition!
# f_phot:  [1.45204087e-03 3.28790916e-05 8.78302992e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.11311064e-18 1.16111625e-18 9.69248116e-19 1.47573615e-18
#  3.98638944e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999866 3.1700759188185135e-15 3.3316861349393668e-15 3.6475278447219115e-15 3.040501091724873e-15
# Goods:  0.00039863894443184023
# Split by photon and electron deposition!
# f_phot:  [1.45204087e-03 3.28790916e-05 8.78302992e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.05013237e-18 1.09271321e-18 9.21445126e-19 1.37565469e-18
#  3.98638944e-04]
# T_m at 1782.0897007485048: 0.4185507324409484
# x_e at 1782.0897007485048: 0.999479882826732
# Standard x_e at 1782.0897007485048: 0.9994798779236036
# Standard T_m at 1782.0897007485048: 0.41855073244016705
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.45204087e-03 3.28790916e-05 8.78302992e-05 1.37565469e-18
#  3.98638944e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.45204087e-03 3.28790916e-05 8.78302992e-05 1.47573615e-18
#  3.98638944e-04]
# 1.7377178097796066e-05
# 5202.085470069377
#
#  SHOULD ALSO BE ONE:  2.0588440864879556
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999848 3.631029982006733e-15 3.8394517068850236e-15 4.237580841733954e-15 3.4653080420104557e-15
# Goods:  0.00043992087723997554
# Split by photon and electron deposition!
# f_phot:  [1.70557474e-03 3.75844522e-05 9.89949504e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.30221898e-18 1.36181214e-18 1.13343903e-18 1.74881205e-18
#  4.39920877e-04]
#
#  SHOULD BE ONE:  1.0001181401702697
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999848 3.631029982006733e-15 3.8394517068850236e-15 4.237580841733954e-15 3.4653080420104557e-15
# Goods:  0.00043992087723997554
# Split by photon and electron deposition!
# f_phot:  [1.70557474e-03 3.75844522e-05 9.89949504e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.30221898e-18 1.36181214e-18 1.13343903e-18 1.74881205e-18
#  4.39920877e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999986 3.3865172171294402e-15 3.569695118706618e-15 3.9237133119100754e-15 3.2402299541087526e-15
# Goods:  0.00043992087723997554
# Split by photon and electron deposition!
# f_phot:  [1.70557474e-03 3.75844522e-05 9.89949504e-05 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.22440927e-18 1.27709006e-18 1.07392462e-18 1.62408178e-18
#  4.39920877e-04]
# T_m at 1778.5290831514778: 0.41771446598355005
# x_e at 1778.5290831514778: 0.9994518276733724
# Standard x_e at 1778.5290831514778: 0.9994518125580235
# Standard T_m at 1778.5290831514778: 0.4177144659827481
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.70557474e-03 3.75844522e-05 9.89949504e-05 1.62408178e-18
#  4.39920877e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.70557474e-03 3.75844522e-05 9.89949504e-05 1.74881205e-18
#  4.39920877e-04]
# 1.7571225588791823e-05
# 5202.910064165408
#
#  SHOULD ALSO BE ONE:  2.057828078754833
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999833 3.907768598605681e-15 4.145819187725795e-15 4.59504249670581e-15 3.71939252931014e-15
# Goods:  0.00046642802213114594
# Split by photon and electron deposition!
# f_phot:  [1.88710989e-03 4.06164209e-05 1.05960852e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.47270901e-18 1.54432524e-18 1.27800236e-18 2.00236847e-18
#  4.66428022e-04]
#
#  SHOULD BE ONE:  1.00011634615581
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999833 3.907768598605681e-15 4.145819187725795e-15 4.59504249670581e-15 3.71939252931014e-15
# Goods:  0.00046642802213114594
# Split by photon and electron deposition!
# f_phot:  [1.88710989e-03 4.06164209e-05 1.05960852e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.47270901e-18 1.54432524e-18 1.27800236e-18 2.00236847e-18
#  4.66428022e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999848 3.630893422504996e-15 3.839300798570285e-15 4.237405019871367e-15 3.4651824931388468e-15
# Goods:  0.00046642802213114594
# Split by photon and electron deposition!
# f_phot:  [1.88710989e-03 4.06164209e-05 1.05960852e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.37974418e-18 1.44283610e-18 1.20667527e-18 1.85223128e-18
#  4.66428022e-04]
# T_m at 1774.9755796731547: 0.4168798703889679
# x_e at 1774.9755796731547: 0.9994223501417638
# Standard x_e at 1774.9755796731547: 0.9994223479672263
# Standard T_m at 1774.9755796731547: 0.41687987038817137
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.88710989e-03 4.06164209e-05 1.05960852e-04 1.85223128e-18
#  4.66428022e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [1.88710989e-03 4.06164209e-05 1.05960852e-04 2.00236847e-18
#  4.66428022e-04]
# 1.7699968404800528e-05
# 5203.734839623511
#
#  SHOULD ALSO BE ONE:  2.0572405786531034
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999821 4.2226868344619824e-15 4.4957347636572666e-15 5.004500800074401e-15 4.007746454417719e-15
# Goods:  0.00048286108427896793
# Split by photon and electron deposition!
# f_phot:  [2.01055287e-03 4.24295328e-05 1.09990643e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.63497392e-18 1.71951674e-18 1.41192228e-18 2.25048306e-18
#  4.82861084e-04]
#
#  SHOULD BE ONE:  1.0001147148342118
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999821 4.2226868344619824e-15 4.4957347636572666e-15 5.004500800074401e-15 4.007746454417719e-15
# Goods:  0.00048286108427896793
# Split by photon and electron deposition!
# f_phot:  [2.01055287e-03 4.24295328e-05 1.09990643e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.63497392e-18 1.71951674e-18 1.41192228e-18 2.25048306e-18
#  4.82861084e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999833 3.907747377031141e-15 4.145795652753377e-15 4.5950149982681186e-15 3.719373070408779e-15
# Goods:  0.00048286108427896793
# Split by photon and electron deposition!
# f_phot:  [2.01055287e-03 4.24295328e-05 1.09990643e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.52581282e-18 1.60001625e-18 1.32817172e-18 2.07293623e-18
#  4.82861084e-04]
# T_m at 1771.4291760995168: 0.4160469423190445
# x_e at 1771.4291760995168: 0.99939138649909
# Standard x_e at 1771.4291760995168: 0.9993913698995639
# Standard T_m at 1771.4291760995168: 0.41604694231834305
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.01055287e-03 4.24295328e-05 1.09990643e-04 2.07293623e-18
#  4.82861084e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.01055287e-03 4.24295328e-05 1.09990643e-04 2.25048306e-18
#  4.82861084e-04]
# 1.7795362065978766e-05
# 5204.559811372019
#
#  SHOULD ALSO BE ONE:  2.056906140914793
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999805 4.581795761213335e-15 4.896305655200112e-15 5.4746479740992395e-15 4.335625988202416e-15
# Goods:  0.0004926872914220947
# Split by photon and electron deposition!
# f_phot:  [2.09033319e-03 4.34212860e-05 1.12113941e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.79748763e-18 1.89632508e-18 1.54264072e-18 2.50522951e-18
#  4.92687291e-04]
#
#  SHOULD BE ONE:  1.0001133368142863
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999805 4.581795761213335e-15 4.896305655200112e-15 5.4746479740992395e-15 4.335625988202416e-15
# Goods:  0.0004926872914220947
# Split by photon and electron deposition!
# f_phot:  [2.09033319e-03 4.34212860e-05 1.12113941e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.79748763e-18 1.89632508e-18 1.54264072e-18 2.50522951e-18
#  4.92687291e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999821 4.22251115372029e-15 4.495539195441559e-15 5.004271620730039e-15 4.007585813581876e-15
# Goods:  0.0004926872914220947
# Split by photon and electron deposition!
# f_phot:  [2.09033319e-03 4.34212860e-05 1.12113941e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.67068178e-18 1.75710368e-18 1.44556365e-18 2.29748279e-18
#  4.92687291e-04]
# T_m at 1767.8898582449453: 0.4152156784422927
# x_e at 1767.8898582449453: 0.9993588707823959
# Standard x_e at 1767.8898582449453: 0.9993588632231998
# Standard T_m at 1767.8898582449453: 0.41521567844164375
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.09033319e-03 4.34212860e-05 1.12113941e-04 2.29748279e-18
#  4.92687291e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.09033319e-03 4.34212860e-05 1.12113941e-04 2.50522951e-18
#  4.92687291e-04]
# 1.7873609851707467e-05
# 5205.384979763447
#
#  SHOULD ALSO BE ONE:  2.056720715560969
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999789 4.9934271977397495e-15 5.3573572846982746e-15 6.017475182540902e-15 4.7103353539885115e-15
# Goods:  0.0004982672140811091
# Split by photon and electron deposition!
# f_phot:  [2.13891287e-03 4.38912072e-05 1.13065779e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.96760003e-18 2.08262953e-18 1.67649933e-18 2.77773915e-18
#  4.98267214e-04]
#
#  SHOULD BE ONE:  1.0001122352048102
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999789 4.9934271977397495e-15 5.3573572846982746e-15 6.017475182540902e-15 4.7103353539885115e-15
# Goods:  0.0004982672140811091
# Split by photon and electron deposition!
# f_phot:  [2.13891287e-03 4.38912072e-05 1.13065779e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.96760003e-18 2.08262953e-18 1.67649933e-18 2.77773915e-18
#  4.98267214e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999805 4.581708648921721e-15 4.896208293436276e-15 5.4745335290644634e-15 4.335546565988899e-15
# Goods:  0.0004982672140811091
# Split by photon and electron deposition!
# f_phot:  [2.13891287e-03 4.38912072e-05 1.13065779e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.82093442e-18 1.92110931e-18 1.56462310e-18 2.53559238e-18
#  4.98267214e-04]
# T_m at 1764.3576119521638: 0.41438607543388634
# x_e at 1764.3576119521638: 0.9993247347750842
# Standard x_e at 1764.3576119521638: 0.9993247175343262
# Standard T_m at 1764.3576119521638: 0.41438607543308864
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.13891287e-03 4.38912072e-05 1.13065779e-04 2.53559238e-18
#  4.98267214e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.13891287e-03 4.38912072e-05 1.13065779e-04 2.77773915e-18
#  4.98267214e-04]
# 1.7943003450825465e-05
# 5206.134340097361
#
#  SHOULD ALSO BE ONE:  2.0566208626058935
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999977 5.466711940456435e-15 5.889780466855026e-15 6.646369393988752e-15 5.139813859563396e-15
# Goods:  0.0005012072749412685
# Split by photon and electron deposition!
# f_phot:  [2.16659349e-03 4.40556264e-05 1.13348362e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.15169252e-18 2.28538456e-18 1.81886040e-18 3.07819396e-18
#  5.01207275e-04]
#
#  SHOULD BE ONE:  1.0001113899030591
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999977 5.466711940456435e-15 5.889780466855026e-15 6.646369393988752e-15 5.139813859563396e-15
# Goods:  0.0005012072749412685
# Split by photon and electron deposition!
# f_phot:  [2.16659349e-03 4.40556264e-05 1.13348362e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.15169252e-18 2.28538456e-18 1.81886040e-18 3.07819396e-18
#  5.01207275e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999789 4.993209929943404e-15 5.357113423664711e-15 6.017187619642835e-15 4.710137873216213e-15
# Goods:  0.0005012072749412685
# Split by photon and electron deposition!
# f_phot:  [2.16659349e-03 4.40556264e-05 1.13348362e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.98241586e-18 2.09836099e-18 1.69032518e-18 2.79637487e-18
#  5.01207275e-04]
# T_m at 1760.8324230921828: 0.41355812997564767
# x_e at 1760.8324230921828: 0.999288907986021
# Standard x_e at 1760.8324230921828: 0.9992888964826013
# Standard T_m at 1760.8324230921828: 0.41355812997479285
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.16659349e-03 4.40556264e-05 1.13348362e-04 2.79637487e-18
#  5.01207275e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.16659349e-03 4.40556264e-05 1.13348362e-04 3.07819396e-18
#  5.01207275e-04]
# 1.8007832996731243e-05
# 5206.835291737878
#
#  SHOULD ALSO BE ONE:  2.056571299455751
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999746 6.013625647515903e-15 6.507878919781834e-15 7.378922524992419e-15 5.634469461172813e-15
# Goods:  0.0005025621432646287
# Split by photon and electron deposition!
# f_phot:  [2.18090174e-03 4.40609472e-05 1.13289118e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.35612032e-18 2.51164593e-18 1.97480580e-18 3.41731545e-18
#  5.02562143e-04]
#
#  SHOULD BE ONE:  1.000110775818985
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999746 6.013625647515903e-15 6.507878919781834e-15 7.378922524992419e-15 5.634469461172813e-15
# Goods:  0.0005025621432646287
# Split by photon and electron deposition!
# f_phot:  [2.18090174e-03 4.40609472e-05 1.13289118e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.35612032e-18 2.51164593e-18 1.97480580e-18 3.41731545e-18
#  5.02562143e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.999999999999977 5.466552711359379e-15 5.8896009458805896e-15 6.6461570016840986e-15 5.139669597261613e-15
# Goods:  0.0005025621432646287
# Split by photon and electron deposition!
# f_phot:  [2.18090174e-03 4.40609472e-05 1.13289118e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.16057215e-18 2.29486278e-18 1.82709697e-18 3.08880721e-18
#  5.02562143e-04]
# T_m at 1757.3142775642418: 0.4127318387560302
# x_e at 1757.3142775642418: 0.9992513175679603
# Standard x_e at 1757.3142775642418: 0.999251299632046
# Standard T_m at 1757.3142775642418: 0.4127318387551703
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18090174e-03 4.40609472e-05 1.13289118e-04 3.08880721e-18
#  5.02562143e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18090174e-03 4.40609472e-05 1.13289118e-04 3.41731545e-18
#  5.02562143e-04]
# 1.8070330090514467e-05
# 5207.536474139059
#
#  SHOULD ALSO BE ONE:  2.056551662185058
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999716 6.648060707028582e-15 7.228400821347006e-15 8.235848267555539e-15 6.206297945582202e-15
# Goods:  0.0005028848660491036
# Split by photon and electron deposition!
# f_phot:  [2.18635836e-03 4.39746057e-05 1.13039540e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.58664214e-18 2.76795307e-18 2.14870556e-18 3.80541550e-18
#  5.02884866e-04]
#
#  SHOULD BE ONE:  1.0001103406307525
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999716 6.648060707028582e-15 7.228400821347006e-15 8.235848267555539e-15 6.206297945582202e-15
# Goods:  0.0005028848660491036
# Split by photon and electron deposition!
# f_phot:  [2.18635836e-03 4.39746057e-05 1.13039540e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.58664214e-18 2.76795307e-18 2.14870556e-18 3.80541550e-18
#  5.02884866e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999746 6.013351681912959e-15 6.507568572094058e-15 7.378554092126648e-15 5.63422208487211e-15
# Goods:  0.0005028848660491036
# Split by photon and electron deposition!
# f_phot:  [2.18635836e-03 4.39746057e-05 1.13039540e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.36039307e-18 2.51624031e-18 1.97877659e-18 3.42162739e-18
#  5.02884866e-04]
# T_m at 1753.8031612957543: 0.411907198470111
# x_e at 1753.8031612957543: 0.9992118883414876
# Standard x_e at 1753.8031612957543: 0.9992118741159807
# Standard T_m at 1753.8031612957543: 0.4119071984692488
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18635836e-03 4.39746057e-05 1.13039540e-04 3.42162739e-18
#  5.02884866e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18635836e-03 4.39746057e-05 1.13039540e-04 3.80541550e-18
#  5.02884866e-04]
# 1.8131664641076638e-05
# 5208.237893043768
#
#  SHOULD ALSO BE ONE:  2.056549255060081
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999684 7.387801824023174e-15 8.07286948010726e-15 9.243821892206176e-15 6.870620783176194e-15
# Goods:  0.0005025037868734839
# Split by photon and electron deposition!
# f_phot:  [2.18598998e-03 4.38315632e-05 1.12675446e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.84975263e-18 3.06178144e-18 2.34531337e-18 4.25455293e-18
#  5.02503787e-04]
#
#  SHOULD BE ONE:  1.0001100306388535
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999684 7.387801824023174e-15 8.07286948010726e-15 9.243821892206176e-15 6.870620783176194e-15
# Goods:  0.0005025037868734839
# Split by photon and electron deposition!
# f_phot:  [2.18598998e-03 4.38315632e-05 1.12675446e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.84975263e-18 3.06178144e-18 2.34531337e-18 4.25455293e-18
#  5.02503787e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999716 6.647819765584369e-15 7.22812651057803e-15 8.235521459259419e-15 6.2060811585352516e-15
# Goods:  0.0005025037868734839
# Split by photon and electron deposition!
# f_phot:  [2.18598998e-03 4.38315632e-05 1.12675446e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.58720099e-18 2.76858596e-18 2.14930045e-18 3.80454888e-18
#  5.02503787e-04]
# T_m at 1750.2990602422503: 0.41108420581957383
# x_e at 1750.2990602422503: 0.9991705427384217
# Standard x_e at 1750.2990602422503: 0.9991705234976908
# Standard T_m at 1750.2990602422503: 0.41108420581871363
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18598998e-03 4.38315632e-05 1.12675446e-04 3.80454888e-18
#  5.02503787e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18598998e-03 4.38315632e-05 1.12675446e-04 4.25455293e-18
#  5.02503787e-04]
# 1.8192458876715385e-05
# 5208.939560371345
#
#  SHOULD ALSO BE ONE:  2.056556898902239
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999647 8.254156471989557e-15 9.067294254784425e-15 1.0435238923618453e-14 7.64568763759235e-15
# Goods:  0.000501658070464397
# Split by photon and electron deposition!
# f_phot:  [2.18196538e-03 4.36577450e-05 1.12250073e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.15286845e-18 3.40175398e-18 2.56992501e-18 4.77890759e-18
#  5.01658070e-04]
#
#  SHOULD BE ONE:  1.0001098100129462
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999647 8.254156471989557e-15 9.067294254784425e-15 1.0435238923618453e-14 7.64568763759235e-15
# Goods:  0.000501658070464397
# Split by photon and electron deposition!
# f_phot:  [2.18196538e-03 4.36577450e-05 1.12250073e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.15286845e-18 3.40175398e-18 2.56992501e-18 4.77890759e-18
#  5.01658070e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999686 7.387438636808554e-15 8.072453793125425e-15 9.243324827495384e-15 6.870295218805551e-15
# Goods:  0.000501658070464397
# Split by photon and electron deposition!
# f_phot:  [2.18196538e-03 4.36577450e-05 1.12250073e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [2.84719581e-18 3.05906249e-18 2.34313796e-18 4.24920468e-18
#  5.01658070e-04]
# T_m at 1746.8019603873208: 0.41026285751269803
# x_e at 1746.8019603873208: 0.9991272007798588
# Standard x_e at 1746.8019603873208: 0.9991271850522471
# Standard T_m at 1746.8019603873208: 0.41026285751182645
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18196538e-03 4.36577450e-05 1.12250073e-04 4.24920468e-18
#  5.01658070e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.18196538e-03 4.36577450e-05 1.12250073e-04 4.77890759e-18
#  5.01658070e-04]
# 1.8253045785160934e-05
# 5209.641483084771
#
#  SHOULD ALSO BE ONE:  2.056570396244119
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999601 9.274363557381406e-15 1.0245095499172971e-14 1.1851842487432771e-14 8.554754453468413e-15
# Goods:  0.0005005025801968733
# Split by photon and electron deposition!
# f_phot:  [2.17567187e-03 4.34675437e-05 1.11792272e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.50506334e-18 3.79849884e-18 2.82890790e-18 5.39619901e-18
#  5.00502580e-04]
#
#  SHOULD BE ONE:  1.0001096513929748
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999601 9.274363557381406e-15 1.0245095499172971e-14 1.1851842487432771e-14 8.554754453468413e-15
# Goods:  0.0005005025801968733
# Split by photon and electron deposition!
# f_phot:  [2.17567187e-03 4.34675437e-05 1.11792272e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.50506334e-18 3.79849884e-18 2.82890790e-18 5.39619901e-18
#  5.00502580e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999647 8.253823879064347e-15 9.066911443509409e-15 1.0434779424541692e-14 7.645390658584994e-15
# Goods:  0.0005005025801968733
# Split by photon and electron deposition!
# f_phot:  [2.17567187e-03 4.34675437e-05 1.11792272e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.14766622e-18 3.39616580e-18 2.56543584e-18 4.76962230e-18
#  5.00502580e-04]
# T_m at 1743.3118477425623: 0.40944315026434386
# x_e at 1743.3118477425623: 0.9990817800447167
# Standard x_e at 1743.3118477425623: 0.999081758424989
# Standard T_m at 1743.3118477425623: 0.4094431502634791
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.17567187e-03 4.34675437e-05 1.11792272e-04 4.76962230e-18
#  5.00502580e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.17567187e-03 4.34675437e-05 1.11792272e-04 5.39619901e-18
#  5.00502580e-04]
# 1.8313605268610903e-05
# 5210.343673431951
#
#  SHOULD ALSO BE ONE:  2.0565872982915647
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999545 1.0481533530410982e-14 1.1647266047110003e-14 1.3545093678690492e-14 9.625920238816718e-15
# Goods:  0.0004991394192997391
# Split by photon and electron deposition!
# f_phot:  [2.16798277e-03 4.32687900e-05 1.11317410e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.91702941e-18 4.26464683e-18 3.12965445e-18 6.12781412e-18
#  4.99139419e-04]
#
#  SHOULD BE ONE:  1.0001095348177917
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999545 1.0481533530410982e-14 1.1647266047110003e-14 1.3545093678690492e-14 9.625920238816718e-15
# Goods:  0.0004991394192997391
# Split by photon and electron deposition!
# f_phot:  [2.16798277e-03 4.32687900e-05 1.11317410e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.91702941e-18 4.26464683e-18 3.12965445e-18 6.12781412e-18
#  4.99139419e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999601 9.273848539178992e-15 1.0244499194402301e-14 1.185112389823025e-14 8.55429645914862e-15
# Goods:  0.0004991394192997391
# Split by photon and electron deposition!
# f_phot:  [2.16798277e-03 4.32687900e-05 1.11317410e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.49738569e-18 3.79019752e-18 2.82230135e-18 5.38304602e-18
#  4.99139419e-04]
# T_m at 1739.8287083475188: 0.4086250807959404
# x_e at 1739.8287083475188: 0.9990341956482276
# Standard x_e at 1739.8287083475188: 0.9990341799680251
# Standard T_m at 1739.8287083475188: 0.40862508079505927
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.16798277e-03 4.32687900e-05 1.11317410e-04 5.38304602e-18
#  4.99139419e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.16798277e-03 4.32687900e-05 1.11317410e-04 6.12781412e-18
#  4.99139419e-04]
# 1.8374235461565756e-05
# 5211.046138296378
#
#  SHOULD ALSO BE ONE:  2.0566061789495813
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999484 1.191863317744648e-14 1.3327292726839134e-14 1.5582335669945467e-14 1.0895526886470894e-14
# Goods:  0.0004976371102697599
# Split by photon and electron deposition!
# f_phot:  [2.15944183e-03 4.30656700e-05 1.10833569e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [4.40240244e-18 4.81638436e-18 3.48152480e-18 7.00141901e-18
#  4.97637110e-04]
#
#  SHOULD BE ONE:  1.0001094461806346
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999484 1.191863317744648e-14 1.3327292726839134e-14 1.5582335669945467e-14 1.0895526886470894e-14
# Goods:  0.0004976371102697599
# Split by photon and electron deposition!
# f_phot:  [2.15944183e-03 4.30656700e-05 1.10833569e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [4.40240244e-18 4.81638436e-18 3.48152480e-18 7.00141901e-18
#  4.97637110e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999545 1.0481110362744061e-14 1.164677301384282e-14 1.3544497108623048e-14 9.625545533214207e-15
# Goods:  0.0004976371102697599
# Split by photon and electron deposition!
# f_phot:  [2.15944183e-03 4.30656700e-05 1.10833569e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [3.90708444e-18 4.25383811e-18 3.12112779e-18 6.11096085e-18
#  4.97637110e-04]
# T_m at 1736.3525282696287: 0.40780864583547194
# x_e at 1736.3525282696287: 0.9989843602179185
# Standard x_e at 1736.3525282696287: 0.9989843350707891
# Standard T_m at 1736.3525282696287: 0.4078086458346047
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.15944183e-03 4.30656700e-05 1.10833569e-04 6.11096085e-18
#  4.97637110e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.15944183e-03 4.30656700e-05 1.10833569e-04 7.00141901e-18
#  4.97637110e-04]
# 1.843499043567179e-05
# 5211.748891713158
#
#  SHOULD ALSO BE ONE:  2.0566262089797047
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999404 1.3638012467384065e-14 1.53510220404444e-14 1.8046944637790357e-14 1.2407548590094033e-14
# Goods:  0.0004960421880317839
# Split by photon and electron deposition!
# f_phot:  [2.15038509e-03 4.28603882e-05 1.10344989e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [4.97748128e-18 5.47321521e-18 3.89559610e-18 8.05083833e-18
#  4.96042188e-04]
#
#  SHOULD BE ONE:  1.0001093757487058
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999404 1.3638012467384065e-14 1.53510220404444e-14 1.8046944637790357e-14 1.2407548590094033e-14
# Goods:  0.0004960421880317839
# Split by photon and electron deposition!
# f_phot:  [2.15038509e-03 4.28603882e-05 1.10344989e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [4.97748128e-18 5.47321521e-18 3.89559610e-18 8.05083833e-18
#  4.96042188e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999484 1.1917859749427024e-14 1.3326385630961094e-14 1.5581233435715217e-14 1.0894845098592458e-14
# Goods:  0.0004960421880317839
# Split by photon and electron deposition!
# f_phot:  [2.15038509e-03 4.28603882e-05 1.10344989e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [4.39003663e-18 4.80286853e-18 3.47099076e-18 6.98040822e-18
#  4.96042188e-04]
# T_m at 1732.883293604167: 0.40699384211746475
# x_e at 1732.883293604167: 0.998932183872338
# Standard x_e at 1732.883293604167: 0.9989321707235725
# Standard T_m at 1732.883293604167: 0.40699384211656764
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.15038509e-03 4.28603882e-05 1.10344989e-04 6.98040822e-18
#  4.96042188e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.15038509e-03 4.28603882e-05 1.10344989e-04 8.05083833e-18
#  4.96042188e-04]
# 1.8495900316857923e-05
# 5212.451938831931
#
#  SHOULD ALSO BE ONE:  2.0566469069628113
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999314 1.5709412902860796e-14 1.7806625381070447e-14 2.1050865567050032e-14 1.4220392898222356e-14
# Goods:  0.0004943863952020307
# Split by photon and electron deposition!
# f_phot:  [2.14101929e-03 4.26540923e-05 1.09853918e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [5.66380573e-18 6.26100453e-18 4.38647061e-18 9.32124595e-18
#  4.94386395e-04]
#
#  SHOULD BE ONE:  1.0001093169389834
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999314 1.5709412902860796e-14 1.7806625381070447e-14 2.1050865567050032e-14 1.4220392898222356e-14
# Goods:  0.0004943863952020307
# Split by photon and electron deposition!
# f_phot:  [2.14101929e-03 4.26540923e-05 1.09853918e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [5.66380573e-18 6.26100453e-18 4.38647061e-18 9.32124595e-18
#  4.94386395e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999404 1.3637548751839816e-14 1.535047437950058e-14 1.80462762449767e-14 1.2407141733502184e-14
# Goods:  0.0004943863952020307
# Split by photon and electron deposition!
# f_phot:  [2.14101929e-03 4.26540923e-05 1.09853918e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [4.96281338e-18 5.45710411e-18 3.88314985e-18 8.02571436e-18
#  4.94386395e-04]
# T_m at 1729.42099047419: 0.4061806663829742
# x_e at 1729.42099047419: 0.998877574201299
# Standard x_e at 1729.42099047419: 0.9988775449628787
# Standard T_m at 1729.42099047419: 0.4061806663820943
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.14101929e-03 4.26540923e-05 1.09853918e-04 8.02571436e-18
#  4.94386395e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.14101929e-03 4.26540923e-05 1.09853918e-04 9.32124595e-18
#  4.94386395e-04]
# 1.855698211412368e-05
# 5213.15529730351
#
#  SHOULD ALSO BE ONE:  2.0566679938550223
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.99999999999992 1.8217365022699212e-14 2.0802304040414656e-14 2.4732387114205594e-14 1.6404272227367234e-14
# Goods:  0.0004926913245172894
# Split by photon and electron deposition!
# f_phot:  [2.13147129e-03 4.24473782e-05 1.09361594e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [6.48703308e-18 7.21084134e-18 4.97138550e-18 1.08678175e-17
#  4.92691325e-04]
#
#  SHOULD BE ONE:  1.000109265379278
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.99999999999992 1.8217365022699212e-14 2.0802304040414656e-14 2.4732387114205594e-14 1.6404272227367234e-14
# Goods:  0.0004926913245172894
# Split by photon and electron deposition!
# f_phot:  [2.13147129e-03 4.24473782e-05 1.09361594e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [6.48703308e-18 7.21084134e-18 4.97138550e-18 1.08678175e-17
#  4.92691325e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999314 1.5708222881553676e-14 1.7805209563173455e-14 2.1049129792067017e-14 1.4219353914269302e-14
# Goods:  0.0004926913245172894
# Split by photon and electron deposition!
# f_phot:  [2.13147129e-03 4.24473782e-05 1.09361594e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [5.64626645e-18 6.24162361e-18 4.37169873e-18 9.29079368e-18
#  4.92691325e-04]
# T_m at 1725.9656050304807: 0.4053691153795711
# x_e at 1725.9656050304807: 0.9988204362479474
# Standard x_e at 1725.9656050304807: 0.9988204298878869
# Standard T_m at 1725.9656050304807: 0.40536911537864095
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.13147129e-03 4.24473782e-05 1.09361594e-04 9.29079368e-18
#  4.92691325e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.13147129e-03 4.24473782e-05 1.09361594e-04 1.08678175e-17
#  4.92691325e-04]
# 1.8618245598609053e-05
# 5213.858968501645
#
#  SHOULD ALSO BE ONE:  2.056689308277437
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999056 2.1278324227621978e-14 2.4487765586421186e-14 2.9283270525614065e-14 1.9055691360252062e-14
# Goods:  0.0004909715571623115
# Split by photon and electron deposition!
# f_phot:  [2.12181878e-03 4.22405587e-05 1.08868737e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [7.48239216e-18 8.36551222e-18 5.67401134e-18 1.27668756e-17
#  4.90971557e-04]
#
#  SHOULD BE ONE:  1.0001092182175473
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999056 2.1278324227621978e-14 2.4487765586421186e-14 2.9283270525614065e-14 1.9055691360252062e-14
# Goods:  0.0004909715571623115
# Split by photon and electron deposition!
# f_phot:  [2.12181878e-03 4.22405587e-05 1.08868737e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [7.48239216e-18 8.36551222e-18 5.67401134e-18 1.27668756e-17
#  4.90971557e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.99999999999992 1.821706430003477e-14 2.0801943476484893e-14 2.4731942992537584e-14 1.6404011019458357e-14
# Goods:  0.0004909715571623115
# Split by photon and electron deposition!
# f_phot:  [2.12181878e-03 4.22405587e-05 1.08868737e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [6.46682930e-18 7.18840563e-18 4.95441999e-18 1.08322514e-17
#  4.90971557e-04]
# T_m at 1722.5171234514928: 0.40455918586132933
# x_e at 1722.5171234514928: 0.9987606724920923
# Standard x_e at 1722.5171234514928: 0.9987606398541891
# Standard T_m at 1722.5171234514928: 0.40455918586044687
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.12181878e-03 4.22405587e-05 1.08868737e-04 1.08322514e-17
#  4.90971557e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.12181878e-03 4.22405587e-05 1.08868737e-04 1.27668756e-17
#  4.90971557e-04]
# 1.867969652086904e-05
# 5214.56297595018
#
#  SHOULD ALSO BE ONE:  2.05671075708159
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998885 2.503336939174442e-14 2.90469931000558e-14 3.494095410655872e-14 2.229045392710189e-14
# Goods:  0.0004892368265295107
# Split by photon and electron deposition!
# f_phot:  [2.11210933e-03 4.20338041e-05 1.08375801e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [8.69180065e-18 9.77645110e-18 6.52226210e-18 1.51118283e-17
#  4.89236827e-04]
#
#  SHOULD BE ONE:  1.0001091736277625
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998885 2.503336939174442e-14 2.90469931000558e-14 3.494095410655872e-14 2.229045392710189e-14
# Goods:  0.0004892368265295107
# Split by photon and electron deposition!
# f_phot:  [2.11210933e-03 4.20338041e-05 1.08375801e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [8.69180065e-18 9.77645110e-18 6.52226210e-18 1.51118283e-17
#  4.89236827e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999999056 2.1276518868842494e-14 2.4485583238862518e-14 2.9280569375658505e-14 1.905413164307091e-14
# Goods:  0.0004892368265295107
# Split by photon and electron deposition!
# f_phot:  [2.11210933e-03 4.20338041e-05 1.08375801e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [7.45825217e-18 8.33852544e-18 5.65392034e-18 1.27235982e-17
#  4.89236827e-04]
# T_m at 1719.0755319432956: 0.40375087458881237
# x_e at 1719.0755319432956: 0.9986981828353603
# Standard x_e at 1719.0755319432956: 0.9986981712975871
# Standard T_m at 1719.0755319432956: 0.4037508745878908
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.11210933e-03 4.20338041e-05 1.08375801e-04 1.27235982e-17
#  4.89236827e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.11210933e-03 4.20338041e-05 1.08375801e-04 1.51118283e-17
#  4.89236827e-04]
# 1.8741338385249623e-05
# 5215.2673173718085
#
#  SHOULD ALSO BE ONE:  2.056732286734164
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998672 2.967891386958678e-14 3.4737429211029867e-14 4.203854392704261e-14 2.62693368759532e-14
# Goods:  0.0004874935573189037
# Split by photon and electron deposition!
# f_phot:  [2.10237201e-03 4.18272126e-05 1.07883083e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.01734457e-17 1.15152444e-17 7.55489727e-18 1.80334129e-17
#  4.87493557e-04]
#
#  SHOULD BE ONE:  1.0001091304622562
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998672 2.967891386958678e-14 3.4737429211029867e-14 4.203854392704261e-14 2.62693368759532e-14
# Goods:  0.0004874935573189037
# Split by photon and electron deposition!
# f_phot:  [2.10237201e-03 4.18272126e-05 1.07883083e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.01734457e-17 1.15152444e-17 7.55489727e-18 1.80334129e-17
#  4.87493557e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998885 2.503261743648692e-14 2.904607628426088e-14 3.493981363601378e-14 2.2289807929981405e-14
# Goods:  0.0004874935573189037
# Split by photon and electron deposition!
# f_phot:  [2.10237201e-03 4.18272126e-05 1.07883083e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [8.66393500e-18 9.74512823e-18 6.49915183e-18 1.50610229e-17
#  4.87493557e-04]
# T_m at 1715.640816739518: 0.40294417832906004
# x_e at 1715.640816739518: 0.9986328645876726
# Standard x_e at 1715.640816739518: 0.9986328315694547
# Standard T_m at 1715.640816739518: 0.40294417832817936
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.10237201e-03 4.18272126e-05 1.07883083e-04 1.50610229e-17
#  4.87493557e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.10237201e-03 4.18272126e-05 1.07883083e-04 1.80334129e-17
#  4.87493557e-04]
# 1.880317343461156e-05
# 5215.972016950904
#
#  SHOULD ALSO BE ONE:  2.056753866497309
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998403 3.5461791220825644e-14 4.188707947019377e-14 5.100344014371913e-14 3.1192592973971766e-14
# Goods:  0.00048574592512058316
# Split by photon and electron deposition!
# f_phot:  [2.09262460e-03 4.16208456e-05 1.07390792e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.19993315e-17 1.36713199e-17 8.81955619e-18 2.16977023e-17
#  4.85745925e-04]
#
#  SHOULD BE ONE:  1.0001090880134529
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998403 3.5461791220825644e-14 4.188707947019377e-14 5.100344014371913e-14 3.1192592973971766e-14
# Goods:  0.00048574592512058316
# Split by photon and electron deposition!
# f_phot:  [2.09262460e-03 4.16208456e-05 1.07390792e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.19993315e-17 1.36713199e-17 8.81955619e-18 2.16977023e-17
#  4.85745925e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998672 2.967635932116474e-14 3.473428631788323e-14 4.2034613995192916e-14 2.626715516475935e-14
# Goods:  0.00048574592512058316
# Split by photon and electron deposition!
# f_phot:  [2.09262460e-03 4.16208456e-05 1.07390792e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.01400859e-17 1.14774821e-17 7.52746576e-18 1.79713587e-17
#  4.85745925e-04]
# T_m at 1712.212964101295: 0.40213909385557606
# x_e at 1712.212964101295: 0.998564612454687
# Standard x_e at 1712.212964101295: 0.9985645866356678
# Standard T_m at 1712.212964101295: 0.402139093854672
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.09262460e-03 4.16208456e-05 1.07390792e-04 1.79713587e-17
#  4.85745925e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.09262460e-03 4.16208456e-05 1.07390792e-04 2.16977023e-17
#  4.85745925e-04]
# 1.8865203201091295e-05
# 5216.677076463574
#
#  SHOULD ALSO BE ONE:  2.0567754788938166
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998067 4.2718811746920086e-14 5.0947265274602525e-14 6.242622912897392e-14 3.7332102418083e-14
# Goods:  0.00048399661656937416
# Split by photon and electron deposition!
# f_phot:  [2.08287797e-03 4.14147438e-05 1.06899068e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.42670304e-17 1.63664757e-17 1.03806818e-17 2.63330682e-17
#  4.83996617e-04]
#
#  SHOULD BE ONE:  1.0001090458511959
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998067 4.2718811746920086e-14 5.0947265274602525e-14 6.242622912897392e-14 3.7332102418083e-14
# Goods:  0.00048399661656937416
# Split by photon and electron deposition!
# f_phot:  [2.08287797e-03 4.14147438e-05 1.06899068e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.42670304e-17 1.63664757e-17 1.03806818e-17 2.63330682e-17
#  4.83996617e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998403 3.54594015777071e-14 4.18841113928406e-14 5.099970883065134e-14 3.119056460825667e-14
# Goods:  0.00048399661656937416
# Split by photon and electron deposition!
# f_phot:  [2.08287797e-03 4.14147438e-05 1.06899068e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.19600317e-17 1.36265473e-17 8.78740915e-18 2.16231707e-17
#  4.83996617e-04]
# T_m at 1708.7919603172115: 0.40133561794831474
# x_e at 1708.7919603172115: 0.9984933185271531
# Standard x_e at 1708.7919603172115: 0.9984932919882463
# Standard T_m at 1708.7919603172115: 0.4013356179473983
# Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.08287797e-03 4.14147438e-05 1.06899068e-04 2.16231707e-17
#  4.83996617e-04]
# Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat:  [2.08287797e-03 4.14147438e-05 1.06899068e-04 2.63330682e-17
#  4.83996617e-04]
# 1.8927428814798225e-05
# 5217.382513027576
#
#  SHOULD ALSO BE ONE:  2.056797113958169
#
# ************************ END OF LOOP **************************
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999997631 5.1897890801385227e-14 6.252519634082003e-14 7.710614681463482e-14 4.5046805936095364e-14
# Goods:  0.0004822473306019645
# Split by photon and electron deposition!
# f_phot:  [2.07313872e-03 4.12089352e-05 1.06408010e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.71048505e-17 1.97620921e-17 1.23226920e-17 3.22462757e-17
#  4.82247331e-04]
#
#  SHOULD BE ONE:  1.0001090037180957
#
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999997631 5.1897890801385227e-14 6.252519634082003e-14 7.710614681463482e-14 4.5046805936095364e-14
# Goods:  0.0004822473306019645
# Split by photon and electron deposition!
# f_phot:  [2.07313872e-03 4.12089352e-05 1.06408010e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.71048505e-17 1.97620921e-17 1.23226920e-17 3.22462757e-17
#  4.82247331e-04]
# Normalized electron heat, lyman, ionH, ionHe, cont:  0.9999999999998067 4.2715849669093123e-14 5.0943549275432685e-14 6.242153154799153e-14 3.7329604257318525e-14
# Goods:  0.0004822473306019645
# Split by photon and electron deposition!
# f_phot:  [2.07313872e-03 4.12089352e-05 1.06408010e-04 0.00000000e+00
#  0.00000000e+00]
# f_elec:  [1.42201425e-17 1.63126872e-17 1.03425602e-17 2.62423070e-17
#  4.82247331e-04]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-1ab25b8ff759> in <module>()
#      14         highengphot_tf_interp, lowengphot_tf_interp,
#      15         lowengelec_tf_interp,
# ---> 16         end_rs, coarsen_factor=1, std_soln=True
#      17     )
#
# <ipython-input-27-99bf1b9ac030> in evolve(in_spec_elec, in_spec_phot, rate_func_N, rate_func_eng, xe_init, T_m_init, highengphot_tf_interp, lowengphot_tf_interp, lowengelec_tf_interp, end_rs, coarsen_factor, std_soln)
#     162                 init_cond, f_raw[2], f_raw[1], f_raw[4],
#     163                 rate_func_eng, np.array([prev_rs, rs]),
# --> 164                 reion_switch = False
#     165             )
#     166
#
# ~/GitHub/DarkHistory/darkhistory/history/tla.py in get_history(init_cond, f_H_ion_in, f_H_exc_in, f_heating_in, dm_injection_rate, rs_vec, reion_switch)
#     394
#     395         soln = odeint(
# --> 396                 tla_before_reion, init_cond, rs_vec, mxstep = 1000
#     397             )
#     398
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/scipy/integrate/odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg)
#     213     output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     214                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
# --> 215                              ixpr, mxstep, mxhnil, mxordn, mxords)
#     216     if output[-1] < 0:
#     217         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# ~/GitHub/DarkHistory/darkhistory/history/tla.py in tla_before_reion(var, rs)
#     197         return [
#     198             dT_dz(yHII, yHeII, yHeIII, T_m, rs),
# --> 199             dyHII_dz(yHII, yHeII, yHeIII, T_m, rs),
#     200             dyHeII_dz(yHII, yHeII, yHeIII, T_m, rs),
#     201             dyHeIII_dz(yHII, yHeII, yHeIII, T_m, rs)
#
# ~/GitHub/DarkHistory/darkhistory/history/tla.py in dyHII_dz(yHII, yHeII, yHeIII, T_m, rs)
#     174                 + f_H_ion(rs, xHI, xHeI, xHeII(yHeII)) * dm_injection_rate(rs)
#     175                     / (phys.rydberg * phys.nH * rs**3)
# --> 176                 + (1 - phys.peebles_C(xHII(yHII), rs)) * (
#     177                     f_H_exc(rs, xHI, xHeI, xHeII(yHeII)) * dm_injection_rate(rs)
#     178                     / (phys.lya_eng * phys.nH * rs**3)
#
# ~/GitHub/DarkHistory/darkhistory/physics.py in peebles_C(xe, rs)
#     312     rate_2s1s = width_2s1s
#     313
# --> 314     rate_exc = (3*rate_2p1s_times_x1s(xe, rs)/4 + (1-xe) * rate_2s1s/4)
#     315
#     316     # Net rate for ionization.
#
# KeyboardInterrupt:

# %%
plt.figure()
# plt.plot(a[3].rs, a[0])
plt.plot(b[3].rs, b[0])
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')


plt.figure()
# plt.plot(a[3].rs, a[1]/phys.kB)
plt.plot(b[3].rs, b[1]/phys.kB)
plt.plot(b[3].rs, phys.TCMB(b[3].rs)/phys.kB, 'k:')
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')

# %%
test_tf = highengphot_tf_interp.get_tf(4, xe_std(3000))
highengphot_tf_interp.xe
# Out:
# array([4.53978687e-05, 2.74578156e-04, 1.65880108e-03, 9.95180187e-03,
#        5.73241759e-02, 2.68941421e-01, 6.89974481e-01, 9.30861580e-01,
#        9.87871565e-01, 9.97974680e-01, 9.99664650e-01])

# %%
plt.figure()

ax = plt.gca()

print(test_tf.in_eng[375])

test_tf.plot(ax, ind=250, indtype='ind')
test_tf.plot(ax, ind=377, indtype='ind')


ax.set_xscale('log')
ax.set_yscale('log')
plt.axis([1e-4, 7e12, 1e-42, 1e7])
# Out:
# 269494554.2705443
# [0.0001, 7000000000000.0, 1e-42, 10000000.0]

# %%
test_spectra = highengphot_tf_interp._grid_vals[-1,-1,:,:]

plt.figure()
ax = plt.gca()

plt.plot(highengphot_tf_interp.eng, test_spectra[370, :])

ax.set_xscale('log')
ax.set_yscale('log')
plt.axis([1e-4, 7e12, 1e-42, 1e7])
# Out:
# [0.0001, 7000000000000.0, 1e-42, 10000000.0]

# %%
tf_before_interp = highengphot_tflist_arr[-1][-1]
tf_before_interp_2 = highengphot_tflist_arr[-1][0]

# print(tf_before_interp.in_eng[376])

plt.figure()
ax = plt.gca()
# tf_before_interp.plot(ax, ind=200, indtype='ind')
tf_before_interp.plot(ax, ind=370, indtype='ind')
# tf_before_interp_2.plot(ax, ind=376, indtype='ind')


ax.set_xscale('log')
ax.set_yscale('log')
plt.axis([1e-4, 7e12, 1e-42, 1e7])
# Out:
# [0.0001, 7000000000000.0, 1e-42, 10000000.0]

# %%
b = np.array([1, 2, 3, 4, 5, 6])
b[0:-1:2]
# Out:
# array([1, 3, 5])
