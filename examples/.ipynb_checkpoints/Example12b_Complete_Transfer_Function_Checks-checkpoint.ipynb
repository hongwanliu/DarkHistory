# %% [markdown]
# -What about electrons? (I don't see any - 2 phys.me)
#
# -1e11 and mDM?
#
# -Compute T(E,z_in, z_dep) by doing a delta function injection

# %% [markdown]
# # Full Transfer Functions

# %%
# %load_ext autoreload
import sys
sys.path.append("..")

# %%
# %autoreload

import matplotlib
matplotlib.rc_file('matplotlibrc')
import matplotlib.pyplot as plt

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [10,10]


from astropy.io import fits

import numpy as np
from numpy.linalg import matrix_power
import copy
import pickle

import darkhistory.physics as phys
import darkhistory.utilities as utils
import darkhistory.spec.spectools as spectools
import darkhistory.spec.transferfunction as tf
import darkhistory.spec.transferfunclist as tflist
from darkhistory.spec.spectrum import Spectrum
from darkhistory.spec.spectra import Spectra
import darkhistory.history.tla as tla

from scipy.interpolate import interp1d

from tqdm import tqdm_notebook as tqdm

from darkhistory.electrons.ics.ics_spectrum import ics_spec
from darkhistory.electrons.ics.ics_spectrum import nonrel_spec
from darkhistory.electrons.ics.ics_spectrum import rel_spec
from darkhistory.electrons.ics.ics_engloss_spectrum import engloss_spec
from darkhistory.electrons.ics.ics_engloss_spectrum import scattered_elec_spec
from darkhistory.electrons.ics.ics_cooling import get_ics_cooling_tf

from darkhistory.electrons import positronium as pos

from darkhistory.low_energy.lowE_deposition import compute_fs

# np.set_printoptions(threshold=np.nan)

# %%
soln = pickle.load(open("../darkhistory/history/std_soln.p", "rb"))
xe_std  = interp1d(soln[0,:], soln[2,:])
T_m_std = interp1d(soln[0,:], soln[1,:])

# %% [markdown]
# ## Photon Transfer Functions

# %%
user = 'hongwan'

highengphot_tflist_arr = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_photspec_60eV_complete_coarse.raw", "rb"))
lowengphot_tflist_arr  = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_lowengphotspec_60eV_complete_coarse.raw", "rb"))
lowengelec_tflist_arr  = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/tfunclist_lowengelecspec_60eV_complete_coarse.raw", "rb"))
CMB_engloss_arr = pickle.load(open("/Users/"+user+"/Dropbox (MIT)/Photon Deposition/CMB_engloss_60eV_complete_coarse.raw", "rb"))

# %%
photeng = highengphot_tflist_arr[0].eng
eleceng = lowengelec_tflist_arr[0].eng

#Split photeng into high and low energy. 
photeng_high = photeng[photeng > 60]
photeng_low  = photeng[photeng <= 60]

# Split eleceng into high and low energy. 
eleceng_high = eleceng[eleceng > 3000]
eleceng_low  = eleceng[eleceng <= 3000]


for highengphot_tflist in highengphot_tflist_arr:
    
#     highengphot_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)

    for tf in highengphot_tflist:
        # tf.rebin(photeng_high)
#         tf.rebin(photeng)
        
        # Pad with zeros so that it becomes photeng x photeng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size, 0), (0, 0)), 'constant')
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = photeng
        tf._rs = tf.rs[0]*np.ones_like(photeng)
    
    highengphot_tflist._eng = photeng
    highengphot_tflist._in_eng = photeng
    highengphot_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in highengphot_tflist._tflist])
    )
    
# lowengphot_tflist.in_eng set to photeng_high
for lowengphot_tflist in lowengphot_tflist_arr:
    
#     lowengphot_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)
    
    for tf in lowengphot_tflist:
#         tf.rebin(photeng)
        # Pad with zeros so that it becomes photeng x photeng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size,0), (0,0)), 'constant')
        # Photons in the low energy bins should be immediately deposited.
        tf._grid_vals[0:photeng_low.size, 0:photeng_low.size] = np.identity(photeng_low.size)
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = photeng
        tf._rs = tf.rs[0]*np.ones_like(photeng)
    
    lowengphot_tflist._eng = photeng
    lowengphot_tflist._in_eng = photeng
    lowengphot_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in lowengphot_tflist._tflist])
    )
    
# lowengelec_tflist.in_eng set to photeng_high 
for lowengelec_tflist in lowengelec_tflist_arr:
    
#     lowengelec_tflist.at_val('in_eng', photeng_high, bounds_error=False, fill_value=0)
    
    for tf in lowengelec_tflist:
#         tf.rebin(eleceng)
        # Pad with zeros so that it becomes photeng x eleceng. 
        tf._grid_vals = np.pad(tf.grid_vals, ((photeng_low.size,0), (0,0)), 'constant')
        tf._N_underflow = np.pad(tf._N_underflow, (photeng_low.size, 0), 'constant')
        tf._eng_underflow = np.pad(tf._eng_underflow, (photeng_low.size, 0), 'constant')
        tf._in_eng = photeng
        tf._eng = eleceng
        tf._rs = tf.rs[0]*np.ones_like(photeng)

    lowengelec_tflist._eng = eleceng
    lowengelec_tflist._in_eng = photeng
    lowengelec_tflist._grid_vals = np.atleast_3d(
        np.stack([tf.grid_vals for tf in lowengelec_tflist._tflist])
    )
    
    for engloss in CMB_engloss_arr:
        engloss = np.pad(engloss, ((0,0),(photeng_low.size, 0)), 'constant')

# %%
xes = 0.5 + 0.5*np.tanh([-5., -4.1, -3.2, -2.3, -1.4, -0.5, 0.4, 1.3, 2.2, 3.1, 4])

highengphot_tf_interp = tflist.TransferFuncInterp(xes, highengphot_tflist_arr)
lowengphot_tf_interp = tflist.TransferFuncInterp(xes, lowengphot_tflist_arr)
lowengelec_tf_interp = tflist.TransferFuncInterp(xes, lowengelec_tflist_arr)

# %% [markdown]
# ## Inverse Compton Scattering

# %% [markdown]
# Set up all of the inverse Compton scattering transfer functions (needs to be hidden away at some point).

# %%
# %%prun

Emax = 1e20
Emin = 1e-8
nEe = 5000
nEp  = 5000

dlnEp = np.log(Emax/Emin)/nEp
lowengEp_rel = Emin*np.exp((np.arange(nEp)+0.5)*dlnEp)        

dlnEe = np.log(Emax/Emin)/nEe
lowengEe_rel = Emin*np.exp((np.arange(nEe)+0.5)*dlnEe)

Emax = 1e10
Emin = 1e-8
nEe = 5000
nEp  = 5000

dlnEp = np.log(Emax/Emin)/nEp
lowengEp_nonrel = Emin*np.exp((np.arange(nEp)+0.5)*dlnEp)  

dlnEe = np.log(Emax/Emin)/nEe
lowengEe_nonrel = Emin*np.exp((np.arange(nEe)+0.5)*dlnEe)

# print('********* Thomson regime scattered photon spectrum *********')
# ics_thomson_ref_tf = nonrel_spec(lowengEe_nonrel, lowengEp_nonrel, phys.TCMB(400))
# print('********* Relativistic regime scattered photon spectrum *********')
# ics_rel_ref_tf = rel_spec(lowengEe_rel, lowengEp_rel, phys.TCMB(400), inf_upp_bound=True)
# print('********* Thomson regime energy loss spectrum *********')
# engloss_ref_tf = engloss_spec(lowengEe_nonrel, lowengEp_nonrel, phys.TCMB(400), nonrel=True)
print('********* Thomson regime scattered electron spectrum *********')
scattered_elec_spec_nonrel_ref_tf = scattered_elec_spec(lowengEe_nonrel, lowengEe_nonrel, phys.TCMB(400), nonrel=True)
print('********* Relativistic regime scattered electron spectrum *********')
scattered_elec_spec_rel_ref_tf = scattered_elec_spec(lowengEe_rel, lowengEe_rel, phys.TCMB(400), nonrel=False)
# Out:
# ********* Thomson regime scattered electron spectrum *********
# Computing nonrelativistic scattered electron spectrum...
# Computing energy loss spectrum by beta expansion...
# Computing integrals 1/6...
# Computing integrals 2/6...
# Computing integrals 3/6...
# Computing integrals 4/6...
# Computing integrals 5/6...
# Computing integrals 6/6...
# Integrals computed!
# Computation by expansion in beta complete!
# Computing energy loss spectrum by analytic series...
# Computing upscattering loss spectra...
# Computing series 1/7...
# Computing series 2/7...
# Computing series 3/7...
# Computing series 4/7...
# Computing series 5/7...
# Computing series 6/7...
# Computing series 7/7...
# Computing downscattering loss spectra...
# Computing series 1/7...
# Computing series 2/7...
# Computing series 3/7...
# Computing series 4/7...
# Computing series 5/7...
# Computing series 6/7...
# Computing series 7/7...
# Computing additional spectra for new spec_type...
# Computing series 1/2...
# Computing series 2/2...
# Nonrelativistic energy loss spectrum computed!
# ********* Relativistic regime scattered electron spectrum *********
# Computing scattered electron spectrum...
# Initializing...
# Computing series 1/4...
# Computing series 2/4...
# Computing series 3/4...
# Computing series 4/4...
# Relativistic Computation Complete!
# Relativistic energy loss spectrum complete!

# %%
# pickle.dump(ics_thomson_ref_tf, open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/ics_thomson_ref_tf.p", "wb"))
# pickle.dump(ics_rel_ref_tf,     open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/ics_rel_ref_tf.p", "wb"))
# pickle.dump(engloss_ref_tf,     open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/engloss_ref_tf.p", "wb"))
pickle.dump(scattered_elec_spec_nonrel_ref_tf, open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/scattered_elec_spec_nonrel_ref_tf.p", "wb"))
pickle.dump(scattered_elec_spec_rel_ref_tf, open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/scattered_elec_spec_rel_ref_tf.p", "wb"))

# %%
ics_thomson_ref_tf_2 = pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/ics_thomson_ref_tf.p", "rb"))
ics_rel_ref_tf_2 = pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/ics_rel_ref_tf.p", "rb"))
engloss_ref_tf_2 = pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/engloss_ref_tf.p", "rb"))
scattered_elec_spec_nonrel_ref_tf_2 = pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/scattered_elec_spec_nonrel_ref_tf.p", "rb"))
scattered_elec_spec_rel_ref_tf_2 = pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/scattered_elec_spec_rel_ref_tf.p", "rb"))

# %%
# %%prun
start_rs = 3000
rs = start_rs
while rs > 2995:
    (ics_sec_phot_tf, ics_sec_elec_tf, continuum_loss) = get_ics_cooling_tf(
        ics_thomson_ref_tf_2, ics_rel_ref_tf_2, engloss_ref_tf_2,
        scattered_elec_spec_nonrel_ref_tf_2, scattered_elec_spec_rel_ref_tf_2,
        eleceng, photeng, rs, fast=False
    )
    rs = np.exp(np.log(rs) - 0.002)
    print(rs)
# Out:
# -------- Injection Energy:  3016.701062885404
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116779645287843
# -------- Energy lost (Analytic):  0.006646204414631108
# -------- Energy lost (Computed from photons):  0.006645554162929673
# -------- Energy lost (Computed from electrons):  0.006645554162915346
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320873900173605e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4275888100703888
# -------- Energy in secondary photons (Analytic):  0.4275788820369999
# -------- Energy gain from photons:  0.006656132448020047
# -------- Deposited Energy:  -1.0578285104700935e-05
# -------- Injection Energy:  3199.0671427921043
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677817093105
# -------- Energy lost (Analytic):  0.007049235739192005
# -------- Energy lost (Computed from photons):  0.007048742693093935
# -------- Energy lost (Computed from electrons):  0.007048742693100962
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208731865409376e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4279918426984146
# -------- Energy in secondary photons (Analytic):  0.4279819133615608
# -------- Energy gain from photons:  0.00705916507604587
# -------- Deposited Energy:  -1.0422382944907937e-05
# -------- Injection Energy:  3392.457645207818
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116770866751867
# -------- Energy lost (Analytic):  0.007476787365768486
# -------- Energy lost (Computed from photons):  0.007476427492636571
# -------- Energy lost (Computed from electrons):  0.007476427492619564
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320872429767637e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.42841932755419077
# -------- Energy in secondary photons (Analytic):  0.42840946498813726
# -------- Energy gain from photons:  0.00748664993182202
# -------- Deposited Energy:  -1.0222439202456357e-05
# -------- Injection Energy:  3597.5390202295966
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116771034540667
# -------- Energy lost (Analytic):  0.007930361054285384
# -------- Energy lost (Computed from photons):  0.007930105572570186
# -------- Energy lost (Computed from electrons):  0.007930105572569346
# -------- Energy lost (Computed from electrons DIRECT):  -7.65432087162724576e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4288729177239738
# -------- Energy in secondary photons (Analytic):  0.4288630386766541
# -------- Energy gain from photons:  0.007940240101605045
# -------- Deposited Energy:  -1.0134529035699114e-05
# -------- Injection Energy:  3815.018006298924
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677115286066
# -------- Energy lost (Analytic):  0.008411551772560652
# -------- Energy lost (Computed from photons):  0.008411392492746972
# -------- Energy lost (Computed from electrons):  0.008411392492746472
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208707762097054e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4293541182426063
# -------- Energy in secondary photons (Analytic):  0.4293442293949294
# -------- Energy gain from photons:  0.00842144062023753
# -------- Deposited Energy:  -1.004812749105799e-05
# -------- Injection Energy:  4045.6440657192725
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116771526984416
# -------- Energy lost (Analytic):  0.008922053632763589
# -------- Energy lost (Computed from photons):  0.008921968440867279
# -------- Energy lost (Computed from electrons):  0.00892196844088744
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320869873726688e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.42986463582877943
# -------- Energy in secondary photons (Analytic):  0.42985473125513235
# -------- Energy gain from photons:  0.008931958206410684
# -------- Deposited Energy:  -9.989765523243932e-06
# -------- Injection Energy:  4290.211967405048
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677191672424
# -------- Energy lost (Analytic):  0.009463666224339485
# -------- Energy lost (Computed from photons):  0.00946364454519602
# -------- Energy lost (Computed from electrons):  0.00946364454517834
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320868916686628e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4304062609688175
# -------- Energy in secondary photons (Analytic):  0.43039634384670816
# -------- Energy gain from photons:  0.009473583346448766
# -------- Deposited Energy:  -9.938801270426012e-06
# -------- Injection Energy:  4549.564525764319
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677185374663
# -------- Energy lost (Analytic):  0.010038301372055292
# -------- Energy lost (Computed from photons):  0.010038328990169673
# -------- Energy lost (Computed from electrons):  0.010038328990191303
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320867901791433e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4309808952109422
# -------- Energy in secondary photons (Analytic):  0.43097097899442405
# -------- Energy gain from photons:  0.010048217588573438
# -------- Deposited Energy:  -9.888598382135072e-06
# -------- Injection Energy:  4824.595505152363
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116771999141685
# -------- Energy lost (Analytic):  0.01064799035012864
# -------- Energy lost (Computed from photons):  0.010648052073852613
# -------- Energy lost (Computed from electrons):  0.010648052073861436
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320866825543637e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4315905808915239
# -------- Energy in secondary photons (Analytic):  0.43158066797249733
# -------- Energy gain from photons:  0.010657903269155167
# -------- Deposited Energy:  -9.851195293730797e-06
# -------- Injection Energy:  5116.252699905599
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677187950033
# -------- Energy lost (Analytic):  0.011294891585934557
# -------- Energy lost (Computed from photons):  0.011294974654644076
# -------- Energy lost (Computed from electrons):  0.01129497465464624
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320865684234343e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.43223746931136364
# -------- Energy in secondary photons (Analytic):  0.43222756920830335
# -------- Energy gain from photons:  0.011304791688994897
# -------- Deposited Energy:  -9.817034348658105e-06
# -------- Injection Energy:  5425.541200570471
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772770580234
# -------- Energy lost (Analytic):  0.011981298889546861
# -------- Energy lost (Computed from photons):  0.011981446778680307
# -------- Energy lost (Computed from electrons):  0.011981446778634108
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208644739304416e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4329239251045881
# -------- Energy in secondary photons (Analytic):  0.4329139765119156
# -------- Energy gain from photons:  0.011991247482219358
# -------- Deposited Energy:  -9.80070358524987e-06
# -------- Injection Energy:  5753.526857582852
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116773150089908
# -------- Energy lost (Analytic):  0.012709650248390719
# -------- Energy lost (Computed from photons):  0.012709869208303907
# -------- Energy lost (Computed from electrons):  0.012709869208293867
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320863190461062e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.43365232760670314
# -------- Energy in secondary photons (Analytic):  0.43364232787075946
# -------- Energy gain from photons:  0.012719649984334391
# -------- Deposited Energy:  -9.780776040524408e-06
# -------- Injection Energy:  6101.339954334253
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772438283083
# -------- Energy lost (Analytic):  0.013482537229590938
# -------- Energy lost (Computed from photons):  0.013482818595580332
# -------- Energy lost (Computed from electrons):  0.013482818595576873
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320861829403193e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4344252508662375
# -------- Energy in secondary photons (Analytic):  0.4344152148519597
# -------- Energy gain from photons:  0.013492573243868766
# -------- Deposited Energy:  -9.754648291893098e-06
# -------- Injection Energy:  6470.1791022827965
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116771752608871
# -------- Energy lost (Analytic):  0.014302715036224151
# -------- Energy lost (Computed from photons):  0.014303058265377012
# -------- Energy lost (Computed from electrons):  0.014303058265397794
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320860386066442e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.43524546350027904
# -------- Energy in secondary photons (Analytic):  0.43523539265859285
# -------- Energy gain from photons:  0.014312785877910295
# -------- Deposited Energy:  -9.727612512500095e-06
# -------- Injection Energy:  6861.315371532226
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116771785385855
# -------- Energy lost (Analytic):  0.015173113267656508
# -------- Energy lost (Computed from photons):  0.01517350851614368
# -------- Energy lost (Computed from electrons):  0.015173508516141965
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320858855476875e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4361159012267174
# -------- Energy in secondary photons (Analytic):  0.43610579089002527
# -------- Energy gain from photons:  0.01518322360434865
# -------- Deposited Energy:  -9.71508820668543e-06
# -------- Injection Energy:  7276.0966711129295
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116771920561232
# -------- Energy lost (Analytic):  0.016096847438506885
# -------- Energy lost (Computed from photons):  0.0160972902743383
# -------- Energy lost (Computed from electrons):  0.016097290274331044
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208572323598704e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.43703967255938236
# -------- Energy in secondary photons (Analytic):  0.43702952506087567
# -------- Energy gain from photons:  0.01610699493701362
# -------- Deposited Energy:  -9.70466268257475e-06
# -------- Injection Energy:  7715.952394060849
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772056035
# -------- Energy lost (Analytic):  0.017077231315568066
# -------- Energy lost (Computed from photons):  0.017077740641785986
# -------- Energy lost (Computed from electrons):  0.01707774064180967
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208555111219446e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.43802008919140123
# -------- Energy in secondary photons (Analytic):  0.43800990893793684
# -------- Energy gain from photons:  0.017087411569032485
# -------- Deposited Energy:  -9.670927222815706e-06
# -------- Injection Energy:  8182.398343301087
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772050531952
# -------- Energy lost (Analytic):  0.018117790137279065
# -------- Energy lost (Computed from photons):  0.01811834416423509
# -------- Energy lost (Computed from electrons):  0.018118344164236078
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208536858314776e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.43906067186416664
# -------- Energy in secondary photons (Analytic):  0.43905046775964784
# -------- Energy gain from photons:  0.018127994241797896
# -------- Deposited Energy:  -9.650077561818016e-06
# -------- Injection Energy:  8677.041955312132
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772061328605
# -------- Energy lost (Analytic):  0.01922227478613671
# -------- Energy lost (Computed from photons):  0.019222844973235332
# -------- Energy lost (Computed from electrons):  0.019222844973228348
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320851750198269e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4401651729523888
# -------- Energy in secondary photons (Analytic):  0.4401549524085055
# -------- Energy gain from photons:  0.019232495330020027
# -------- Deposited Energy:  -9.65035679167947e-06
# -------- Injection Energy:  9201.587839571177
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772495985676
# -------- Energy lost (Analytic):  0.020394676990807718
# -------- Energy lost (Computed from photons):  0.02039525347210705
# -------- Energy lost (Computed from electrons):  0.020395253472145214
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320849697551861e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.44133758621831587
# -------- Energy in secondary photons (Analytic):  0.44132735461317646
# -------- Energy gain from photons:  0.020404908595947124
# -------- Deposited Energy:  -9.65512380191047e-06
# -------- Injection Energy:  9757.843652871728
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772130439755
# -------- Energy lost (Analytic):  0.021639245641734625
# -------- Energy lost (Computed from photons):  0.021639817030563297
# -------- Energy lost (Computed from electrons):  0.021639817030518316
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208475208185545e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4425821468320262
# -------- Energy in secondary photons (Analytic):  0.44257192326410333
# -------- Energy gain from photons:  0.021649469209657435
# -------- Deposited Energy:  -9.652179139119088e-06
# -------- Injection Energy:  10347.72632875567
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772079049207
# -------- Energy lost (Analytic):  0.022960504311770914
# -------- Energy lost (Computed from photons):  0.022961056335946688
# -------- Energy lost (Computed from electrons):  0.022961056335986996
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208452124970295e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4439033856376044
# -------- Energy in secondary photons (Analytic):  0.4438931819341396
# -------- Energy gain from photons:  0.022970708015235652
# -------- Deposited Energy:  -9.65167924865673e-06
# -------- Injection Energy:  10973.26868352847
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772109561583
# -------- Energy lost (Analytic):  0.024363270081937557
# -------- Energy lost (Computed from photons):  0.024363853302096818
# -------- Energy lost (Computed from electrons):  0.024363853302133975
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320842764632494e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.44530618224482565
# -------- Energy in secondary photons (Analytic):  0.44529594770430625
# -------- Energy gain from photons:  0.02437350462245691
# -------- Deposited Energy:  -9.651320322934254e-06
# -------- Injection Energy:  11636.626421621419
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772166025694
# -------- Energy lost (Analytic):  0.025852673781832262
# -------- Energy lost (Computed from photons):  0.025853331978136128
# -------- Energy lost (Computed from electrons):  0.025853331978055394
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208401687892724e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4467956864011358
# -------- Energy in secondary photons (Analytic):  0.446785351404201
# -------- Energy gain from photons:  0.02586300877876707
# -------- Deposited Energy:  -9.676800711677647e-06
# -------- Injection Energy:  12340.08556444419
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772204033844
# -------- Energy lost (Analytic):  0.02743418176466659
# -------- Energy lost (Computed from photons):  0.027434960745852006
# -------- Energy lost (Computed from electrons):  0.02743496074583618
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320837416021734e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4483772919397617
# -------- Energy in secondary photons (Analytic):  0.4483668593870353
# -------- Energy gain from photons:  0.02744461431739298
# -------- Deposited Energy:  -9.653571556800244e-06
# -------- Injection Energy:  13086.070328326896
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772383966438
# -------- Energy lost (Analytic):  0.029113619348442903
# -------- Energy lost (Computed from photons):  0.029114490374265386
# -------- Energy lost (Computed from electrons):  0.029114490374354318
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320834496843466e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4500568242707965
# -------- Energy in secondary photons (Analytic):  0.45004629697081167
# -------- Energy gain from photons:  0.029124146648427773
# -------- Deposited Energy:  -9.656274073455151e-06
# -------- Injection Energy:  13877.151478700514
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772253892708
# -------- Energy lost (Analytic):  0.030897196067563453
# -------- Energy lost (Computed from photons):  0.030898154082211193
# -------- Energy lost (Computed from electrons):  0.03089815408236518
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320831401194581e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4518404868810436
# -------- Energy in secondary photons (Analytic):  0.45182987368993216
# -------- Energy gain from photons:  0.030907809258674868
# -------- Deposited Energy:  -9.655176309686375e-06
# -------- Injection Energy:  14716.055189306091
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772282781938
# -------- Energy lost (Analytic):  0.03279153289331484
# -------- Energy lost (Computed from photons):  0.03279256907946195
# -------- Energy lost (Computed from electrons):  0.032792569079447276
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320828118407051e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4537349032569393
# -------- Energy in secondary photons (Analytic):  0.45372421051568357
# -------- Energy gain from photons:  0.03280222563457058
# -------- Deposited Energy:  -9.65655512330521e-06
# -------- Injection Energy:  15605.672436961962
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677226671463
# -------- Energy lost (Analytic):  0.034803691597348446
# -------- Energy lost (Computed from photons):  0.034804796139035234
# -------- Energy lost (Computed from electrons):  0.03480479613904208
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208246371679405e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.45574712985605914
# -------- Energy in secondary photons (Analytic):  0.45573636921971716
# -------- Energy gain from photons:  0.034814452233690396
# -------- Deposited Energy:  -9.65609464831374e-06
# -------- Injection Energy:  16549.06896426488
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677229766979
# -------- Energy lost (Analytic):  0.03694120644966911
# -------- Energy lost (Computed from photons):  0.036942366374739063
# -------- Energy lost (Computed from electrons):  0.036942366374660196
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208209454804236e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4578847010283438
# -------- Energy in secondary photons (Analytic):  0.4578738840720379
# -------- Energy gain from photons:  0.03695202340597503
# -------- Deposited Energy:  -9.657031314835862e-06
# -------- Injection Energy:  17549.49584455794
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772340098484
# -------- Energy lost (Analytic):  0.03921211846193931
# -------- Energy lost (Computed from photons):  0.03921331804226039
# -------- Energy lost (Computed from electrons):  0.039213318042470746
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320817030622442e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4601556538904241
# -------- Energy in secondary photons (Analytic):  0.4601447960843081
# -------- Energy gain from photons:  0.039222976268055376
# -------- Deposited Energy:  -9.658225584630031e-06
# -------- Injection Energy:  18610.40068557317
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772371627763
# -------- Energy lost (Analytic):  0.04162501240832778
# -------- Energy lost (Computed from photons):  0.04162623208822142
# -------- Energy lost (Computed from electrons):  0.04162623208844707
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320812879102858e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4625685691247861
# -------- Energy in secondary photons (Analytic):  0.4625576900306965
# -------- Energy gain from photons:  0.041635891502417366
# -------- Deposited Energy:  -9.659413970297681e-06
# -------- Injection Energy:  19735.439510359953
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772388925288
# -------- Energy lost (Analytic):  0.04418905687993657
# -------- Energy lost (Computed from photons):  0.044190273613930395
# -------- Energy lost (Computed from electrons):  0.04419027361382177
# -------- Energy lost (Computed from electrons DIRECT):  -7.65432080847661497e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4651326116630135
# -------- Energy in secondary photons (Analytic):  0.46512173450230526
# -------- Energy gain from photons:  0.04419993404064476
# -------- Deposited Energy:  -9.660426822988288e-06
# -------- Injection Energy:  20928.48935643857
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772400061113
# -------- Energy lost (Analytic):  0.04691404765528058
# -------- Energy lost (Computed from photons):  0.046915233714435595
# -------- Energy lost (Computed from electrons):  0.046915233714571514
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543208038079872024e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.467857572259193
# -------- Energy in secondary photons (Analytic):  0.46784672527764926
# -------- Energy gain from photons:  0.046924894636824255
# -------- Deposited Energy:  -9.660922252741067e-06
# -------- Injection Energy:  22193.661636602308
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772425402556
# -------- Energy lost (Analytic):  0.049810454698733936
# -------- Energy lost (Computed from photons):  0.04981160650295633
# -------- Energy lost (Computed from electrons):  0.049811606502998984
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320798857130826e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.47075394608304355
# -------- Energy in secondary photons (Analytic):  0.47074313232110265
# -------- Energy gain from photons:  0.049821268460674806
# -------- Deposited Energy:  -9.661957675821675e-06
# -------- Injection Energy:  23535.316307407513
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772462560824
# -------- Energy lost (Analytic):  0.05288947313157505
# -------- Energy lost (Computed from photons):  0.05289083831043769
# -------- Energy lost (Computed from electrons):  0.05289083831053176
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320793606984512e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.47383317916726764
# -------- Energy in secondary photons (Analytic):  0.4738221507539438
# -------- Energy gain from photons:  0.05290050154489889
# -------- Deposited Energy:  -9.663234367129903e-06
# -------- Injection Energy:  24958.076894179627
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772478154062
# -------- Energy lost (Analytic):  0.05616307855671605
# -------- Energy lost (Computed from photons):  0.05616465295737903
# -------- Energy lost (Computed from electrons):  0.05616465295724993
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543207880394555406e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4771069949174003
# -------- Energy in secondary photons (Analytic):  0.47709575617908473
# -------- Energy gain from photons:  0.05617431729503153
# -------- Deposited Energy:  -9.664337781600807e-06
# -------- Injection Energy:  26466.846424312855
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677249613942
# -------- Energy lost (Analytic):  0.05964408715879161
# -------- Energy lost (Computed from photons):  0.05964586368745112
# -------- Energy lost (Computed from electrons):  0.05964586368759228
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543207821353574455e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.48058820664944957
# -------- Energy in secondary photons (Analytic):  0.48057676478116035
# -------- Energy gain from photons:  0.05965552902708082
# -------- Deposited Energy:  -9.665339488540425e-06
# -------- Injection Energy:  28066.82432377321
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772518506161
# -------- Energy lost (Analytic):  0.06334622104651622
# -------- Energy lost (Computed from photons):  0.0633481887743668
# -------- Energy lost (Computed from electrons):  0.06334818877417092
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543207758743438975e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4842905328675363
# -------- Energy in secondary photons (Analytic):  0.48427889866888496
# -------- Energy gain from photons:  0.06335785524516757
# -------- Deposited Energy:  -9.666470996649856e-06
# -------- Injection Energy:  29763.52433503029
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772545767932
# -------- Energy lost (Analytic):  0.06728417935463786
# -------- Energy lost (Computed from photons):  0.06728632337226065
# -------- Energy lost (Computed from electrons):  0.06728632337217277
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320769234838589e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.48822866879237214
# -------- Energy in secondary photons (Analytic):  0.4882168569770066
# -------- Energy gain from photons:  0.0672959911700034
# -------- Deposited Energy:  -9.66779783062588e-06
# -------- Injection Energy:  31562.793518167862
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677257113963
# -------- Energy lost (Analytic):  0.07147371567906366
# -------- Energy lost (Computed from photons):  0.07147601621723268
# -------- Energy lost (Computed from electrons):  0.07147601621727517
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320762193960878e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.49241836283746376
# -------- Energy in secondary photons (Analytic):  0.49240639330143243
# -------- Energy gain from photons:  0.07148568521509502
# -------- Deposited Energy:  -9.668997819844982e-06
# -------- Injection Energy:  33470.83240065101
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772594600942
# -------- Energy lost (Analytic):  0.07593172248147091
# -------- Energy lost (Computed from photons):  0.0759341539533494
# -------- Energy lost (Computed from electrons):  0.07593415395331249
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320754727446936e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.4968765017356155
# -------- Energy in secondary photons (Analytic):  0.4968644001038396
# -------- Energy gain from photons:  0.07594382411324674
# -------- Deposited Energy:  -9.670159934249689e-06
# -------- Injection Energy:  35494.21634519176
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772612070698
# -------- Energy lost (Analytic):  0.08067632316976667
# -------- Energy lost (Computed from photons):  0.08067885355884713
# -------- Energy lost (Computed from electrons):  0.08067885355831095
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320746809566137e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5016212021546873
# -------- Energy in secondary photons (Analytic):  0.5016090007921354
# -------- Energy gain from photons:  0.08068852453231856
# -------- Deposited Energy:  -9.670974007613964e-06
# -------- Injection Energy:  37639.91820934747
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772638675658
# -------- Energy lost (Analytic):  0.08572697263895285
# -------- Energy lost (Computed from photons):  0.08572956225876019
# -------- Energy lost (Computed from electrons):  0.08572956225862072
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543207384130323815e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5066719119339302
# -------- Energy in secondary photons (Analytic):  0.5066596502613216
# -------- Energy gain from photons:  0.0857392343115615
# -------- Deposited Energy:  -9.672052940778997e-06
# -------- Injection Energy:  39915.332374940335
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677265704899
# -------- Energy lost (Analytic):  0.09110456714431307
# -------- Energy lost (Computed from photons):  0.09110716778663333
# -------- Energy lost (Computed from electrons):  0.09110716778650385
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320729508910067e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5120495180660676
# -------- Energy in secondary photons (Analytic):  0.5120372447666819
# -------- Energy gain from photons:  0.09111684044369883
# -------- Deposited Energy:  -9.672657194981227e-06
# -------- Injection Energy:  42328.30023010768
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772675336163
# -------- Energy lost (Analytic):  0.0968315644764483
# -------- Energy lost (Computed from photons):  0.09683411753400625
# -------- Energy lost (Computed from electrons):  0.09683411753394466
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320720066514371e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5177764683529481
# -------- Energy in secondary photons (Analytic):  0.517764242098817
# -------- Energy gain from photons:  0.09684379073057936
# -------- Deposited Energy:  -9.673196634696346e-06
# -------- Injection Energy:  44887.1371917972
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772694795397
# -------- Energy lost (Analytic):  0.102932115516786
# -------- Energy lost (Computed from photons):  0.1029345511033033
# -------- Energy lost (Computed from electrons):  0.10293455110331706
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320710053305508e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5238769021474972
# -------- Energy in secondary photons (Analytic):  0.5238647931391548
# -------- Energy gain from photons:  0.10294422452512841
# -------- Deposited Energy:  -9.673421811351446e-06
# -------- Injection Energy:  47600.66136183002
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677271300575
# -------- Energy lost (Analytic):  0.10943220837417497
# -------- Energy lost (Computed from photons):  0.10943494693489324
# -------- Energy lost (Computed from electrons):  0.10943494693492539
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320699434776592e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5303772982610361
# -------- Energy in secondary photons (Analytic):  0.5303648859965436
# -------- Energy gain from photons:  0.10944462063866733
# -------- Deposited Energy:  -9.67370374194143e-06
# -------- Injection Energy:  50478.22391528421
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677271885456
# -------- Energy lost (Analytic):  0.11635982643961047
# -------- Energy lost (Computed from photons):  0.11636303719744309
# -------- Energy lost (Computed from electrons):  0.11636303719751595
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320688174334721e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5373053884299925
# -------- Energy in secondary photons (Analytic):  0.5372925040619791
# -------- Energy gain from photons:  0.11637271080762379
# -------- Deposited Energy:  -9.673610107840958e-06
# -------- Injection Energy:  53529.7413259219
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772743797894
# -------- Energy lost (Analytic):  0.1237451218487721
# -------- Energy lost (Computed from photons):  0.12374879446749891
# -------- Energy lost (Computed from electrons):  0.12374879446815612
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320676233174874e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5446911456475403
# -------- Energy in secondary photons (Analytic):  0.5446777994711408
# -------- Energy gain from photons:  0.12375846802517154
# -------- Deposited Energy:  -9.673557015421608e-06
# -------- Injection Energy:  56765.7295397133
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772761851866
# -------- Energy lost (Analytic):  0.13162060601285971
# -------- Energy lost (Computed from photons):  0.13162472234100098
# -------- Energy lost (Computed from electrons):  0.13162472234034794
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543206635701461825e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.55256707350623
# -------- Energy in secondary photons (Analytic):  0.5525532836352284
# -------- Energy gain from photons:  0.13163439588386128
# -------- Deposited Energy:  -9.673543513333271e-06
# -------- Injection Energy:  60197.34021422308
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772778158383
# -------- Energy lost (Analytic):  0.1400213590694001
# -------- Energy lost (Computed from photons):  0.14002589149912972
# -------- Energy lost (Computed from electrons):  0.14002589149913547
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320650141610119e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5609682426489898
# -------- Energy in secondary photons (Analytic):  0.5609540366917688
# -------- Energy gain from photons:  0.14003556502662107
# -------- Deposited Energy:  -9.673527485598576e-06
# -------- Injection Energy:  63836.39914874645
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772793358372
# -------- Energy lost (Analytic):  0.14898526031876128
# -------- Energy lost (Computed from photons):  0.14899017005827137
# -------- Energy lost (Computed from electrons):  0.14899017005791393
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543206359012901136e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5699325212973488
# -------- Energy in secondary photons (Analytic):  0.56991793794113
# -------- Energy gain from photons:  0.1489998436749801
# -------- Deposited Energy:  -9.673617066163764e-06
# -------- Injection Energy:  67695.44703762903
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772811039004
# -------- Energy lost (Analytic):  0.15855324195182463
# -------- Energy lost (Computed from photons):  0.1585584770654881
# -------- Energy lost (Computed from electrons):  0.15855847706643544
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320620800112077e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5795008286682698
# -------- Energy in secondary photons (Analytic):  0.5794859195741933
# -------- Energy gain from photons:  0.15856815104590105
# -------- Deposited Energy:  -9.673979465607552e-06
# -------- Injection Energy:  71787.78268721356
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772827579578
# -------- Energy lost (Analytic):  0.1687695686427846
# -------- Energy lost (Computed from photons):  0.1687750615452688
# -------- Energy lost (Computed from electrons):  0.1687750615474215
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320604786035288e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.5897174137468058
# -------- Energy in secondary photons (Analytic):  0.5897022462651533
# -------- Energy gain from photons:  0.168784736124437
# -------- Deposited Energy:  -9.674577015506003e-06
# -------- Injection Energy:  76127.50884534378
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772846517632
# -------- Energy lost (Analytic):  0.17968214588187523
# -------- Energy lost (Computed from photons):  0.1796878107450242
# -------- Energy lost (Computed from electrons):  0.17968781074705475
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543205878038730476e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.600630163939028
# -------- Energy in secondary photons (Analytic):  0.6006148235042439
# -------- Energy gain from photons:  0.17969748631665927
# -------- Deposited Energy:  -9.675569604516987e-06
# -------- Injection Energy:  80729.58080136002
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772866195988
# -------- Energy lost (Analytic):  0.19134286025993183
# -------- Energy lost (Computed from photons):  0.1913489642281591
# -------- Energy lost (Computed from electrons):  0.1913489642283821
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320569795102505e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.6122909442942239
# -------- Energy in secondary photons (Analytic):  0.6122755378823006
# -------- Energy gain from photons:  0.19135826667185518
# -------- Deposited Energy:  -9.302443473080402e-06
# -------- Injection Energy:  85609.85792407085
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772885725308
# -------- Energy lost (Analytic):  0.20380795529453413
# -------- Energy lost (Computed from photons):  0.203813726182969
# -------- Energy lost (Computed from electrons):  0.2038137261824886
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543205506976629766e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.624755973117786
# -------- Energy in secondary photons (Analytic):  0.6247406329169028
# -------- Energy gain from photons:  0.20382329549541722
# -------- Deposited Energy:  -9.569312928614515e-06
# -------- Injection Energy:  90785.15831530391
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677290826905
# -------- Energy lost (Analytic):  0.21713844681101196
# -------- Energy lost (Computed from photons):  0.2171438944056533
# -------- Energy lost (Computed from electrons):  0.21714389440603554
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320530445742076e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.6380862369057057
# -------- Energy in secondary photons (Analytic):  0.6380711244333807
# -------- Energy gain from photons:  0.2171535592833369
# -------- Deposited Energy:  -9.664877301363006e-06
# -------- Injection Energy:  96273.31676738377
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677292978491
# -------- Energy lost (Analytic):  0.23140058236649302
# -------- Energy lost (Computed from photons):  0.23140616285414903
# -------- Energy lost (Computed from electrons):  0.2314061628530908
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320508969548916e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.6523485371046903
# -------- Energy in secondary photons (Analytic):  0.6523332599888618
# -------- Energy gain from photons:  0.23141585948232157
# -------- Deposited Energy:  -9.696629230782072e-06
# -------- Injection Energy:  102093.24622426316
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772953673577
# -------- Energy lost (Analytic):  0.24666634973767368
# -------- Energy lost (Computed from photons):  0.2466730484958619
# -------- Energy lost (Computed from electrons):  0.24667304849754146
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320486195073601e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.667615431482425
# -------- Energy in secondary photons (Analytic):  0.6675990273600424
# -------- Energy gain from photons:  0.24668275386005623
# -------- Deposited Energy:  -9.705362514766946e-06
# -------- Injection Energy:  108265.00295811152
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116772976263588
# -------- Energy lost (Analytic):  0.26301404009024676
# -------- Energy lost (Computed from photons):  0.2630218563498112
# -------- Energy lost (Computed from electrons):  0.2630218563499511
# -------- Energy lost (Computed from electrons DIRECT):  -7.6543204620438321765e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.6839642404124637
# -------- Energy in secondary photons (Analytic):  0.6839467177126155
# -------- Energy gain from photons:  0.263031562790095
# -------- Deposited Energy:  -9.706440143864015e-06
# -------- Injection Energy:  114809.85568597034
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677299901756
# -------- Energy lost (Analytic):  0.2805288721178612
# -------- Energy lost (Computed from photons):  0.28053778207665425
# -------- Energy lost (Computed from electrons):  0.28053778207504365
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320436432596164e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.7014801642177853
# -------- Energy in secondary photons (Analytic):  0.7014615497402299
# -------- Energy gain from photons:  0.2805474865954165
# -------- Deposited Energy:  -9.704520372855185e-06
# -------- Injection Energy:  121750.35886465822
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.2211677301953273
# -------- Energy lost (Analytic):  0.2993036841900567
# -------- Energy lost (Computed from photons):  0.2993136398152657
# -------- Energy lost (Computed from electrons):  0.29931363981449977
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320409273105746e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  0.7202560184731299
# -------- Energy in secondary photons (Analytic):  0.7202363618124253
# -------- Energy gain from photons:  0.2993233408507612
# -------- Deposited Energy:  -9.701036261411389e-06
# -------- Injection Energy:  129110.43041651015
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.22116773037629262
# -------- Energy lost (Analytic):  0.3194397023919083
# -------- Energy lost (Computed from photons):  0.319450627616967
# -------- Energy lost (Computed from electrons):  0.31945062761951704
# -------- Energy lost (Computed from electrons DIRECT):  -7.654320380471765607e-176
# -------- Energy of upscattered photons:  0.42093267762236874
# ...
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.03305945368553026
# -------- Energy lost (Analytic):  3336918863077.23
# -------- Energy lost (Computed from photons):  22104070952.600235
# -------- Energy lost (Computed from electrons):  22104070952.600235
# -------- Energy lost (Computed from electrons DIRECT):  22787974028.1146242
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  22104070952.600235
# -------- Energy in secondary photons (Analytic):  3336918863077.651
# -------- Energy gain from photons:  22104070952.179302
# -------- Deposited Energy:  0.4209327697753906
# -------- Injection Energy:  1321320093607.8591
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.032511319207071475
# -------- Energy lost (Analytic):  3752561206161.6787
# -------- Energy lost (Computed from photons):  23611701026.467487
# -------- Energy lost (Computed from electrons):  23611701026.467495
# -------- Energy lost (Computed from electrons DIRECT):  23571423064.430413485
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  23611701026.467487
# -------- Energy in secondary photons (Analytic):  3752561206162.099
# -------- Energy gain from photons:  23611701026.046555
# -------- Deposited Energy:  0.4209403991699219
# -------- Injection Energy:  1401196740564.3086
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.03191608025240961
# -------- Energy lost (Analytic):  4219975438820.8594
# -------- Energy lost (Computed from photons):  25151685497.852478
# -------- Energy lost (Computed from electrons):  25151685497.852478
# -------- Energy lost (Computed from electrons DIRECT):  24369369477.248693842
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  25151685497.852478
# -------- Energy in secondary photons (Analytic):  4219975438821.279
# -------- Energy gain from photons:  25151685497.431545
# -------- Deposited Energy:  0.4209327697753906
# -------- Injection Energy:  1485902102954.5662
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.030587082762112777
# -------- Energy lost (Analytic):  4745610203444.959
# -------- Energy lost (Computed from photons):  25700176245.08651
# -------- Energy lost (Computed from electrons):  25700176245.086502
# -------- Energy lost (Computed from electrons DIRECT):  25180339797.276338607
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  25700176245.08651
# -------- Energy in secondary photons (Analytic):  4745610203445.38
# -------- Energy gain from photons:  25700176244.665577
# -------- Deposited Energy:  0.4209251403808594
# -------- Injection Energy:  1575728087031.9531
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.0285469134938695
# -------- Energy lost (Analytic):  5336717377367.815
# -------- Energy lost (Computed from photons):  25032150342.922443
# -------- Energy lost (Computed from electrons):  25032150342.922443
# -------- Energy lost (Computed from electrons DIRECT):  26006386893.003085328
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  25032150342.922447
# -------- Energy in secondary photons (Analytic):  5336717377368.235
# -------- Energy gain from photons:  25032150342.501514
# -------- Deposited Energy:  0.420928955078125
# -------- Injection Energy:  1670984245411.8242
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.027798121670326692
# -------- Energy lost (Analytic):  6001452122823.378
# -------- Energy lost (Computed from photons):  26239013583.515938
# -------- Energy lost (Computed from electrons):  26236469479.90805
# -------- Energy lost (Computed from electrons DIRECT):  26844121834.198863339
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  26239013583.515938
# -------- Energy in secondary photons (Analytic):  6001452122823.799
# -------- Energy gain from photons:  26239013583.095005
# -------- Deposited Energy:  -2544103.1869544983
# -------- Injection Energy:  1771998843832.1865
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.027604080465002033
# -------- Energy lost (Analytic):  6748985399001.94
# -------- Energy lost (Computed from photons):  28469443879.79878
# -------- Energy lost (Computed from electrons):  28469443879.79878
# -------- Energy lost (Computed from electrons DIRECT):  27697421775.599328361
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  28469443879.79878
# -------- Energy in secondary photons (Analytic):  6748985399002.36
# -------- Energy gain from photons:  28469443879.377846
# -------- Deposited Energy:  0.4209327697753906
# -------- Injection Energy:  1879119992402.2852
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.026932359776460864
# -------- Energy lost (Analytic):  7589630488469.783
# -------- Energy lost (Computed from photons):  29990474914.00212
# -------- Energy lost (Computed from electrons):  29990474914.002113
# -------- Energy lost (Computed from electrons DIRECT):  28561985984.507109372
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  29990474914.00212
# -------- Energy in secondary photons (Analytic):  7589630488470.203
# -------- Energy gain from photons:  29990474913.58119
# -------- Deposited Energy:  0.4209251403808594
# -------- Injection Energy:  1992716845237.605
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.02485773219833471
# -------- Energy lost (Analytic):  8534985283564.216
# -------- Energy lost (Computed from photons):  28774236089.839993
# -------- Energy lost (Computed from electrons):  28774236089.839996
# -------- Energy lost (Computed from electrons DIRECT):  29440745982.870464813
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  28774236089.839993
# -------- Energy in secondary photons (Analytic):  8534985283564.636
# -------- Energy gain from photons:  28774236089.41906
# -------- Deposited Energy:  0.42093658447265625
# -------- Injection Energy:  2113180872615.4043
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.023574459756397
# -------- Energy lost (Analytic):  9598092295807.32
# -------- Energy lost (Computed from photons):  28810515474.158585
# -------- Energy lost (Computed from electrons):  28559942115.214542
# -------- Energy lost (Computed from electrons DIRECT):  30331252873.42580041
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  28810515474.158585
# -------- Energy in secondary photons (Analytic):  9598092295807.74
# -------- Energy gain from photons:  28810515473.73765
# -------- Deposited Energy:  -250573358.52310944
# -------- Injection Energy:  2240927210034.778
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.023557108151896197
# -------- Energy lost (Analytic):  10793618595895.6
# -------- Energy lost (Computed from photons):  31532212482.52346
# -------- Energy lost (Computed from electrons):  31532212482.52346
# -------- Energy lost (Computed from electrons DIRECT):  31234503768.44679758
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  31532212482.52346
# -------- Energy in secondary photons (Analytic):  10793618595896.02
# -------- Energy gain from photons:  31532212482.102528
# -------- Deposited Energy:  0.4209327697753906
# -------- Injection Energy:  2376396088830.3022
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.02341107958471283
# -------- Energy lost (Analytic):  12138058166793.652
# -------- Energy lost (Computed from photons):  34194053721.38853
# -------- Energy lost (Computed from electrons):  34194053721.388527
# -------- Energy lost (Computed from electrons DIRECT):  32150020298.779647157
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  34194053721.38853
# -------- Energy in secondary photons (Analytic):  12138058166794.07
# -------- Energy gain from photons:  34194053720.967598
# -------- Deposited Energy:  0.420928955078125
# -------- Injection Energy:  2520054353269.385
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.021939833847444738
# -------- Energy lost (Analytic):  13649959461680.936
# -------- Energy lost (Computed from photons):  33756020470.33976
# -------- Energy lost (Computed from electrons):  33756020470.339767
# -------- Energy lost (Computed from electrons DIRECT):  33076747308.569183964
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  33756020470.33976
# -------- Energy in secondary photons (Analytic):  13649959461681.355
# -------- Energy gain from photons:  33756020469.918827
# -------- Deposited Energy:  0.4209403991699219
# -------- Injection Energy:  2672397069361.388
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.019991025452828052
# -------- Energy lost (Analytic):  15350181306236.613
# -------- Energy lost (Computed from photons):  31694957949.893013
# -------- Energy lost (Computed from electrons):  30567056741.920296
# -------- Energy lost (Computed from electrons DIRECT):  34016301891.893286789
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  31694957949.893013
# -------- Energy in secondary photons (Analytic):  15350181306237.031
# -------- Energy gain from photons:  31694957949.47208
# -------- Deposited Energy:  -1127901207.5517845
# -------- Injection Energy:  2833949230922.7637
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.019823357113725036
# -------- Energy lost (Analytic):  17262180675799.06
# -------- Energy lost (Computed from photons):  34181418983.154167
# -------- Energy lost (Computed from electrons):  34181418983.15416
# -------- Energy lost (Computed from electrons DIRECT):  34965453507.19239185
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  34181418983.154167
# -------- Energy in secondary photons (Analytic):  17262180675799.479
# -------- Energy gain from photons:  34181418982.733234
# -------- Deposited Energy:  0.4209251403808594
# -------- Injection Energy:  3005267568777.472
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.02005776819718788
# -------- Energy lost (Analytic):  19412336317694.71
# -------- Energy lost (Computed from photons):  38075534082.98268
# -------- Energy lost (Computed from electrons):  38075534082.98267
# -------- Energy lost (Computed from electrons DIRECT):  35928045080.351319235
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  38075534082.98267
# -------- Energy in secondary photons (Analytic):  19412336317695.133
# -------- Energy gain from photons:  38075534082.561745
# -------- Deposited Energy:  0.420928955078125
# -------- Injection Energy:  3186942469327.463
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.019480365264940257
# -------- Energy lost (Analytic):  21830312683566.63
# -------- Energy lost (Computed from photons):  39798549423.94863
# -------- Energy lost (Computed from electrons):  39798549423.94862
# -------- Energy lost (Computed from electrons DIRECT):  36899382187.954472482
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  39798549423.94863
# -------- Energy in secondary photons (Analytic):  21830312683567.047
# -------- Energy gain from photons:  39798549423.5277
# -------- Deposited Energy:  0.42092132568359375
# -------- Injection Energy:  3379600009104.9067
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.01713602979124545
# -------- Energy lost (Analytic):  24549469192667.508
# -------- Energy lost (Computed from photons):  35529027334.81737
# -------- Energy lost (Computed from electrons):  35529027334.81738
# -------- Energy lost (Computed from electrons DIRECT):  37883155038.865662232
# -------- Energy of upscattered photons:  0.42093267762236874
# -------- Energy in secondary photons (Computed):  35529027334.81737
# -------- Energy in secondary photons (Analytic):  24549469192667.926
# -------- Energy gain from photons:  35529027334.39644
# -------- Deposited Energy:  0.4209442138671875
# -------- Injection Energy:  3583904112317.4634
# -------- No. of Scatters (Analytic):  0.2211664602506056
# -------- No. of Scatters (Computed):  0.016467625849282224
# -------- Energy lost (Analytic):  27607320472485.5
# -------- Energy lost (Computed from photons):  36354425287.83339
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-52d2b74e2042> in <module>()
# ----> 1 get_ipython().run_cell_magic('prun', '', 'start_rs = 3000\nrs = start_rs\nwhile rs > 2500:\n    (ics_sec_phot_tf, ics_sec_elec_tf, continuum_loss) = get_ics_cooling_tf(\n        ics_thomson_ref_tf_2, ics_rel_ref_tf_2, engloss_ref_tf_2,\n        scattered_elec_spec_nonrel_ref_tf_2, scattered_elec_spec_rel_ref_tf_2,\n        eleceng, photeng, rs, fast=False\n    )\n    rs = np.exp(np.log(rs) - 0.002)\n    print(rs)')
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-56> in prun(self, parameter_s, cell)
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/IPython/core/magics/execution.py in prun(self, parameter_s, cell)
#     300             arg_str += '\n' + cell
#     301         arg_str = self.shell.input_splitter.transform_cell(arg_str)
# --> 302         return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#     303
#     304     def _run_with_profiler(self, code, opts, namespace):
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/IPython/core/magics/execution.py in _run_with_profiler(self, code, opts, namespace)
#     322         prof = profile.Profile()
#     323         try:
# --> 324             prof = prof.runctx(code, namespace, namespace)
#     325             sys_exit = ''
#     326         except SystemExit:
#
# ~/anaconda/envs/python3/lib/python3.6/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>()
#
# ~/GitHub/DarkHistory/darkhistory/electrons/ics/ics_cooling.py in get_ics_cooling_tf(raw_nonrel_tf, raw_rel_tf, raw_engloss_tf, raw_scattered_elec_nonrel_tf, raw_scattered_elec_rel_tf, eleceng, photeng, rs, fast)
#     222         print(
#     223             '-------- Energy lost (Computed from photons): ',
# --> 224             engloss_tf[i].toteng()
#     225         )
#     226         print(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evolution

# %%
# mDM = 605662.1322589782*2
# mDM = 10**9.104*2
# mDM = 1.27164e9*2
mDM = 10**7*2
# mDM = 10**6.5*2

phot_spec_init = spectools.rebin_N_arr(np.array([2]), 
                                      np.array([mDM/2]), 
                                      photeng)
phot_spec_init.switch_spec_type()

elec_spec_init = spectools.rebin_N_arr(np.array([2]), 
    np.array([mDM/2 - phys.me]),
    eleceng)

elec_spec_init.switch_spec_type()

# %%
print(phot_spec_init.toteng(bound_type = 'eng', bound_arr = np.array([1,1e13]))/mDM)

# %%
# %autoreload
phot_spec_init.rs = 3000
elec_spec_init.rs = 3000
end_rs   = 4
#mDM = 1e8
sigmav = 1e-26
tau = 1e25

def rate_func_swave_N(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)/(2*mDM)

def rate_func_swave_eng(rs):
    # This is dE/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav)

def rate_func_decay_N(rs):
    # This is dN/dV dt
    return phys.inj_rate('decay', rs, tau=tau)/mDM

def rate_func_decay_eng(rs):
    # This is dE/dV dt
    return phys.inj_rate('decay', rs, tau=tau)


def rate_func_swave_N_2(rs):
    # This is dN/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav*1e-30)/(2*mDM)

def rate_func_swave_eng_2(rs):
    # This is dE/dV dt
    return phys.inj_rate('swave', rs, mDM=mDM, sigmav=sigmav*1e-30)


def evolve(
    in_spec_elec, in_spec_phot, 
    rate_func_N, rate_func_eng, xe_init, T_m_init,
    highengphot_tf_interp, lowengphot_tf_interp, 
    lowengelec_tf_interp, 
    end_rs, coarsen_factor=1, std_soln=False
):
    """
    Main function that computes the temperature and ionization history. 
    
    Parameters
    ----------
    in_spec_elec : Spectrum
        Spectrum per annihilation/decay into electrons. 
    in_spec_phot : Spectrum
        Spectrum per annihilation/decay into photons.
    rate_func_N : function
        Function describing the rate of annihilation/decay, dN/(dV dt)
    rate_func_eng : function
        Function describing the rate of annihilation/decay, dE/(dV dt)
    xe_init : float
        xe at the initial redshift. 
    T_m_init : float
        Matter temperature at the initial redshift. 
    highengphot_tf_interp : TransferFuncInterp
        Interpolation table for high energy photons. 
    lowengphot_tf_interp : TransferFuncInterp
        Interpolation table for low energy photons. 
    lowengelec_tf_interp : TransferFuncInterp
        Interpolation table for low energy electrons. 
    end_rs : float
        Final redshift to evolve to. 
    coarsen_factor : int
        Coarsening to apply to the transfer function matrix. 
    std_soln : bool
        If true, uses the standard TLA solution for f(z). 
    """
    
    # Initialize the next spectrum as None.
    next_highengphot_spec = None
    next_lowengphot_spec  = None
    next_lowengelec_spec  = None
    
    if (
        highengphot_tf_interp.dlnz    != lowengphot_tf_interp.dlnz
        or highengphot_tf_interp.dlnz != lowengelec_tf_interp.dlnz
        or lowengphot_tf_interp.dlnz  != lowengelec_tf_interp.dlnz
    ):
        raise TypeError('TransferFuncInterp objects must all have the same dlnz.')
    
    if in_spec_elec.rs != in_spec_phot.rs:
        raise TypeError('Input spectra must have the same rs.')
    
    # redshift/timestep related quantities. 
    dlnz = highengphot_tf_interp.dlnz
    prev_rs = None
    rs = in_spec_phot.rs
    dt = dlnz*coarsen_factor/phys.hubble(rs)
    
    # Function that changes the normalization from per annihilation to per baryon. 
    def norm_fac(rs): 
        return rate_func_N(rs) * dlnz * coarsen_factor /phys.hubble(rs) / (phys.nB * rs**3)
    
    # ICS for in_spec_elec goes here.
    
    (ics_sec_phot_tf, ics_sec_elec_tf, continuum_loss) = get_ics_cooling_tf(
        ics_thomson_ref_tf_2, ics_rel_ref_tf_2, engloss_ref_tf_2,
        eleceng, photeng, rs, fast=True
    )
    
    ics_phot_spec = ics_sec_phot_tf.sum_specs(in_spec_elec) * norm_fac(rs)
    ics_lowengelec_spec = ics_sec_elec_tf.sum_specs(in_spec_elec) * norm_fac(rs)
    positronium_phot_spec = pos.weighted_photon_spec(photeng)*in_spec_elec.totN()/2*norm_fac(rs)
    if positronium_phot_spec.spec_type != 'N':
        positronium_phot_spec.switch_spec_type()
        
    print('input electron energy: ', (phys.me*2 + in_spec_elec.toteng())*norm_fac(rs))
    print('ICS secondary photon spectrum energy: ', ics_phot_spec.toteng())
    print('Upscattered photon energy: ', np.dot(in_spec_elec.N, continuum_loss)*norm_fac(rs))
    print('ICS low energy electron spectrum energy: ', ics_lowengelec_spec.toteng() + phys.me*norm_fac(rs))
    print('Positronium spectrum energy: ', positronium_phot_spec.toteng())
    
    init_inj_spec = in_spec_phot * norm_fac(rs) + ics_phot_spec + positronium_phot_spec
    
    # Initialize the Spectra object that will contain all the 
    # output spectra during the evolution.
    out_highengphot_specs = Spectra([init_inj_spec], spec_type=init_inj_spec.spec_type)
    out_lowengphot_specs  = Spectra([], spec_type=init_inj_spec.spec_type)
    out_lowengelec_specs  = Spectra([], spec_type=init_inj_spec.spec_type)
    
    # Initialize the xe and T array that will store the solutions.
    xe_arr  = np.array([xe_init])
    T_m_arr = np.array([T_m_init])
    
    # Load the standard TLA solution if necessary. 
#     if std_soln:
    if True:
        soln = pickle.load(open("../darkhistory/history/std_soln.p", "rb"))
        xe_std  = interp1d(soln[0,:], soln[2,:])
        T_m_std = interp1d(soln[0,:], soln[1,:])

    # Define these methods for speed.
    append_highengphot_spec = out_highengphot_specs.append
    append_lowengphot_spec  = out_lowengphot_specs.append
    append_lowengelec_spec  = out_lowengelec_specs.append
    
    # For the tqdm bar
    pbar = tqdm(total = (np.log(rs) - np.log(end_rs))/dlnz/coarsen_factor)
    
    # Loop while we are still at a redshift above end_rs.
    while rs > end_rs:
        
        # Update tqdm bar.
        pbar.update(1)
        
        # If prev_rs exists, calculate xe and T_m. 
        if prev_rs is not None:
#             print('here at least?')
            
            # f_continuum, f_lyman, f_ionH, f_ionHe, f_heat
            # f_raw takes in dE/(dV dt)
            if std_soln:
                f_raw = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_std(rs), 0, 0]), rate_func_eng(rs), dt
                )
#                 print("\n SHOULD BE ONE: ", (next_lowengelec_spec.toteng() + next_lowengphot_spec.toteng())/(
#                 np.sum(f_raw) * rate_func_eng(rs) * dt / phys.nB / rs**3), '\n')   
            else:
                f_raw = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_arr[-1], 0, 0]), rate_func_eng(rs), dt
                )
                
            std_f = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_std(rs), 0, 0]), rate_func_eng(rs), dt
                )
            
            backreaction_f = compute_fs(
                    next_lowengelec_spec, next_lowengphot_spec,
                    np.array([1-xe_arr[-1], 0, 0]), rate_func_eng(rs), dt
                )
            
            f_raw = np.float64(f_raw)
            
            init_cond = np.array([T_m_arr[-1], xe_arr[-1], 0, 0])

            new_vals = tla.get_history(
                init_cond, f_raw[2], f_raw[1], f_raw[4], 
                rate_func_eng, np.array([prev_rs, rs]),
                reion_switch = False
            )

            T_m_arr = np.append(T_m_arr, new_vals[-1,0])
            xe_arr  = np.append(xe_arr,  new_vals[-1,1])
            
        print('T_m at '+str(rs)+': '+ str(T_m_arr[-1]))
        print('x_e at '+str(rs)+': '+ str(xe_arr[-1]))
        print('Standard x_e at '+str(rs)+': '+str(xe_std(rs)))
        print('Standard T_m at '+str(rs)+': '+str(T_m_std(rs)))
        if prev_rs is not None:
            print('Back Reaction f_cont, f_lyman, f_ionH, f_ionHe, f_heat: ', backreaction_f)
            print('Standard f_cont, f_lyman, f_ionH, f_ionHe, f_heat: ', std_f)
            
        if std_soln:
            highengphot_tf = highengphot_tf_interp.get_tf(rs, xe_std(rs))
            lowengphot_tf  = lowengphot_tf_interp.get_tf(rs, xe_std(rs))
            lowengelec_tf  = lowengelec_tf_interp.get_tf(rs, xe_std(rs))
        else:
            highengphot_tf = highengphot_tf_interp.get_tf(rs, xe_arr[-1])
            lowengphot_tf  = lowengphot_tf_interp.get_tf(rs, xe_arr[-1])
            lowengelec_tf  = lowengelec_tf_interp.get_tf(rs, xe_arr[-1])
        
        if coarsen_factor > 1:
            prop_tf = np.zeros_like(highengphot_tf._grid_vals)
            for i in np.arange(coarsen_factor):
                prop_tf += matrix_power(highengphot_tf._grid_vals, i)
            lowengphot_tf._grid_vals = np.matmul(prop_tf, lowengphot_tf._grid_vals)
            lowengelec_tf._grid_vals = np.matmul(prop_tf, lowengelec_tf._grid_vals)
            highengphot_tf._grid_vals = matrix_power(
                highengphot_tf._grid_vals, coarsen_factor
            )
            
        next_highengphot_spec = highengphot_tf.sum_specs(out_highengphot_specs[-1])
        next_lowengphot_spec  = lowengphot_tf.sum_specs(out_highengphot_specs[-1])
        next_lowengelec_spec  = lowengelec_tf.sum_specs(out_highengphot_specs[-1]) + ics_lowengelec_spec
        
#         print('\n SHOULD ALSO BE ONE: ', 
#               out_highengphot_specs[-1].toteng(bound_type = 'eng', bound_arr = np.array([100,1e13]))/(
#         next_highengphot_spec.toteng(bound_type = 'eng', bound_arr = np.array([100,1e13])) + 
#             next_lowengphot_spec.toteng(bound_type = 'eng', bound_arr = np.array([100,1e13])) + 
#             next_lowengelec_spec.toteng(bound_type = 'eng', bound_arr = np.array([100,1e13]))), '\n')
        
#         print('ENERGIES:')
#         print(out_highengphot_specs[-1].toteng())
#         for i in np.arange(500):
#             print(i, highengphot_tf.in_eng[i], highengphot_tf[i].toteng())
    
#         print('\n SHOULD ALSO BE ONE (JUST HIGH ENERGY): ', 
#               out_highengphot_specs[-1].toteng()/(
#         next_highengphot_spec.toteng()), '\n')
        
#         output_eng = next_highengphot_spec.N*next_highengphot_spec.eng/norm_fac(rs)
#         output_N   = next_highengphot_spec.dNdE/norm_fac(rs)
#         utils.compare_arr([next_highengphot_spec.eng, output_eng])
#         print(output_eng[385:391]/1e9)
#         print(output_N[385:391])
#         print(next_highengphot_spec.eng[385:391])
        
#         utils.compare_arr([out_highengphot_specs[-1].N, next_highengphot_spec.N])
        
        # Re-define existing variables.
        prev_rs = rs
        rs = np.exp(np.log(rs) - 0.002*coarsen_factor)
        
        dt = dlnz*coarsen_factor/phys.hubble(rs)
        next_highengphot_spec.rs = rs
        next_lowengphot_spec.rs  = rs
        next_lowengelec_spec.rs  = rs
        
        # Add the next injection spectrum to next_highengphot_spec
    
        (ics_sec_phot_tf, ics_sec_elec_tf, continuum_loss) = get_ics_cooling_tf(
            ics_thomson_ref_tf_2, ics_rel_ref_tf_2, engloss_ref_tf_2,
            eleceng, photeng, rs, fast=True
        )

        ics_phot_spec = ics_sec_phot_tf.sum_specs(in_spec_elec) * norm_fac(rs)
        ics_lowengelec_spec = ics_sec_elec_tf.sum_specs(in_spec_elec) * norm_fac(rs)
        positronium_phot_spec = pos.weighted_photon_spec(photeng)*in_spec_elec.totN()/2 * norm_fac(rs)
        if positronium_phot_spec.spec_type != 'N':
            positronium_phot_spec.switch_spec_type()
    

        next_inj_spec = in_spec_phot * norm_fac(rs) + ics_phot_spec + positronium_phot_spec

        # This keeps the redshift. 
        next_highengphot_spec.N += next_inj_spec.N
        
        append_highengphot_spec(next_highengphot_spec)
        append_lowengphot_spec(next_lowengphot_spec)
        append_lowengelec_spec(next_lowengelec_spec)
        
        print('************************ END OF LOOP **************************')
        
        
    return (
        xe_arr, T_m_arr, 
        out_highengphot_specs, out_lowengphot_specs, out_lowengelec_specs
    )

# %%
# %%prun
# a = evolve(
#         phot_spec_init*0, phot_spec_init, 
#         rate_func_decay_N, rate_func_decay_eng, .9999, phys.TCMB(phot_spec_init.rs),
#         highengphot_tf_interp, lowengphot_tf_interp, 
#         lowengelec_tf_interp, 
#         end_rs, coarsen_factor=1, std_soln=False
#     )

b_t = evolve(
        elec_spec_init, phot_spec_init*0, 
        rate_func_decay_N, rate_func_decay_eng, xe_std(phot_spec_init.rs), phys.TCMB(phot_spec_init.rs),
        #rate_func_decay_N, rate_func_decay_eng, 2e-4, phys.TCMB(phot_spec_init.rs),
        highengphot_tf_interp, lowengphot_tf_interp, 
        lowengelec_tf_interp, 
        end_rs, coarsen_factor=10, std_soln=True
    )

# %%
plt.figure()
# plt.plot(a[3].rs, a[0])
plt.plot(b[3].rs, b[0])
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')


plt.figure()
# plt.plot(a[3].rs, a[1]/phys.kB)
plt.plot(b[3].rs, b[1]/phys.kB)
plt.plot(b[3].rs, phys.TCMB(b[3].rs)/phys.kB, 'k:')
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')

# %%
test_tf = highengphot_tf_interp.get_tf(4, xe_std(3000))
highengphot_tf_interp.xe

# %%
plt.figure()

ax = plt.gca()

print(test_tf.in_eng[375])

test_tf.plot(ax, ind=250, indtype='ind')
test_tf.plot(ax, ind=377, indtype='ind')


ax.set_xscale('log')
ax.set_yscale('log')
plt.axis([1e-4, 7e12, 1e-42, 1e7])

# %%
test_spectra = highengphot_tf_interp._grid_vals[-1,-1,:,:]

plt.figure()
ax = plt.gca()

plt.plot(highengphot_tf_interp.eng, test_spectra[370, :])

ax.set_xscale('log')
ax.set_yscale('log')
plt.axis([1e-4, 7e12, 1e-42, 1e7])

# %%
tf_before_interp = highengphot_tflist_arr[-1][-1]
tf_before_interp_2 = highengphot_tflist_arr[-1][0]

# print(tf_before_interp.in_eng[376])

plt.figure()
ax = plt.gca()
# tf_before_interp.plot(ax, ind=200, indtype='ind')
tf_before_interp.plot(ax, ind=370, indtype='ind')
# tf_before_interp_2.plot(ax, ind=376, indtype='ind')


ax.set_xscale('log')
ax.set_yscale('log')
plt.axis([1e-4, 7e12, 1e-42, 1e7])

# %%
lowengphot_spectra = b[3]
print(lowengphot_spectra.in_eng)

lowengphot_spectra *= (rate_func_decay_N(3000) * (0.002/phys.hubble(3000)) / (phys.nB * 3000**3))**(-1)

print(lowengphot_spectra[0].toteng())

plt.figure()
ax = plt.gca()

lowengphot_spectra.switch_spec_type()
lowengphot_spectra.plot(ax, ind=0, indtype='ind')
lowengphot_spectra.switch_spec_type()

ax.set_xscale('log')
ax.set_yscale('log')

plt.axis([1e-4, 1e3, 1e-10, 1e6])

# %%
lowengelec_spectra = b[4]

lowengelec_spectra *= (rate_func_decay_N(3000) * (0.002/phys.hubble(3000)) / (phys.nB * 3000**3))**(-1)

print(lowengelec_spectra[0].toteng())
utils.compare_arr([lowengelec_spectra[0].eng, lowengelec_spectra[0].dNdE])

plt.figure()
ax = plt.gca()

lowengelec_spectra.switch_spec_type()
lowengelec_spectra.plot(ax, ind=0, indtype='ind')
lowengelec_spectra.switch_spec_type()

ax.set_xscale('log')
ax.set_yscale('log')

plt.axis([1, 3e3, 1e-4, 1e3])

# %%
highengphot_spectra = b[2]

highengphot_spectra *= (rate_func_decay_N(3000) * (0.002/phys.hubble(3000)) / (phys.nB * 3000**3))**(-1)

print(2*10**9.104)
print(highengphot_spectra[0].toteng())
print(highengphot_spectra[1].toteng())

plt.figure()
ax = plt.gca()

highengphot_spectra.switch_spec_type()
highengphot_spectra.plot(ax, ind=1, indtype='ind')
highengphot_spectra.switch_spec_type()

ax.set_xscale('log')
ax.set_yscale('log')

plt.axis([1e-4,5e12, 1e-40, 1e10])
