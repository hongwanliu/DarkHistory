# %% [markdown]
# # Initialization

# %%
# %load_ext autoreload
# %load_ext line_profiler
import sys
sys.path.append("..")

# %%
# %autoreload

import numpy as np
import pickle

import main


import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc_file('matplotlibrc')

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [10,10]


import darkhistory.physics as phys
import darkhistory.utilities as utils
import darkhistory.spec.transferfunction as tf
import darkhistory.spec.spectools as spectools

from darkhistory.spec.spectrum import Spectrum

from darkhistory.electrons.ics.ics_spectrum import ics_spec
from darkhistory.electrons.ics.ics_engloss_spectrum import engloss_spec
from darkhistory.electrons.elec_cooling import get_elec_cooling_tf_fast

from darkhistory.electrons import positronium

from scipy.interpolate import interp1d

# %%
ics_thomson_ref_tf=pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/tflists/ics/ics_thomson_ref_tf.raw", "rb")) 
ics_rel_ref_tf=pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/tflists/ics/ics_rel_ref_tf.raw", "rb"))
engloss_ref_tf=pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/tflists/ics/engloss_ref_tf.raw", "rb"))

# %%
# %autoreload

eleceng = 10**np.arange(0, np.log10(5e12), 0.0254)
photeng = 10**np.arange(-4, np.log10(5e12), 0.0334)


rs = 600
xe = 1e-2

from darkhistory.spec.spectra import Spectra

coll_ion_sec_elec_specs = (
    phys.coll_ion_sec_elec_spec(eleceng, eleceng, species='HI'),
    phys.coll_ion_sec_elec_spec(eleceng, eleceng, species='HeI'),
    phys.coll_ion_sec_elec_spec(eleceng, eleceng, species='HeII')
)

coll_exc_sec_elec_tf_HI = tf.TransFuncAtRedshift(
    np.squeeze(np.identity(eleceng.size)[:, np.where(eleceng > phys.lya_eng)]),
    in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    eng = eleceng[eleceng > phys.lya_eng] - phys.lya_eng,
    dlnz = -1, spec_type = 'N'
)

coll_exc_sec_elec_tf_HeI = tf.TransFuncAtRedshift(
    np.squeeze(np.identity(eleceng.size)[:, np.where(eleceng > phys.He_exc_eng)]),
    in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    eng = eleceng[eleceng > phys.He_exc_eng] - phys.He_exc_eng,
    dlnz = -1, spec_type = 'N'
)

coll_exc_sec_elec_tf_HeII = tf.TransFuncAtRedshift(
    np.squeeze(np.identity(eleceng.size)[:, np.where(eleceng > 4*phys.lya_eng)]),
    in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    eng = eleceng[eleceng > 4*phys.lya_eng] - 4*phys.lya_eng,
    dlnz = -1, spec_type = 'N'
)

coll_exc_sec_elec_tf_HI.rebin(eleceng)
coll_exc_sec_elec_tf_HeI.rebin(eleceng)
coll_exc_sec_elec_tf_HeII.rebin(eleceng)

coll_exc_sec_elec_specs = (
    coll_exc_sec_elec_tf_HI.grid_vals,
    coll_exc_sec_elec_tf_HeI.grid_vals,
    coll_exc_sec_elec_tf_HeII.grid_vals
)

from darkhistory.spec.spectools import EnglossRebinData

ics_engloss_data = EnglossRebinData(eleceng, photeng, eleceng)
# Out:
# ../darkhistory/spec/spectra.py:401: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   np.issubdtype(type(other), float)
# ../darkhistory/spec/spectra.py:402: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   or np.issubdtype(type(other), int)

# %%
# %%prun
get_elec_cooling_tf_fast(
    ics_thomson_ref_tf, ics_rel_ref_tf, engloss_ref_tf, 
    coll_ion_sec_elec_specs, coll_exc_sec_elec_specs, 
    eleceng, photeng, rs, xe, xHe=0, ics_engloss_data = ics_engloss_data, check_conservation_eng=True, verbose=False
)

# %% [markdown]
# # With Linear Algebra

# %%
def get_elec_cooling_tf_fast_linalg(
    raw_nonrel_tf, raw_rel_tf, raw_engloss_tf,
    coll_ion_sec_elec_specs, coll_exc_sec_elec_specs,
    eleceng, photeng, rs, xe, xHe=0, ics_engloss_data=None, 
    check_conservation_eng = False, verbose=False
):

    """Returns transfer function for complete electron cooling through ICS and atomic processes.

    Parameters
    ----------
    nonrel_tf : TransFuncAtRedshift
        Raw nonrelativistic primary electron ICS transfer function.
    rel_tf : string
        Raw relativistic primary electron ICS transfer function.
    engloss_tf_filename : string
        Raw primary electron ICS energy loss transfer function.
    coll_ion_sec_elec_specs : tuple of ndarray
        Normalized collisional ionization secondary electron spectra, order HI, HeI, HeII, indexed by eleceng (injection) x eleceng (abscissa).
    coll_exc_sec_elec_specs : tuple of ndarray
        Normalized collisional excitation secondary electron spectra, order HI, HeI, HeII, indexed by eleceng (injection) x eleceng (abscissa).
    eleceng : ndarray
        The electron *kinetic* energy abscissa.
    photeng : ndarray
        The photon energy abscissa.
    rs : float
        The redshift.
    xe : float
        Free electron fraction. 
    xHe : float, optional
        Singly-ionized helium fraction, nHe+/nH. Set to nHe/nH*xe if None.
    ics_engloss_data : EnglossRebinData
        Stores rebinning information for speed. 
    check_conservation_eng : bool
        If true, checks for energy conservation.
    verbose : bool
        If true, prints energy conservation checks.
    
    Returns
    -------

    tuple of TransFuncAtRedshift
        Transfer functions for photons and low energy electrons.

    Note
    ----
    The raw transfer functions should be generated when the code package is first installed. The transfer function corresponds to the fully resolved
    photon spectrum after scattering by one electron.

    This version of the code works faster, but dispenses with energy conservation checks and several other safeguards. Use only with default abscissa, or when get_ics_cooling_tf works.

    """

    if xHe is None:
        xHe = xe*phys.nHe/phys.nH
        
    # v/c of electrons, important subsequently.
    beta_ele = np.sqrt(1 - 1/(1 + eleceng/phys.me)**2)
        
    #####################################
    # Inverse Compton
    #####################################

    T = phys.TCMB(rs)

    # Photon transfer function for single primary electron single scattering.
    # This is dN/(dE dt), dt = 1 s.
    phot_ICS_tf = ics_spec(
        eleceng, photeng, T, nonrel_tf = raw_nonrel_tf, rel_tf = raw_rel_tf
    )

    # Downcasting speeds up np.dot
    phot_ICS_tf._grid_vals = phot_ICS_tf.grid_vals.astype('float64')

    # Energy loss transfer function for single primary electron
    # single scattering. This is dN/(dE dt), dt = 1 s.
    engloss_ICS_tf = engloss_spec(
        eleceng, photeng, T, nonrel_tf = raw_engloss_tf, rel_tf = raw_rel_tf
    )

    # Downcasting speeds up np.dot
    engloss_ICS_tf._grid_vals = engloss_ICS_tf.grid_vals.astype('float64')

    # Switch the spectra type here to type 'N'.
    if phot_ICS_tf.spec_type == 'dNdE':
        phot_ICS_tf.switch_spec_type()
    if engloss_ICS_tf.spec_type == 'dNdE':
        engloss_ICS_tf.switch_spec_type()


    # Define some useful lengths.
    N_eleceng = eleceng.size
    N_photeng = photeng.size

    # Create the secondary electron transfer functions.

    # ICS transfer function.
    elec_ICS_tf = tf.TransFuncAtRedshift(
        np.zeros((N_eleceng, N_eleceng)), in_eng = eleceng,
        rs = rs*np.ones_like(eleceng), eng = eleceng,
        dlnz = -1, spec_type = 'N'
    )

    if ics_engloss_data is not None:
        elec_ICS_tf._grid_vals = ics_engloss_data.rebin(
            engloss_ICS_tf.grid_vals
        )
    else:
        elec_ICS_tf._grid_vals = spectools.engloss_rebin_fast(
            eleceng, photeng, engloss_ICS_tf.grid_vals, eleceng
        )
    
    # Total upscattered photon energy.
    cont_loss_ICS_vec = np.zeros_like(eleceng)
    # Deposited energy, enforces energy conservation.
    deposited_ICS_vec = np.zeros_like(eleceng)
    
    
    #####################
    # Excitation  
    #####################
    
    # Construct the rate matrices first. Secondary electron spectrum is an electron at in_eng - excitation energy, 
    # with a per second rate given by n*sigma*c.
    

    # rate_matrix_exc_HI = np.diag(
    #     (1 - xe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HI') * beta_ele * phys.c
    # )
    
    # rate_matrix_exc_HeI = np.diag(
    #     (phys.nHe/phys.nH - xHe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeI') * beta_ele * phys.c
    # )
    
    # rate_matrix_exc_HeII = np.diag(
    #     xHe*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeII') * beta_ele * phys.c
    # )

    # Construct the TransFuncAtRedshift objects.
    # Electrons scatter from in_eng to in_eng - excitation energy.
    # Remove all of the columns (eng) that have energies below the excitation energy, 
    # elec_exc_HI_tf = tf.TransFuncAtRedshift(
    #     np.squeeze(rate_matrix_exc_HI[:, np.where(eleceng > phys.lya_eng)]), 
    #     in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    #     eng = eleceng[eleceng > phys.lya_eng] - phys.lya_eng,
    #     dlnz = -1, spec_type = 'N'
    # )
    # elec_exc_HeI_tf = tf.TransFuncAtRedshift(
    #     np.squeeze(rate_matrix_exc_HeI[:, np.where(eleceng > phys.He_exc_eng)]), 
    #     in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    #     eng = eleceng[eleceng > phys.He_exc_eng] - phys.He_exc_eng,
    #     dlnz = -1, spec_type = 'N'
    # )
    # elec_exc_HeII_tf = tf.TransFuncAtRedshift(
    #     np.squeeze(rate_matrix_exc_HeII[:, np.where(eleceng > 4*phys.lya_eng)]), 
    #     in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    #     eng = eleceng[eleceng > 4*phys.lya_eng] - 4*phys.lya_eng,
    #     dlnz = -1, spec_type = 'N'
    # )
    
    # Rebin these transfer functions back to eleceng.
    # elec_exc_HI_tf.rebin(eleceng)
    # elec_exc_HeI_tf.rebin(eleceng)
    # elec_exc_HeII_tf.rebin(eleceng)

    rate_vec_exc_HI = (
        (1 - xe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HI') * beta_ele * phys.c
    )
    
    rate_vec_exc_HeI = (
        (phys.nHe/phys.nH - xHe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeI') * beta_ele * phys.c
    )
    
    rate_vec_exc_HeII = (
        xHe*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeII') * beta_ele * phys.c
    )

    elec_exc_HI_tf = tf.TransFuncAtRedshift(
        rate_vec_exc_HI[:, np.newaxis]*coll_exc_sec_elec_specs[0],
        in_eng = eleceng, rs = rs*np.ones_like(eleceng),
        eng = eleceng, dlnz = -1, spec_type  = 'N'
    )

    elec_exc_HeI_tf = tf.TransFuncAtRedshift(
        rate_vec_exc_HeI[:, np.newaxis]*coll_exc_sec_elec_specs[1],
        in_eng = eleceng, rs = rs*np.ones_like(eleceng),
        eng = eleceng, dlnz = -1, spec_type  = 'N'
    )

    elec_exc_HeII_tf = tf.TransFuncAtRedshift(
        rate_vec_exc_HeII[:, np.newaxis]*coll_exc_sec_elec_specs[2],
        in_eng = eleceng, rs = rs*np.ones_like(eleceng),
        eng = eleceng, dlnz = -1, spec_type  = 'N'
    )
   
    # Deposited energy for excitation.
    deposited_exc_vec = np.zeros_like(eleceng)
    
    #####################
    # Ionization  
    #####################
    
    # Construct the rate vector first. Secondary electron spectrum is an electron at in_eng - excitation energy, 
    # with a per second rate given by n*sigma*c.
    rate_vec_ion_HI = (
        (1 - xe)*phys.nH*rs**3 
        * phys.coll_ion_xsec(eleceng, species='HI') * beta_ele * phys.c
    )
    
    rate_vec_ion_HeI = (
        (phys.nHe/phys.nH - xHe)*phys.nH*rs**3 
        * phys.coll_ion_xsec(eleceng, species='HeI') * beta_ele * phys.c
    )
    
    rate_vec_ion_HeII = (
        xHe*phys.nH*rs**3 * 
        phys.coll_ion_xsec(eleceng, species='HeII') * beta_ele * phys.c
    )
    
    # Construct the spectra. 
    # elec_spec_ion_HI = np.array(
    #     [rate*phys.coll_ion_sec_elec_spec(in_eng, eleceng, species='HI') 
    # for rate,in_eng in zip(rate_vec_ion_HI,eleceng)]
    # )
    # elec_spec_ion_HeI = np.array(
    #     [rate*phys.coll_ion_sec_elec_spec(in_eng, eleceng, species='HeI') 
    # for rate,in_eng in zip(rate_vec_ion_HeI,eleceng)]
    # )
    # elec_spec_ion_HeII = np.array(
    #     [rate*phys.coll_ion_sec_elec_spec(in_eng, eleceng, species='HeII') 
    # for rate,in_eng in zip(rate_vec_ion_HeII,eleceng)]
    # )

    # transpose to force multiplication along first axis.
    elec_spec_ion_HI   = (
        rate_vec_ion_HI[:,np.newaxis]   * coll_ion_sec_elec_specs[0]
    )
    elec_spec_ion_HeI  = (
        rate_vec_ion_HeI[:,np.newaxis]  * coll_ion_sec_elec_specs[1]
    )
    elec_spec_ion_HeII = (
        rate_vec_ion_HeII[:,np.newaxis] * coll_ion_sec_elec_specs[2]
    )
    
    # Construct the TransFuncAtRedshift objects.
    # Electrons scatter from in_eng to in_eng - excitation energy.
    # Remove all of the columns (eng) that have energies below the 
    # excitation energy, 
    elec_ion_HI_tf = tf.TransFuncAtRedshift(
        elec_spec_ion_HI, in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
        eng = eleceng, dlnz = -1, spec_type = 'N'
    )
    elec_ion_HeI_tf = tf.TransFuncAtRedshift(
        elec_spec_ion_HeI, in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
        eng = eleceng, dlnz = -1, spec_type = 'N'
    )
    elec_ion_HeII_tf = tf.TransFuncAtRedshift(
        elec_spec_ion_HeII, in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
        eng = eleceng, dlnz = -1, spec_type = 'N'
    )
    
    # Deposited energy for ionization.
    deposited_ion_vec = np.zeros_like(eleceng)
    
    #############################################
    # Heating
    #############################################
    
    dE_heat_dt = phys.elec_heating_engloss_rate(eleceng, xe, rs)
    
    deposited_heat_vec = np.zeros_like(eleceng)

    # new_eleceng = eleceng - dE_heat_dt

    # if not np.all(new_eleceng[1:] > eleceng[:-1]):
    #     utils.compare_arr([new_eleceng, eleceng])
    #     raise ValueError('heating loss is too large: smaller time step required.')

    # # After the check above, we can define the spectra by
    # # manually assigning slightly less than 1 particle along
    # # diagonal, and a small amount in the bin below. 

    # # N_n-1 E_n-1 + N_n E_n = E_n - dE_dt
    # # N_n-1 + N_n = 1
    # # therefore, (1 - N_n) E_n-1 - (1 - N_n) E_n = - dE_dt
    # # i.e. N_n = 1 + dE_dt/(E_n-1 - E_n)

    elec_heat_spec_grid = np.identity(eleceng.size)
    elec_heat_spec_grid[0,0] -= dE_heat_dt[0]/eleceng[0]
    elec_heat_spec_grid[1:, 1:] += np.diag(
        dE_heat_dt[1:]/(eleceng[:-1] - eleceng[1:])
    )
    elec_heat_spec_grid[1:, :-1] -= np.diag(
        dE_heat_dt[1:]/(eleceng[:-1] - eleceng[1:])
    )

    
    
    #############################################
    # Initialization of secondary spectra 
    #############################################

    # Low and high energy boundaries
    loweng = 3000
    eleceng_high = eleceng[eleceng > loweng]
    eleceng_high_ind = np.arange(eleceng.size)[eleceng > loweng]
    eleceng_low = eleceng[eleceng <= loweng]
    eleceng_low_ind  = np.arange(eleceng.size)[eleceng <= loweng]


    if eleceng_low.size == 0:
        raise TypeError('Energy abscissa must contain a low energy bin below 3 keV.')

    # Empty containers for quantities.
    # Final secondary photon spectrum.
    sec_phot_tf = tf.TransFuncAtRedshift(
        np.zeros((N_eleceng, N_photeng)), in_eng = eleceng,
        rs = rs*np.ones_like(eleceng), eng = photeng,
        dlnz = -1, spec_type = 'N'
    )
    # Final secondary low energy electron spectrum.
    sec_lowengelec_tf = tf.TransFuncAtRedshift(
        np.zeros((N_eleceng, N_eleceng)), in_eng = eleceng,
        rs = rs*np.ones_like(eleceng), eng = eleceng,
        dlnz = -1, spec_type = 'N'
    )

    # Start building sec_phot_tf and sec_lowengelec_tf.
    # Low energy regime first.

    sec_lowengelec_tf._grid_vals[:eleceng_low.size, :eleceng_low.size] = (
        np.identity(eleceng_low.size)
    )

    # Continuum energy loss rate per electron, dU_CMB/dt.
    CMB_upscatter_eng_rate = phys.thomson_xsec*phys.c*phys.CMB_eng_density(T)
    
    sec_elec_spec_N_arr = (
        elec_ICS_tf.grid_vals
        + elec_exc_HI_tf.grid_vals + elec_exc_HeI_tf.grid_vals + elec_exc_HeII_tf.grid_vals
        + elec_ion_HI_tf.grid_vals + elec_ion_HeI_tf.grid_vals + elec_ion_HeII_tf.grid_vals
        + elec_heat_spec_grid
    )
    
    sec_phot_spec_N_arr = phot_ICS_tf.grid_vals
    
    sec_elec_totN_arr = np.sum(sec_elec_spec_N_arr, axis=1)
    sec_elec_toteng_arr = np.dot(sec_elec_spec_N_arr, eleceng)
    sec_phot_toteng_arr = np.dot(sec_phot_spec_N_arr, photeng)
    
    deposited_ICS_eng_arr = (
        np.sum(elec_ICS_tf.grid_vals, axis=1)*eleceng
        - np.dot(elec_ICS_tf.grid_vals, eleceng)
        - (np.dot(sec_phot_spec_N_arr, photeng) - CMB_upscatter_eng_rate)
    )
    
    deposited_ICS_eng_arr[eleceng > 20*phys.me - phys.me] -= CMB_upscatter_eng_rate
    continuum_engloss_arr = CMB_upscatter_eng_rate*np.ones_like(eleceng)
    continuum_engloss_arr[eleceng > 20*phys.me - phys.me] = 0
    
    
    deposited_exc_eng_arr = (
        phys.lya_eng*np.sum(elec_exc_HI_tf.grid_vals, axis=1)
        + phys.He_exc_eng*np.sum(elec_exc_HeI_tf.grid_vals, axis=1)
        + 4*phys.lya_eng*np.sum(elec_exc_HeII_tf.grid_vals, axis=1)
    )
    
    deposited_ion_eng_arr = (
        phys.rydberg*np.sum(elec_ion_HI_tf.grid_vals, axis=1)/2
        + phys.He_ion_eng*np.sum(elec_ion_HeI_tf.grid_vals, axis=1)/2
        + 4*phys.rydberg*np.sum(elec_ion_HeII_tf.grid_vals, axis=1)/2
    )
    deposited_heat_eng_arr = dE_heat_dt
    
    # remove self-scattering, re-normalize. 
    np.fill_diagonal(sec_elec_spec_N_arr, 0)
    
    toteng_no_self_scatter_arr = (
        np.dot(sec_elec_spec_N_arr, eleceng)
        + np.dot(sec_phot_spec_N_arr, photeng)
        - continuum_engloss_arr
        + deposited_ICS_eng_arr
        + deposited_exc_eng_arr
        + deposited_ion_eng_arr
        + deposited_heat_eng_arr
    )
    
    fac_arr = eleceng/toteng_no_self_scatter_arr
    
    sec_elec_spec_N_arr *= fac_arr[:, np.newaxis]
    sec_phot_spec_N_arr *= fac_arr[:, np.newaxis]
    continuum_engloss_arr  *= fac_arr
    deposited_ICS_eng_arr  *= fac_arr
    deposited_exc_eng_arr  *= fac_arr
    deposited_ion_eng_arr  *= fac_arr
    deposited_heat_eng_arr *= fac_arr
    
    deposited_ICS_eng_arr[eleceng < loweng]  = 0
    deposited_exc_eng_arr[eleceng < loweng]  = 0
    deposited_ion_eng_arr[eleceng < loweng]  = 0
    deposited_heat_eng_arr[eleceng < loweng] = 0
    
    continuum_engloss_arr[eleceng < loweng]  = 0
    
    sec_phot_spec_N_arr[eleceng < loweng] = 0
    
    sec_lowengelec_N_arr = np.identity(eleceng.size)
    sec_lowengelec_N_arr[eleceng >= loweng] = 0
    sec_lowengelec_N_arr[eleceng_high_ind[0]:, :eleceng_high_ind[0]] += sec_elec_spec_N_arr[eleceng_high_ind[0]:, :eleceng_high_ind[0]]

    sec_highengelec_N_arr = np.zeros_like(sec_elec_spec_N_arr)
    sec_highengelec_N_arr[:, eleceng_high_ind[0]:] = sec_elec_spec_N_arr[:, eleceng_high_ind[0]:]
    
    # T = E.T + Prompt
    deposited_ICS_vec_linalg  = np.linalg.solve(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_ICS_eng_arr)
    deposited_exc_vec_linalg  = np.linalg.solve(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_exc_eng_arr)
    deposited_ion_vec_linalg  = np.linalg.solve(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_ion_eng_arr)
    deposited_heat_vec_linalg = np.linalg.solve(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_heat_eng_arr)
    
    continuum_engloss_vec_linalg = np.linalg.solve(np.identity(eleceng.size) - sec_elec_spec_N_arr, continuum_engloss_arr)
    
    sec_phot_tf_linalg = np.linalg.solve(np.identity(eleceng.size) - sec_elec_spec_N_arr, sec_phot_spec_N_arr)
    
    # Prompt: low energy e produced in secondary spectrum upon scattering (sec_lowengelec_N_arr).
    # T : high energy e produced (sec_highengelec_N_arr). 
    sec_lowengelec_tf_linalg = np.linalg.solve(np.identity(eleceng.size) - sec_highengelec_N_arr, sec_lowengelec_N_arr)
    # High energy electron loop to get fully resolved spectrum.
    for i, eng in zip(eleceng_high_ind, eleceng_high):
        
        phot_ICS_N = phot_ICS_tf.grid_vals[i]
        
        elec_ICS_N      = elec_ICS_tf.grid_vals[i]
        
        elec_exc_HI_N   = elec_exc_HI_tf.grid_vals[i]
        elec_exc_HeI_N  = elec_exc_HeI_tf.grid_vals[i]
        elec_exc_HeII_N = elec_exc_HeII_tf.grid_vals[i]
        
        elec_ion_HI_N   = elec_ion_HI_tf.grid_vals[i]
        elec_ion_HeI_N  = elec_ion_HeI_tf.grid_vals[i]
        elec_ion_HeII_N = elec_ion_HeII_tf.grid_vals[i]
                
        # elec_heat_spec = spectools.rebin_N_arr(np.array([1]), np.array([eng]), eleceng)
        # elec_heat_spec.eng -= dE_heat_dt[i]
        # elec_heat_spec.rebin(eleceng)
        # elec_heat_N = elec_heat_spec.N

        elec_heat_N = elec_heat_spec_grid[i]        
        
        sec_elec_spec_N = sec_elec_spec_N_arr[i]
        sec_phot_spec_N = phot_ICS_N
        

        sec_elec_totN = sec_elec_totN_arr[i]
        # The *net* total energy of secondary electrons produced
        # per unit time.
        sec_elec_toteng = sec_elec_toteng_arr[i]
        # The total energy of secondary photons produced per unit time.
        sec_phot_toteng = sec_phot_toteng_arr[i]
        # Deposited ICS energy per unit time, dD/dt.
        # Numerical error (should be zero except for numerics)
        deposited_ICS_eng = deposited_ICS_eng_arr[i]
        # Deposited excitation energy. 
        deposited_exc_eng = deposited_exc_eng_arr[i]
        # Deposited ionization energy. Remember that the secondary spectrum
        # has two electrons for each ionization event.
        deposited_ion_eng = deposited_ion_eng_arr[i]
        # Deposited heating energy. 
        deposited_heat_eng = deposited_heat_eng_arr[i]
        
        # In the original code, the energy of the electron has gamma > 20,
        # then the continuum energy loss is assigned 
        # to deposited_eng instead.
        # I'm not sure if this is necessary, but let's be consistent with the
        # original code for now.

#         continuum_engloss = CMB_upscatter_eng_rate
        
#         if eng + phys.me > 20*phys.me:
#             deposited_ICS_eng -= CMB_upscatter_eng_rate
#             continuum_engloss = 0

        continuum_engloss = continuum_engloss_arr[i]

        # Remove self-scattering.
#         sec_elec_spec_N[i] = 0
        
        # Rescale.
#         toteng_no_self_scatter = (
#             np.dot(sec_elec_spec_N, eleceng)
#             + np.dot(sec_phot_spec_N, photeng)
#             - continuum_engloss
#             + deposited_ICS_eng
#             + deposited_exc_eng
#             + deposited_ion_eng
#             + deposited_heat_eng
#         )
        toteng_no_self_scatter = toteng_no_self_scatter_arr[i]
        
#         fac = eng/toteng_no_self_scatter
        # Normalize to one electron. 
        
#         sec_elec_spec_N    *= fac
#         sec_phot_spec_N    *= fac
#         continuum_engloss  *= fac
#         deposited_ICS_eng  *= fac
#         deposited_exc_eng  *= fac
#         deposited_ion_eng  *= fac
#         deposited_heat_eng *= fac

        # Get the full secondary photon spectrum. Type 'N'
        resolved_phot_spec_vals = np.dot(
            sec_elec_spec_N, sec_phot_tf.grid_vals
        )
        
        # Get the full secondary low energy electron spectrum. Type 'N'.

        resolved_lowengelec_spec_vals = np.dot(
            sec_elec_spec_N, sec_lowengelec_tf.grid_vals
        )
        
        # Add the resolved spectrum to the first scatter.
        sec_phot_spec_N += resolved_phot_spec_vals

        # Resolve the secondary electron continuum loss and deposition.
        continuum_engloss += np.dot(sec_elec_spec_N, cont_loss_ICS_vec)

        deposited_ICS_eng  += np.dot(sec_elec_spec_N, deposited_ICS_vec)
        deposited_exc_eng  += np.dot(sec_elec_spec_N, deposited_exc_vec)
        deposited_ion_eng  += np.dot(sec_elec_spec_N, deposited_ion_vec)
        deposited_heat_eng += np.dot(sec_elec_spec_N, deposited_heat_vec)

        # Now, append the resulting spectrum to the transfer function.
        # Do this without calling append of course: just add to the zeros
        # that fill the current row in _grid_vals.
        sec_phot_tf._grid_vals[i] += sec_phot_spec_N
        sec_lowengelec_tf._grid_vals[i] += resolved_lowengelec_spec_vals
        # Set the correct values in cont_loss_vec and deposited_vec.
        
        cont_loss_ICS_vec[i]  = continuum_engloss
        deposited_ICS_vec[i]  = deposited_ICS_eng
        deposited_exc_vec[i]  = deposited_exc_eng
        deposited_ion_vec[i]  = deposited_ion_eng
        deposited_heat_vec[i] = deposited_heat_eng

        
        failed_conservation_check = False
        
        if check_conservation_eng:

            conservation_check = (
                eng
                - np.dot(sec_lowengelec_tf.grid_vals[i], eleceng)
                + cont_loss_ICS_vec[i]
                - np.dot(sec_phot_tf.grid_vals[i], photeng)
                - deposited_exc_vec[i]
                - deposited_ion_vec[i]
                - deposited_heat_vec[i]
            )

            if np.abs(conservation_check/eng) > 0.1:
                failed_conservation_check = True
                print('failed!')
                
            if verbose or failed_conservation_check:
                
                print('***************************************************')
                print('rs: ', rs)
                print('injected energy: ', eng)
                print(
                    'Energy in low energy electrons: ',
                    np.dot(sec_lowengelec_tf.grid_vals[i], eleceng)
                )
                print(
                    'Energy in low energy electrons (linalg): ',
                    np.dot(sec_lowengelec_tf_linalg[i], eleceng)
                )
                utils.compare_arr([eleceng, sec_lowengelec_tf.grid_vals[i], sec_lowengelec_tf_linalg[i]])
                print('Energy in photons: ', np.dot(sec_phot_tf.grid_vals[i], photeng))
                print('Energy in photons (linalg): ', np.dot(sec_phot_tf_linalg[i], photeng))
                print('Continuum_engloss: ', cont_loss_ICS_vec[i])
                print('Continuum_engloss (linalg): ', continuum_engloss_vec_linalg[i])
                
                print(
                    'Energy in photons - Continuum: ',
                    np.dot(sec_phot_tf.grid_vals[i], photeng) - cont_loss_ICS_vec[i]
                )
                print(
                    'Deposited in ionization: ', deposited_ion_vec[i]
                )
                print(
                    'Deposited in ionization (linalg): ', deposited_ion_vec_linalg[i]
                )
                print(
                    'Deposited in excitation: ', deposited_exc_vec[i]
                )
                print(
                    'Deposited in excitation (linalg): ', deposited_exc_vec_linalg[i]
                )
                print(
                    'Deposited in heating: ', deposited_heat_vec[i]
                )
                print(
                    'Deposited in heating (linalg): ', deposited_heat_vec_linalg[i]
                )
                print(
                    'Energy is conserved up to (%): ',
                    conservation_check/eng*100
                )
                print('Deposited in ICS: ', deposited_ICS_vec[i])
                print('Deposited in ICS (linalg): ', deposited_ICS_vec_linalg[i])
                print(
                    'Energy conservation with deposited (%): ',
                    (conservation_check - deposited_ICS_vec[i])/eng*100
                )
                print('***************************************************')
                
            if failed_conservation_check:
                raise RuntimeError('Conservation of energy failed.')


    return (
        sec_phot_tf, sec_lowengelec_tf,
        deposited_ion_vec, deposited_exc_vec, deposited_heat_vec,
        cont_loss_ICS_vec, deposited_ICS_vec
    )

# %%
# %%prun
get_elec_cooling_tf_fast_linalg(
    ics_thomson_ref_tf, ics_rel_ref_tf, engloss_ref_tf, 
    coll_ion_sec_elec_specs, coll_exc_sec_elec_specs, 
    eleceng, photeng, rs, xe, xHe=0, ics_engloss_data = ics_engloss_data, check_conservation_eng=True, verbose=True
)
# Out:
# ***************************************************
# rs:  600
# injected energy:  3018.5613014197993
# Energy in low energy electrons:  2901.50338868706
# Energy in low energy electrons (linalg):  2901.50338868706
# [[1.00000000e+00 1.38950284e-02 1.38950284e-02]
#  [1.06022978e+00 1.47086070e-02 1.47086070e-02]
#  [1.12408719e+00 1.55666490e-02 1.55666490e-02]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  2672.465358972423
# Energy in photons (linalg):  2672.465358972423
# Continuum_engloss:  2630.84103571871
# Continuum_engloss (linalg):  2630.84103571871
# Energy in photons - Continuum:  41.6243232537131
# Deposited in ionization:  40.13101693341628
# Deposited in ionization (linalg):  40.13101693341628
# Deposited in excitation:  27.84907658465386
# Deposited in excitation (linalg):  27.84907658465386
# Deposited in heating:  7.512255561388976
# Deposited in heating (linalg):  7.512255561388976
# Energy is conserved up to (%):  -0.0019466094793372003
# Deposited in ICS:  -0.0587596004339604
# Deposited in ICS (linalg):  -0.0587596004339604
# Energy conservation with deposited (%):  3.0419024154926075e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3200.368594586517
# Energy in low energy electrons:  2963.516543788905
# Energy in low energy electrons (linalg):  2963.516543788905
# [[1.00000000e+00 2.76703330e-02 2.76703330e-02]
#  [1.06022978e+00 2.92904838e-02 2.92904838e-02]
#  [1.12408719e+00 3.09991789e-02 3.09991789e-02]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  5388.308064862846
# Energy in photons (linalg):  5388.308064862847
# Continuum_engloss:  5301.769895970508
# Continuum_engloss (linalg):  5301.769895970508
# Energy in photons - Continuum:  86.53816889233804
# Deposited in ionization:  79.94052174076654
# Deposited in ionization (linalg):  79.94052174076653
# Deposited in excitation:  55.56557393289815
# Deposited in excitation (linalg):  55.565573932898154
# Deposited in heating:  14.925481005743613
# Deposited in heating (linalg):  14.925481005743613
# Energy is conserved up to (%):  -0.003677538091506404
# Deposited in ICS:  -0.11769477413599216
# Deposited in ICS (linalg):  -0.11769477413599218
# Energy conservation with deposited (%):  4.5770610959256875e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3393.1261016293156
# Energy in low energy electrons:  3030.502259418956
# Energy in low energy electrons (linalg):  3030.502259418956
# [[1.00000000e+00 4.16610962e-02 4.16610962e-02]
#  [1.06022978e+00 4.41004381e-02 4.41004381e-02]
#  [1.12408719e+00 4.66730958e-02 4.66730958e-02]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  8215.759657580944
# Energy in photons (linalg):  8215.759657580946
# Continuum_engloss:  8079.598180526447
# Continuum_engloss (linalg):  8079.598180526447
# Energy in photons - Continuum:  136.16147705449657
# Deposited in ionization:  120.39661705055867
# Deposited in ionization (linalg):  120.39661705055866
# Deposited in excitation:  83.82335254669772
# Deposited in excitation (linalg):  83.82335254669772
# Deposited in heating:  22.42116176416137
# Deposited in heating (linalg):  22.421161764161365
# Energy is conserved up to (%):  -0.005268481046689338
# Deposited in ICS:  -0.17876620555604186
# Deposited in ICS (linalg):  -0.17876620555604186
# Energy conservation with deposited (%):  4.221913602213523e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3597.4933515574235
# Energy in low energy electrons:  3101.6336469687103
# Energy in low energy electrons (linalg):  3101.6336469687103
# [[1.00000000e+00 5.59782339e-02 5.59782339e-02]
#  [1.06022978e+00 5.92558803e-02 5.92558803e-02]
#  [1.12408719e+00 6.27126593e-02 6.27126593e-02]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  11181.656040091286
# Energy in photons (linalg):  11181.656040091288
# Continuum_engloss:  10990.281852628403
# Continuum_engloss (linalg):  10990.281852628403
# Energy in photons - Continuum:  191.37418746288313
# Deposited in ionization:  161.82024687432158
# Deposited in ionization (linalg):  161.82024687432155
# Deposited in excitation:  112.84923725167019
# Deposited in excitation (linalg):  112.84923725167016
# Deposited in heating:  30.05877582918204
# Deposited in heating (linalg):  30.058775829182032
# Energy is conserved up to (%):  -0.006747554633816057
# Deposited in ICS:  -0.24274282934643845
# Deposited in ICS (linalg):  -0.24274282934643845
# Energy conservation with deposited (%):  6.117965106564268e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3814.169596669385
# Energy in low energy electrons:  3176.528325934346
# Energy in low energy electrons (linalg):  3176.528325934346
# [[1.00000000e+00 7.06742697e-02 7.06742697e-02]
#  [1.06022978e+00 7.48124095e-02 7.48124095e-02]
#  [1.12408719e+00 7.91767121e-02 7.91767121e-02]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  14302.340711597371
# Energy in photons (linalg):  14302.340711597371
# Continuum_engloss:  14049.373240114548
# Continuum_engloss (linalg):  14049.373240114548
# Energy in photons - Continuum:  252.96747148282338
# Deposited in ionization:  204.36387030665713
# Deposited in ionization (linalg):  204.3638703066571
# Deposited in excitation:  142.7537477969991
# Deposited in excitation (linalg):  142.75374779699908
# Deposited in heating:  37.86604407423313
# Deposited in heating (linalg):  37.86604407423312
# Energy is conserved up to (%):  -0.00812399443234491
# Deposited in ICS:  -0.3098629256755979
# Deposited in ICS (linalg):  -0.3098629256755979
# Energy conservation with deposited (%):  5.2036115616240946e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4043.8962050781943
# Energy in low energy electrons:  3254.9783669598805
# Energy in low energy electrons (linalg):  3254.9783669598805
# [[1.00000000e+00 8.57767057e-02 8.57767057e-02]
#  [1.06022978e+00 9.07991384e-02 9.07991384e-02]
#  [1.12408719e+00 9.60960655e-02 9.60960655e-02]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  17589.81610122651
# Energy in photons (linalg):  17589.81610122651
# Continuum_engloss:  17268.08021368926
# Continuum_engloss (linalg):  17268.08021368926
# Energy in photons - Continuum:  321.735887537252
# Deposited in ionization:  248.1077315520071
# Deposited in ionization (linalg):  248.1077315520071
# Deposited in excitation:  173.59750437304368
# Deposited in excitation (linalg):  173.59750437304365
# Deposited in heating:  45.85712974769302
# Deposited in heating (linalg):  45.85712974769302
# Energy is conserved up to (%):  -0.009407142824350402
# Deposited in ICS:  -0.3804150916854834
# Deposited in ICS (linalg):  -0.3804150916854834
# Energy conservation with deposited (%):  1.3085813176728214e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4287.459197337658
# Energy in low energy electrons:  3336.844724449694
# Energy in low energy electrons (linalg):  3336.844724449694
# [[1.00000000e+00 1.01300925e-01 1.01300925e-01]
#  [1.06022978e+00 1.07232351e-01 1.07232351e-01]
#  [1.12408719e+00 1.13487954e-01 1.13487954e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  21054.099324833383
# Energy in photons (linalg):  21054.09932483339
# Continuum_engloss:  20655.583767616794
# Continuum_engloss (linalg):  20655.583767616798
# Energy in photons - Continuum:  398.5155572165895
# Deposited in ionization:  293.097074226023
# Deposited in ionization (linalg):  293.097074226023
# Deposited in excitation:  205.41685744411413
# Deposited in excitation (linalg):  205.41685744411413
# Deposited in heating:  54.03968912576557
# Deposited in heating (linalg):  54.03968912576557
# Energy is conserved up to (%):  -0.010605468264475124
# Deposited in ICS:  -0.45470512452854556
# Deposited in ICS (linalg):  -0.45470512452854556
# Energy conservation with deposited (%):  6.018307636104938e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4545.6919358492405
# Energy in low energy electrons:  3422.0319087029234
# Energy in low energy electrons (linalg):  3422.0319087029234
# [[1.00000000e+00 1.17253260e-01 1.17253260e-01]
#  [1.06022978e+00 1.24118750e-01 1.24118750e-01]
#  [1.12408719e+00 1.31359471e-01 1.31359471e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  24703.73892398987
# Energy in photons (linalg):  24703.73892398987
# Continuum_engloss:  24219.543498864037
# Continuum_engloss (linalg):  24219.54349886404
# Energy in photons - Continuum:  484.1954251258321
# Deposited in ionization:  339.35097030261505
# Deposited in ionization (linalg):  339.350970302615
# Deposited in excitation:  238.22989999272443
# Deposited in excitation (linalg):  238.22989999272443
# Deposited in heating:  62.41657123620645
# Deposited in heating (linalg):  62.41657123620646
# Energy is conserved up to (%):  -0.011721857058949865
# Deposited in ICS:  -0.5328395110604452
# Deposited in ICS (linalg):  -0.5328395110604452
# Energy conservation with deposited (%):  -3.004106612503695e-16
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4819.477976251272
# Energy in low energy electrons:  3510.453621766782
# Energy in low energy electrons (linalg):  3510.453621766782
# [[1.00000000e+00 1.33635110e-01 1.33635110e-01]
#  [1.06022978e+00 1.41459818e-01 1.41459818e-01]
#  [1.12408719e+00 1.49712184e-01 1.49712184e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  28546.542445583047
# Energy in photons (linalg):  28546.542445583047
# Continuum_engloss:  27966.809971317234
# Continuum_engloss (linalg):  27966.809971317234
# Energy in photons - Continuum:  579.7324742658129
# Deposited in ionization:  386.8741956719678
# Deposited in ionization (linalg):  386.87419567196775
# Deposited in excitation:  272.04461106780434
# Deposited in excitation (linalg):  272.04461106780434
# Deposited in heating:  70.98807877260515
# Deposited in heating (linalg):  70.98807877260516
# Energy is conserved up to (%):  -0.01276082797207276
# Deposited in ICS:  -0.6150052937038034
# Deposited in ICS (linalg):  -0.6150052937038034
# Energy conservation with deposited (%):  5.073255193156434e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5109.754090546754
# Energy in low energy electrons:  3602.040355126357
# Energy in low energy electrons (linalg):  3602.040355126357
# [[1.00000000e+00 1.50441937e-01 1.50441937e-01]
#  [1.06022978e+00 1.59250750e-01 1.59250750e-01]
#  [1.12408719e+00 1.68541012e-01 1.68541012e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  32589.332259092273
# Energy in photons (linalg):  32589.332259092273
# Continuum_engloss:  31903.18003381545
# Continuum_engloss (linalg):  31903.180033815453
# Energy in photons - Continuum:  686.1522252768227
# Deposited in ionization:  435.65431415236696
# Deposited in ionization (linalg):  435.65431415236685
# Deposited in excitation:  306.85675979082856
# Deposited in excitation (linalg):  306.8567597908285
# Deposited in heating:  79.75144783222504
# Deposited in heating (linalg):  79.75144783222505
# Energy is conserved up to (%):  -0.013719087443858502
# Deposited in ICS:  -0.7010116318445394
# Deposited in ICS (linalg):  -0.7010116318445394
# Energy conservation with deposited (%):  -7.253951020599771e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5417.513472313468
# Energy in low energy electrons:  3696.7115888702538
# Energy in low energy electrons (linalg):  3696.7115888702538
# [[1.00000000e+00 1.67666684e-01 1.67666684e-01]
#  [1.06022978e+00 1.77484077e-01 1.77484077e-01]
#  [1.12408719e+00 1.87838048e-01 1.87838048e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  36838.547796951316
# Energy in photons (linalg):  36838.54779695132
# Continuum_engloss:  36033.985237940164
# Continuum_engloss (linalg):  36033.98523794017
# Energy in photons - Continuum:  804.5625590111522
# Deposited in ionization:  485.6715232291574
# Deposited in ionization (linalg):  485.67152322915723
# Deposited in excitation:  342.65666517016024
# Deposited in excitation (linalg):  342.65666517016024
# Deposited in heating:  88.70271584282871
# Deposited in heating (linalg):  88.70271584282871
# Energy is conserved up to (%):  -0.01461149684498182
# Deposited in ICS:  -0.7915798100846746
# Deposited in ICS (linalg):  -0.7915798100846747
# Energy conservation with deposited (%):  2.0806767581891467e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5743.809134963175
# Energy in low energy electrons:  3794.387412573378
# Energy in low energy electrons (linalg):  3794.387412573378
# [[1.00000000e+00 1.85298183e-01 1.85298183e-01]
#  [1.06022978e+00 1.96147977e-01 1.96147977e-01]
#  [1.12408719e+00 2.07590780e-01 2.07590780e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  41299.88986361965
# Energy in photons (linalg):  41299.88986361965
# Continuum_engloss:  40363.737664495035
# Continuum_engloss (linalg):  40363.737664495035
# Energy in photons - Continuum:  936.1521991246191
# Deposited in ionization:  536.8940612957254
# Deposited in ionization (linalg):  536.8940612957252
# Deposited in excitation:  379.4259494997853
# Deposited in excitation (linalg):  379.4259494997853
# Deposited in heating:  97.83587950135065
# Deposited in heating (linalg):  97.83587950135066
# Energy is conserved up to (%):  -0.015431693687223953
# Deposited in ICS:  -0.8863670316809301
# Deposited in ICS (linalg):  -0.8863670316809302
# Energy conservation with deposited (%):  -9.357766950158644e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6089.757514677294
# Energy in low energy electrons:  3894.955302976026
# Energy in low energy electrons (linalg):  3894.955302976026
# [[1.00000000e+00 2.03325265e-01 2.03325265e-01]
#  [1.06022978e+00 2.15230627e-01 2.15230627e-01]
#  [1.12408719e+00 2.27786696e-01 2.27786696e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  45979.05875539517
# Energy in photons (linalg):  45979.05875539517
# Continuum_engloss:  44896.851891472535
# Continuum_engloss (linalg):  44896.85189147254
# Energy in photons - Continuum:  1082.2068639226345
# Deposited in ionization:  589.2900497032922
# Deposited in ionization (linalg):  589.2900497032921
# Deposited in excitation:  417.14569904089524
# Deposited in excitation (linalg):  417.14569904089524
# Deposited in heating:  107.14512794873491
# Deposited in heating (linalg):  107.14512794873491
# Energy is conserved up to (%):  -0.016183385166248627
# Deposited in ICS:  -0.9855289142834455
# Deposited in ICS (linalg):  -0.9855289142834456
# Energy conservation with deposited (%):  -1.2070920148509656e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6456.542290346556
# Energy in low energy electrons:  3998.313850593191
# Energy in low energy electrons (linalg):  3998.313850593191
# [[1.00000000e+00 2.21731442e-01 2.21731442e-01]
#  [1.06022978e+00 2.34714573e-01 2.34714573e-01]
#  [1.12408719e+00 2.48407324e-01 2.48407324e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  50880.69112234366
# Energy in photons (linalg):  50880.69112234366
# Continuum_engloss:  49636.59341348516
# Continuum_engloss (linalg):  49636.59341348516
# Energy in photons - Continuum:  1244.0977088584987
# Deposited in ionization:  642.8121430798161
# Deposited in ionization (linalg):  642.812143079816
# Deposited in excitation:  455.78577532728315
# Deposited in excitation (linalg):  455.7857753272832
# Deposited in heating:  116.62197591249465
# Deposited in heating (linalg):  116.62197591249465
# Energy is conserved up to (%):  -0.01686914412928334
# Deposited in ICS:  -1.0891634247223771
# Deposited in ICS (linalg):  -1.0891634247223774
# Energy conservation with deposited (%):  -6.683132570756422e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6845.4184335848
# Energy in low energy electrons:  4104.3464583676505
# Energy in low energy electrons (linalg):  4104.3464583676505
# [[1.00000000e+00 2.40498323e-01 2.40498323e-01]
#  [1.06022978e+00 2.54580349e-01 2.54580349e-01]
#  [1.12408719e+00 2.69432062e-01 2.69432062e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  56008.95725981012
# Energy in photons (linalg):  56008.95725981012
# Continuum_engloss:  54585.664040143674
# Continuum_engloss (linalg):  54585.664040143674
# Energy in photons - Continuum:  1423.2932196664478
# Deposited in ionization:  697.4073747984474
# Deposited in ionization (linalg):  697.4073747984474
# Deposited in excitation:  495.31159169822416
# Deposited in excitation (linalg):  495.31159169822416
# Deposited in heating:  126.2571217259265
# Deposited in heating (linalg):  126.25712172592651
# Energy is conserved up to (%):  -0.01749100779613121
# Deposited in ICS:  -1.1973326718953892
# Deposited in ICS (linalg):  -1.1973326718953892
# Energy conservation with deposited (%):  -1.068149290086885e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  7257.716502674278
# Energy in low energy electrons:  4212.922649061483
# Energy in low energy electrons (linalg):  4212.922649061484
# [[1.00000000e+00 2.59605542e-01 2.59605542e-01]
#  [1.06022978e+00 2.74806395e-01 2.74806395e-01]
#  [1.12408719e+00 2.90838094e-01 2.90838094e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  61367.498927878616
# Energy in photons (linalg):  61367.49892787862
# Continuum_engloss:  59746.13626748022
# Continuum_engloss (linalg):  59746.13626748023
# Energy in photons - Continuum:  1621.362660398394
# Deposited in ionization:  753.0169481801813
# Deposited in ionization (linalg):  753.0169481801812
# Deposited in excitation:  535.6839312782239
# Deposited in excitation (linalg):  535.6839312782239
# Deposited in heating:  136.04041430205393
# Deposited in heating (linalg):  136.04041430205396
# Energy is conserved up to (%):  -0.01805113971562615
# Deposited in ICS:  -1.310100546055461
# Deposited in ICS (linalg):  -1.3101005460554611
# Energy conservation with deposited (%):  -8.720287395968306e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  7694.847195134288
# Energy in low energy electrons:  4323.899014550869
# Energy in low energy electrons (linalg):  4323.899014550869
# [[1.00000000e+00 2.79030829e-01 2.79030829e-01]
#  [1.06022978e+00 2.95369137e-01 2.95369137e-01]
#  [1.12408719e+00 3.12600469e-01 3.12600469e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  66959.39588324304
# Energy in photons (linalg):  66959.39588324304
# Continuum_engloss:  65119.416570512156
# Continuum_engloss (linalg):  65119.41657051216
# Energy in photons - Continuum:  1839.9793127308803
# Deposited in ionization:  809.5764320494084
# Deposited in ionization (linalg):  809.5764320494083
# Deposited in excitation:  576.8590528992987
# Deposited in excitation (linalg):  576.8590528992987
# Deposited in heating:  145.96089268595156
# Deposited in heating (linalg):  145.96089268595162
# Energy is conserved up to (%):  -0.018551502660372213
# Deposited in ICS:  -1.4275097821176117
# Deposited in ICS (linalg):  -1.427509782117612
# Energy conservation with deposited (%):  9.066640714004107e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  8158.306174490077
# Energy in low energy electrons:  4437.120200101795
# Energy in low energy electrons (linalg):  4437.120200101795
# [[1.00000000e+00 2.98750129e-01 2.98750129e-01]
#  [1.06022978e+00 3.16243112e-01 3.16243112e-01]
#  [1.12408719e+00 3.34692239e-01 3.34692239e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  72787.14535049316
# Energy in photons (linalg):  72787.14535049316
# Continuum_engloss:  70706.22166326942
# Continuum_engloss (linalg):  70706.22166326942
# Energy in photons - Continuum:  2080.923687223738
# Deposited in ionization:  867.0161096416816
# Deposited in ionization (linalg):  867.0161096416815
# Deposited in excitation:  618.7889108823292
# Deposited in excitation (linalg):  618.7889108823292
# Deposited in heating:  156.00685131014845
# Deposited in heating (linalg):  156.00685131014856
# Energy is conserved up to (%):  -0.018993950906882003
# Deposited in ICS:  -1.5495846696162912
# Deposited in ICS (linalg):  -1.5495846696162914
# Energy conservation with deposited (%):  6.40688138952071e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  8649.67918775693
# Energy in low energy electrons:  4552.419942724832
# Energy in low energy electrons (linalg):  4552.419942724832
# [[1.00000000e+00 3.18737753e-01 3.18737753e-01]
#  [1.06022978e+00 3.37401128e-01 3.37401128e-01]
#  [1.12408719e+00 3.57084626e-01 3.57084626e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  78852.64951835378
# Energy in photons (linalg):  78852.6495183538
# Continuum_engloss:  76506.5627460368
# Continuum_engloss (linalg):  76506.56274603678
# Energy in photons - Continuum:  2346.0867723169795
# Deposited in ionization:  925.2614106792835
# Deposited in ionization (linalg):  925.2614106792834
# Deposited in excitation:  661.421439235204
# Deposited in excitation (linalg):  661.421439235204
# Deposited in heating:  166.16591814639656
# Deposited in heating (linalg):  166.16591814639668
# Energy is conserved up to (%):  -0.01937985570772397
# Deposited in ICS:  -1.676295345803237
# Deposited in ICS (linalg):  -1.6762953458032372
# Energy conservation with deposited (%):  4.036355880667191e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  9170.647491149313
# Energy in low energy electrons:  4669.622256224608
# Energy in low energy electrons (linalg):  4669.6222562246085
# [[1.00000000e+00 3.38966560e-01 3.38966560e-01]
#  [1.06022978e+00 3.58814453e-01 3.58814453e-01]
#  [1.12408719e+00 3.79747221e-01 3.79747221e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  85157.21347548533
# Energy in photons (linalg):  85157.21347548533
# Continuum_engloss:  82519.7400689398
# Continuum_engloss (linalg):  82519.7400689398
# Energy in photons - Continuum:  2637.473406545527
# Deposited in ionization:  984.2334307799998
# Deposited in ionization (linalg):  984.2334307799996
# Deposited in excitation:  704.7009048910361
# Deposited in excitation (linalg):  704.700904891036
# Deposited in heating:  176.42514609838057
# Deposited in heating (linalg):  176.42514609838068
# Energy is conserved up to (%):  -0.019711295107415094
# Deposited in ICS:  -1.8076533902449068
# Deposited in ICS (linalg):  -1.8076533902449066
# Energy conservation with deposited (%):  4.0425245081181394e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  9722.993602579225
# Energy in low energy electrons:  4788.542683548641
# Energy in low energy electrons (linalg):  4788.542683548641
# [[1.00000000e+00 3.59408147e-01 3.59408147e-01]
#  [1.06022978e+00 3.80453021e-01 3.80453021e-01]
#  [1.12408719e+00 4.02648206e-01 4.02648206e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  91701.55042714077
# Energy in photons (linalg):  91701.55042714076
# Continuum_engloss:  88744.3448280246
# Continuum_engloss (linalg):  88744.34482802461
# Energy in photons - Continuum:  2957.205599116176
# Deposited in ionization:  1043.8494955458873
# Deposited in ionization (linalg):  1043.849495545887
# Deposited in excitation:  748.5682994903757
# Deposited in excitation (linalg):  748.5682994903756
# Deposited in heating:  186.77111011461176
# Deposited in heating (linalg):  186.7711101146119
# Energy is conserved up to (%):  -0.019989576419671033
# Deposited in ICS:  -1.94358523646358
# Deposited in ICS (linalg):  -1.94358523646358
# Energy conservation with deposited (%):  -3.825664577952e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  10308.607400626246
# Energy in low energy electrons:  4908.9896815589
# Energy in low energy electrons (linalg):  4908.9896815589
# [[1.00000000e+00 3.80033068e-01 3.80033068e-01]
#  [1.06022978e+00 4.02285662e-01 4.02285662e-01]
#  [1.12408719e+00 4.25754591e-01 4.25754591e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  98485.79740837352
# Energy in photons (linalg):  98485.79740837352
# Continuum_engloss:  95178.27120567462
# Continuum_engloss (linalg):  95178.27120567464
# Energy in photons - Continuum:  3307.526202698893
# Deposited in ionization:  1104.0237876858007
# Deposited in ionization (linalg):  1104.0237876858002
# Deposited in excitation:  792.9617835975171
# Deposited in excitation (linalg):  792.9617835975167
# Deposited in heating:  197.19001320151253
# Deposited in heating (linalg):  197.19001320151264
# Energy is conserved up to (%):  -0.020216776479903432
# Deposited in ICS:  -2.0840681163752137
# Deposited in ICS (linalg):  -2.0840681163752137
# Energy conservation with deposited (%):  -1.7231782823471744e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  10929.492590847412
# Energy in low energy electrons:  5030.76603179817
# Energy in low energy electrons (linalg):  5030.76603179817
# [[1.00000000e+00 4.00811053e-01 4.00811053e-01]
#  [1.06022978e+00 4.24280336e-01 4.24280336e-01]
#  [1.12408719e+00 4.49032466e-01 4.49032466e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  105509.53732034123
# Energy in photons (linalg):  105509.53732034123
# Continuum_engloss:  101818.73467057626
# Continuum_engloss (linalg):  101818.73467057628
# Energy in photons - Continuum:  3690.80264976497
# Deposited in ionization:  1164.6679905817923
# Deposited in ionization (linalg):  1164.6679905817916
# Deposited in excitation:  837.8171493650773
# Deposited in excitation (linalg):  837.8171493650768
# Deposited in heating:  207.667793314877
# Deposited in heating (linalg):  207.66779331487712
# Energy is conserved up to (%):  -0.020394578787096877
# Deposited in ICS:  -2.2290239774701357
# Deposited in ICS (linalg):  -2.229023977470136
# Energy conservation with deposited (%):  -1.422126618921754e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  11587.773561551261
# Energy in low energy electrons:  5153.670333128259
# Energy in low energy electrons (linalg):  5153.670333128259
# [[1.00000000e+00 4.21711245e-01 4.21711245e-01]
#  [1.06022978e+00 4.46404375e-01 4.46404375e-01]
#  [1.12408719e+00 4.72447258e-01 4.72447258e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  112771.83058196475
# Energy in photons (linalg):  112771.83058196475
# Continuum_engloss:  108662.29946804323
# Continuum_engloss (linalg):  108662.29946804326
# Energy in photons - Continuum:  4109.531113921519
# Deposited in ionization:  1225.6919675121317
# Deposited in ionization (linalg):  1225.6919675121312
# Deposited in excitation:  883.0683160405854
# Deposited in excitation (linalg):  883.0683160405849
# Deposited in heating:  218.19023452163864
# Deposited in heating (linalg):  218.19023452163879
# Energy is conserved up to (%):  -0.020525112613213204
# Deposited in ICS:  -2.3784035728539417
# Deposited in ICS (linalg):  -2.3784035728539417
# Energy conservation with deposited (%):  -1.6052368080007235e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  12285.702652493868
# Energy in low energy electrons:  5277.498481691703
# Energy in low energy electrons (linalg):  5277.498481691703
# [[1.00000000e+00 4.42702423e-01 4.42702423e-01]
#  [1.06022978e+00 4.68624732e-01 4.68624732e-01]
#  [1.12408719e+00 4.95963994e-01 4.95963994e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  120271.25268307947
# Energy in photons (linalg):  120271.25268307947
# Continuum_engloss:  115704.91172638493
# Continuum_engloss (linalg):  115704.91172638498
# Energy in photons - Continuum:  4566.340956694534
# Deposited in ionization:  1287.0044368280096
# Deposited in ionization (linalg):  1287.0044368280091
# Deposited in excitation:  928.6478289545115
# Deposited in excitation (linalg):  928.6478289545112
# Deposited in heating:  228.74307572708256
# Deposited in heating (linalg):  228.7430757270827
# Energy is conserved up to (%):  -0.020610358834071463
# Deposited in ICS:  -2.5321274019460174
# Deposited in ICS (linalg):  -2.532127401946017
# Energy conservation with deposited (%):  -1.628306268022447e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  13025.667861366888
# Energy in low energy electrons:  5402.045164291183
# Energy in low energy electrons (linalg):  5402.045164291183
# [[1.00000000e+00 4.63753241e-01 4.63753241e-01]
#  [1.06022978e+00 4.90908226e-01 4.90908226e-01]
#  [1.12408719e+00 5.19547553e-01 5.19547553e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  128005.93899759572
# Energy in photons (linalg):  128005.93899759573
# Continuum_engloss:  122941.93935042896
# Continuum_engloss (linalg):  122941.939350429
# Energy in photons - Continuum:  5063.999647166755
# Deposited in ionization:  1348.5136490636396
# Deposited in ionization (linalg):  1348.513649063639
# Deposited in excitation:  974.4873662658155
# Deposited in excitation (linalg):  974.4873662658151
# Deposited in heating:  239.31211816175687
# Deposited in heating (linalg):  239.312118161757
# Energy is conserved up to (%):  -0.020652173929850647
# Deposited in ICS:  -2.690083582254265
# Deposited in ICS (linalg):  -2.6900835822542644
# Energy conservation with deposited (%):  9.068842463769114e-16
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  13810.201014445469
# Energy in low energy electrons:  5527.105302466966
# Energy in low energy electrons (linalg):  5527.105302466967
# [[1.00000000e+00 4.84832447e-01 4.84832447e-01]
#  [1.06022978e+00 5.13221774e-01 5.13221774e-01]
#  [1.12408719e+00 5.43162925e-01 5.43162925e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  135973.634558331
# Energy in photons (linalg):  135973.634558331
# Continuum_engloss:  130368.21632541137
# Continuum_engloss (linalg):  130368.21632541141
# Energy in photons - Continuum:  5605.418232919619
# Deposited in ionization:  1410.1280421726824
# Deposited in ionization (linalg):  1410.1280421726817
# Deposited in excitation:  1020.5182354204085
# Deposited in excitation (linalg):  1020.5182354204081
# Deposited in heating:  249.88332776158222
# Deposited in heating (linalg):  249.88332776158236
# Energy is conserved up to (%):  -0.02065231558039826
# Deposited in ICS:  -2.852126295762197
# Deposited in ICS (linalg):  -2.8521262957621962
# Energy conservation with deposited (%):  -2.0595663801508325e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  14641.986429352755
# Energy in low energy electrons:  5652.475444778134
# Energy in low energy electrons (linalg):  5652.475444778134
# [[1.00000000e+00 5.05909100e-01 5.05909100e-01]
#  [1.06022978e+00 5.35532624e-01 5.35532624e-01]
#  [1.12408719e+00 5.66775446e-01 5.66775446e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  144171.7488746472
# Energy in photons (linalg):  144171.7488746472
# Continuum_engloss:  137978.09138562882
# Continuum_engloss (linalg):  137978.09138562885
# Energy in photons - Continuum:  6193.657489018369
# Deposited in ionization:  1471.7568718855764
# Deposited in ionization (linalg):  1471.7568718855757
# Deposited in excitation:  1066.6718567444327
# Deposited in excitation (linalg):  1066.6718567444325
# Deposited in heating:  260.44293213349766
# Deposited in heating (linalg):  260.44293213349783
# Energy is conserved up to (%):  -0.02061308567535817
# Deposited in ICS:  -3.018165207245841
# Deposited in ICS (linalg):  -3.0181652072458403
# Energy conservation with deposited (%):  -7.484496372364433e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  15523.870099580816
# Energy in low energy electrons:  5777.955079438625
# Energy in low energy electrons (linalg):  5777.955079438625
# [[1.00000000e+00 5.26952769e-01 5.26952769e-01]
#  [1.06022978e+00 5.57808562e-01 5.57808562e-01]
#  [1.12408719e+00 5.90351022e-01 5.90351022e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  152597.41408139787
# Energy in photons (linalg):  152597.41408139787
# Continuum_engloss:  145765.47955938225
# Continuum_engloss (linalg):  145765.4795593823
# Energy in photons - Continuum:  6831.934522015625
# Deposited in ionization:  1533.3108045292556
# Deposited in ionization (linalg):  1533.3108045292545
# Deposited in excitation:  1112.8802241969856
# Deposited in excitation (linalg):  1112.8802241969854
# Deposited in heating:  270.97751017301505
# Deposited in heating (linalg):  270.97751017301516
# Energy is conserved up to (%):  -0.020536378829786383
# Deposited in ICS:  -3.188040772660881
# Deposited in ICS (linalg):  -3.18804077266088
# Energy conservation with deposited (%):  -2.1239450770345e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  16458.869432193034
# Energy in low energy electrons:  5903.347844965152
# Energy in low energy electrons (linalg):  5903.347844965152
# [[1.00000000e+00 5.47933720e-01 5.47933720e-01]
#  [1.06022978e+00 5.80018112e-01 5.80018112e-01]
#  [1.12408719e+00 6.13856343e-01 6.13856343e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  161247.54561412497
# Energy in photons (linalg):  161247.54561412497
# Continuum_engloss:  153723.91524794805
# Continuum_engloss (linalg):  153723.91524794814
# Energy in photons - Continuum:  7523.63036617692
# Deposited in ionization:  1594.7024622042195
# Deposited in ionization (linalg):  1594.7024622042184
# Deposited in excitation:  1159.076335132518
# Deposited in excitation (linalg):  1159.0763351325174
# Deposited in heating:  281.4740728430482
# Deposited in heating (linalg):  281.47407284304825
# Energy is conserved up to (%):  -0.020424544606031447
# Deposited in ICS:  -3.3616491287661896
# Deposited in ICS (linalg):  -3.3616491287661887
# Energy conservation with deposited (%):  -3.6789625200269876e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  17450.183572026446
# Energy in low energy electrons:  6028.462636399498
# Energy in low energy electrons (linalg):  6028.462636399498
# [[1.00000000e+00 5.68823083e-01 5.68823083e-01]
#  [1.06022978e+00 6.02130715e-01 6.02130715e-01]
#  [1.12408719e+00 6.37259064e-01 6.37259064e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  170118.9046120952
# Energy in photons (linalg):  170118.9046120952
# Continuum_engloss:  161846.60651454495
# Continuum_engloss (linalg):  161846.60651454504
# Energy in photons - Continuum:  8272.298097550258
# Deposited in ionization:  1655.8469198324435
# Deposited in ionization (linalg):  1655.8469198324422
# Deposited in excitation:  1205.1945880580704
# Deposited in excitation (linalg):  1205.19458805807
# Deposited in heating:  291.92013526799997
# Deposited in heating (linalg):  291.92013526799997
# Energy is conserved up to (%):  -0.020279471944923168
# Deposited in ICS:  -3.5388050817993935
# Deposited in ICS (linalg):  -3.5388050817993926
# Energy conservation with deposited (%):  -1.5645263696662573e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  18501.204347718587
# Energy in low energy electrons:  6153.114194799367
# Energy in low energy electrons (linalg):  6153.114194799367
# [[1.00000000e+00 5.89592934e-01 5.89592934e-01]
#  [1.06022978e+00 6.24116811e-01 6.24116811e-01]
#  [1.12408719e+00 6.60527901e-01 6.60527901e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  179208.1358003618
# Energy in photons (linalg):  179208.1358003618
# Continuum_engloss:  170126.46297791484
# Continuum_engloss (linalg):  170126.46297791493
# Energy in photons - Continuum:  9081.67282244697
# Deposited in ionization:  1716.6619534105896
# Deposited in ionization (linalg):  1716.6619534105882
# Deposited in excitation:  1251.1709960613498
# Deposited in excitation (linalg):  1251.1709960613491
# Deposited in heating:  302.3037461008873
# Deposited in heating (linalg):  302.30374610088734
# Energy is conserved up to (%):  -0.020103367492510744
# Deposited in ICS:  -3.719365100504318
# Deposited in ICS (linalg):  -3.7193651005043167
# Energy conservation with deposited (%):  -3.130865158728746e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  19615.527877010823
# Energy in low energy electrons:  6277.1247351771
# Energy in low energy electrons (linalg):  6277.1247351771
# [[1.00000000e+00 6.10216554e-01 6.10216554e-01]
#  [1.06022978e+00 6.45948118e-01 6.45948118e-01]
#  [1.12408719e+00 6.83632923e-01 6.83632923e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  188511.87904660864
# Energy in photons (linalg):  188511.87904660864
# Continuum_engloss:  178556.19891874716
# Continuum_engloss (linalg):  178556.19891874722
# Energy in photons - Continuum:  9955.680127861473
# Deposited in ionization:  1777.0687992696835
# Deposited in ionization (linalg):  1777.0687992696817
# Deposited in excitation:  1296.943788946515
# Deposited in excitation (linalg):  1296.9437889465146
# Deposited in heating:  312.6136041277843
# Deposited in heating (linalg):  312.6136041277844
# Energy is conserved up to (%):  -0.019898411076182
# Deposited in ICS:  -3.9031783717093718
# Deposited in ICS (linalg):  -3.9031783717093713
# Energy conservation with deposited (%):  -1.0867724016449517e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  20796.966871036937
# Energy in low energy electrons:  6400.32428357583
# Energy in low energy electrons (linalg):  6400.32428357583
# [[1.00000000e+00 6.30668474e-01 6.30668474e-01]
#  [1.06022978e+00 6.67597672e-01 6.67597672e-01]
#  [1.12408719e+00 7.06545593e-01 7.06545593e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  198026.80769261642
# Energy in photons (linalg):  198026.80769261642
# Continuum_engloss:  187128.3598986941
# Continuum_engloss (linalg):  187128.35989869412
# Energy in photons - Continuum:  10898.447793922329
# Deposited in ionization:  1836.9922862878418
# Deposited in ionization (linalg):  1836.99228628784
# Deposited in excitation:  1342.4535450174067
# Deposited in excitation (linalg):  1342.4535450174062
# Deposited in heating:  322.8390678870368
# Deposited in heating (linalg):  322.8390678870369
# Energy is conserved up to (%):  -0.019666837375256242
# Deposited in ICS:  -4.09010565352891
# Deposited in ICS (linalg):  -4.09010565352891
# Energy conservation with deposited (%):  7.770132187174257e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  22049.563679696334
# Energy in low energy electrons:  6522.55126986461
# Energy in low energy electrons (linalg):  6522.55126986461
# [[1.00000000e+00 6.50924556e-01 6.50924556e-01]
#  [1.06022978e+00 6.89039925e-01 6.89039925e-01]
#  [1.12408719e+00 7.29238870e-01 7.29238870e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  207749.68908719232
# Energy in photons (linalg):  207749.68908719232
# Continuum_engloss:  195835.37147047452
# Continuum_engloss (linalg):  195835.37147047458
# Energy in photons - Continuum:  11914.317616717803
# Deposited in ionization:  1896.361097737032
# Deposited in ionization (linalg):  1896.3610977370301
# Deposited in excitation:  1387.6434218911602
# Deposited in excitation (linalg):  1387.64342189116
# Deposited in heating:  332.97018777941844
# Deposited in heating (linalg):  332.97018777941855
# Energy is conserved up to (%):  -0.019410426237307415
# Deposited in ICS:  -4.279914293664029
# Deposited in ICS (linalg):  -4.279914293664029
# Energy conservation with deposited (%):  -1.431062998572719e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  23377.604122746896
# Energy in low energy electrons:  6643.652986678826
# Energy in low energy electrons (linalg):  6643.652986678826
# [[1.00000000e+00 6.70962067e-01 6.70962067e-01]
#  [1.06022978e+00 7.10250810e-01 7.10250810e-01]
#  [1.12408719e+00 7.51687285e-01 7.51687285e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  217677.4430509614
# Energy in photons (linalg):  217677.44305096136
# Continuum_engloss:  204669.58447863325
# Continuum_engloss (linalg):  204669.58447863327
# Energy in photons - Continuum:  13007.858572328143
# Deposited in ionization:  1955.107972085439
# Deposited in ionization (linalg):  1955.1079720854373
# Deposited in excitation:  1432.4593421951924
# Deposited in excitation (linalg):  1432.4593421951922
# Deposited in heating:  342.99772820631125
# Deposited in heating (linalg):  342.99772820631136
# Energy is conserved up to (%):  -0.019131467551335487
# Deposited in ICS:  -4.4724787470044935
# Deposited in ICS (linalg):  -4.4724787470044935
# Energy conservation with deposited (%):  -7.91198083992611e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  24785.63215394193
# Energy in low energy electrons:  6763.485926637373
# Energy in low energy electrons (linalg):  6763.485926637373
# [[1.00000000e+00 6.90759720e-01 6.90759720e-01]
#  [1.06022978e+00 7.31207795e-01 7.31207795e-01]
#  [1.12408719e+00 7.73866990e-01 7.73866990e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  227807.19767576773
# Energy in photons (linalg):  227807.19767576776
# Continuum_engloss:  213623.31698274374
# Continuum_engloss (linalg):  213623.31698274374
# Energy in photons - Continuum:  14183.880693023995
# Deposited in ionization:  2013.1698486321018
# Deposited in ionization (linalg):  2013.1698486320997
# Deposited in excitation:  1476.850137994805
# Deposited in excitation (linalg):  1476.8501379948043
# Deposited in heating:  352.9131808495932
# Deposited in heating (linalg):  352.9131808495933
# Energy is conserved up to (%):  -0.018832011896823302
# Deposited in ICS:  -4.667633196002897
# Deposited in ICS (linalg):  -4.667633196002897
# Energy conservation with deposited (%):  2.811746711519182e-13
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  26278.46540838493
# Energy in low energy electrons:  6881.916000805828
# Energy in low energy electrons (linalg):  6881.916000805828
# [[1.00000000e+00 7.10297708e-01 7.10297708e-01]
#  [1.06022978e+00 7.51889912e-01 7.51889912e-01]
#  [1.12408719e+00 7.95755793e-01 7.95755793e-01]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  238136.3424151843
# Energy in photons (linalg):  238136.3424151843
# Continuum_engloss:  222688.89218373052
# Continuum_engloss (linalg):  222688.89218373055
# Energy in photons - Continuum:  15447.450231453782
# Deposited in ionization:  2070.487959322977
# Deposited in ionization (linalg):  2070.4879593229753
# Deposited in excitation:  1520.767654419195
# Deposited in excitation (linalg):  1520.7676544191943
# Deposited in heating:  362.7087694067713
# Deposited in heating (linalg):  362.70876940677147
# Energy is conserved up to (%):  -0.01851404542854719
# ...
# Energy in photons:  2343150361275.7173
# Energy in photons (linalg):  2343150361275.718
# Continuum_engloss:  872362.3445480634
# Continuum_engloss (linalg):  872362.3445480649
# Energy in photons - Continuum:  2343149488913.3726
# Deposited in ionization:  3737.934553040243
# Deposited in ionization (linalg):  3737.9345530402443
# Deposited in excitation:  2850.6502184436545
# Deposited in excitation (linalg):  2850.650218443651
# Deposited in heating:  748.8469038285078
# Deposited in heating (linalg):  748.8469038285091
# Energy is conserved up to (%):  -8.123971246855884e-10
# Deposited in ICS:  -19.03618723131248
# Deposited in ICS (linalg):  -19.03618723131252
# Energy conservation with deposited (%):  2.168076156835852e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2484276893696.798
# Energy in low energy electrons:  10362.300405441718
# Energy in low energy electrons (linalg):  10362.300405441716
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  2484277748378.447
# Energy in photons (linalg):  2484277748378.447
# Continuum_engloss:  872362.3445480631
# Continuum_engloss (linalg):  872362.3445480645
# Energy in photons - Continuum:  2484276876016.102
# Deposited in ionization:  3737.934553040215
# Deposited in ionization (linalg):  3737.9345530402165
# Deposited in excitation:  2850.650218443628
# Deposited in excitation (linalg):  2850.6502184436245
# Deposited in heating:  748.8469582259412
# Deposited in heating (linalg):  748.8469582259424
# Energy is conserved up to (%):  -7.662681219466456e-10
# Deposited in ICS:  -19.036653952413293
# Deposited in ICS (linalg):  -19.036653952413324
# Energy conservation with deposited (%):  1.739158503107962e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2633904352747.313
# Energy in low energy electrons:  10362.300405441682
# Energy in low energy electrons (linalg):  10362.300405441678
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  2633905207428.963
# Energy in photons (linalg):  2633905207428.963
# Continuum_engloss:  872362.3445480634
# Continuum_engloss (linalg):  872362.3445480647
# Energy in photons - Continuum:  2633904335066.618
# Deposited in ionization:  3737.9345530401974
# Deposited in ionization (linalg):  3737.934553040199
# Deposited in excitation:  2850.6502184436113
# Deposited in excitation (linalg):  2850.650218443607
# Deposited in heating:  748.8470262403321
# Deposited in heating (linalg):  748.8470262403334
# Energy is conserved up to (%):  -7.227774408088821e-10
# Deposited in ICS:  -19.036625874991838
# Deposited in ICS (linalg):  -19.03662587499188
# Energy conservation with deposited (%):  -2.432127606580313e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2792543841237.3364
# Energy in low energy electrons:  10362.300405441834
# Energy in low energy electrons (linalg):  10362.300405441832
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  2792544695918.9854
# Energy in photons (linalg):  2792544695918.9854
# Continuum_engloss:  872362.3445480636
# Continuum_engloss (linalg):  872362.3445480649
# Energy in photons - Continuum:  2792543823556.6406
# Deposited in ionization:  3737.9345530402716
# Deposited in ionization (linalg):  3737.9345530402734
# Deposited in excitation:  2850.6502184436836
# Deposited in excitation (linalg):  2850.6502184436804
# Deposited in heating:  748.8471054804422
# Deposited in heating (linalg):  748.8471054804434
# Energy is conserved up to (%):  -6.816855968664815e-10
# Deposited in ICS:  -19.0365701910313
# Deposited in ICS (linalg):  -19.036570191031338
# Energy conservation with deposited (%):  7.199139774407676e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2960738151747.425
# Energy in low energy electrons:  10362.300405441882
# Energy in low energy electrons (linalg):  10362.300405441878
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  2960739006429.074
# Energy in photons (linalg):  2960739006429.074
# Continuum_engloss:  872362.3445480638
# Continuum_engloss (linalg):  872362.3445480652
# Energy in photons - Continuum:  2960738134066.7295
# Deposited in ionization:  3737.934553040293
# Deposited in ionization (linalg):  3737.9345530402948
# Deposited in excitation:  2850.6502184437054
# Deposited in excitation (linalg):  2850.6502184437018
# Deposited in heating:  748.8471655536177
# Deposited in heating (linalg):  748.8471655536189
# Energy is conserved up to (%):  -6.429787617364966e-10
# Deposited in ICS:  -19.036936026608156
# Deposited in ICS (linalg):  -19.036936026608196
# Energy conservation with deposited (%):  6.25527877896039e-16
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3139062769137.661
# Energy in low energy electrons:  10362.300405441889
# Energy in low energy electrons (linalg):  10362.300405441885
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  3139067395498.457
# Energy in photons (linalg):  3139067395498.457
# Continuum_engloss:  872362.3445480636
# Continuum_engloss (linalg):  872362.3445480651
# Energy in photons - Continuum:  3139066523136.1123
# Deposited in ionization:  3737.9345530402966
# Deposited in ionization (linalg):  3737.934553040298
# Deposited in excitation:  2850.650218443708
# Deposited in excitation (linalg):  2850.6502184437054
# Deposited in heating:  748.8472150455883
# Deposited in heating (linalg):  748.8472150455895
# Energy is conserved up to (%):  -0.00012015364014168804
# Deposited in ICS:  -3771698.1837447565
# Deposited in ICS (linalg):  -3771698.1837447565
# Energy conservation with deposited (%):  9.346209247380382e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3328127839596.5234
# Energy in low energy electrons:  10362.30040544173
# Energy in low energy electrons (linalg):  10362.300405441729
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  3328128946989.6074
# Energy in photons (linalg):  3328128946989.6074
# Continuum_engloss:  872362.3445480634
# Continuum_engloss (linalg):  872362.3445480649
# Energy in photons - Continuum:  3328128074627.2627
# Deposited in ionization:  3737.934553040222
# Deposited in ionization (linalg):  3737.9345530402234
# Deposited in excitation:  2850.6502184436354
# Deposited in excitation (linalg):  2850.6502184436326
# Deposited in heating:  748.8472777547104
# Deposited in heating (linalg):  748.8472777547114
# Energy is conserved up to (%):  -7.593772949258431e-06
# Deposited in ICS:  -252730.47128450335
# Deposited in ICS (linalg):  -252730.47128450335
# Energy conservation with deposited (%):  -9.480298676297832e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3528580258285.263
# Energy in low energy electrons:  10362.30040544171
# Energy in low energy electrons (linalg):  10362.300405441707
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  3528581349958.633
# Energy in photons (linalg):  3528581349958.633
# Continuum_engloss:  872362.3445480631
# Continuum_engloss (linalg):  872362.3445480645
# Energy in photons - Continuum:  3528580477596.288
# Deposited in ionization:  3737.9345530402124
# Deposited in ionization (linalg):  3737.9345530402143
# Deposited in excitation:  2850.6502184436285
# Deposited in excitation (linalg):  2850.650218443625
# Deposited in heating:  748.847366594818
# Deposited in heating (linalg):  748.847366594819
# Energy is conserved up to (%):  -6.716887245993041e-06
# Deposited in ICS:  -237010.7573849978
# Deposited in ICS (linalg):  -237010.75738499776
# Energy conservation with deposited (%):  1.4625321616647656e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3741105882720.5215
# Energy in low energy electrons:  10362.30040544186
# Energy in low energy electrons (linalg):  10362.300405441856
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  3741106960643.123
# Energy in photons (linalg):  3741106960643.123
# Continuum_engloss:  872362.3445480637
# Continuum_engloss (linalg):  872362.3445480656
# Energy in photons - Continuum:  3741106088280.7783
# Deposited in ionization:  3737.9345530402825
# Deposited in ionization (linalg):  3737.9345530402843
# Deposited in excitation:  2850.650218443697
# Deposited in excitation (linalg):  2850.6502184436936
# Deposited in heating:  748.8474535840483
# Deposited in heating (linalg):  748.8474535840494
# Energy is conserved up to (%):  -5.9677538234127775e-06
# Deposited in ICS:  -223259.989253361
# Deposited in ICS (linalg):  -223259.989253361
# Energy conservation with deposited (%):  -2.689398662198069e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3966431879468.582
# Energy in low energy electrons:  10362.300405442089
# Energy in low energy electrons (linalg):  10362.300405442085
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  3966577498498.9487
# Energy in photons (linalg):  3966577498498.9487
# Continuum_engloss:  872362.344548064
# Continuum_engloss (linalg):  872362.3445480654
# Energy in photons - Continuum:  3966576626136.604
# Deposited in ionization:  3737.934553040392
# Deposited in ionization (linalg):  3737.934553040393
# Deposited in excitation:  2850.6502184438027
# Deposited in excitation (linalg):  2850.6502184437986
# Deposited in heating:  748.8475062868973
# Deposited in heating (linalg):  748.8475062868987
# Energy is conserved up to (%):  -0.003649737904333775
# Deposited in ICS:  -144764367.75463474
# Deposited in ICS (linalg):  -144764367.75463483
# Energy conservation with deposited (%):  2.3029292042329064e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4205329212180.4136
# Energy in low energy electrons:  10362.300405441852
# Energy in low energy electrons (linalg):  10362.300405441852
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  4205339054940.1025
# Energy in photons (linalg):  4205339054940.1025
# Continuum_engloss:  872362.3445480635
# Continuum_engloss (linalg):  872362.3445480651
# Energy in photons - Continuum:  4205338182577.758
# Deposited in ionization:  3737.93455304028
# Deposited in ionization (linalg):  3737.934553040281
# Deposited in excitation:  2850.650218443694
# Deposited in excitation (linalg):  2850.6502184436904
# Deposited in heating:  748.8475545619283
# Deposited in heating (linalg):  748.8475545619293
# Energy is conserved up to (%):  -0.00021373111648010726
# Deposited in ICS:  -8988097.077707466
# Deposited in ICS (linalg):  -8988097.077707471
# Energy conservation with deposited (%):  2.0216466897435416e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4458615279480.692
# Energy in low energy electrons:  10362.300405441652
# Energy in low energy electrons (linalg):  10362.300405441649
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  4458624586616.707
# Energy in photons (linalg):  4458624586616.707
# Continuum_engloss:  872362.3445480631
# Continuum_engloss (linalg):  872362.3445480647
# Energy in photons - Continuum:  4458623714254.362
# Deposited in ionization:  3737.9345530401847
# Deposited in ionization (linalg):  3737.9345530401847
# Deposited in excitation:  2850.6502184436013
# Deposited in excitation (linalg):  2850.6502184435976
# Deposited in heating:  748.8476394693465
# Deposited in heating (linalg):  748.8476394693479
# Energy is conserved up to (%):  -0.00018957619963341088
# Deposited in ICS:  -8452473.40231599
# Deposited in ICS (linalg):  -8452473.402315993
# Energy conservation with deposited (%):  -1.7899939324414935e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4727156711736.159
# Energy in low energy electrons:  10362.30040544171
# Energy in low energy electrons (linalg):  10362.300405441707
# [[1.00000000e+00 1.27547821e+00 1.27547821e+00]
#  [1.06022978e+00 1.35016868e+00 1.35016868e+00]
#  [1.12408719e+00 1.42894287e+00 1.42894287e+00]
#  ...
#  [4.20532921e+12 0.00000000e+00 0.00000000e+00]
#  [4.45861528e+12 0.00000000e+00 0.00000000e+00]
#  [4.72715671e+12 0.00000000e+00 0.00000000e+00]]
# Energy in photons:  4727165621637.655
# Energy in photons (linalg):  4727165621637.655
# Continuum_engloss:  872362.3445480629
# Continuum_engloss (linalg):  872362.3445480645
# Energy in photons - Continuum:  4727164749275.311
# Deposited in ionization:  3737.9345530402124
# Deposited in ionization (linalg):  3737.934553040214
# Deposited in excitation:  2850.650218443631
# Deposited in excitation (linalg):  2850.650218443627
# Deposited in heating:  748.8477633325484
# Deposited in heating (linalg):  748.8477633325497
# Energy is conserved up to (%):  -0.00017040346609801263
# Deposited in ICS:  -8055238.884279968
# Deposited in ICS (linalg):  -8055238.884279974
# Energy conservation with deposited (%):  -8.531258480845907e-15
# ***************************************************
