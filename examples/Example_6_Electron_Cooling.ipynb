# %% [markdown]
# # Example ? Electron Cooling

# %% [markdown]
# In this example, we will show how to use the electron cooling module, found in [*darkhistory.elec.elec_cooling*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/darkhistory.electrons.elec_cooling.html). This module takes an injected electron with some initial energy, and cools it completely through inverse Compton scattering (ICS) as well as ionization, excitation (both on HI, HeI and HeII) as well as Coulomb heating from free electrons.

# %% [markdown]
# ## Initialization

# %% [markdown]
# Let's load the stuff that we need. The function of interest is [*get_elec_cooling_tf*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/elec_cooling/darkhistory.electrons.elec_cooling.get_elec_cooling_tf.html).
#
# We have also imported the default binning for photons and electrons used throughout DarkHistory using [*config.load_data*](https://darkhistory.readthedocs.io/en/master/_autosummary/config/config.load_data.html).

# %%
# %load_ext autoreload
import sys
sys.path.append("..")

# %%
# %matplotlib inline

# %%
# %autoreload

import matplotlib
matplotlib.rc_file('matplotlibrc')
import matplotlib.pyplot as plt

import numpy as np

from config import load_data
import darkhistory.physics as phys
from darkhistory.electrons.elec_cooling import get_elec_cooling_tf

photeng = load_data('binning')['phot']
eleceng = load_data('binning')['elec']

# %% [markdown]
# ## Electron Cooling Function: [*get_elec_cooling_tf*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/elec_cooling/darkhistory.electrons.elec_cooling.get_elec_cooling_tf.html)

# %% [markdown]
# The user should refer to the online documentation for details on how to use [*get_elec_cooling_tf*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/elec_cooling/darkhistory.electrons.elec_cooling.get_elec_cooling_tf.html). In the simplest default case, we just need to give the function the electron and photon abscissae of interest, the redshift, and the ionization levels of hydrogen and helium.
#
# If we do not specify any ICS transfer functions to the function, DarkHistory automatically loads the required transfer functions from the downloaded data. If this is the first time the transfer functions are loaded, the successful completion of the import would look like this:
#
# ```
# ****** Loading transfer functions... ******
#     for inverse Compton (Thomson)...  Done!
#     for inverse Compton (relativistic)...  Done!
#     for inverse Compton (energy loss)...  Done!
# ****** Loading complete! ******
# ```

# %%
# %autoreload
rs = 600
# This function returns the baseline value of xHII. 
# xHII  = phys.xHII_std(rs)
xHII = 0.01

elec_cooling_info = get_elec_cooling_tf(
    eleceng, photeng, rs, xHII, check_conservation_eng=True, verbose=True
)
# Out:
# ***************************************************
# rs:  600
# injected energy:  1.029782576544676
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.0920351523673162
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.1580510305357166
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.2280577107449062
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.3022964457049966
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.3810230721719563
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.464508892793674
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.5530416112742387
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.6469263233011588
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.7464865684742108
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.8520654450403526
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.9640267921495251
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.0827564439969137
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.2086635591695085
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.34218203072669
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.483771981613245
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.633921350177843
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.7931475715595298
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.9619993612286635
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.14105860539712
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.3309423667378724
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.5323050105944276
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.74584046023665
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.9722845879150555
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4.2124177510268055
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4.4670674814260565
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4.737111336668022
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.023479924944695
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.32716011145385
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.649198419589084
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.990704637486488
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6.3528556420933455
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6.7368994553689845
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  7.144159544724971
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  7.576039384061005
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  8.03402729035588
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  8.519701552519109
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  9.03473587037297
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  9.580905122566037
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  10.160091482975986
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  10.774290907022078
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  11.42562000977341
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  12.116323360300157
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  12.848781216773205
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  13.625517729029525
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  14.44920963718323
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  15.32269549620105
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  16.24898545764154
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  17.23127164330799
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  18.27293914562324
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  19.377577693143394
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  20.548994021199178
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  21.791224990563933
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  23.108551498909947
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  24.5055132334237
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  25.986924315046053
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  27.557889888819773
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  29.223823716747575
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  30.990466834511608
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  32.86390733567532
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  34.85060135216918
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  36.957395303063095
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  39.19154948822688
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  41.56076310825301
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  44.07320079696365
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  46.73752075800439
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  49.56290460197488
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  52.55908898770576
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  55.73639917600667
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  59.105784611951094
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  62.678856658109
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  66.46792860905407
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  70.48605812445749
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  74.74709222768433
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  79.26571502455045
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  84.05749830661807
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  89.1389552137698
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  94.52759714098647
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  100.24199408461573
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  106.30183863738785
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  112.72801385167986
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  119.54266520531382
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  126.76927691808669
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  134.43275288149016
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  142.55950248084264
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  151.17753160570282
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  160.3165391620132
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  170.0080194186885
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  180.28537054092158
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  191.18400968506467
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  202.74149505078094
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  214.99765531200683
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  227.99472687160596
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  241.77749941428192
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  256.3934702575207
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  271.8930080339778
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  288.3295262688189
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  305.7596674498054
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# ...
# ***************************************************
# rs:  600
# injected energy:  1321320093607.8591
# Fraction of Energy in low energy electrons:  7.884759729297163e-09
# Fraction of Energy in photons - Continuum:  0.9999999865377575
# Fraction Deposited in ionization:  2.8441366766192096e-09
# Fraction Deposited in excitation:  2.1756777510543114e-09
# Fraction Deposited in heating:  5.721164586461518e-10
# Energy is conserved up to (%):  -1.4448055042977264e-09
# Fraction Deposited in ICS (Numerical Error):  -1.444805331613033e-11
# Energy conservation with deposited (%):  -1.7268469314606998e-16
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1401196740564.3086
# Fraction of Energy in low energy electrons:  7.435280972317071e-09
# Fraction of Energy in photons - Continuum:  0.9999999873051862
# Fraction Deposited in ionization:  2.6820037693426306e-09
# Fraction Deposited in excitation:  2.0516510254840445e-09
# Fraction Deposited in heating:  5.39502417266845e-10
# Energy is conserved up to (%):  -1.3624468853801632e-09
# Fraction Deposited in ICS (Numerical Error):  -1.3624461438885118e-11
# Energy conservation with deposited (%):  -7.414916514869472e-16
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1485902102954.5662
# Fraction of Energy in low energy electrons:  7.011425209557789e-09
# Fraction of Energy in photons - Continuum:  0.999999988028867
# Fraction Deposited in ionization:  2.5291134135362532e-09
# Fraction Deposited in excitation:  1.934694569694407e-09
# Fraction Deposited in heating:  5.087475688948143e-10
# Energy is conserved up to (%):  -1.2847992707972764e-09
# Fraction Deposited in ICS (Numerical Error):  -1.2847753468628476e-11
# Energy conservation with deposited (%):  -2.3923934428708572e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1575728087031.9531
# Fraction of Energy in low energy electrons:  6.611731776143247e-09
# Fraction of Energy in photons - Continuum:  0.9999999887112935
# Fraction Deposited in ionization:  2.3849387281423217e-09
# Fraction Deposited in excitation:  1.8244053357572755e-09
# Fraction Deposited in heating:  4.797459296667373e-10
# Energy is conserved up to (%):  -1.2115303890747848e-09
# Fraction Deposited in ICS (Numerical Error):  -1.21151637405459e-11
# Energy conservation with deposited (%):  -1.4015020194678648e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1670984245411.8242
# Fraction of Energy in low energy electrons:  6.23482327388607e-09
# Fraction of Energy in photons - Continuum:  0.9999999894408681
# Fraction Deposited in ionization:  2.2489828674943272e-09
# Fraction Deposited in excitation:  1.7204032519021175e-09
# Fraction Deposited in heating:  4.5239755874063437e-10
# Energy is conserved up to (%):  -9.74750664067841e-09
# Fraction Deposited in ICS (Numerical Error):  -9.747520240958051e-11
# Energy conservation with deposited (%):  1.3600279641743828e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1771998843832.1865
# Fraction of Energy in low energy electrons:  5.879400824585027e-09
# Fraction of Energy in photons - Continuum:  0.9999999899688226
# Fraction Deposited in ionization:  2.1207773091188653e-09
# Fraction Deposited in excitation:  1.6223299127366664e-09
# Fraction Deposited in heating:  4.266082097839182e-10
# Energy is conserved up to (%):  -1.7938817911746582e-09
# Fraction Deposited in ICS (Numerical Error):  -1.7938792537374808e-11
# Energy conservation with deposited (%):  -2.5374371773828816e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1879119992402.2852
# Fraction of Energy in low energy electrons:  5.544239593913282e-09
# Fraction of Energy in photons - Continuum:  0.9999999905401359
# Fraction Deposited in ionization:  1.999880239143181e-09
# Fraction Deposited in excitation:  1.529847344132965e-09
# Fraction Deposited in heating:  4.0228900612364915e-10
# Energy is conserved up to (%):  -1.6392120283374568e-09
# Fraction Deposited in ICS (Numerical Error):  -1.639204738271972e-11
# Energy conservation with deposited (%):  -7.29006548514268e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1992716845237.605
# Fraction of Energy in low energy electrons:  5.228184570471963e-09
# Fraction of Energy in photons - Continuum:  0.9999999910790092
# Fraction Deposited in ionization:  1.885875029744198e-09
# Fraction Deposited in excitation:  1.4426368385223507e-09
# Fraction Deposited in heating:  3.793561387750229e-10
# Energy is conserved up to (%):  -1.506172463228071e-09
# Fraction Deposited in ICS (Numerical Error):  -1.5061621593759242e-11
# Energy conservation with deposited (%):  -1.0303852147006161e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2113180872615.4043
# Fraction of Energy in low energy electrons:  4.930146585463094e-09
# Fraction of Energy in photons - Continuum:  1.0000000079999867
# Fraction Deposited in ionization:  1.7783688033921353e-09
# Fraction Deposited in excitation:  1.360397856585648e-09
# Fraction Deposited in heating:  3.5773058199699475e-10
# Energy is conserved up to (%):  -1.6426630695029298e-06
# Fraction Deposited in ICS (Numerical Error):  -1.6426630735997056e-08
# Energy conservation with deposited (%):  4.0967758274890725e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2240927210034.778
# Fraction of Energy in low energy electrons:  4.6490985592651425e-09
# Fraction of Energy in photons - Continuum:  0.9999999933001196
# Fraction Deposited in ionization:  1.6769910789408797e-09
# Fraction Deposited in excitation:  1.282846991553628e-09
# Fraction Deposited in heating:  3.3733781445548983e-10
# Energy is conserved up to (%):  -1.2463940427499877e-07
# Fraction Deposited in ICS (Numerical Error):  -1.2463941847365132e-09
# Energy conservation with deposited (%):  1.4198652557914671e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2376396088830.3022
# Fraction of Energy in low energy electrons:  4.384071961976201e-09
# Fraction of Energy in photons - Continuum:  0.9999999935978894
# Fraction Deposited in ionization:  1.5813924948992795e-09
# Fraction Deposited in excitation:  1.2097169925485049e-09
# Fraction Deposited in heating:  3.1810755834449715e-10
# Energy is conserved up to (%):  -1.091178385390347e-07
# Fraction Deposited in ICS (Numerical Error):  -1.0911783122848977e-09
# Energy conservation with deposited (%):  -7.31054493075867e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2520054353269.385
# Fraction of Energy in low energy electrons:  4.134153475727555e-09
# Fraction of Energy in photons - Continuum:  0.9999999938933446
# Fraction Deposited in ionization:  1.4912436054836928e-09
# Fraction Deposited in excitation:  1.1407558436008822e-09
# Fraction Deposited in heating:  2.9997353782080674e-10
# Energy is conserved up to (%):  -9.594710822262694e-08
# Fraction Deposited in ICS (Numerical Error):  -9.594711654969477e-10
# Energy conservation with deposited (%):  8.327067825793106e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2672397069361.388
# Fraction of Energy in low energy electrons:  3.898481847265518e-09
# Fraction of Energy in photons - Continuum:  1.0000008690202922
# Fraction Deposited in ionization:  1.406233745302801e-09
# Fraction Deposited in excitation:  1.0757258951682822e-09
# Fraction Deposited in heating:  2.828732603089884e-10
# Energy is conserved up to (%):  -8.75683606831199e-05
# Fraction Deposited in ICS (Numerical Error):  -8.756836065450909e-07
# Energy conservation with deposited (%):  -2.8610808704516494e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2833949230922.7637
# Fraction of Energy in low energy electrons:  3.6762449199552215e-09
# Fraction of Energy in photons - Continuum:  1.0000000538909244
# Fraction Deposited in ionization:  1.3260699587623113e-09
# Fraction Deposited in excitation:  1.014403045162443e-09
# Fraction Deposited in heating:  2.667478032072052e-10
# Energy is conserved up to (%):  -6.017439006989002e-06
# Fraction Deposited in ICS (Numerical Error):  -6.017438983911589e-08
# Energy conservation with deposited (%):  -2.3077413623884512e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3005267568777.472
# Fraction of Energy in low energy electrons:  3.4666768349777616e-09
# Fraction of Energy in photons - Continuum:  1.0000000470488255
# Fraction Deposited in ionization:  1.2504759904998968e-09
# Fraction Deposited in excitation:  9.565759666628451e-10
# Fraction Deposited in heating:  2.5154159919575657e-10
# Energy is conserved up to (%):  -5.297409611583829e-06
# Fraction Deposited in ICS (Numerical Error):  -5.297409584983312e-08
# Energy conservation with deposited (%):  -2.6600516979901244e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3186942469327.463
# Fraction of Energy in low energy electrons:  3.269055392076002e-09
# Fraction of Energy in photons - Continuum:  1.000000041140797
# Fraction Deposited in ionization:  1.1791913333714327e-09
# Fraction Deposited in excitation:  9.020453796552339e-10
# Fraction Deposited in heating:  2.3720223974643054e-10
# Energy is conserved up to (%):  -4.672829130919711e-06
# Fraction Deposited in ICS (Numerical Error):  -4.6728291198313524e-08
# Energy conservation with deposited (%):  -1.1088358670590565e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3379600009104.9067
# Fraction of Energy in low energy electrons:  3.0826995607537533e-09
# Fraction of Energy in photons - Continuum:  1.000000037034779
# Fraction Deposited in ionization:  1.1119703307077672e-09
# Fraction Deposited in excitation:  8.506233642854451e-10
# Fraction Deposited in heating:  2.2368030150406071e-10
# Energy is conserved up to (%):  -4.230375265809453e-06
# Fraction Deposited in ICS (Numerical Error):  -4.2303752613335624e-08
# Energy conservation with deposited (%):  -4.475891129098373e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3583904112317.4634
# Fraction of Energy in low energy electrons:  2.906967133351724e-09
# Fraction of Energy in photons - Continuum:  1.0000000334829566
# Fraction Deposited in ionization:  1.0485813297483142e-09
# Fraction Deposited in excitation:  8.021327132619532e-10
# Fraction Deposited in heating:  2.1092919228937349e-10
# Energy is conserved up to (%):  -3.8451566900411364e-06
# Fraction Deposited in ICS (Numerical Error):  -3.8451566872365975e-08
# Energy conservation with deposited (%):  -2.8045393008616465e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3800558838821.8413
# Fraction of Energy in low energy electrons:  2.7412525119122758e-09
# Fraction of Energy in photons - Continuum:  1.0000000306660717
# Fraction Deposited in ionization:  9.888058833340371e-10
# Fraction Deposited in excitation:  7.564063211753785e-10
# Fraction Deposited in heating:  1.9890497833084774e-10
# Energy is conserved up to (%):  -3.535144143418718e-06
# Fraction Deposited in ICS (Numerical Error):  -3.535144106049045e-08
# Energy conservation with deposited (%):  -3.736967248590877e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4030310810410.256
# Fraction of Energy in low energy electrons:  2.584984621205999e-09
# Fraction of Energy in photons - Continuum:  1.0000000285853583
# Fraction Deposited in ionization:  9.324379971086366e-10
# Fraction Deposited in excitation:  7.132866086303603e-10
# Fraction Deposited in heating:  1.8756622363561453e-10
# Energy is conserved up to (%):  -3.300363372138774e-06
# Fraction Deposited in ICS (Numerical Error):  -3.30036337453254e-08
# Energy conservation with deposited (%):  2.393765761696047e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4273951783771.138
# Fraction of Energy in low energy electrons:  2.4376249407284006e-09
# Fraction of Energy in photons - Continuum:  1.0000000248564336
# Fraction Deposited in ionization:  8.792834196338307e-10
# Fraction Deposited in excitation:  6.726249792054082e-10
# Fraction Deposited in heating:  1.7687384018755777e-10
# Energy is conserved up to (%):  -2.9022840790956767e-06
# Fraction Deposited in ICS (Numerical Error):  -2.9022840693105766e-08
# Energy conservation with deposited (%):  -9.785100442140391e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4532321378990.888
# Fraction of Energy in low energy electrons:  2.298665648884491e-09
# Fraction of Energy in photons - Continuum:  1.0000000226693084
# Fraction Deposited in ionization:  8.291589729722786e-10
# Fraction Deposited in excitation:  6.342813073692555e-10
# Fraction Deposited in heating:  1.6679097562957267e-10
# Energy is conserved up to (%):  -2.6598205142485966e-06
# Fraction Deposited in ICS (Numerical Error):  -2.6598205159606296e-08
# Energy conservation with deposited (%):  1.7120331148151422e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4806309972999.415
# Fraction of Energy in low energy electrons:  2.1676278729665945e-09
# Fraction of Energy in photons - Continuum:  1.000000020932964
# Fraction Deposited in ionization:  7.818919214315745e-10
# Fraction Deposited in excitation:  5.98123455589323e-10
# Fraction Deposited in heating:  1.5728289785417147e-10
# Energy is conserved up to (%):  -2.463788981794126e-06
# Fraction Deposited in ICS (Numerical Error):  -2.463788994722423e-08
# Energy conservation with deposited (%):  1.2928296374805902e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5096861767930.699
# Fraction of Energy in low energy electrons:  2.044060038893392e-09
# Fraction of Energy in photons - Continuum:  1.0000000200695291
# Fraction Deposited in ionization:  7.373193762933653e-10
# Fraction Deposited in excitation:  5.64026818967643e-10
# Fraction Deposited in heating:  1.483168486471884e-10
# Energy is conserved up to (%):  -2.3563252220630595e-06
# Fraction Deposited in ICS (Numerical Error):  -2.3563252178837992e-08
# Energy conservation with deposited (%):  -4.179260090514445e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5404978044972.385
# Fraction of Energy in low energy electrons:  1.9275363150238133e-09
# Fraction of Energy in photons - Continuum:  1.0000000169358485
# Fraction Deposited in ionization:  6.952877344765186e-10
# Fraction Deposited in excitation:  5.318738958353066e-10
# Fraction Deposited in heating:  1.398619203418752e-10
# Energy is conserved up to (%):  -2.0230408344399596e-06
# Fraction Deposited in ICS (Numerical Error):  -2.0230408271853468e-08
# Energy conservation with deposited (%):  -7.254612863069224e-15
# ***************************************************

# %% [markdown]
# The output, stored in *elec_cooling_info*, is a tuple containing the following, as well as what each variable is indexed by:
#
# 0. The secondary propagating photon transfer function $\overline{T}_\text{ICS}$ (*eleceng*, *photeng*). This spectrum has the original upscattered CMB photons **already subtracted**, and generically contains negative values at low energies. This spectrum should be viewed as a **distortion** to the CMB spectrum;
# 1. The low-energy electron transfer function $\overline{T}_e$ (*eleceng*, *eleceng*);
# 2. The energy deposited into ionization $\overline{R}_\text{ion}$ (*eleceng*);
# 3. The energy deposited into excitation $\overline{R}_\text{exc}$ (*eleceng*);
# 4. The energy deposited into heating $\overline{R}_\text{heat}$ (*eleceng*);
# 5. The total energy of upscattered CMB photons $\overline{R}_\text{CMB}$ (*eleceng*), and
# 6. Numerical error away from energy conservation (*eleceng*).
#
# These transfer functions are functions of the injected electron energy, and tell us how energy is deposited by a *single* electron with that energy.
#
# Let's make some plots to understand this. First, let's extract the high-energy deposition into ionization, excitation and heating.

# %% [markdown]
# ## High-Energy Deposition Fractions

# %%
elec_dep_ion  = elec_cooling_info[2]
elec_dep_exc  = elec_cooling_info[3]
elec_dep_heat = elec_cooling_info[4]

# %% [markdown]
# We'll make a plot of the fraction of energy deposited into each of these channels, as a function of the energy injected. These high-energy deposition fractions (for electrons above 3 keV) do *not* include the energy in low-energy electrons, which are processed separately in DarkHistory by [`physics.low_energy`](https://hongwanliu.github.io/DarkHistory/html/_autosummary/darkhistory/darkhistory.low_energy.html).

# %%
plt.figure()

plt.loglog()

ion_plot,  = plt.plot(eleceng, elec_dep_ion/eleceng,  label='Ionization')
exc_plot,  = plt.plot(eleceng, elec_dep_exc/eleceng,  label='Excitation')
heat_plot, = plt.plot(eleceng, elec_dep_heat/eleceng, label='Heating')

plt.xlabel('Electron Energy [eV]')
plt.ylabel('Fraction')
plt.title('High-Energy Deposition Fraction')

plt.legend(handles=[ion_plot, exc_plot, heat_plot])

plt.axis([3.2e3, 5e12, 1e-10, 1])
# Out:
# [3200.0, 5000000000000.0, 1e-10, 1]

# %% [markdown]
# This plot reflects the fact that for higher energy electrons, atomic processes become less important as channels of energy deposition: instead, most of the energy is instead transferred to CMB photons that undergo inverse Compton scattering (ICS).

# %% [markdown]
# ## Comparing Inverse Compton Scattering and Atomic Processes

# %% [markdown]
# Let's explicitly compare the energy deposited into inverse Compton scattering against the energy deposited via atomic processes plus the low-energy electrons. We will ultimately reproduce the plot shown as Fig. 2 of [arXiv:1506.03812](https://arxiv.org/abs/1506.03812).
#
# Let's add up all the energy in atomic processes plus low-energy electrons. First, we get the low-energy electrons, which is saved as a [*TransFuncAtRedshift*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/transferfunction/darkhistory.spec.transferfunction.TransFuncAtRedshift.html). We can obtain the total energy for each injected electron using `TransFuncAtRedshift.toteng()`. The function `toteng()` sums over the the last axis, i.e. it sums the energy of all photons in each spectrum corresponding to an injected electron. This can then be added to the other components to get the total energy deposited as atomic processes.

# %%
lowengelec_tf = elec_cooling_info[1]

eng_dep_lowengelec = lowengelec_tf.toteng()

eng_dep_atomic = eng_dep_lowengelec + elec_dep_ion + elec_dep_exc + elec_dep_heat

# %% [markdown]
# Now let's look at the energy deposited into ICS. This is equal to the energy stored in the secondary propagating photon spectrum, minus the initial energy of these upscattered photons. Again, we can use `TransFuncAtRedshift.toteng()` to get the total energy in the photon spectrum.

# %%
ICS_phot_tf = elec_cooling_info[0]

eng_dep_ICS_phot = ICS_phot_tf.toteng()

eng_dep_ICS = eng_dep_ICS_phot

# %% [markdown]
# All right, let's make the plot!

# %%
plt.figure()

ax = plt.gca()
ax.set_xscale('log')

atomic_plot, = plt.plot(eleceng, eng_dep_atomic/eleceng,  label='Atomic Processes')
ICS_plot,    = plt.plot(eleceng, eng_dep_ICS/eleceng,  label='Inverse Compton')

plt.xlabel('Electron Energy [eV]')
plt.ylabel('Fraction')
plt.title(r'Deposition Fractions, $z=600$')

plt.legend(handles=[atomic_plot, ICS_plot])

plt.axis([1, 5e12, 0, 1.1])
# Out:
# [1, 5000000000000.0, 0, 1.1]

# %% [markdown]
# ## Getting Spectra

# %% [markdown]
# The transfer function stored in `ICS_phot_tf` is essentially a list of photon spectra produced by a single electron at some injected energy. Acting this function by matrix multiplication on any arbitrary injection electron spectrum therefore gives the secondary photon spectrum produced after complete cooling of that spectrum. Again, we emphasize that `ICS_phot_tf` has the upscattered CMB photons **subtracted** from the spectrum.
#
# Let's take some electron spectrum, produced by annihilation of dark matter into a $\tau^+ \tau^-$ pair. This can be obtained from the [*darkhistory.spec.pppc*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/darkhistory.spec.pppc.html), which returns the same flux produced by PPPC4DMID <cite data-cite="6232408/W944VR5Z"></cite>. We'll pick $m_\text{DM}$ = 50 GeV, and obtain the spectrum per annihilation.

# %%
from darkhistory.spec.pppc import get_pppc_spec

mDM = 50e9

elec_spec = get_pppc_spec(mDM, eleceng, 'tau', 'elec')

# %% [markdown]
# `elec_spec` here is a [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object, and contains the abscissa (`eleceng`) and the spectrum, stored as dN/dE or N. To contract this spectrum with `ICS_phot_tf`, we use the `TransferFuncAtRedshift.sum_specs`, which acts the matrix stored in `ICS_phot_tf` on the spectrum.

# %%
phot_spec = ICS_phot_tf.sum_specs(elec_spec.N)

# %% [markdown]
# This produces a photon [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object, with the abscissa given by `photeng`.
#
# We can also produce the initial spectrum of photons that got scattered. This is a blackbody spectrum, since we are only tracking photons that get upscattered in the nonrelativistic, Thomson regime (see the paper for more details). The CMB spectrum at any temperature can be obtained using [*physics.CMB_spec*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/physics/darkhistory.physics.CMB_spec.html). This returns a spectrum containing $dN/(dE\, dV)$ of the CMB.
#
# We simply have to rescale this spectrum to the total energy of CMB photons upscattered, which is stored in the output above.

# %%
eng_initial_cmb = elec_cooling_info[5]

# %% [markdown]
# First, let's put the spectrum in a [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object.

# %%
from darkhistory.spec.spectrum import Spectrum

# Use physics.TCMB() to get the temperature at the right redshift.
CMB_spec = Spectrum(photeng, phys.CMB_spec(photeng, phys.TCMB(rs)), spec_type='dNdE')

# %% [markdown]
# Now, we want to rescale this spectrum so that it has the energy of the photons that got upscattered. This energy is given by `np.dot(eng_initial_cmb, elec_spec.N)`, since `eng_initial_cmb` has each bin normalized to one injected electron at some energy.
#
# We can do the rescaling simply by multiplying the [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object itself.

# %%
CMB_spec *= np.dot(eng_initial_cmb, elec_spec.N)/CMB_spec.toteng()

# %% [markdown]
# Here are the produced spectra. To recap, `elec_spec` contains the injected electron spectrum. `phot_spec` contains the secondary photon spectrum produced with the initial upscattered CMB spectrum subtracted. `CMB_spec` is that initial upscattered CMB spectrum, and `phot_spec + CMB_spec` gives the final spectrum of all photons upscattered by ICS.

# %%
plt.figure()

plt.loglog()

elec_spec_plot, = plt.plot(eleceng, elec_spec.dNdE*eleceng**2, label=r'Injected $e^+e^-$ Spectrum')
phot_spec_plot, = plt.plot(photeng, phot_spec.dNdE*photeng**2, label='ICS Secondary Photon Spectrum')
CMB_plot,       = plt.plot(photeng, CMB_spec.dNdE*photeng**2,  'k--', label='Upscattered CMB')
combined_plot,  = plt.plot(photeng, (phot_spec.dNdE + CMB_spec.dNdE)*photeng**2, label='ICS Scattered Photon Spectrum')

plt.xlabel('Energy [eV]')
plt.ylabel(r'$E^2\, dN/dE$ [eV]')
plt.title('ICS Spectra')

plt.text(0.1, 0.92, r'$\chi \chi \to \tau^+\tau^-$, $m_\chi$ = 50 GeV', fontsize=20, transform=ax.transAxes) 

plt.legend(handles=[elec_spec_plot, phot_spec_plot, CMB_plot, combined_plot], loc=(0.1, 0.58))

plt.axis([1e-4, 1e12, 1e-10, 1e25])
# Out:
# [0.0001, 1000000000000.0, 1e-10, 1e+25]

# %% [markdown]
# The black dashed line shows the spectrum of photons that got upscattered as the electron spectrum (blue) cools completely, producing the final photon spectrum shown in orange.

# %% [markdown]
# ## Bibliography

# %% [markdown]
# <div class="cite2c-biblio"></div>
