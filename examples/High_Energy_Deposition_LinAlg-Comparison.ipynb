# %% [markdown]
# # Initialization

# %%
# %load_ext autoreload
# %load_ext line_profiler
import sys
sys.path.append("..")

# %%
# %autoreload

import numpy as np
import pickle

import main


import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc_file('matplotlibrc')

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [10,10]


import darkhistory.physics as phys
import darkhistory.utilities as utils
import darkhistory.spec.transferfunction as tf
import darkhistory.spec.spectools as spectools

from darkhistory.spec.spectrum import Spectrum

from darkhistory.electrons.ics.ics_spectrum import ics_spec
from darkhistory.electrons.ics.ics_engloss_spectrum import engloss_spec
from darkhistory.electrons.elec_cooling import get_elec_cooling_tf_fast

from darkhistory.electrons import positronium

from scipy.interpolate import interp1d
from scipy.linalg import solve_triangular

from astropy.io import fits

# %%
ics_thomson_ref_tf=pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/tflists/ics/ics_thomson_ref_tf.raw", "rb")) 
ics_rel_ref_tf=pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/tflists/ics/ics_rel_ref_tf.raw", "rb"))
engloss_ref_tf=pickle.load(open("/Users/hongwan/Dropbox (MIT)/Photon Deposition/tflists/ics/engloss_ref_tf.raw", "rb"))

# %%
# %autoreload

# eleceng = 10**np.arange(0, np.log10(5e12), 0.0254)
# photeng = 10**np.arange(-4, np.log10(5e12), 0.0334)

hdul = fits.open(
    '/Users/hongwan/Dropbox (MIT)/Photon Deposition/idl_comparison/final_darkhistory_comparison/'
    +'tf_elec_z_3.000E+03_nstep_6622_logE_6.477E+00_xe_0.000E+00.fits'
)

data = hdul[1].data

eleceng = data.field('eleceng')[0]
photeng = data.field('energy')[0]


rs = 3000
xH = 1

from darkhistory.spec.spectra import Spectra

coll_ion_sec_elec_specs = (
    phys.coll_ion_sec_elec_spec(eleceng, eleceng, species='HI'),
    phys.coll_ion_sec_elec_spec(eleceng, eleceng, species='HeI'),
    phys.coll_ion_sec_elec_spec(eleceng, eleceng, species='HeII')
)

coll_exc_sec_elec_tf_HI = tf.TransFuncAtRedshift(
    np.squeeze(np.identity(eleceng.size)[:, np.where(eleceng > phys.lya_eng)]),
    in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    eng = eleceng[eleceng > phys.lya_eng] - phys.lya_eng,
    dlnz = -1, spec_type = 'N'
)

coll_exc_sec_elec_tf_HeI = tf.TransFuncAtRedshift(
    np.squeeze(np.identity(eleceng.size)[:, np.where(eleceng > phys.He_exc_eng)]),
    in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    eng = eleceng[eleceng > phys.He_exc_eng] - phys.He_exc_eng,
    dlnz = -1, spec_type = 'N'
)

coll_exc_sec_elec_tf_HeII = tf.TransFuncAtRedshift(
    np.squeeze(np.identity(eleceng.size)[:, np.where(eleceng > 4*phys.lya_eng)]),
    in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    eng = eleceng[eleceng > 4*phys.lya_eng] - 4*phys.lya_eng,
    dlnz = -1, spec_type = 'N'
)

coll_exc_sec_elec_tf_HI.rebin(eleceng)
coll_exc_sec_elec_tf_HeI.rebin(eleceng)
coll_exc_sec_elec_tf_HeII.rebin(eleceng)

coll_exc_sec_elec_specs = (
    coll_exc_sec_elec_tf_HI.grid_vals,
    coll_exc_sec_elec_tf_HeI.grid_vals,
    coll_exc_sec_elec_tf_HeII.grid_vals
)

from darkhistory.spec.spectools import EnglossRebinData

ics_engloss_data = EnglossRebinData(eleceng, photeng, eleceng)
# Out:
# ../darkhistory/spec/spectra.py:401: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   np.issubdtype(type(other), float)
# ../darkhistory/spec/spectra.py:402: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   or np.issubdtype(type(other), int)

# %% [markdown]
# # With Linear Algebra

# %%
def get_elec_cooling_tf_fast_linalg(
    raw_nonrel_tf, raw_rel_tf, raw_engloss_tf,
    coll_ion_sec_elec_specs, coll_exc_sec_elec_specs,
    eleceng, photeng, rs, xH, xHe=0, ics_engloss_data=None, 
    check_conservation_eng = False, verbose=False
):

    """Returns transfer function for complete electron cooling through ICS and atomic processes.

    Parameters
    ----------
    nonrel_tf : TransFuncAtRedshift
        Raw nonrelativistic primary electron ICS transfer function.
    rel_tf : string
        Raw relativistic primary electron ICS transfer function.
    engloss_tf_filename : string
        Raw primary electron ICS energy loss transfer function.
    coll_ion_sec_elec_specs : tuple of ndarray
        Normalized collisional ionization secondary electron spectra, order HI, HeI, HeII, indexed by eleceng (injection) x eleceng (abscissa).
    coll_exc_sec_elec_specs : tuple of ndarray
        Normalized collisional excitation secondary electron spectra, order HI, HeI, HeII, indexed by eleceng (injection) x eleceng (abscissa).
    eleceng : ndarray
        The electron *kinetic* energy abscissa.
    photeng : ndarray
        The photon energy abscissa.
    rs : float
        The redshift.
    xe : float
        Free electron fraction. 
    xHe : float, optional
        Singly-ionized helium fraction, nHe+/nH. Set to nHe/nH*xe if None.
    ics_engloss_data : EnglossRebinData
        Stores rebinning information for speed. 
    check_conservation_eng : bool
        If true, checks for energy conservation.
    verbose : bool
        If true, prints energy conservation checks.
    
    Returns
    -------

    tuple of TransFuncAtRedshift
        Transfer functions for photons and low energy electrons.

    Note
    ----
    The raw transfer functions should be generated when the code package is first installed. The transfer function corresponds to the fully resolved
    photon spectrum after scattering by one electron.

    This version of the code works faster, but dispenses with energy conservation checks and several other safeguards. Use only with default abscissa, or when get_ics_cooling_tf works.

    """
    xe = xH + xHe
    
    # v/c of electrons, important subsequently.
    beta_ele = np.sqrt(1 - 1/(1 + eleceng/phys.me)**2)
        
    #####################################
    # Inverse Compton
    #####################################

    T = phys.TCMB(rs)

    # Photon transfer function for single primary electron single scattering.
    # This is dN/(dE dt), dt = 1 s.
    phot_ICS_tf = ics_spec(
        eleceng, photeng, T, nonrel_tf = raw_nonrel_tf, rel_tf = raw_rel_tf
    )

    # Downcasting speeds up np.dot
    phot_ICS_tf._grid_vals = phot_ICS_tf.grid_vals.astype('float64')

    # Energy loss transfer function for single primary electron
    # single scattering. This is dN/(dE dt), dt = 1 s.
    engloss_ICS_tf = engloss_spec(
        eleceng, photeng, T, nonrel_tf = raw_engloss_tf, rel_tf = raw_rel_tf
    )

    # Downcasting speeds up np.dot
    engloss_ICS_tf._grid_vals = engloss_ICS_tf.grid_vals.astype('float64')

    # Switch the spectra type here to type 'N'.
    if phot_ICS_tf.spec_type == 'dNdE':
        phot_ICS_tf.switch_spec_type()
    if engloss_ICS_tf.spec_type == 'dNdE':
        engloss_ICS_tf.switch_spec_type()


    # Define some useful lengths.
    N_eleceng = eleceng.size
    N_photeng = photeng.size

    # Create the secondary electron transfer functions.

    # ICS transfer function.
    elec_ICS_tf = tf.TransFuncAtRedshift(
        np.zeros((N_eleceng, N_eleceng)), in_eng = eleceng,
        rs = rs*np.ones_like(eleceng), eng = eleceng,
        dlnz = -1, spec_type = 'N'
    )

    if ics_engloss_data is not None:
        elec_ICS_tf._grid_vals = ics_engloss_data.rebin(
            engloss_ICS_tf.grid_vals
        )
    else:
        elec_ICS_tf._grid_vals = spectools.engloss_rebin_fast(
            eleceng, photeng, engloss_ICS_tf.grid_vals, eleceng
        )
    
    # Total upscattered photon energy.
    cont_loss_ICS_vec = np.zeros_like(eleceng)
    # Deposited energy, enforces energy conservation.
    deposited_ICS_vec = np.zeros_like(eleceng)
    
    
    #####################
    # Excitation  
    #####################
    
    # Construct the rate matrices first. Secondary electron spectrum is an electron at in_eng - excitation energy, 
    # with a per second rate given by n*sigma*c.
    

    # rate_matrix_exc_HI = np.diag(
    #     (1 - xe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HI') * beta_ele * phys.c
    # )
    
    # rate_matrix_exc_HeI = np.diag(
    #     (phys.nHe/phys.nH - xHe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeI') * beta_ele * phys.c
    # )
    
    # rate_matrix_exc_HeII = np.diag(
    #     xHe*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeII') * beta_ele * phys.c
    # )

    # Construct the TransFuncAtRedshift objects.
    # Electrons scatter from in_eng to in_eng - excitation energy.
    # Remove all of the columns (eng) that have energies below the excitation energy, 
    # elec_exc_HI_tf = tf.TransFuncAtRedshift(
    #     np.squeeze(rate_matrix_exc_HI[:, np.where(eleceng > phys.lya_eng)]), 
    #     in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    #     eng = eleceng[eleceng > phys.lya_eng] - phys.lya_eng,
    #     dlnz = -1, spec_type = 'N'
    # )
    # elec_exc_HeI_tf = tf.TransFuncAtRedshift(
    #     np.squeeze(rate_matrix_exc_HeI[:, np.where(eleceng > phys.He_exc_eng)]), 
    #     in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    #     eng = eleceng[eleceng > phys.He_exc_eng] - phys.He_exc_eng,
    #     dlnz = -1, spec_type = 'N'
    # )
    # elec_exc_HeII_tf = tf.TransFuncAtRedshift(
    #     np.squeeze(rate_matrix_exc_HeII[:, np.where(eleceng > 4*phys.lya_eng)]), 
    #     in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
    #     eng = eleceng[eleceng > 4*phys.lya_eng] - 4*phys.lya_eng,
    #     dlnz = -1, spec_type = 'N'
    # )
    
    # Rebin these transfer functions back to eleceng.
    # elec_exc_HI_tf.rebin(eleceng)
    # elec_exc_HeI_tf.rebin(eleceng)
    # elec_exc_HeII_tf.rebin(eleceng)

    rate_vec_exc_HI = (
        (1 - xH)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HI') * beta_ele * phys.c
    )
    
    rate_vec_exc_HeI = (
        (phys.nHe/phys.nH - xHe)*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeI') * beta_ele * phys.c
    )
    
    rate_vec_exc_HeII = (
        xHe*phys.nH*rs**3 * phys.coll_exc_xsec(eleceng, species='HeII') * beta_ele * phys.c
    )

    elec_exc_HI_tf = tf.TransFuncAtRedshift(
        rate_vec_exc_HI[:, np.newaxis]*coll_exc_sec_elec_specs[0],
        in_eng = eleceng, rs = rs*np.ones_like(eleceng),
        eng = eleceng, dlnz = -1, spec_type  = 'N'
    )

    elec_exc_HeI_tf = tf.TransFuncAtRedshift(
        rate_vec_exc_HeI[:, np.newaxis]*coll_exc_sec_elec_specs[1],
        in_eng = eleceng, rs = rs*np.ones_like(eleceng),
        eng = eleceng, dlnz = -1, spec_type  = 'N'
    )

    elec_exc_HeII_tf = tf.TransFuncAtRedshift(
        rate_vec_exc_HeII[:, np.newaxis]*coll_exc_sec_elec_specs[2],
        in_eng = eleceng, rs = rs*np.ones_like(eleceng),
        eng = eleceng, dlnz = -1, spec_type  = 'N'
    )
   
    # Deposited energy for excitation.
    deposited_exc_vec = np.zeros_like(eleceng)
    
    #####################
    # Ionization  
    #####################
    
    # Construct the rate vector first. Secondary electron spectrum is an electron at in_eng - excitation energy, 
    # with a per second rate given by n*sigma*c.
    rate_vec_ion_HI = (
        (1 - xH)*phys.nH*rs**3 
        * phys.coll_ion_xsec(eleceng, species='HI') * beta_ele * phys.c
    )
    
    rate_vec_ion_HeI = (
        (phys.nHe/phys.nH - xHe)*phys.nH*rs**3 
        * phys.coll_ion_xsec(eleceng, species='HeI') * beta_ele * phys.c
    )
    
    rate_vec_ion_HeII = (
        xHe*phys.nH*rs**3 * 
        phys.coll_ion_xsec(eleceng, species='HeII') * beta_ele * phys.c
    )
    
    # Construct the spectra. 
    # elec_spec_ion_HI = np.array(
    #     [rate*phys.coll_ion_sec_elec_spec(in_eng, eleceng, species='HI') 
    # for rate,in_eng in zip(rate_vec_ion_HI,eleceng)]
    # )
    # elec_spec_ion_HeI = np.array(
    #     [rate*phys.coll_ion_sec_elec_spec(in_eng, eleceng, species='HeI') 
    # for rate,in_eng in zip(rate_vec_ion_HeI,eleceng)]
    # )
    # elec_spec_ion_HeII = np.array(
    #     [rate*phys.coll_ion_sec_elec_spec(in_eng, eleceng, species='HeII') 
    # for rate,in_eng in zip(rate_vec_ion_HeII,eleceng)]
    # )

    # transpose to force multiplication along first axis.
    elec_spec_ion_HI   = (
        rate_vec_ion_HI[:,np.newaxis]   * coll_ion_sec_elec_specs[0]
    )
    elec_spec_ion_HeI  = (
        rate_vec_ion_HeI[:,np.newaxis]  * coll_ion_sec_elec_specs[1]
    )
    elec_spec_ion_HeII = (
        rate_vec_ion_HeII[:,np.newaxis] * coll_ion_sec_elec_specs[2]
    )
    
    # Construct the TransFuncAtRedshift objects.
    # Electrons scatter from in_eng to in_eng - excitation energy.
    # Remove all of the columns (eng) that have energies below the 
    # excitation energy, 
    elec_ion_HI_tf = tf.TransFuncAtRedshift(
        elec_spec_ion_HI, in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
        eng = eleceng, dlnz = -1, spec_type = 'N'
    )
    elec_ion_HeI_tf = tf.TransFuncAtRedshift(
        elec_spec_ion_HeI, in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
        eng = eleceng, dlnz = -1, spec_type = 'N'
    )
    elec_ion_HeII_tf = tf.TransFuncAtRedshift(
        elec_spec_ion_HeII, in_eng = eleceng, rs = rs*np.ones_like(eleceng), 
        eng = eleceng, dlnz = -1, spec_type = 'N'
    )
    
    # Deposited energy for ionization.
    deposited_ion_vec = np.zeros_like(eleceng)
    
    #############################################
    # Heating
    #############################################
    
    dE_heat_dt = phys.elec_heating_engloss_rate(eleceng, xe, rs)
    
    deposited_heat_vec = np.zeros_like(eleceng)

    # new_eleceng = eleceng - dE_heat_dt

    # if not np.all(new_eleceng[1:] > eleceng[:-1]):
    #     utils.compare_arr([new_eleceng, eleceng])
    #     raise ValueError('heating loss is too large: smaller time step required.')

    # # After the check above, we can define the spectra by
    # # manually assigning slightly less than 1 particle along
    # # diagonal, and a small amount in the bin below. 

    # # N_n-1 E_n-1 + N_n E_n = E_n - dE_dt
    # # N_n-1 + N_n = 1
    # # therefore, (1 - N_n) E_n-1 - (1 - N_n) E_n = - dE_dt
    # # i.e. N_n = 1 + dE_dt/(E_n-1 - E_n)

    elec_heat_spec_grid = np.identity(eleceng.size)
    elec_heat_spec_grid[0,0] -= dE_heat_dt[0]/eleceng[0]
    elec_heat_spec_grid[1:, 1:] += np.diag(
        dE_heat_dt[1:]/(eleceng[:-1] - eleceng[1:])
    )
    elec_heat_spec_grid[1:, :-1] -= np.diag(
        dE_heat_dt[1:]/(eleceng[:-1] - eleceng[1:])
    )

    
    
    #############################################
    # Initialization of secondary spectra 
    #############################################

    # Low and high energy boundaries
    loweng = 3000
    eleceng_high = eleceng[eleceng > loweng]
    eleceng_high_ind = np.arange(eleceng.size)[eleceng > loweng]
    eleceng_low = eleceng[eleceng <= loweng]
    eleceng_low_ind  = np.arange(eleceng.size)[eleceng <= loweng]


    if eleceng_low.size == 0:
        raise TypeError('Energy abscissa must contain a low energy bin below 3 keV.')

    # Empty containers for quantities.
    # Final secondary photon spectrum.
    sec_phot_tf = tf.TransFuncAtRedshift(
        np.zeros((N_eleceng, N_photeng)), in_eng = eleceng,
        rs = rs*np.ones_like(eleceng), eng = photeng,
        dlnz = -1, spec_type = 'N'
    )
    # Final secondary low energy electron spectrum.
    sec_lowengelec_tf = tf.TransFuncAtRedshift(
        np.zeros((N_eleceng, N_eleceng)), in_eng = eleceng,
        rs = rs*np.ones_like(eleceng), eng = eleceng,
        dlnz = -1, spec_type = 'N'
    )

    # Start building sec_phot_tf and sec_lowengelec_tf.
    # Low energy regime first.

    sec_lowengelec_tf._grid_vals[:eleceng_low.size, :eleceng_low.size] = (
        np.identity(eleceng_low.size)
    )

    # Continuum energy loss rate per electron, dU_CMB/dt.
    CMB_upscatter_eng_rate = phys.thomson_xsec*phys.c*phys.CMB_eng_density(T)
    
    sec_elec_spec_N_arr = (
        elec_ICS_tf.grid_vals
        + elec_exc_HI_tf.grid_vals + elec_exc_HeI_tf.grid_vals + elec_exc_HeII_tf.grid_vals
        + elec_ion_HI_tf.grid_vals + elec_ion_HeI_tf.grid_vals + elec_ion_HeII_tf.grid_vals
        + elec_heat_spec_grid
    )
    
    sec_phot_spec_N_arr = phot_ICS_tf.grid_vals
    
    sec_elec_totN_arr = np.sum(sec_elec_spec_N_arr, axis=1)
    sec_elec_toteng_arr = np.dot(sec_elec_spec_N_arr, eleceng)
    sec_phot_toteng_arr = np.dot(sec_phot_spec_N_arr, photeng)
    
    deposited_ICS_eng_arr = (
        np.sum(elec_ICS_tf.grid_vals, axis=1)*eleceng
        - np.dot(elec_ICS_tf.grid_vals, eleceng)
        - (np.dot(sec_phot_spec_N_arr, photeng) - CMB_upscatter_eng_rate)
    )
    
    deposited_ICS_eng_arr[eleceng > 20*phys.me - phys.me] -= CMB_upscatter_eng_rate
    continuum_engloss_arr = CMB_upscatter_eng_rate*np.ones_like(eleceng)
    continuum_engloss_arr[eleceng > 20*phys.me - phys.me] = 0
    
    
    deposited_exc_eng_arr = (
        phys.lya_eng*np.sum(elec_exc_HI_tf.grid_vals, axis=1)
        + phys.He_exc_eng*np.sum(elec_exc_HeI_tf.grid_vals, axis=1)
        + 4*phys.lya_eng*np.sum(elec_exc_HeII_tf.grid_vals, axis=1)
    )
    
    deposited_ion_eng_arr = (
        phys.rydberg*np.sum(elec_ion_HI_tf.grid_vals, axis=1)/2
        + phys.He_ion_eng*np.sum(elec_ion_HeI_tf.grid_vals, axis=1)/2
        + 4*phys.rydberg*np.sum(elec_ion_HeII_tf.grid_vals, axis=1)/2
    )
    deposited_heat_eng_arr = dE_heat_dt

    # with self-scattering. 
    sec_elec_spec_N_full_arr = np.array(sec_elec_spec_N_arr)
    sec_phot_spec_N_full_arr = np.array(sec_phot_spec_N_arr)
    continuum_engloss_full_arr = np.array(continuum_engloss_arr)
    deposited_ICS_eng_full_arr = np.array(deposited_ICS_eng_arr)
    deposited_exc_eng_full_arr = np.array(deposited_exc_eng_arr)
    deposited_ion_eng_full_arr = np.array(deposited_ion_eng_arr)
    deposited_heat_eng_full_arr = np.array(deposited_heat_eng_arr)

    # remove self-scattering, re-normalize. 
    np.fill_diagonal(sec_elec_spec_N_arr, 0)
    
    toteng_no_self_scatter_arr = (
        np.dot(sec_elec_spec_N_arr, eleceng)
        + np.dot(sec_phot_spec_N_arr, photeng)
        - continuum_engloss_arr
        + deposited_ICS_eng_arr
        + deposited_exc_eng_arr
        + deposited_ion_eng_arr
        + deposited_heat_eng_arr
    )
    
    toteng_full_arr = (
        np.dot(sec_elec_spec_N_full_arr, eleceng)
        + np.dot(sec_phot_spec_N_arr, photeng)
        - continuum_engloss_arr
        + deposited_ICS_eng_arr
        + deposited_exc_eng_arr
        + deposited_ion_eng_arr
        + deposited_heat_eng_arr
    )
    
    fac_arr = eleceng/toteng_no_self_scatter_arr
    fac_arr_full = eleceng/toteng_full_arr
        
    sec_elec_spec_N_arr *= fac_arr[:, np.newaxis]
    sec_phot_spec_N_arr *= fac_arr[:, np.newaxis]
    continuum_engloss_arr  *= fac_arr
    deposited_ICS_eng_arr  *= fac_arr
    deposited_exc_eng_arr  *= fac_arr
    deposited_ion_eng_arr  *= fac_arr
    deposited_heat_eng_arr *= fac_arr
    
    sec_elec_spec_N_full_arr *= fac_arr_full[:, np.newaxis]
    sec_phot_spec_N_full_arr *= fac_arr_full[:, np.newaxis]
    continuum_engloss_full_arr *= fac_arr_full
    deposited_ICS_eng_full_arr *= fac_arr_full
    deposited_exc_eng_full_arr *= fac_arr_full
    deposited_ion_eng_full_arr *= fac_arr_full
    deposited_heat_eng_full_arr *= fac_arr_full
    
    deposited_ICS_eng_arr[eleceng < loweng]  = 0
    deposited_exc_eng_arr[eleceng < loweng]  = 0
    deposited_ion_eng_arr[eleceng < loweng]  = 0
    deposited_heat_eng_arr[eleceng < loweng] = 0
    
    continuum_engloss_arr[eleceng < loweng]  = 0
    
    sec_phot_spec_N_arr[eleceng < loweng] = 0
    
    sec_lowengelec_N_arr = np.identity(eleceng.size)
    sec_lowengelec_N_arr[eleceng >= loweng] = 0
    sec_lowengelec_N_arr[eleceng_high_ind[0]:, :eleceng_high_ind[0]] += sec_elec_spec_N_arr[eleceng_high_ind[0]:, :eleceng_high_ind[0]]

    sec_highengelec_N_arr = np.zeros_like(sec_elec_spec_N_arr)
    sec_highengelec_N_arr[:, eleceng_high_ind[0]:] = sec_elec_spec_N_arr[:, eleceng_high_ind[0]:]
    
    deposited_ICS_eng_full_arr[eleceng < loweng]  = 0
    deposited_exc_eng_full_arr[eleceng < loweng]  = 0
    deposited_ion_eng_full_arr[eleceng < loweng]  = 0
    deposited_heat_eng_full_arr[eleceng < loweng] = 0
    
    continuum_engloss_full_arr[eleceng < loweng]  = 0
    
    sec_phot_spec_N_full_arr[eleceng < loweng] = 0
    
    sec_lowengelec_N_full_arr = np.identity(eleceng.size)
    sec_lowengelec_N_full_arr[eleceng >= loweng] = 0
    sec_lowengelec_N_full_arr[eleceng_high_ind[0]:, :eleceng_high_ind[0]] += sec_elec_spec_N_full_arr[eleceng_high_ind[0]:, :eleceng_high_ind[0]]

    sec_highengelec_N_full_arr = np.zeros_like(sec_elec_spec_N_full_arr)
    sec_highengelec_N_full_arr[:, eleceng_high_ind[0]:] = sec_elec_spec_N_full_arr[:, eleceng_high_ind[0]:]
    
    
    print(np.allclose(sec_elec_spec_N_arr, np.tril(sec_elec_spec_N_arr)))
    
    # T = E.T + Prompt
    deposited_ICS_vec_linalg  = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_ICS_eng_arr, lower=True)
    deposited_exc_vec_linalg  = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_exc_eng_arr, lower=True)
    deposited_ion_vec_linalg  = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_ion_eng_arr, lower=True)
    deposited_heat_vec_linalg = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_arr, deposited_heat_eng_arr, lower=True)
    
    continuum_engloss_vec_linalg = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_arr, continuum_engloss_arr, lower=True)
    
    sec_phot_tf_linalg = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_arr, sec_phot_spec_N_arr, lower=True)
    
    # Prompt: low energy e produced in secondary spectrum upon scattering (sec_lowengelec_N_arr).
    # T : high energy e produced (sec_highengelec_N_arr). 
    sec_lowengelec_tf_linalg = solve_triangular(np.identity(eleceng.size) - sec_highengelec_N_arr, sec_lowengelec_N_arr, lower=True)

    # Now, without doing the same bin removal.
    deposited_ICS_vec_full  = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_full_arr, deposited_ICS_eng_full_arr, lower=True)
    deposited_exc_vec_full  = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_full_arr, deposited_exc_eng_full_arr, lower=True)
    deposited_ion_vec_full  = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_full_arr, deposited_ion_eng_full_arr, lower=True)
    deposited_heat_vec_full = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_full_arr, deposited_heat_eng_full_arr, lower=True)
    
    continuum_engloss_vec_full = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_full_arr, continuum_engloss_full_arr, lower=True)
    
    sec_phot_tf_full = solve_triangular(np.identity(eleceng.size) - sec_elec_spec_N_full_arr, sec_phot_spec_N_full_arr, lower=True)
    
    # Prompt: low energy e produced in secondary spectrum upon scattering (sec_lowengelec_N_arr).
    # T : high energy e produced (sec_highengelec_N_arr). 
    sec_lowengelec_tf_full = solve_triangular(np.identity(eleceng.size) - sec_highengelec_N_full_arr, sec_lowengelec_N_full_arr, lower=True)

    
    for i, eng in zip(eleceng_high_ind, eleceng_high):
        
        failed_conservation_check = False
        
        if check_conservation_eng:

            conservation_check = (
                eng
                - np.dot(sec_lowengelec_tf_linalg[i], eleceng)
                + continuum_engloss_vec_linalg[i]
                - np.dot(sec_phot_tf_linalg[i], photeng)
                - deposited_exc_vec_linalg[i]
                - deposited_ion_vec_linalg[i]
                - deposited_heat_vec_linalg[i]
            )
            
            conservation_check_full = (
                eng
                - np.dot(sec_lowengelec_tf_full[i], eleceng)
                + continuum_engloss_vec_full[i]
                - np.dot(sec_phot_tf_full[i], photeng)
                - deposited_exc_vec_full[i]
                - deposited_ion_vec_full[i]
                - deposited_heat_vec_full[i]
            )

            if np.abs(conservation_check/eng) > 0.1:
                failed_conservation_check = True
                print('failed no-scattering linalg!')
                
            if np.abs(conservation_check_full/eng) > 0.1:
                failed_conservation_check = True
                print('failed full linalg!')
                
            if verbose or failed_conservation_check:
                
                print('***************************************************')
                print('rs: ', rs)
                print('injected energy: ', eng)
                print(
                    'Energy in low energy electrons (no self-scatter): ',
                    np.dot(sec_lowengelec_tf_linalg[i], eleceng)
                )
                print(
                    'Energy in low energy electrons (full): ',
                    np.dot(sec_lowengelec_tf_full[i], eleceng)
                )
                print('Energy in photons (no self-scatter): ', np.dot(sec_phot_tf_linalg[i], photeng))
                print('Energy in photons (full): ', np.dot(sec_phot_tf_full[i], photeng))
                print('Continuum_engloss (no self-scatter): ', continuum_engloss_vec_linalg[i])
                print('Continuum_engloss (full): ', continuum_engloss_vec_full[i])
                print(
                    'Deposited in ionization (no self-scatter): ', deposited_ion_vec_linalg[i]
                )
                print(
                    'Deposited in ionization (full): ', deposited_ion_vec_full[i]
                )
                print(
                    'Deposited in excitation (no self-scatter): ', deposited_exc_vec_linalg[i]
                )
                print(
                    'Deposited in excitation (full): ', deposited_exc_vec_full[i]
                )
                print(
                    'Deposited in heating (no self-scatter): ', deposited_heat_vec_linalg[i]
                )
                print(
                    'Deposited in heating (full): ', deposited_heat_vec_full[i]
                )
                print('Deposited in ICS (no self-scatter): ', deposited_ICS_vec_linalg[i])
                print('Deposited in ICS (full): ', deposited_ICS_vec_full[i])
                print(
                    'Energy conservation with deposited (no self-scatter) (%): ',
                    (conservation_check - deposited_ICS_vec_linalg[i])/eng*100
                )
                print(
                    'Energy conservation with deposited (full) (%): ',
                    (conservation_check - deposited_ICS_vec_full[i])/eng*100
                )
                print('***************************************************')
                
            if failed_conservation_check:
                raise RuntimeError('Conservation of energy failed.')


    return (
        sec_phot_tf, sec_lowengelec_tf,
        deposited_ion_vec, deposited_exc_vec, deposited_heat_vec,
        cont_loss_ICS_vec, deposited_ICS_vec
    )

# %%
# %lprun -f get_elec_cooling_tf_fast_linalg get_elec_cooling_tf_fast_linalg(ics_thomson_ref_tf, ics_rel_ref_tf, engloss_ref_tf, coll_ion_sec_elec_specs, coll_exc_sec_elec_specs, eleceng, photeng, rs, xH, xHe=xH*phys.nHe/phys.nH, ics_engloss_data = ics_engloss_data, check_conservation_eng=True, verbose=True)
# Out:
# True
# ***************************************************
# rs:  3000
# injected energy:  3016.701062885404
# Energy in low energy electrons (no self-scatter):  2845.118074807503
# Energy in low energy electrons (full):  2845.1180748105216
# Energy in photons (no self-scatter):  2882.3712129754294
# Energy in photons (full):  2882.371212978487
# Continuum_engloss (no self-scatter):  2837.5054623630117
# Continuum_engloss (full):  2837.505462366022
# Deposited in ionization (no self-scatter):  0.4707976377945742
# Deposited in ionization (full):  0.4707976377950737
# Deposited in excitation (no self-scatter):  0.38909131851362727
# Deposited in excitation (full):  0.3890913185140401
# Deposited in heating (no self-scatter):  125.92549553065011
# Deposited in heating (full):  125.9254955307837
# Deposited in ICS (no self-scatter):  -0.06814702147464119
# Deposited in ICS (full):  -0.06814702147471348
# Energy conservation with deposited (no self-scatter) (%):  -1.1399590967383358e-14
# Energy conservation with deposited (full) (%):  -9.003284698250996e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3199.0671427921043
# Energy in low energy electrons (no self-scatter):  2845.650431744769
# Energy in low energy electrons (full):  2845.650431748578
# Energy in photons (no self-scatter):  5950.723209677859
# Energy in photons (full):  5950.723209682572
# Continuum_engloss (no self-scatter):  5855.250574959987
# Continuum_engloss (full):  5855.250574964625
# Deposited in ionization (no self-scatter):  0.9618270726461458
# Deposited in ionization (full):  0.9618270726469127
# Deposited in excitation (no self-scatter):  0.7962194183884908
# Deposited in excitation (full):  0.796219418389125
# Deposited in heating (no self-scatter):  256.32553421402685
# Deposited in heating (full):  256.32553421423177
# Deposited in ICS (no self-scatter):  -0.13950437559922432
# Deposited in ICS (full):  -0.1395043755993354
# Energy conservation with deposited (no self-scatter) (%):  3.312466022529997e-14
# Energy conservation with deposited (full) (%):  3.65968541073202e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3392.457645207818
# Energy in low energy electrons (no self-scatter):  2846.265077027799
# Energy in low energy electrons (full):  2846.26507702844
# Energy in photons (no self-scatter):  9213.758354254152
# Energy in photons (full):  9213.758354248617
# Continuum_engloss (no self-scatter):  9061.264040746988
# Continuum_engloss (full):  9061.264040741544
# Deposited in ionization (no self-scatter):  1.4732938208461928
# Deposited in ionization (full):  1.4732938208453203
# Deposited in excitation (no self-scatter):  1.2216889196847172
# Deposited in excitation (full):  1.2216889196839922
# Deposited in heating (no self-scatter):  391.2170617087403
# Deposited in heating (full):  391.21706170850996
# Deposited in ICS (no self-scatter):  -0.21378977641634497
# Deposited in ICS (full):  -0.21378977641621819
# Energy conservation with deposited (no self-scatter) (%):  -2.2719357465203792e-14
# Energy conservation with deposited (full) (%):  -2.6456691359152114e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3597.5390202295966
# Energy in low energy electrons (no self-scatter):  2846.9423151609917
# Energy in low energy electrons (full):  2846.942315164368
# Energy in photons (no self-scatter):  12679.197586020158
# Energy in photons (full):  12679.197586026807
# Continuum_engloss (no self-scatter):  12462.54197178485
# Continuum_engloss (full):  12462.541971791383
# Deposited in ionization (no self-scatter):  2.0051869931409723
# Deposited in ionization (full):  2.005186993142027
# Deposited in excitation (no self-scatter):  1.6656263747846185
# Deposited in excitation (full):  1.6656263747854942
# Deposited in heating (no self-scatter):  530.5621669362534
# Deposited in heating (full):  530.562166936533
# Deposited in ICS (no self-scatter):  -0.2918894708811778
# Deposited in ICS (full):  -0.2918894708813315
# Energy conservation with deposited (no self-scatter) (%):  -1.2915171543461818e-14
# Energy conservation with deposited (full) (%):  -8.642518018510113e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3815.018006298924
# Energy in low energy electrons (no self-scatter):  2847.6726919246216
# Energy in low energy electrons (full):  2847.672691924699
# Energy in photons (no self-scatter):  16354.25349521854
# Energy in photons (full):  16354.25349520624
# Continuum_engloss (no self-scatter):  16065.511685679585
# Continuum_engloss (full):  16065.511685667505
# Deposited in ionization (no self-scatter):  2.5573655971237033
# Deposited in ionization (full):  2.5573655971217955
# Deposited in excitation (no self-scatter):  2.128049942303992
# Deposited in excitation (full):  2.128049942302402
# Deposited in heating (no self-scatter):  674.291970129123
# Deposited in heating (full):  674.2919701286214
# Deposited in ICS (no self-scatter):  -0.3738808332019389
# Deposited in ICS (full):  -0.37388083320165943
# Energy conservation with deposited (no self-scatter) (%):  -7.18542262599005e-14
# Energy conservation with deposited (full) (%):  -7.917904451336005e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4045.6440657192725
# Energy in low energy electrons (no self-scatter):  2848.450769113457
# Energy in low energy electrons (full):  2848.450769125092
# Energy in photons (no self-scatter):  20245.667747581967
# Energy in photons (full):  20245.667747651805
# Continuum_engloss (no self-scatter):  19876.06378852159
# Continuum_engloss (full):  19876.063788590156
# Deposited in ionization (no self-scatter):  3.1295724781813794
# Deposited in ionization (full):  3.1295724781921694
# Deposited in excitation (no self-scatter):  2.608879418224611
# Deposited in excitation (full):  2.608879418233606
# Deposited in heating (no self-scatter):  822.310953604718
# Deposited in heating (full):  822.3109536075528
# Deposited in ICS (no self-scatter):  -0.460067955680348
# Deposited in ICS (full):  -0.4600679556819352
# Energy conservation with deposited (no self-scatter) (%):  -9.439646934008381e-14
# Energy conservation with deposited (full) (%):  -5.516339986161099e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4290.211967405048
# Energy in low energy electrons (no self-scatter):  2849.272952736585
# Energy in low energy electrons (full):  2849.2729527487522
# Energy in photons (no self-scatter):  24359.673611318358
# Energy in photons (full):  24359.67361139277
# Continuum_engloss (no self-scatter):  23899.5115701966
# Continuum_engloss (full):  23899.51157026965
# Deposited in ionization (no self-scatter):  3.7214368582116295
# Deposited in ionization (full):  3.721436858223118
# Deposited in excitation (no self-scatter):  3.107936824636806
# Deposited in excitation (full):  3.107936824646385
# Deposited in heating (no self-scatter):  974.498183250114
# Deposited in heating (full):  974.498183253132
# Deposited in ICS (no self-scatter):  -0.5505833862538432
# Deposited in ICS (full):  -0.5505833862555337
# Energy conservation with deposited (no self-scatter) (%):  -9.517945303390655e-14
# Energy conservation with deposited (full) (%):  -5.577495245350157e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4549.564525764319
# Energy in low energy electrons (no self-scatter):  2850.136524790123
# Energy in low energy electrons (full):  2850.1365247953363
# Energy in photons (no self-scatter):  28701.947885790265
# Energy in photons (full):  28701.947885794652
# Continuum_engloss (no self-scatter):  28140.539998175424
# Continuum_engloss (full):  28140.539998179822
# Deposited in ionization (no self-scatter):  4.332475783874168
# Deposited in ionization (full):  4.332475783875086
# Deposited in excitation (no self-scatter):  3.624946091548062
# Deposited in excitation (full):  3.6249460915487974
# Deposited in heating (no self-scatter):  1130.7081795104953
# Deposited in heating (full):  1130.7081795107547
# Deposited in ICS (no self-scatter):  -0.6454880265582538
# Deposited in ICS (full):  -0.6454880265583695
# Energy conservation with deposited (no self-scatter) (%):  -1.0028347754735042e-13
# Energy conservation with deposited (full) (%):  -9.774070145282945e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4824.595505152363
# Energy in low energy electrons (no self-scatter):  2851.039330846689
# Energy in low energy electrons (full):  2851.039330853748
# Energy in photons (no self-scatter):  33277.55472082549
# Energy in photons (full):  33277.55472085142
# Continuum_engloss (no self-scatter):  32603.1467721997
# Continuum_engloss (full):  32603.1467722252
# Deposited in ionization (no self-scatter):  4.962094905375447
# Deposited in ionization (full):  4.962094905379576
# Deposited in excitation (no self-scatter):  4.159532187918181
# Deposited in excitation (full):  4.159532187921608
# Deposited in heating (no self-scatter):  1290.7715533574546
# Deposited in heating (full):  1290.7715533585492
# Deposited in ICS (no self-scatter):  -0.7449547708596382
# Deposited in ICS (full):  -0.744954770860236
# Energy conservation with deposited (no self-scatter) (%):  -8.241882207018066e-14
# Energy conservation with deposited (full) (%):  -7.002930514964647e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  5116.252699905599
# Energy in low energy electrons (no self-scatter):  2851.988004684437
# Energy in low energy electrons (full):  2851.9880047016145
# Energy in photons (no self-scatter):  38090.75189633819
# Energy in photons (full):  38090.75189649928
# Continuum_engloss (no self-scatter):  37290.44939312878
# Continuum_engloss (full):  37290.4493932866
# Deposited in ionization (no self-scatter):  5.609569543935511
# Deposited in ionization (full):  5.609569543959545
# Deposited in excitation (no self-scatter):  4.711203728917884
# Deposited in excitation (full):  4.711203728938027
# Deposited in heating (no self-scatter):  1454.4904681797227
# Deposited in heating (full):  1454.4904681859784
# Deposited in ICS (no self-scatter):  -0.8490494408170874
# Deposited in ICS (full):  -0.8490494408206978
# Energy conservation with deposited (no self-scatter) (%):  -3.8248288698492313e-14
# Energy conservation with deposited (full) (%):  3.231769905745183e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  5425.541200570471
# Energy in low energy electrons (no self-scatter):  2852.973192105548
# Energy in low energy electrons (full):  2852.9731921197285
# Energy in photons (no self-scatter):  43145.352849211056
# Energy in photons (full):  43145.352849326824
# Continuum_engloss (no self-scatter):  42205.035941451126
# Continuum_engloss (full):  42205.03594156462
# Deposited in ionization (no self-scatter):  6.27410867160516
# Deposited in ionization (full):  6.274108671622605
# Deposited in excitation (no self-scatter):  5.279405163093605
# Deposited in excitation (full):  5.279405163108203
# Deposited in heating (no self-scatter):  1621.6555881053946
# Deposited in heating (full):  1621.655588109947
# Deposited in ICS (no self-scatter):  -0.9580012350949004
# Deposited in ICS (full):  -0.9580012350975046
# Energy conservation with deposited (no self-scatter) (%):  -1.4060262640158028e-13
# Energy conservation with deposited (full) (%):  -9.260485013758373e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  5753.526857582852
# Energy in low energy electrons (no self-scatter):  2853.9931133423333
# Energy in low energy electrons (full):  2853.9931133502864
# Energy in photons (no self-scatter):  48444.30856790311
# Energy in photons (full):  48444.30856791318
# Continuum_engloss (no self-scatter):  47348.554045658464
# Continuum_engloss (full):  47348.55404566866
# Deposited in ionization (no self-scatter):  6.954802797153555
# Deposited in ionization (full):  6.954802797155826
# Deposited in excitation (no self-scatter):  5.863471765854133
# Deposited in excitation (full):  5.863471765855937
# Deposited in heating (no self-scatter):  1792.0327323258741
# Deposited in heating (full):  1792.0327323265167
# Deposited in ICS (no self-scatter):  -1.0717848929932208
# Deposited in ICS (full):  -1.0717848929934863
# Energy conservation with deposited (no self-scatter) (%):  -1.667362532346171e-13
# Energy conservation with deposited (full) (%):  -1.6212055656605397e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  6101.339954334253
# Energy in low energy electrons (no self-scatter):  2855.0454682101376
# Energy in low energy electrons (full):  2855.0454682142135
# Energy in photons (no self-scatter):  53989.81567468711
# Energy in photons (full):  53989.81567462386
# Continuum_engloss (no self-scatter):  52721.814102916585
# Continuum_engloss (full):  52721.81410285517
# Deposited in ionization (no self-scatter):  7.650650465254316
# Deposited in ionization (full):  7.650650465246196
# Deposited in excitation (no self-scatter):  6.462650588396441
# Deposited in excitation (full):  6.462650588389468
# Deposited in heating (no self-scatter):  1965.3699307013128
# Deposited in heating (full):  1965.369930699286
# Deposited in ICS (no self-scatter):  -1.1903174013680553
# Deposited in ICS (full):  -1.1903174013667042
# Energy conservation with deposited (no self-scatter) (%):  -1.298530094639602e-13
# Energy conservation with deposited (full) (%):  -1.5199800435166507e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  6470.1791022827965
# Energy in low energy electrons (no self-scatter):  2856.1283942139235
# Energy in low energy electrons (full):  2856.128394221636
# Energy in photons (no self-scatter):  59783.282728679944
# Energy in photons (full):  59783.28272869281
# Continuum_engloss (no self-scatter):  58324.7538220196
# Continuum_engloss (full):  58324.753822032464
# Deposited in ionization (no self-scatter):  8.360562967808507
# Deposited in ionization (full):  8.360562967811035
# Deposited in excitation (no self-scatter):  7.076103341941585
# Deposited in excitation (full):  7.076103341943623
# Deposited in heating (no self-scatter):  2141.3986918849478
# Deposited in heating (full):  2141.398691885648
# Deposited in ICS (no self-scatter):  -1.3135567861521027
# Deposited in ICS (full):  -1.3135567861524242
# Energy conservation with deposited (no self-scatter) (%):  -3.1192456826620674e-13
# Energy conservation with deposited (full) (%):  -3.069552995203384e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  6861.315371532226
# Energy in low energy electrons (no self-scatter):  2857.2398718460695
# Energy in low energy electrons (full):  2857.2398718539166
# Energy in photons (no self-scatter):  65825.34235260358
# Energy in photons (full):  65825.34235261955
# Continuum_engloss (no self-scatter):  64156.4484209449
# Continuum_engloss (full):  64156.44842096078
# Deposited in ionization (no self-scatter):  9.083375680865561
# Deposited in ionization (full):  9.083375680868517
# Deposited in excitation (no self-scatter):  7.702914974184237
# Deposited in excitation (full):  7.702914974186638
# Deposited in heating (no self-scatter):  2319.836931844167
# Deposited in heating (full):  2319.8369318449763
# Deposited in ICS (no self-scatter):  -1.4416544717344772
# Deposited in ICS (full):  -1.4416544717348667
# Energy conservation with deposited (no self-scatter) (%):  -1.2162540176365449e-13
# Energy conservation with deposited (full) (%):  -1.1594913976505272e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  7276.0966711129295
# Energy in low energy electrons (no self-scatter):  2858.377742691214
# Energy in low energy electrons (full):  2858.377742706293
# Energy in photons (no self-scatter):  72115.85883790381
# Energy in photons (full):  72115.85883810223
# Continuum_engloss (no self-scatter):  70215.11672348401
# Continuum_engloss (full):  70215.11672367754
# Deposited in ionization (no self-scatter):  9.817857997790506
# Deposited in ionization (full):  9.817857997818301
# Deposited in excitation (no self-scatter):  8.342101267746365
# Deposited in excitation (full):  8.342101267769873
# Deposited in heating (no self-scatter):  2500.3914426785586
# Deposited in heating (full):  2500.391442685694
# Deposited in ICS (no self-scatter):  -1.5745879421733935
# Deposited in ICS (full):  -1.5745879421777667
# Energy conservation with deposited (no self-scatter) (%):  -9.962272981550308e-14
# Energy conservation with deposited (full) (%):  -3.951950838139883e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  7715.952394060849
# Energy in low energy electrons (no self-scatter):  2859.5397289613456
# Energy in low energy electrons (full):  2859.539728981225
# Energy in photons (no self-scatter):  78653.94709153881
# Energy in photons (full):  78653.94709186925
# Continuum_engloss (no self-scatter):  76498.13831530526
# Continuum_engloss (full):  76498.13831562719
# Deposited in ionization (no self-scatter):  10.56272406372557
# Deposited in ionization (full):  10.562724063771094
# Deposited in excitation (no self-scatter):  8.992617311256243
# Deposited in excitation (full):  8.992617311294845
# Deposited in heating (no self-scatter):  2682.7604878174234
# Deposited in heating (full):  2682.7604878290617
# Deposited in ICS (no self-scatter):  -1.7119403264466357
# Deposited in ICS (full):  -1.7119403264538824
# Energy conservation with deposited (no self-scatter) (%):  -6.816201349690204e-14
# Energy conservation with deposited (full) (%):  2.5755721556922792e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  8182.398343301087
# Energy in low energy electrons (no self-scatter):  2860.723457574387
# Energy in low energy electrons (full):  2860.723457599333
# Energy in photons (no self-scatter):  85438.02124207333
# Energy in photons (full):  85438.02124255511
# Continuum_engloss (no self-scatter):  83002.09955833862
# Continuum_engloss (full):  83002.09955880757
# Deposited in ionization (no self-scatter):  11.31664620799457
# Deposited in ionization (full):  11.316646208060137
# Deposited in excitation (no self-scatter):  9.65336852184117
# Deposited in excitation (full):  9.65336852189687
# Deposited in heating (no self-scatter):  2866.6369878875457
# Deposited in heating (full):  2866.636987904261
# Deposited in ICS (no self-scatter):  -1.8538006253833559
# Deposited in ICS (full):  -1.853800625393886
# Energy conservation with deposited (no self-scatter) (%):  -1.0647961444191182e-13
# Energy conservation with deposited (full) (%):  2.221152057207422e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  8677.041955312132
# Energy in low energy electrons (no self-scatter):  2861.9264812012784
# Energy in low energy electrons (full):  2861.9264812201836
# Energy in photons (no self-scatter):  92465.83268333707
# Energy in photons (full):  92465.83268362367
# Continuum_engloss (no self-scatter):  89722.8294125921
# Continuum_engloss (full):  89722.82941287167
# Deposited in ionization (no self-scatter):  12.07826622439639
# Deposited in ionization (full):  12.078266224436463
# Deposited in excitation (no self-scatter):  10.323220003414379
# Deposited in excitation (full):  10.32322000344829
# Deposited in heating (no self-scatter):  3051.711110867505
# Deposited in heating (full):  3051.711110877779
# Deposited in ICS (no self-scatter):  -2.0003937294295393
# Deposited in ICS (full):  -2.000393729435847
# Energy conservation with deposited (no self-scatter) (%):  -1.2078942911247344e-13
# Energy conservation with deposited (full) (%):  -4.809365134400716e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  9201.587839571177
# Energy in low energy electrons (no self-scatter):  2863.146300043441
# Energy in low energy electrons (full):  2863.1463000497747
# Energy in photons (no self-scatter):  99734.51889602357
# Energy in photons (full):  99734.51889587226
# Continuum_engloss (no self-scatter):  96655.44576690136
# Continuum_engloss (full):  96655.44576675654
# Deposited in ionization (no self-scatter):  12.846206974942666
# Deposited in ionization (full):  12.846206974926332
# Deposited in excitation (no self-scatter):  11.001006387637739
# Deposited in excitation (full):  11.001006387623347
# Deposited in heating (no self-scatter):  3237.672884324908
# Deposited in heating (full):  3237.672884320966
# Deposited in ICS (no self-scatter):  -2.151687281946592
# Deposited in ICS (full):  -2.1516872819434525
# Energy conservation with deposited (no self-scatter) (%):  -1.4317475123973737e-13
# Energy conservation with deposited (full) (%):  -1.7729615254982108e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  9757.843652871728
# Energy in low energy electrons (no self-scatter):  2864.3803852554693
# Energy in low energy electrons (full):  2864.3803852516216
# Energy in photons (no self-scatter):  107240.67033445233
# Energy in photons (full):  107240.67033391984
# Continuum_engloss (no self-scatter):  103794.41924628546
# Continuum_engloss (full):  103794.4192457717
# Deposited in ionization (no self-scatter):  13.619084946166891
# Deposited in ionization (full):  13.619084946102149
# Deposited in excitation (no self-scatter):  11.685542720166787
# Deposited in excitation (full):  11.685542720110858
# Deposited in heating (no self-scatter):  3424.2149861969865
# Deposited in heating (full):  3424.214986180873
# Deposited in ICS (no self-scatter):  -2.3074344139179472
# Deposited in ICS (full):  -2.3074344139066056
# Energy conservation with deposited (no self-scatter) (%):  -1.5581600626652776e-13
# Energy conservation with deposited (full) (%):  -2.720465458593908e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  10347.72632875567
# Energy in low energy electrons (no self-scatter):  2865.6262010608525
# Energy in low energy electrons (full):  2865.626201052414
# Energy in photons (no self-scatter):  114980.40022439475
# Energy in photons (full):  114980.40022367807
# Continuum_engloss (no self-scatter):  111133.63898084777
# Continuum_engloss (full):  111133.638980156
# Deposited in ionization (no self-scatter):  14.395521900409522
# Deposited in ionization (full):  14.39552190032172
# Deposited in excitation (no self-scatter):  12.375634757374971
# Deposited in excitation (full):  12.37563475729922
# Deposited in heating (no self-scatter):  3611.035269103874
# Deposited in heating (full):  3611.0352690819764
# Deposited in ICS (no self-scatter):  -2.467541613803253
# Deposited in ICS (full):  -2.467541613787959
# Energy conservation with deposited (no self-scatter) (%):  -1.0254921064039483e-13
# Energy conservation with deposited (full) (%):  -2.503496820881687e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  10973.26868352847
# Energy in low energy electrons (no self-scatter):  2866.881223318259
# Energy in low energy electrons (full):  2866.881223307354
# Energy in photons (no self-scatter):  122949.40407748925
# Energy in photons (full):  122949.40407666673
# Continuum_engloss (no self-scatter):  118666.46771293164
# Continuum_engloss (full):  118666.46771213772
# Deposited in ionization (no self-scatter):  15.174154335865454
# Deposited in ionization (full):  15.17415433576459
# Deposited in excitation (no self-scatter):  13.070087508548115
# Deposited in excitation (full):  13.070087508461112
# Deposited in heating (no self-scatter):  3797.8387199288027
# Deposited in heating (full):  3797.838719903636
# Deposited in ICS (no self-scatter):  -2.631866120597689
# Deposited in ICS (full):  -2.6318661205801295
# Energy conservation with deposited (no self-scatter) (%):  -1.0881194044908081e-13
# Energy conservation with deposited (full) (%):  -2.688347372392435e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  11636.626421621419
# Energy in low energy electrons (no self-scatter):  2868.142961969641
# Energy in low energy electrons (full):  2868.142961960948
# Energy in photons (no self-scatter):  131143.05274742993
# Energy in photons (full):  131143.05274670856
# Continuum_engloss (no self-scatter):  126385.82989538377
# Continuum_engloss (full):  126385.8298946873
# Deposited in ionization (no self-scatter):  15.953645369894645
# Deposited in ionization (full):  15.953645369806082
# Deposited in excitation (no self-scatter):  13.767716110441151
# Deposited in excitation (full):  13.767716110364765
# Deposited in heating (no self-scatter):  3984.3399734290683
# Deposited in heating (full):  3984.339973406974
# Deposited in ICS (no self-scatter):  -2.8007273037887273
# Deposited in ICS (full):  -2.800727303773327
# Energy conservation with deposited (no self-scatter) (%):  8.543563040264794e-14
# Energy conservation with deposited (full) (%):  -4.690621044708741e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  12340.08556444419
# Energy in low energy electrons (no self-scatter):  2869.4089787382295
# Energy in low energy electrons (full):  2869.408978729672
# Energy in photons (no self-scatter):  139556.4676356831
# Energy in photons (full):  139556.46763496828
# Continuum_engloss (no self-scatter):  134284.28313396993
# Continuum_engloss (full):  134284.2831332798
# Deposited in ionization (no self-scatter):  16.7326937263911
# Deposited in ionization (full):  16.73269372630333
# Deposited in excitation (no self-scatter):  14.467354300253186
# Deposited in excitation (full):  14.467354300177481
# Deposited in heating (no self-scatter):  4170.265106002708
# Deposited in heating (full):  4170.26510598081
# Deposited in ICS (no self-scatter):  -2.973070036531542
# Deposited in ICS (full):  -2.9730700365162823
# Energy conservation with deposited (no self-scatter) (%):  -3.3278389520716937e-13
# Energy conservation with deposited (full) (%):  -4.564442486883178e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  13086.070328326896
# Energy in low energy electrons (no self-scatter):  2870.6769057544966
# Energy in low energy electrons (full):  2870.6769057366914
# Energy in photons (no self-scatter):  148184.6179120202
# Energy in photons (full):  148184.617910828
# Continuum_engloss (no self-scatter):  142354.10676372447
# Continuum_engloss (full):  142354.10676257574
# Deposited in ionization (no self-scatter):  17.510043378160724
# Deposited in ionization (full):  17.510043378016547
# Deposited in excitation (no self-scatter):  15.167863630469633
# Deposited in excitation (full):  15.167863630345062
# Deposited in heating (no self-scatter):  4355.3535712328785
# Deposited in heating (full):  4355.353571196949
# Deposited in ICS (no self-scatter):  -3.1492039647994305
# Deposited in ICS (full):  -3.1492039647740255
# Energy conservation with deposited (no self-scatter) (%):  -3.4573343552318475e-13
# Energy conservation with deposited (full) (%):  -5.398712537565111e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  13877.151478700514
# Energy in low energy electrons (no self-scatter):  2871.944456170065
# Energy in low energy electrons (full):  2871.9444561479245
# Energy in photons (no self-scatter):  157022.37560474625
# Energy in photons (full):  157022.37560331696
# Continuum_engloss (no self-scatter):  150587.35130583943
# Continuum_engloss (full):  150587.35130446331
# Deposited in ionization (no self-scatter):  18.284488373994215
# Deposited in ionization (full):  18.28448837382243
# Deposited in excitation (no self-scatter):  15.868138488376164
# Deposited in excitation (full):  15.868138488227633
# Deposited in heating (no self-scatter):  4539.358980072886
# Deposited in heating (full):  4539.358980030102
# Deposited in ICS (no self-scatter):  -3.3288833115784504
# Deposited in ICS (full):  -3.3288833115480188
# Energy conservation with deposited (no self-scatter) (%):  -4.654357413201709e-13
# Energy conservation with deposited (full) (%):  -6.847289964301532e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  14716.055189306091
# Energy in low energy electrons (no self-scatter):  2873.209437007482
# Energy in low energy electrons (full):  2873.209436987978
# Energy in photons (no self-scatter):  166064.59695662165
# Energy in photons (full):  166064.59695534478
# Continuum_engloss (no self-scatter):  158975.91146321336
# Continuum_engloss (full):  158975.91146198317
# Deposited in ionization (no self-scatter):  19.054879187436168
# Deposited in ionization (full):  19.05487918728187
# Deposited in excitation (no self-scatter):  16.567112578369972
# Deposited in excitation (full):  16.567112578236646
# Deposited in heating (no self-scatter):  4722.050246864859
# Deposited in heating (full):  4722.050246826409
# Deposited in ICS (no self-scatter):  -3.5119797402935964
# Deposited in ICS (full):  -3.5119797402663884
# Energy conservation with deposited (no self-scatter) (%):  -4.601478455011846e-13
# Energy conservation with deposited (full) (%):  -6.450344422819264e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  15605.672436961962
# Energy in low energy electrons (no self-scatter):  2874.469758830133
# Energy in low energy electrons (full):  2874.4697588033187
# Energy in photons (no self-scatter):  175306.19327351326
# Energy in photons (full):  175306.19327179051
# Continuum_engloss (no self-scatter):  167511.58852023343
# Continuum_engloss (full):  167511.58851857722
# Deposited in ionization (no self-scatter):  19.82012725900258
# Deposited in ionization (full):  19.820127258797875
# Deposited in excitation (no self-scatter):  17.26376386213235
# Deposited in excitation (full):  17.263763861955116
# Deposited in heating (no self-scatter):  4903.21231171226
# Deposited in heating (full):  4903.212311661339
# Deposited in ICS (no self-scatter):  -3.6982779813276423
# Deposited in ICS (full):  -3.6982779812910285
# Energy conservation with deposited (no self-scatter) (%):  -3.281423160269761e-13
# Energy conservation with deposited (full) (%):  -5.627609986400267e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  16549.06896426488
# Energy in low energy electrons (no self-scatter):  2875.7234434465017
# Energy in low energy electrons (full):  2875.723443421613
# Energy in photons (no self-scatter):  184742.1989197085
# Energy in photons (full):  184742.1989181094
# Continuum_engloss (no self-scatter):  176186.14872497908
# Continuum_engloss (full):  176186.1487234408
# Deposited in ionization (no self-scatter):  20.579208490198358
# Deposited in ionization (full):  20.57920849000743
# Deposited in excitation (no self-scatter):  17.957118613979073
# Deposited in excitation (full):  17.957118613813858
# Deposited in heating (no self-scatter):  5082.64662578855
# Deposited in heating (full):  5082.646625741032
# Deposited in ICS (no self-scatter):  -3.887626803689901
# Deposited in ICS (full):  -3.88762680365589
# Energy conservation with deposited (no self-scatter) (%):  -4.578455070832068e-13
# Energy conservation with deposited (full) (%):  -6.633616983506331e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  17549.49584455794
# Energy in low energy electrons (no self-scatter):  2876.968629510442
# Energy in low energy electrons (full):  2876.9686294831204
# Energy in photons (no self-scatter):  194367.8338762101
# Energy in photons (full):  194367.83387444663
# Continuum_engloss (no self-scatter):  184991.3756137581
# Continuum_engloss (full):  184991.3756120634
# Deposited in ionization (no self-scatter):  21.331165609949167
# Deposited in ionization (full):  21.331165609740204
# Deposited in excitation (no self-scatter):  18.646254496762094
# Deposited in excitation (full):  18.64625449658111
# Deposited in heating (no self-scatter):  5260.1713853202045
# Deposited in heating (full):  5260.171385268239
# Deposited in ICS (no self-scatter):  -4.079852831326639
# Deposited in ICS (full):  -4.079852831289178
# Energy conservation with deposited (no self-scatter) (%):  -3.7067204786642953e-13
# Energy conservation with deposited (full) (%):  -5.841345297401105e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  18610.40068557317
# Energy in low energy electrons (no self-scatter):  2878.203576274272
# Energy in low energy electrons (full):  2878.2035762774694
# Energy in photons (no self-scatter):  204178.56169359275
# Energy in photons (full):  204178.56169399427
# Continuum_engloss (no self-scatter):  193919.1167730679
# Continuum_engloss (full):  193919.11677342936
# Deposited in ionization (no self-scatter):  22.07510957051235
# Deposited in ionization (full):  22.07510957053746
# Deposited in excitation (no self-scatter):  19.330302779646697
# Deposited in excitation (full):  19.33030277967068
# Deposited in heating (no self-scatter):  5435.6215550829975
# Deposited in heating (full):  5435.621555088667
# Deposited in ICS (no self-scatter):  -4.274778659057069
# Deposited in ICS (full):  -4.274778659064935
# Energy conservation with deposited (no self-scatter) (%):  -3.7657286046917786e-13
# Energy conservation with deposited (full) (%):  -3.343077409924015e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  19735.439510359953
# Energy in low energy electrons (no self-scatter):  2879.4266655581255
# Energy in low energy electrons (full):  2879.4266655745632
# Energy in photons (no self-scatter):  214170.1419892615
# Energy in photons (full):  214170.14199064788
# Continuum_engloss (no self-scatter):  202961.32428138916
# Continuum_engloss (full):  202961.32428268396
# Deposited in ionization (no self-scatter):  22.810220009596147
# Deposited in ionization (full):  22.810220009726148
# Deposited in excitation (no self-scatter):  20.008449712414386
# Deposited in excitation (full):  20.00844971253038
# Deposited in heating (no self-scatter):  5608.848692682
# Deposited in heating (full):  5608.848692713463
# Deposited in ICS (no self-scatter):  -4.47222547448351
# Deposited in ICS (full):  -4.472225474511941
# Energy conservation with deposited (no self-scatter) (%):  -2.1817154569889462e-13
# Energy conservation with deposited (full) (%):  -7.411297938383177e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  20928.48935643857
# Energy in low energy electrons (no self-scatter):  2880.63640220026
# Energy in low energy electrons (full):  2880.636402212178
# Energy in photons (no self-scatter):  224338.6780782377
# Energy in photons (full):  224338.67807927198
# Continuum_engloss (no self-scatter):  212110.08940760695
# Continuum_engloss (full):  212110.0894085689
# Deposited in ionization (no self-scatter):  23.535744931006874
# Deposited in ionization (full):  23.535744931099938
# Deposited in excitation (no self-scatter):  20.679937178386847
# Deposited in excitation (full):  20.679937178470386
# Deposited in heating (no self-scatter):  5779.72061137524
# Deposited in heating (full):  5779.720611397633
# Deposited in ICS (no self-scatter):  -4.672009877025863
# Deposited in ICS (full):  -4.672009877046961
# Energy conservation with deposited (no self-scatter) (%):  -1.9010002802618757e-13
# Energy conservation with deposited (full) (%):  -8.92868350592258e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  22193.661636602308
# Energy in low energy electrons (no self-scatter):  2881.831412499024
# Energy in low energy electrons (full):  2881.8314125146403
# Energy in photons (no self-scatter):  234680.6549045424
# Energy in photons (full):  234680.65490587792
# Continuum_engloss (no self-scatter):  221357.66658038367
# Continuum_engloss (full):  221357.66658162975
# Deposited in ionization (no self-scatter):  24.250999309448048
# Deposited in ionization (full):  24.25099930957224
# Deposited in excitation (no self-scatter):  21.34406233717611
# Deposited in excitation (full):  21.344062337287042
# Deposited in heating (no self-scatter):  5948.120813099876
# Deposited in heating (full):  5948.120813129903
# Deposited in ICS (no self-scatter):  -4.873974801902302
# Deposited in ICS (full):  -4.8739748019296565
# Energy conservation with deposited (no self-scatter) (%):  -1.8519806871650204e-13
# Energy conservation with deposited (full) (%):  -6.194612670792694e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  23535.316307407513
# Energy in low energy electrons (no self-scatter):  2883.01043779936
# Energy in low energy electrons (full):  2883.010437817896
# Energy in photons (no self-scatter):  245192.94302008947
# Energy in photons (full):  245192.94302167327
# Continuum_engloss (no self-scatter):  230696.46201451487
# Continuum_engloss (full):  230696.46201599462
# Deposited in ionization (no self-scatter):  24.95536090660222
# Deposited in ionization (full):  24.95536090675169
# Deposited in excitation (no self-scatter):  22.000174641281966
# Deposited in excitation (full):  22.00017464141518
# Deposited in heating (no self-scatter):  6113.947288754398
# Deposited in heating (full):  6113.947288790617
# Deposited in ICS (no self-scatter):  -5.077960268655944
# Deposited in ICS (full):  -5.07796026868844
# Energy conservation with deposited (no self-scatter) (%):  -3.178417067581942e-13
# Energy conservation with deposited (full) (%):  -1.7976549993976208e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  24958.076894179627
# Energy in low energy electrons (no self-scatter):  2884.172341801876
# Energy in low energy electrons (full):  2884.1723418174774
# Energy in photons (no self-scatter):  255872.91141266303
# Energy in photons (full):  255872.9114139864
# Continuum_engloss (no self-scatter):  240119.13231068727
# Continuum_engloss (full):  240119.13231192259
# Deposited in ionization (no self-scatter):  25.64827439761791
# Deposited in ionization (full):  25.64827439774127
# Deposited in excitation (no self-scatter):  22.647680547818275
# Deposited in excitation (full):  22.647680547928438
# Deposited in heating (no self-scatter):  6277.113297976602
# Deposited in heating (full):  6277.113298006431
# Deposited in ICS (no self-scatter):  -5.283802520027199
# Deposited in ICS (full):  -5.283802520054317
# Energy conservation with deposited (no self-scatter) (%):  -2.9021046146162225e-14
# Energy conservation with deposited (full) (%):  7.963261184704748e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  26466.846424312855
# Energy in low energy electrons (no self-scatter):  2885.316101137548
# Energy in low energy electrons (full):  2885.316101147522
# Energy in photons (no self-scatter):  266718.4163411071
# Energy in photons (full):  266718.41634191026
# Continuum_engloss (no self-scatter):  249618.55579370333
# Continuum_engloss (full):  249618.5557944518
# Deposited in ionization (no self-scatter):  26.329245573671535
# Deposited in ionization (full):  26.329245573743542
# Deposited in excitation (no self-scatter):  23.28603897935278
# Deposited in excitation (full):  23.28603897941753
# Deposited in heating (no self-scatter):  6437.5458352190335
# Deposited in heating (full):  6437.5458352363075
# Deposited in ICS (no self-scatter):  -5.491344000512306
# Deposited in ICS (full):  -5.491344000528715
# Energy conservation with deposited (no self-scatter) (%):  4.8994899957970705e-14
# Energy conservation with deposited (full) (%):  1.109902274801317e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  28066.82432377321
# Energy in low energy electrons (no self-scatter):  2886.440800817585
# Energy in low energy electrons (full):  2886.440800828797
# Energy in photons (no self-scatter):  277727.8275477184
# Energy in photons (full):  277727.8275486406
# Continuum_engloss (no self-scatter):  259187.8410093389
# Continuum_engloss (full):  259187.84101019843
# Deposited in ionization (no self-scatter):  26.997838546031225
# Deposited in ionization (full):  26.997838546114796
# Deposited in excitation (no self-scatter):  23.914759511649937
# Deposited in excitation (full):  23.91475951172493
# Deposited in heating (no self-scatter):  6595.18482406465
# Deposited in heating (full):  6595.184824084749
# Deposited in ICS (no self-scatter):  -5.700437546117117
# Deposited in ICS (full):  -5.7004375461359675
# Energy conservation with deposited (no self-scatter) (%):  -2.927491356293655e-13
# Energy conservation with deposited (full) (%):  -2.2558550299940492e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  29763.52433503029
# Energy in low energy electrons (no self-scatter):  2887.545629176622
# Energy in low energy electrons (full):  2887.545629178746
# Energy in photons (no self-scatter):  288900.05139869975
# Energy in photons (full):  288900.0513987128
# Continuum_engloss (no self-scatter):  268820.3311021191
# Continuum_engloss (full):  268820.3311021327
# Deposited in ionization (no self-scatter):  27.653672726889432
# Deposited in ionization (full):  27.65367272688598
# Deposited in excitation (no self-scatter):  24.53340029972204
# Deposited in excitation (full):  24.533400299719833
# Deposited in heating (no self-scatter):  6749.982278741342
# Deposited in heating (full):  6749.982278740201
# Deposited in ICS (no self-scatter):  -5.910942494866661
# Deposited in ICS (full):  -5.910942494866911
# Energy conservation with deposited (no self-scatter) (%):  -1.1253404001585398e-13
# Energy conservation with deposited (full) (%):  -1.1169251899322209e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  31562.793518167862
# Energy in low energy electrons (no self-scatter):  2888.629872500095
# Energy in low energy electrons (full):  2888.6298725045117
# Energy in photons (no self-scatter):  300234.5516843054
# Energy in photons (full):  300234.5516845567
# Continuum_engloss (no self-scatter):  278509.6047606334
# Continuum_engloss (full):  278509.6047608679
# Deposited in ionization (no self-scatter):  28.296419677928117
# Deposited in ionization (full):  28.29641967794711
# Deposited in excitation (no self-scatter):  25.14156582439815
# Deposited in excitation (full):  25.141565824415885
# Deposited in heating (no self-scatter):  6901.901452487987
# Deposited in heating (full):  6901.9014524923205
# Deposited in ICS (no self-scatter):  -6.122715994542998
# Deposited in ICS (full):  -6.1227159945481056
# Energy conservation with deposited (no self-scatter) (%):  -1.1490987243438368e-13
# Energy conservation with deposited (full) (%):  -9.872653274122487e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  33470.83240065101
# Energy in low energy electrons (no self-scatter):  2889.69290943697
# Energy in low energy electrons (full):  2889.6929094460274
# Energy in photons (no self-scatter):  311731.3685037204
# Energy in photons (full):  311731.36850447225
# Continuum_engloss (no self-scatter):  288249.4740791598
# Continuum_engloss (full):  288249.47407985723
# Deposited in ionization (no self-scatter):  28.92579988413885
# Deposited in ionization (full):  28.925799884204295
# Deposited in excitation (no self-scatter):  25.738904511933487
# Deposited in excitation (full):  25.738904511992562
# Deposited in heating (no self-scatter):  7050.915984421527
# Deposited in heating (full):  7050.915984437184
# Deposited in ICS (no self-scatter):  -6.335622164085932
# Deposited in ICS (full):  -6.335622164101216
# Energy conservation with deposited (no self-scatter) (%):  -1.2546435463321442e-13
# Energy conservation with deposited (full) (%):  -7.980139034463437e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  35494.21634519176
# Energy in low energy electrons (no self-scatter):  2890.734205304564
# Energy in low energy electrons (full):  2890.7342053073057
# Energy in photons (no self-scatter):  323391.1356530745
# Energy in photons (full):  323391.13565311965
# Continuum_engloss (no self-scatter):  298033.97973159
# Continuum_engloss (full):  298033.97973163624
# Deposited in ionization (no self-scatter):  29.541579506682893
# Deposited in ionization (full):  29.54157950668379
# Deposited in excitation (no self-scatter):  26.325106276931447
# Deposited in excitation (full):  26.325106276933
# Deposited in heating (no self-scatter):  7197.009055612427
# Deposited in heating (full):  7197.009055612359
# Deposited in ICS (no self-scatter):  -6.549522993165706
# Deposited in ICS (full):  -6.549522993166678
# Energy conservation with deposited (no self-scatter) (%):  -4.613174697246628e-13
# Energy conservation with deposited (full) (%):  -4.585774307275674e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  37639.91820934747
# Energy in low energy electrons (no self-scatter):  2891.753306394103
# Energy in low energy electrons (full):  2891.753306381837
# Energy in photons (no self-scatter):  335215.0971563867
# Energy in photons (full):  335215.0971546923
# Continuum_engloss (no self-scatter):  307857.38398670644
# Continuum_engloss (full):  307857.3839851549
# Deposited in ionization (no self-scatter):  30.14356716989385
# Deposited in ionization (full):  30.143567169738304
# Deposited in excitation (no self-scatter):  26.899900041309202
# Deposited in excitation (full):  26.899900041171147
# Deposited in heating (no self-scatter):  7340.172565398273
# Deposited in heating (full):  7340.172565360111
# Deposited in ICS (no self-scatter):  -6.764299336342487
# Deposited in ICS (full):  -6.764299336308353
# Energy conservation with deposited (no self-scatter) (%):  -7.721553024158672e-14
# Energy conservation with deposited (full) (%):  -1.6790006536105677e-13
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  39915.332374940335
# Energy in low energy electrons (no self-scatter):  2892.7498343416337
# Energy in low energy electrons (full):  2892.749834327156
# Energy in photons (no self-scatter):  347205.12319945835
# Energy in photons (full):  347205.1231974985
# Continuum_engloss (no self-scatter):  317714.16183502186
# Continuum_engloss (full):  317714.16183322744
# Deposited in ionization (no self-scatter):  30.731610814190738
# Deposited in ionization (full):  30.7316108140117
# Deposited in excitation (no self-scatter):  27.46305126088482
# Deposited in excitation (full):  27.46305126072577
# Deposited in heating (no self-scatter):  7480.406333500032
# Deposited in heating (full):  7480.4063334561515
# ...
# Energy in low energy electrons (no self-scatter):  2917.531883105603
# Energy in low energy electrons (full):  2917.5318831979307
# Energy in photons (no self-scatter):  2376829412312.7603
# Energy in photons (full):  2376829412312.746
# Continuum_engloss (no self-scatter):  897149.9019737488
# Continuum_engloss (full):  897149.9019969654
# Deposited in ionization (no self-scatter):  45.22118414640551
# Deposited in ionization (full):  45.2211841477714
# Deposited in excitation (no self-scatter):  42.06080688497063
# Deposited in excitation (full):  42.060806886237565
# Deposited in heating (no self-scatter):  12545.177430145573
# Deposited in heating (full):  12545.177430499683
# Deposited in ICS (no self-scatter):  -432441882.5473331
# Deposited in ICS (full):  -432441882.5473325
# Energy conservation with deposited (no self-scatter) (%):  8.979337632260184e-16
# Energy conservation with deposited (full) (%):  8.72851814532554e-16
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  2520054353269.385
# Energy in low energy electrons (no self-scatter):  2917.531883105448
# Energy in low energy electrons (full):  2917.531883197761
# Energy in photons (no self-scatter):  2520472443214.582
# Energy in photons (full):  2520472443214.5566
# Continuum_engloss (no self-scatter):  897149.9019737482
# Continuum_engloss (full):  897149.901996961
# Deposited in ionization (no self-scatter):  45.221184146314876
# Deposited in ionization (full):  45.22118414768054
# Deposited in excitation (no self-scatter):  42.06080688485263
# Deposited in excitation (full):  42.0608068861194
# Deposited in heating (no self-scatter):  12545.192466733433
# Deposited in heating (full):  12545.19246708749
# Deposited in ICS (no self-scatter):  -417208345.301816
# Deposited in ICS (full):  -417208345.3018137
# Energy conservation with deposited (no self-scatter) (%):  8.325548587362045e-15
# Energy conservation with deposited (full) (%):  8.235670506021205e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  2672397069361.388
# Energy in low energy electrons (no self-scatter):  2917.531883105791
# Energy in low energy electrons (full):  2917.531883198116
# Energy in photons (no self-scatter):  2731794030314.8545
# Energy in photons (full):  2731794030314.836
# Continuum_engloss (no self-scatter):  897149.9019737493
# Continuum_engloss (full):  897149.9019969655
# Deposited in ionization (no self-scatter):  45.22118414651428
# Deposited in ionization (full):  45.22118414788014
# Deposited in excitation (no self-scatter):  42.06080688511196
# Deposited in excitation (full):  42.06080688637888
# Deposited in heating (no self-scatter):  12545.242313904171
# Deposited in heating (full):  12545.24231425827
# Deposited in ICS (no self-scatter):  -59396079353.619865
# Deposited in ICS (full):  -59396079353.61947
# Energy conservation with deposited (no self-scatter) (%):  -2.3695571041958696e-14
# Energy conservation with deposited (full) (%):  -3.854098904414969e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  2833949230922.7637
# Energy in low energy electrons (no self-scatter):  2917.5318831057634
# Energy in low energy electrons (full):  2917.5318831980867
# Energy in photons (no self-scatter):  2836746447707.3545
# Energy in photons (full):  2836746447707.335
# Continuum_engloss (no self-scatter):  897149.9019737495
# Continuum_engloss (full):  897149.9019969648
# Deposited in ionization (no self-scatter):  45.22118414649846
# Deposited in ionization (full):  45.221184147864264
# Deposited in excitation (no self-scatter):  42.0608068850905
# Deposited in excitation (full):  42.060806886357405
# Deposited in heating (no self-scatter):  12545.236197971759
# Deposited in heating (full):  12545.236198325852
# Deposited in ICS (no self-scatter):  -2796335184.738936
# Deposited in ICS (full):  -2796335184.7389035
# Energy conservation with deposited (no self-scatter) (%):  1.5479818084251031e-15
# Energy conservation with deposited (full) (%):  4.038213413282878e-16
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3005267568777.472
# Energy in low energy electrons (no self-scatter):  2917.5318831057034
# Energy in low energy electrons (full):  2917.5318831980335
# Energy in photons (no self-scatter):  3007789986928.126
# Energy in photons (full):  3007789986928.1084
# Continuum_engloss (no self-scatter):  897149.9019737495
# Continuum_engloss (full):  897149.9019969662
# Deposited in ionization (no self-scatter):  45.221184146463955
# Deposited in ionization (full):  45.22118414782988
# Deposited in excitation (no self-scatter):  42.06080688504474
# Deposited in excitation (full):  42.0608068863117
# Deposited in heating (no self-scatter):  12545.227408509018
# Deposited in heating (full):  12545.227408863138
# Deposited in ICS (no self-scatter):  -2521536550.7927194
# Deposited in ICS (full):  -2521536550.7926927
# Energy conservation with deposited (no self-scatter) (%):  -1.2360168861481473e-14
# Energy conservation with deposited (full) (%):  -1.3248704748828021e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3186942469327.463
# Energy in low energy electrons (no self-scatter):  2917.531883105531
# Energy in low energy electrons (full):  2917.53188319787
# Energy in photons (no self-scatter):  3189303959824.6426
# Energy in photons (full):  3189303959824.6357
# Continuum_engloss (no self-scatter):  897149.9019737485
# Continuum_engloss (full):  897149.9019969687
# Deposited in ionization (no self-scatter):  45.22118414636395
# Deposited in ionization (full):  45.22118414772999
# Deposited in excitation (no self-scatter):  42.06080688491487
# Deposited in excitation (full):  42.060806886181986
# Deposited in heating (no self-scatter):  12545.228970051332
# Deposited in heating (full):  12545.228970405495
# Deposited in ICS (no self-scatter):  -2360608897.319913
# Deposited in ICS (full):  -2360608897.319897
# Energy conservation with deposited (no self-scatter) (%):  -1.9405991797522647e-14
# Energy conservation with deposited (full) (%):  -1.9899744865616902e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3379600009104.9067
# Energy in low energy electrons (no self-scatter):  2917.5318831028203
# Energy in low energy electrons (full):  2917.5318831951663
# Energy in photons (no self-scatter):  3382088293700.3037
# Energy in photons (full):  3382088293700.3037
# Continuum_engloss (no self-scatter):  897149.9019737373
# Continuum_engloss (full):  897149.9019969589
# Deposited in ionization (no self-scatter):  45.221184144788836
# Deposited in ionization (full):  45.221184146154975
# Deposited in excitation (no self-scatter):  42.0608068829151
# Deposited in excitation (full):  42.0608068841823
# Deposited in heating (no self-scatter):  12545.26730683137
# Deposited in heating (full):  12545.267307185553
# Deposited in ICS (no self-scatter):  -2487402995.5756097
# Deposited in ICS (full):  -2487402995.5755982
# Energy conservation with deposited (no self-scatter) (%):  -1.6084576840072104e-14
# Energy conservation with deposited (full) (%):  -1.642319951038941e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3583904112317.4634
# Energy in low energy electrons (no self-scatter):  2917.531883105682
# Energy in low energy electrons (full):  2917.5318831980076
# Energy in photons (no self-scatter):  3586320178802.8887
# Energy in photons (full):  3586320178802.865
# Continuum_engloss (no self-scatter):  897149.9019737493
# Continuum_engloss (full):  897149.901996965
# Deposited in ionization (no self-scatter):  45.221184146451606
# Deposited in ionization (full):  45.22118414781742
# Deposited in excitation (no self-scatter):  42.06080688503181
# Deposited in excitation (full):  42.06080688629872
# Deposited in heating (no self-scatter):  12545.303479654964
# Deposited in heating (full):  12545.303480009059
# Deposited in ICS (no self-scatter):  -2415184885.6400275
# Deposited in ICS (full):  -2415184885.6400003
# Energy conservation with deposited (no self-scatter) (%):  -1.7269843498894113e-14
# Energy conservation with deposited (full) (%):  -1.802822645685788e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  3800558838821.8413
# Energy in low energy electrons (no self-scatter):  2917.5318831056534
# Energy in low energy electrons (full):  2917.5318831979957
# Energy in photons (no self-scatter):  3802772827240.6855
# Energy in photons (full):  3802772827240.6826
# Continuum_engloss (no self-scatter):  897149.9019737489
# Continuum_engloss (full):  897149.9019969697
# Deposited in ionization (no self-scatter):  45.22118414643519
# Deposited in ionization (full):  45.22118414780128
# Deposited in excitation (no self-scatter):  42.06080688500927
# Deposited in excitation (full):  42.06080688627643
# Deposited in heating (no self-scatter):  12545.289253274397
# Deposited in heating (full):  12545.289253628565
# Deposited in ICS (no self-scatter):  -2213106819.0451574
# Deposited in ICS (full):  -2213106819.0451446
# Energy conservation with deposited (no self-scatter) (%):  -5.470274498921086e-15
# Energy conservation with deposited (full) (%):  -5.809030029817575e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4030310810410.256
# Energy in low energy electrons (no self-scatter):  2917.5318831055347
# Energy in low energy electrons (full):  2917.5318831978443
# Energy in photons (no self-scatter):  4032374531602.3926
# Energy in photons (full):  4032374531602.343
# Continuum_engloss (no self-scatter):  897149.9019737481
# Continuum_engloss (full):  897149.901996959
# Deposited in ionization (no self-scatter):  45.22118414636604
# Deposited in ionization (full):  45.22118414773162
# Deposited in excitation (no self-scatter):  42.06080688491847
# Deposited in excitation (full):  42.060806886185155
# Deposited in heating (no self-scatter):  12545.277171177542
# Deposited in heating (full):  12545.277171531572
# Deposited in ICS (no self-scatter):  -2062839592.3256567
# Deposited in ICS (full):  -2062839592.3256207
# Energy conservation with deposited (no self-scatter) (%):  -2.6620368910154095e-15
# Energy conservation with deposited (full) (%):  -3.555298158889469e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4273951783771.138
# Energy in low energy electrons (no self-scatter):  2917.5318831047857
# Energy in low energy electrons (full):  2917.531883197092
# Energy in photons (no self-scatter):  4276022981025.2905
# Energy in photons (full):  4276022981025.2334
# Continuum_engloss (no self-scatter):  897149.9019737453
# Continuum_engloss (full):  897149.9019969554
# Deposited in ionization (no self-scatter):  45.22118414593084
# Deposited in ionization (full):  45.22118414729637
# Deposited in excitation (no self-scatter):  42.06080688436073
# Deposited in excitation (full):  42.06080688562736
# Deposited in heating (no self-scatter):  12545.317675841132
# Deposited in heating (full):  12545.317676195149
# Deposited in ICS (no self-scatter):  -2070315654.381666
# Deposited in ICS (full):  -2070315654.3816283
# Energy conservation with deposited (no self-scatter) (%):  -5.327382117565427e-15
# Energy conservation with deposited (full) (%):  -6.208770991466303e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4532321378990.888
# Energy in low energy electrons (no self-scatter):  2917.5318831056898
# Energy in low energy electrons (full):  2917.5318831980226
# Energy in photons (no self-scatter):  4534476780742.461
# Energy in photons (full):  4534476780742.447
# Continuum_engloss (no self-scatter):  897149.901973749
# Continuum_engloss (full):  897149.9019969678
# Deposited in ionization (no self-scatter):  45.22118414645568
# Deposited in ionization (full):  45.221184147821624
# Deposited in excitation (no self-scatter):  42.06080688503788
# Deposited in excitation (full):  42.06080688630492
# Deposited in heating (no self-scatter):  12545.386792435853
# Deposited in heating (full):  12545.386792789994
# Deposited in ICS (no self-scatter):  -2154520151.8723016
# Deposited in ICS (full):  -2154520151.8722835
# Energy conservation with deposited (no self-scatter) (%):  8.669151754787003e-15
# Energy conservation with deposited (full) (%):  8.269360775804108e-15
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  4806309972999.415
# Energy in low energy electrons (no self-scatter):  2917.5318831056675
# Energy in low energy electrons (full):  2917.531883198004
# Energy in photons (no self-scatter):  4808384544006.39
# Energy in photons (full):  4808384544006.381
# Continuum_engloss (no self-scatter):  897149.9019737488
# Continuum_engloss (full):  897149.9019969683
# Deposited in ionization (no self-scatter):  45.22118414644275
# Deposited in ionization (full):  45.22118414780874
# Deposited in excitation (no self-scatter):  42.060806885020035
# Deposited in excitation (full):  42.06080688628712
# Deposited in heating (no self-scatter):  12545.367686336642
# Deposited in heating (full):  12545.367686690794
# Deposited in ICS (no self-scatter):  -2073689407.2542014
# Deposited in ICS (full):  -2073689407.2541878
# Energy conservation with deposited (no self-scatter) (%):  6.597508524969135e-16
# Energy conservation with deposited (full) (%):  3.7700048714109346e-16
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  5096861767930.699
# Energy in low energy electrons (no self-scatter):  2917.5318831055906
# Energy in low energy electrons (full):  2917.53188319794
# Energy in photons (no self-scatter):  5098620238209.963
# Energy in photons (full):  5098620238209.972
# Continuum_engloss (no self-scatter):  897149.9019737488
# Continuum_engloss (full):  897149.9019969725
# Deposited in ionization (no self-scatter):  45.221184146397505
# Deposited in ionization (full):  45.221184147763715
# Deposited in excitation (no self-scatter):  42.06080688495991
# Deposited in excitation (full):  42.060806886227184
# Deposited in heating (no self-scatter):  12545.341136561607
# Deposited in heating (full):  12545.34113691582
# Deposited in ICS (no self-scatter):  -1757588679.5152128
# Deposited in ICS (full):  -1757588679.5152054
# Energy conservation with deposited (no self-scatter) (%):  -2.883366644998667e-14
# Energy conservation with deposited (full) (%):  -2.897867677768777e-14
# ***************************************************
# ***************************************************
# rs:  3000
# injected energy:  5404978044972.385
# Energy in low energy electrons (no self-scatter):  2917.5318831051163
# Energy in low energy electrons (full):  2917.531883197497
# Energy in photons (no self-scatter):  5406626924698.214
# Energy in photons (full):  5406626924698.287
# Continuum_engloss (no self-scatter):  897149.901973747
# Continuum_engloss (full):  897149.9019969804
# Deposited in ionization (no self-scatter):  45.221184146122006
# Deposited in ionization (full):  45.22118414748874
# Deposited in excitation (no self-scatter):  42.060806884607864
# Deposited in excitation (full):  42.06080688587562
# Deposited in heating (no self-scatter):  12545.360400000241
# Deposited in heating (full):  12545.360400354588
# Deposited in ICS (no self-scatter):  -1647998126.1011763
# Deposited in ICS (full):  -1647998126.1011894
# Energy conservation with deposited (no self-scatter) (%):  -3.6876732980314004e-15
# Energy conservation with deposited (full) (%):  -3.4450632126345976e-15
# ***************************************************

# %%
# %autoreload

from darkhistory.electrons.elec_cooling import get_elec_cooling_tf_fast_linalg

# %lprun -f get_elec_cooling_tf_fast get_elec_cooling_tf_fast(ics_thomson_ref_tf, ics_rel_ref_tf, engloss_ref_tf, coll_ion_sec_elec_specs, coll_exc_sec_elec_specs, eleceng, photeng, rs, xe, xHe=0, linalg=False, ics_engloss_data = ics_engloss_data, check_conservation_eng=True, verbose=True)
# Out:
# ***************************************************
# rs:  2750
# injected energy:  3016.701062885404
# Energy in low energy electrons:  2846.294789387355
# Energy in photons:  2806.7889781466815
# Continuum_engloss:  2763.099252286273
# Energy in photons - Continuum:  43.689725860408544
# Deposited in ionization:  1.2852967581070838
# Deposited in excitation:  0.26550088845996717
# Deposited in heating:  125.22734744635872
# Energy is conserved up to (%):  -0.0020418813134401807
# Deposited in ICS:  -0.06159745528587722
# Energy conservation with deposited (%):  1.5541258339431474e-14
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  3199.0671427921043
# Energy in low energy electrons:  2848.2290043079074
# Energy in photons:  5793.4433458984895
# Continuum_engloss:  5700.491910679315
# Energy in photons - Continuum:  92.95143521917453
# Deposited in ionization:  2.6268515664054632
# Deposited in excitation:  0.5429899298795923
# Deposited in heating:  254.8431924510967
# Energy is conserved up to (%):  -0.003948985023464174
# Deposited in ICS:  -0.1263306823594091
# Energy conservation with deposited (%):  -4.485567808606847e-16
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  3392.457645207818
# Energy in low energy electrons:  2850.4005604951126
# Energy in photons:  8969.879868208645
# Continuum_engloss:  8821.414554053059
# Energy in photons - Continuum:  148.46531415558638
# Deposited in ionization:  4.026086674720422
# Deposited in excitation:  0.8327882087217453
# Deposited in heating:  388.9279026252008
# Energy is conserved up to (%):  -0.005748250145414809
# Deposited in ICS:  -0.1950069515272277
# Energy conservation with deposited (%):  1.0120909632595954e-13
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  3597.5390202295966
# Energy in low energy electrons:  2852.7637848170443
# Energy in photons:  12344.358830410278
# Continuum_engloss:  12133.408108427942
# Energy in photons - Continuum:  210.95072198233538
# Deposited in ionization:  5.483499561062261
# Deposited in excitation:  1.1350256452458969
# Deposited in heating:  527.4737601641818
# Energy is conserved up to (%):  -0.007443197662853555
# Deposited in ICS:  -0.2677719402724399
# Energy conservation with deposited (%):  -4.264321156213989e-14
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  3815.018006298924
# Energy in low energy electrons:  2855.2963123382824
# Energy in photons:  15924.45575621661
# Continuum_engloss:  15643.270379260739
# Energy in photons - Continuum:  281.1853769558711
# Deposited in ionization:  6.9991344693349795
# Deposited in excitation:  1.449737928411909
# Deposited in heating:  670.4322222179983
# Energy is conserved up to (%):  -0.00903737834019273
# Deposited in ICS:  -0.34477761097585685
# Energy conservation with deposited (%):  3.810826183116914e-15
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:
-14
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  4030310810410.256
# Energy in low energy electrons:  3105.214154086537
# Energy in photons:  4031688655618.2017
# Continuum_engloss:  893383.4470676893
# Energy in photons - Continuum:  4031687762234.7544
# Deposited in ionization:  132.81156650026105
# Deposited in excitation:  28.447221582306554
# Deposited in heating:  12692.652395626454
# Energy is conserved up to (%):  -0.03416530010706319
# Deposited in ICS:  -1376967783.624102
# Energy conservation with deposited (%):  6.862139541284166e-16
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  4273951783771.138
# Energy in low energy electrons:  3105.2141540843736
# Energy in photons:  4275355564989.557
# Continuum_engloss:  893383.4470676817
# Energy in photons - Continuum:  4275354671606.11
# Deposited in ionization:  132.81156649921573
# Deposited in excitation:  28.447221582065342
# Deposited in heating:  12692.698304801352
# Energy is conserved up to (%):  -0.032824511485369884
# Deposited in ICS:  -1402903794.1423786
# Energy conservation with deposited (%):  -1.753852290850859e-14
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  4532321378990.888
# Energy in low energy electrons:  3105.2141540871908
# Energy in photons:  4533754033329.9375
# Continuum_engloss:  893383.4470676916
# Energy in photons - Continuum:  4533753139946.49
# Deposited in ionization:  132.81156650057738
# Deposited in excitation:  28.447221582380052
# Deposited in heating:  12692.743319444464
# Energy is conserved up to (%):  -0.03159036606396381
# Deposited in ICS:  -1431776914.818393
# Energy conservation with deposited (%):  -2.6670266624253703e-15
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  4806309972999.415
# Energy in low energy electrons:  3105.2141540870775
# Energy in photons:  4807704537344.525
# Continuum_engloss:  893383.4470676915
# Energy in photons - Continuum:  4807703643961.078
# Deposited in ionization:  132.81156650052176
# Deposited in excitation:  28.447221582367074
# Deposited in heating:  12692.72725839125
# Energy is conserved up to (%):  -0.028997025341527413
# Deposited in ICS:  -1393686920.8615735
# Energy conservation with deposited (%):  -2.967390676418448e-14
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  5096861767930.699
# Energy in low energy electrons:  3105.2141540867465
# Energy in photons:  5098036855280.611
# Continuum_engloss:  893383.4470676902
# Energy in photons - Continuum:  5098035961897.164
# Deposited in ionization:  132.8115665003622
# Deposited in excitation:  28.447221582330005
# Deposited in heating:  12692.706602959828
# Energy is conserved up to (%):  -0.023037900165003407
# Deposited in ICS:  -1174209925.64389
# Energy conservation with deposited (%):  -4.1631997307735455e-15
# ***************************************************
# ***************************************************
# rs:  2750
# injected energy:  5404978044972.385
# Energy in low energy electrons:  3105.2141540854172
# Energy in photons:  5406109041941.307
# Continuum_engloss:  893383.4470676857
# Energy in photons - Continuum:  5406108148557.859
# Deposited in ionization:  132.81156649971913
# Deposited in excitation:  28.447221582181477
# Deposited in heating:  12692.739312149177
# Energy is conserved up to (%):  -0.020908864666671387
# Deposited in ICS:  -1130119544.6873457
# Energy conservation with deposited (%):  1.4225773189176157e-14
# ***************************************************

# %%
# %%prun
for i in np.arange(120):
    get_elec_cooling_tf_fast(
        ics_thomson_ref_tf, ics_rel_ref_tf, engloss_ref_tf, 
        coll_ion_sec_elec_specs, coll_exc_sec_elec_specs, 
        eleceng, photeng, rs, xe, xHe=0, 
        linalg=False, ics_engloss_data = ics_engloss_data, 
        check_conservation_eng=False, verbose=False
    )
    get_elec_cooling_tf_fast_linalg(
        ics_thomson_ref_tf, ics_rel_ref_tf, engloss_ref_tf, 
        coll_ion_sec_elec_specs, coll_exc_sec_elec_specs, 
        eleceng, photeng, rs, xe, xHe=0, 
        ics_engloss_data = ics_engloss_data, 
        check_conservation_eng=False, verbose=False
    )
